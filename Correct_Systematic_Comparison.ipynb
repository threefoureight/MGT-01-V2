# %% [markdown]
# # Test 1 Censoring

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

path = 'Test1/A_20250212_ZQ0.35_ZG0.4_testfile.csv'
df = pd.read_csv(path)

df["is_stockout"] = (df["Zensiert"] == 1)
df = df.dropna(subset=['Verkauf_MBR'])
df = df.dropna(subset=['Verkauf'])

df.head()
len(df)
# Out:
# 277894

# %% [markdown]
# # N3

# %%
# Grouping N3

import pandas as pd
import numpy as np

def apply_n3_uncensoring(df):
    df = df.copy()
    
    # Mark closed observations
    df["is_closed"] = (df["Zensiert"] == 1)
    df['Verkauf_Uncensored'] = df['Verkauf'].copy()
    
    # Compute open group means
    open_means = (
        df[~df['is_closed']]
        .groupby(['EHASTRA_EH_NUMMER'])['Verkauf_Uncensored']
        .mean()
        .rename('open_mean')
        .reset_index()
        .round()
    )
    
    # Merge open means back to df
    df = df.merge(open_means, on=['EHASTRA_EH_NUMMER'], how='left')
    
    # Compute the max(mean, observed) for censored rows only
    mask = df['is_closed'] & df['open_mean'].notna()
    df.loc[mask, 'Verkauf_Uncensored'] = np.maximum(df.loc[mask, 'Verkauf_Uncensored'], df.loc[mask, 'open_mean'])
    
    return df.drop(['is_closed', 'open_mean'], axis=1)

# # Naive N3
# def apply_n3_uncensoring(df):
#     """
#     N3 uncensoring: replace censored values with max(current_value, mean_of_uncensored).
#     """
#     df = df.copy()
    
#     # Calculate mean of all uncensored observations
#     uncensored_mean = df[df['Zensiert'] == 0]['Verkauf'].mean()
    
#     # Replace censored values with max(current, uncensored_mean)
#     df.loc[df['Zensiert'] == 1, 'Verkauf'] = np.maximum(
#         df.loc[df['Zensiert'] == 1, 'Verkauf'], 
#         uncensored_mean
#     )
    
#     return df

df_n3_uncensored = apply_n3_uncensoring(df)

# %% [markdown]
# Saving file

# %%
df_n3_uncensored.to_csv(path[:-4] + '_n3.csv', index=False)
df_n3_uncensored
# Out:
#        EHASTRA_EH_NUMMER  Heftjahr  Heftnummer    Period  Bezug_MBR  \
# 0             EHA0017186      2022           4  2022-004        5.0
# 1             EHA0017186      2022           5  2022-005        5.0
# 2             EHA0017186      2022           6  2022-006        5.0
# 3             EHA0017186      2022           7  2022-007        4.0
# 4             EHA0017186      2022           8  2022-008        3.0
# ...                  ...       ...         ...       ...        ...
# 277889        EHJ9923970      2024          25  2024-025        9.0
# 277890        EHJ9923970      2024          26  2024-026        8.0
# 277891        EHJ9923970      2024          27  2024-027       10.0
# 277892        EHJ9923970      2024          28  2024-028       10.0
# 277893        EHJ9923970      2024          29  2024-029       10.0
#
#         Verkauf_MBR  Remission_MBR  Bezug  Verkauf  Remission  ... SBC XYZ  \
# 0               1.0            4.0    5.0      1.0        4.0  ...   I   Z
# 1               0.0            5.0    5.0      0.0        5.0  ...   I   Z
# 2               0.0            5.0    5.0      0.0        5.0  ...   I   Z
# 3               0.0            4.0    4.0      0.0        4.0  ...   I   Z
# 4               0.0            3.0    3.0      0.0        3.0  ...   I   Z
# ...             ...            ...    ...      ...        ...  ...  ..  ..
# 277889          7.0            2.0    9.0      7.0        2.0  ...   S   X
# 277890          8.0            0.0    9.0      8.0        1.0  ...   S   X
# 277891          8.0            2.0    7.0      7.0        0.0  ...   S   X
# 277892          9.0            1.0    5.0      5.0        0.0  ...   S   X
# 277893          9.0            1.0    9.0      9.0        0.0  ...   S   X
#
#        Laenge  Zensierungsquote  Zensierungsgrad  Zensiert  \
# 0          36            0.3160              0.4         0
# 1          36            0.3160              0.4         0
# 2          36            0.3160              0.4         0
# 3          36            0.3160              0.4         0
# 4          36            0.3160              0.4         0
# ...       ...               ...              ...       ...
# 277889    132            0.2735              0.4         0
# 277890    132            0.2735              0.4         0
# 277891    132            0.2735              0.4         1
# 277892    132            0.2735              0.4         1
# 277893    132            0.2735              0.4         1
#
#         Entgangener Verkauf  Steigung  is_stockout  Verkauf_Uncensored
# 0                       0.0    0.0085        False                 1.0
# 1                       0.0    0.0085        False                 0.0
# 2                       0.0    0.0085        False                 0.0
# 3                       0.0    0.0085        False                 0.0
# 4                       0.0    0.0085        False                 0.0
# ...                     ...       ...          ...                 ...
# 277889                  0.0    0.0085        False                 7.0
# 277890                  0.0    0.0085        False                 8.0
# 277891                  1.0    0.0085         True                10.0
# 277892                  4.0    0.0085         True                10.0
# 277893                  0.0    0.0085         True                10.0
#
# [277894 rows x 21 columns]

# %% [markdown]
# # N2

# %%
# Grouping N2
def apply_n2_uncensoring(df):
    """
    N2 uncensoring with grouping: replace censored values with mean of uncensored values within each group.
    """
    df = df.copy()

    df['Verkauf_Uncensored'] = df['Verkauf'].copy()
    
    # Calculate mean of uncensored observations for each group
    uncensored_means = (
        df[df['Zensiert'] == 0]
        .groupby(['EHASTRA_EH_NUMMER'])['Verkauf_Uncensored']
        .mean()
        .rename('uncensored_mean')
        .reset_index()
        .round()
    )
    
    # Merge back to original DataFrame
    df = df.merge(uncensored_means, on=['EHASTRA_EH_NUMMER'], how='left')
    
    # Replace censored values with group mean
    df.loc[df['Zensiert'] == 1, 'Verkauf_Uncensored'] = df.loc[df['Zensiert'] == 1, 'uncensored_mean']
    
    return df.drop('uncensored_mean', axis=1)

df_n2_uncensored = apply_n2_uncensoring(df)

# Naive N2 

# def apply_n2_uncensoring(df):
#     """
#     Simple N2 uncensoring: replace censored values with mean of all uncensored values.
#     """
#     df = df.copy()
    
#     # Calculate mean of all uncensored observations
#     uncensored_mean = df[df['Zensiert'] == 0]['Verkauf'].mean()
    
#     # Replace censored values with this mean
#     df.loc[df['Zensiert'] == 1, 'Verkauf'] = uncensored_mean
    
#     return df

# df_n2_uncensored = apply_n2_uncensoring(df)

# %% [markdown]
# Saving File

# %%
df_n2_uncensored.to_csv(path[:-4] + '_n2.csv', index=False)

# %% [markdown]
# # N1

# %%
# Grouping N1

import pandas as pd
import numpy as np

def apply_n1_uncensoring(df):
    df = df.copy()
    df['Verkauf_Uncensored'] = df['Verkauf'].copy()

    # Identify closed observations
    is_closed = (df["Zensiert"] == 1)

    # Compute mean Verkauf per group and broadcast using transform
    group_means = df.groupby(['EHASTRA_EH_NUMMER'])['Verkauf_Uncensored'].transform('mean').round()
    
    # Replace closed observations
    df.loc[is_closed, 'Verkauf_Uncensored'] = group_means[is_closed]
    
    return df

df_n1_uncensored = apply_n1_uncensoring(df)

# # Naive N1

# def apply_n1_uncensoring(df):
#     """
#     N1 uncensoring: replace censored values with mean of all values.
#     """
#     df = df.copy()
    
#     # Calculate mean of all observations (censored and uncensored)
#     overall_mean = df['Verkauf'].mean()
    
#     # Replace censored values with this mean
#     df.loc[df['Zensiert'] == 1, 'Verkauf'] = overall_mean
    
#     return df

# %% [markdown]
# Saving File

# %%
df_n1_uncensored.to_csv(path[:-4] + '_n1.csv', index=False)

# %% [markdown]
# # EM

# %%
import numpy as np
from scipy.stats import poisson
import pandas as pd

def apply_em_uncensoring(df, max_iter=30, tolerance=1e-6):

    df = df.copy()
    df['Verkauf_Uncensored'] = df['Verkauf'].copy()
    
    # Direct boolean indexing without extra columns
    stockout_condition = (df['Zensiert'] == 1)
    
    # Process groups with minimal overhead
    for (pos), group in df.groupby(['EHASTRA_EH_NUMMER']):
        group_stockout = stockout_condition.loc[group.index]
        
        if not group_stockout.any():
            continue
            
        sales = group['Verkauf_Uncensored'].values
        is_stockout = group_stockout.values
        
        uncensored = sales[~is_stockout]
        censored = sales[is_stockout]
        
        # Quick lambda initialization
        lambda_est = np.mean(uncensored) if len(uncensored) > 0 else np.mean(sales) * 1.5
        lambda_est = max(lambda_est, 0.1)
        
        # Fast EM loop
        for _ in range(max_iter):
            lambda_old = lambda_est
            
            # Batch E-step
            surv_prob = 1 - poisson.cdf(censored - 1, lambda_est)
            exact_prob = poisson.pmf(censored, lambda_est)
            surv_prob = np.maximum(surv_prob, 1e-12)
            
            expected = lambda_est + censored * exact_prob / surv_prob
            expected = np.maximum(expected, censored.astype(float))
            
            # M-step
            lambda_est = max(np.mean(np.concatenate([uncensored, expected])), 0.1)
            
            if abs(lambda_est - lambda_old) < tolerance:
                break
        
        # Final update
        surv_prob = 1 - poisson.cdf(censored - 1, lambda_est)
        exact_prob = poisson.pmf(censored, lambda_est)
        surv_prob = np.maximum(surv_prob, 1e-12)
        
        final_expected = lambda_est + censored * exact_prob / surv_prob
        final_expected = np.maximum(final_expected, censored.astype(float))
        
        # Update original dataframe
        stockout_indices = group.index[is_stockout]
        df.loc[stockout_indices, 'Verkauf_Uncensored'] = final_expected.round()
    
    return df

df_em_uncensored = apply_em_uncensoring(df)

# %% [markdown]
# Saving File

# %%
df_em_uncensored.to_csv(path[:-4] + '_em.csv', index=False)

# %% [markdown]
# # PD (Poisson, Grouped by HF & POS)

# %%
import pandas as pd
import numpy as np
from scipy.stats import poisson

def apply_projection_detruncation_fixed1(df, tau=0.5, max_iter=20, tolerance=1e-4):
    """
    Proper Projection Detruncation implementation using Poisson distribution.
    
    Parameters:
    - tau: Parameter that controls the aggressiveness of unconstraining (0 < tau < 1)
           tau = 0.5 gives balanced results similar to EM
           smaller tau values are more aggressive
    - max_iter: Maximum number of iterations
    - tolerance: Convergence tolerance
    """
    df = df.copy()
    df["is_closed"] = (df["Zensiert"] == 1)
    df['Verkauf_Uncensored'] = df['Verkauf'].copy()

    def compute_pd_projection1(obs_val, lambda_est, tau):
        """
        Compute the PD projection for a single observation using Poisson distribution.
        This balances area A (original to new estimate) with area B (new estimate to infinity)
        weighted by parameter tau.
        """
        # For Poisson distribution, we need to find the projection value
        # that balances the two areas according to tau
        
        def objective(k_proj):
            k_proj = int(round(k_proj))  # Ensure integer for discrete distribution
            
            if k_proj < obs_val:
                return float('inf')  # Invalid projection
            
            # Area A: P(obs_val <= X <= k_proj) = P(X <= k_proj) - P(X <= obs_val-1)
            area_A = poisson.cdf(k_proj, lambda_est) - poisson.cdf(obs_val - 1, lambda_est)
            
            # Area B: P(X > k_proj) = 1 - P(X <= k_proj)
            area_B = 1 - poisson.cdf(k_proj, lambda_est)
            
            # PD tries to balance: tau * area_A = (1 - tau) * area_B
            # Rearranging: area_A / area_B = (1 - tau) / tau
            if area_B > 1e-10:  # Avoid division by zero
                ratio = area_A / area_B
                target_ratio = (1 - tau) / tau
                return abs(ratio - target_ratio)
            else:
                return abs(area_A - (1 - tau))
        
        # Search for optimal projection in reasonable range
        # For Poisson, search from obs_val to obs_val + reasonable upper bound
        upper_bound = int(obs_val + max(10, int(3 * np.sqrt(lambda_est))))
        
        best_k = obs_val
        best_objective = float('inf')
        
        # Discrete search since Poisson is discrete
        for k in range(int(obs_val), upper_bound + 1):
            obj_val = objective(k)
            if obj_val < best_objective:
                best_objective = obj_val
                best_k = k
        
        return best_k
    
    # Process groups
    grouped = df.groupby(['EHASTRA_EH_NUMMER', 'Heftnummer'])
    
    # can group by different things, just pass in appropriate arguments here 
    for (pos, hf), group in grouped:
        open_mask = ~group['is_closed']
        closed_mask = group['is_closed']
        
        open_sales = group.loc[open_mask, 'Verkauf_Uncensored'].values
        closed_sales = group.loc[closed_mask, 'Verkauf_Uncensored'].values
        
        if len(closed_sales) == 0:
            continue
        
        # Initialize lambda parameter using all available data
        all_sales = group['Verkauf_Uncensored'].values
        lambda_est = np.mean(all_sales)
        
        # Ensure minimum lambda for numerical stability
        lambda_est = max(lambda_est, 0.1)
        
        closed_indices = group[closed_mask].index.values
        
        # Iterative process
        for iteration in range(max_iter):
            lambda_old = lambda_est
            
            # Project closed observations using PD heuristic
            projected_values = np.array([
                compute_pd_projection1(obs, lambda_est, tau) 
                for obs in closed_sales
            ])
            
            # Re-estimate lambda using open + projected values
            all_values = np.concatenate([open_sales, projected_values])
            lambda_est = np.mean(all_values)
            
            # Ensure minimum lambda
            lambda_est = max(lambda_est, 0.1)
            
            # Check convergence
            if abs(lambda_est - lambda_old) < tolerance:
                break
        
        # Final projection
        final_projections = np.array([
            compute_pd_projection1(obs, lambda_est, tau) 
            for obs in closed_sales
        ])
        
        # Update dataframe (already integers from Poisson)
        df.loc[closed_indices, 'Verkauf_Uncensored'] = final_projections.round()
    
    return df.drop('is_closed', axis=1)

def apply_projection_detruncation_aggressive1(df, max_iter=20, tolerance=1e-4):
    """
    More aggressive PD implementation with tau=0.3 as mentioned in the paper
    """
    return apply_projection_detruncation_fixed1(df, tau=0.3, max_iter=max_iter, tolerance=tolerance)

def apply_projection_detruncation_balanced1(df, max_iter=20, tolerance=1e-4):
    """
    Balanced PD implementation with tau=0.5 (similar to EM results)
    """
    return apply_projection_detruncation_fixed1(df, tau=0.5, max_iter=max_iter, tolerance=tolerance)

df_projection_uncensored = apply_projection_detruncation_balanced1(df)

# %% [markdown]
# Saving File

# %%
df_projection_uncensored.to_csv(path[:-4] + '_pd.csv', index=False)

# %% [markdown]
# # Conrad

# %%
from scipy.stats import poisson
import pandas as pd
import numpy as np

def berechnung(links, rechts, n, N, r, x_summe, value_tol=0.00001, max_iterations=1000):
    """
    Till's Code
    """
    iteration = 0
    
    while iteration < max_iterations:
        mu = (links + rechts) / 2
        wert_0 = (x_summe - mu * n) * (1 - poisson.cdf(N-1, mu)) + mu * (n - r) * (1 - poisson.cdf(N-2, mu))
        
        if iteration < 3:
            print(f"Iter {iteration}: mu={mu:.4f}, wert_0={wert_0:.8f}")
        
        if abs(wert_0 - 0) < value_tol:
            print(f"Converged after {iteration} iterations: mu={mu:.4f}")
            return mu
        elif wert_0 - 0 < 0:  # Your condition: je kleiner mu desto kleiner wird der wert
            rechts = mu
        elif wert_0 - 0 > 0:
            links = mu
            
        iteration += 1
    
    print(f"✗ Max iterations reached: mu={mu:.4f}")
    return mu

def test_conrad_example():
    links = 1
    rechts = 100
    n = 13
    N = 10
    r = 7
    x_summe = 58
    
    print("Testing with EXACT German implementation:")
    print(f"links={links}, rechts={rechts}")
    print(f"n={n}, N={N}, r={r}, x_summe={x_summe}")
    
    result = berechnung(links, rechts, n, N, r, x_summe)
    print(f"Result: μ = {result:.4f}")
    print(f"Expected: μ ≈ 10.18")
    
    return result

def create_order_specific_mu_dict(df):

    order_specific_mu_dict = {}
    
    for (year, week), week_data in df.groupby(['Heftjahr', 'Heftnummer']):
        for bezug_val, group in week_data.groupby('Bezug'):
            n = len(group)
            N = bezug_val
            
            # Count non-stockouts
            stockouts_mask = (group['Verkauf'] == bezug_val)
            r = n - stockouts_mask.sum()  # r = number of NON-stockouts
            
            # x_summe = sum of UNCENSORED observations only
            uncensored_sales = group[~stockouts_mask]['Verkauf']
            x_summe = uncensored_sales.sum()
            
            # Skip problematic cases
            if n < 3:
                continue
            if r == n:  # No stockouts = no censoring information
                continue
            if r == 0:  # All stockouts = no uncensored observations
                continue
            
            try:
                links = 1
                rechts = 100
                mu_est = berechnung(links, rechts, n, N, r, x_summe)
                if mu_est:
                    key = (year, week, bezug_val)
                    order_specific_mu_dict[key] = mu_est
            except Exception as e:
                print(f"Error in week {week}, Bezug {N}: {e}")
                continue

    print(f"Successfully estimated μ for {len(order_specific_mu_dict)} groups")
    return order_specific_mu_dict

def expected_poisson_tail(mu, N, max_k=200):
    """
    Compute E[X | X >= N] for X ~ Poisson(mu)
    """
    k_vals = np.arange(N, max_k)
    pmf = poisson.pmf(k_vals, mu)
    tail_prob = 1 - poisson.cdf(N - 1, mu)
    if tail_prob < 1e-8:
        return N  # fallback: don't uncensor
    return np.sum(k_vals * pmf) / tail_prob

def uncensor_dataset(df, order_specific_mu_dict):
    """
    Given a DataFrame with Verkauf, Bezug, is_stockout, Heftjahr, Heftnummer,
    replace Verkauf with E[X | X >= Bezug] when censored.
    """
    df = df.copy()
    df['Verkauf_Uncensored'] = df['Verkauf'].copy()

    for idx, row in df.iterrows():
        # Skip if no stockout occurred
        if not row['is_stockout']:
            continue
            
        # Get the order-quantity-specific demand parameter
        key = (row['Heftjahr'], row['Heftnummer'], row['Bezug'])
        mu = order_specific_mu_dict.get(key, None)

        if mu is None:
            # no estimate available for this specific (week, order_quantity) — keep original value
            continue

        # POS sold out — uncensor using the specific distribution for this order quantity
        est_demand = expected_poisson_tail(mu, row['Bezug'])
        df.at[idx, 'Verkauf_Uncensored'] = np.round(est_demand)

    return df

# Usage
print("Example:")
test_result = test_conrad_example()

print("\nRunning on actual data:")
order_specific_mu_dict = create_order_specific_mu_dict(df)
df_conrad_uncensored = uncensor_dataset(df, order_specific_mu_dict)
# Out:
# Testing Conrad's example first:
# Testing with EXACT German implementation:
# links=1, rechts=100
# n=13, N=10, r=7, x_summe=58
# Iter 0: mu=50.5000, wert_0=-295.50000000
# Iter 1: mu=25.7500, wert_0=-122.21964104
# Iter 2: mu=13.3750, wert_0=-25.84454646
# ✓ Converged after 22 iterations: mu=10.1819
# Result: μ = 10.1819
# Expected: μ ≈ 10.18
#
# Now running on your data:
# Iter 0: mu=50.5000, wert_0=-101.00000000
# Iter 1: mu=25.7500, wert_0=-51.49999998
# Iter 2: mu=13.3750, wert_0=-26.74777675
# ✓ Converged after 23 iterations: mu=3.9797
# Iter 0: mu=50.5000, wert_0=-8620.50000000
# Iter 1: mu=25.7500, wert_0=-4338.74999833
# Iter 2: mu=13.3750, wert_0=-2197.76755762
# ✓ Converged after 16 iterations: mu=1.8527
# Iter 0: mu=50.5000, wert_0=-13048.50000000
# Iter 1: mu=25.7500, wert_0=-6539.24997769
# Iter 2: mu=13.3750, wert_0=-3283.86478561
# ✓ Converged after 26 iterations: mu=1.7449
# Iter 0: mu=50.5000, wert_0=-6390.00000000
# Iter 1: mu=25.7500, wert_0=-3122.99989831
# Iter 2: mu=13.3750, wert_0=-1487.71558458
# ✓ Converged after 25 iterations: mu=3.1311
# Iter 0: mu=50.5000, wert_0=-2776.00000000
# Iter 1: mu=25.7500, wert_0=-1340.49959102
# Iter 2: mu=13.3750, wert_0=-619.00666414
# ✓ Converged after 27 iterations: mu=4.7264
# Iter 0: mu=50.5000, wert_0=-3322.50000000
# Iter 1: mu=25.7500, wert_0=-1614.74819891
# Iter 2: mu=13.3750, wert_0=-751.82063082
# ✓ Converged after 23 iterations: mu=3.9004
# Iter 0: mu=50.5000, wert_0=-3229.00000000
# Iter 1: mu=25.7500, wert_0=-1545.99307704
# Iter 2: mu=13.3750, wert_0=-685.91976517
# ✓ Converged after 25 iterations: mu=4.2747
# Iter 0: mu=50.5000, wert_0=-2542.00000000
# Iter 1: mu=25.7500, wert_0=-1205.48058078
# Iter 2: mu=13.3750, wert_0=-509.00528472
# ✓ Converged after 22 iterations: mu=4.5299
# Iter 0: mu=50.5000, wert_0=-3219.00000000
# Iter 1: mu=25.7500, wert_0=-1486.42069063
# Iter 2: mu=13.3750, wert_0=-559.82555748
# ✓ Converged after 25 iterations: mu=5.5207
# Iter 0: mu=50.5000, wert_0=-2326.00000000
# Iter 1: mu=25.7500, wert_0=-1088.32566520
# Iter 2: mu=13.3750, wert_0=-393.42467685
# ✓ Converged after 23 iterations: mu=5.2920
# Iter 0: mu=50.5000, wert_0=-2400.49999999
# Iter 1: mu=25.7500, wert_0=-1088.27361035
# Iter 2: mu=13.3750, wert_0=-323.62619304
# ✓ Converged after 24 iterations: mu=6.5320
# Iter 0: mu=50.5000, wert_0=-2383.49999995
# Iter 1: mu=25.7500, wert_0=-1070.70626129
# Iter 2: mu=13.3750, wert_0=-277.98095401
# ✓ Converged after 21 iterations: mu=6.1514
# Iter 0: mu=50.5000, wert_0=-2082.49999980
# Iter 1: mu=25.7500, wert_0=-917.19492896
# Iter 2: mu=13.3750, wert_0=-187.85924597
# ✓ Converged after 19 iterations: mu=6.9247
# Iter 0: mu=50.5000, wert_0=-1557.99999938
# Iter 1: mu=25.7500, wert_0=-663.72372493
# Iter 2: mu=13.3750, wert_0=-94.91032743
# ✓ Converged after 20 iterations: mu=8.3330
# Iter 0: mu=50.5000, wert_0=-1820.49999737
# Iter 1: mu=25.7500, wert_0=-749.07737762
# Iter 2: mu=13.3750, wert_0=-73.11524420
# ✓ Converged after 19 iterations: mu=9.1291
# Iter 0: mu=50.5000, wert_0=-1245.49999397
# Iter 1: mu=25.7500, wert_0=-518.79791218
# Iter 2: mu=13.3750, wert_0=-41.93871372
# ✓ Converged after 16 iterations: mu=8.4224
# Iter 0: mu=50.5000, wert_0=-950.49998474
# Iter 1: mu=25.7500, wert_0=-369.81795377
# Iter 2: mu=13.3750, wert_0=-15.48549423
# ✓ Converged after 20 iterations: mu=10.1993
# Iter 0: mu=50.5000, wert_0=-674.99996568
# Iter 1: mu=25.7500, wert_0=-264.97480158
# Iter 2: mu=13.3750, wert_0=-8.17963146
# ✓ Converged after 18 iterations: mu=9.9903
# Iter 0: mu=50.5000, wert_0=-1326.49981817
# Iter 1: mu=25.7500, wert_0=-471.72894078
# Iter 2: mu=13.3750, wert_0=-6.87203961
# ✓ Converged after 20 iterations: mu=11.1144
# Iter 0: mu=50.5000, wert_0=-344.49908751
# Iter 1: mu=25.7500, wert_0=-94.14656888
# Iter 2: mu=13.3750, wert_0=0.17135854
# ✓ Converged after 16 iterations: mu=14.2353
# Iter 0: mu=50.5000, wert_0=-334.49805681
# Iter 1: mu=25.7500, wert_0=-80.24029318
# Iter 2: mu=13.3750, wert_0=0.10710242
# ✓ Converged after 19 iterations: mu=14.4231
# Iter 0: mu=50.5000, wert_0=-497.49362554
# Iter 1: mu=25.7500, wert_0=-114.42803433
# Iter 2: mu=13.3750, wert_0=-0.01805996
# ✓ Converged after 17 iterations: mu=13.1405
# Iter 0: mu=50.5000, wert_0=-292.99154584
# Iter 1: mu=25.7500, wert_0=-53.62315476
# Iter 2: mu=13.3750, wert_0=0.04742650
# ✓ Converged after 16 iterations: mu=15.2429
# Iter 0: mu=50.5000, wert_0=-250.44062338
# Iter 1: mu=25.7500, wert_0=-25.45819314
# Iter 2: mu=13.3750, wert_0=0.00788774
# ✓ Converged after 10 iterations: mu=16.5171
# Iter 0: mu=50.5000, wert_0=-135.10467042
# Iter 1: mu=25.7500, wert_0=-0.07591214
# Iter 2: mu=13.3750, wert_0=0.00004451
# ✓ Converged after 18 iterations: mu=25.4756
# Iter 0: mu=50.5000, wert_0=-35.99199002
# Iter 1: mu=25.7500, wert_0=0.01586187
# Iter 2: mu=38.1250, wert_0=-2.13256615
# ✓ Converged after 18 iterations: mu=34.0979
# Iter 0: mu=50.5000, wert_0=-50.50000000
# Iter 1: mu=25.7500, wert_0=-25.74999998
# Iter 2: mu=13.3750, wert_0=-13.37200796
# ✓ Converged after 19 iterations: mu=4.9698
# Iter 0: mu=50.5000, wert_0=-8975.00000000
# Iter 1: mu=25.7500, wert_0=-4519.99999821
# Iter 2: mu=13.3750, wert_0=-2292.38488637
# ✓ Converged after 26 iterations: mu=1.8724
# Iter 0: mu=50.5000, wert_0=-17930.00000000
# Iter 1: mu=25.7500, wert_0=-8970.49997304
# Iter 2: mu=13.3750, wert_0=-4489.83056741
# ✓ Converged after 27 iterations: mu=1.5348
# Iter 0: mu=50.5000, wert_0=-10191.50000000
# Iter 1: mu=25.7500, wert_0=-4969.24986960
# Iter 2: mu=13.3750, wert_0=-2355.83637729
# ✓ Converged after 24 iterations: mu=2.7276
# Iter 0: mu=50.5000, wert_0=-5560.00000000
# Iter 1: mu=25.7500, wert_0=-2639.49949116
# Iter 2: mu=13.3750, wert_0=-1174.66744701
# ✓ Converged after 26 iterations: mu=4.1370
# Iter 0: mu=50.5000, wert_0=-5460.00000000
# Iter 1: mu=25.7500, wert_0=-2588.99772931
# Iter 2: mu=13.3750, wert_0=-1142.41009745
# ✓ Converged after 24 iterations: mu=3.9167
# Iter 0: mu=50.5000, wert_0=-5554.50000000
# Iter 1: mu=25.7500, wert_0=-2559.73988743
# Iter 2: mu=13.3750, wert_0=-1037.03130831
# ✓ Converged after 26 iterations: mu=5.0931
# Iter 0: mu=50.5000, wert_0=-2578.50000000
# Iter 1: mu=25.7500, wert_0=-1167.73158178
# Iter 2: mu=13.3750, wert_0=-438.08209366
# ✓ Converged after 25 iterations: mu=5.9495
# Iter 0: mu=50.5000, wert_0=-2293.00000000
# Iter 1: mu=25.7500, wert_0=-1005.94942690
# Iter 2: mu=13.3750, wert_0=-328.42622784
# ✓ Converged after 25 iterations: mu=6.8690
# Iter 0: mu=50.5000, wert_0=-2528.00000000
# Iter 1: mu=25.7500, wert_0=-1092.34829675
# Iter 2: mu=13.3750, wert_0=-319.80004335
# ✓ Converged after 21 iterations: mu=7.0568
# Iter 0: mu=50.5000, wert_0=-1607.99999999
# Iter 1: mu=25.7500, wert_0=-667.22565177
# Iter 2: mu=13.3750, wert_0=-148.43716958
# ✓ Converged after 14 iterations: mu=8.6891
# Iter 0: mu=50.5000, wert_0=-1890.99999996
# Iter 1: mu=25.7500, wert_0=-751.76033233
# Iter 2: mu=13.3750, wert_0=-120.19691279
# ✓ Converged after 25 iterations: mu=9.7329
# Iter 0: mu=50.5000, wert_0=-778.49999992
# Iter 1: mu=25.7500, wert_0=-307.52121682
# Iter 2: mu=13.3750, wert_0=-37.96236188
# ✓ Converged after 23 iterations: mu=10.2200
# Iter 0: mu=50.5000, wert_0=-1085.49999961
# Iter 1: mu=25.7500, wert_0=-415.36393543
# Iter 2: mu=13.3750, wert_0=-37.44895748
# ✓ Converged after 24 iterations: mu=10.4824
# Iter 0: mu=50.5000, wert_0=-651.49999906
# Iter 1: mu=25.7500, wert_0=-228.54298059
# Iter 2: mu=13.3750, wert_0=-4.61430970
# ✓ Converged after 22 iterations: mu=12.6819
# Iter 0: mu=50.5000, wert_0=-773.99999639
# Iter 1: mu=25.7500, wert_0=-274.37722806
# Iter 2: mu=13.3750, wert_0=-7.27401598
# ✓ Converged after 21 iterations: mu=12.0764
# Iter 0: mu=50.5000, wert_0=-363.99998092
# Iter 1: mu=25.7500, wert_0=-110.30213932
# Iter 2: mu=13.3750, wert_0=2.59110166
# ✓ Converged after 23 iterations: mu=15.0985
# Iter 0: mu=50.5000, wert_0=-486.99981877
# Iter 1: mu=25.7500, wert_0=-124.84150484
# Iter 2: mu=13.3750, wert_0=2.18927880
# ✓ Converged after 20 iterations: mu=16.1329
# Iter 0: mu=50.5000, wert_0=-169.49976121
# Iter 1: mu=25.7500, wert_0=-35.49163023
# Iter 2: mu=13.3750, wert_0=1.38124727
# ✓ Converged after 23 iterations: mu=19.2860
# Iter 0: mu=50.5000, wert_0=-233.49940568
# Iter 1: mu=25.7500, wert_0=-46.57562719
# Iter 2: mu=13.3750, wert_0=0.67519868
# ✓ Converged after 17 iterations: mu=18.0168
# Iter 0: mu=50.5000, wert_0=-134.99912273
# Iter 1: mu=25.7500, wert_0=-24.73963340
# Iter 2: mu=13.3750, wert_0=0.25111354
# ✓ Converged after 21 iterations: mu=18.4111
# Iter 0: mu=50.5000, wert_0=-2339.50000000
# Iter 1: mu=25.7500, wert_0=-1176.24999876
# Iter 2: mu=13.3750, wert_0=-594.54557932
# ✓ Converged after 28 iterations: mu=3.2314
# Iter 0: mu=50.5000, wert_0=-16225.00000000
# Iter 1: mu=25.7500, wert_0=-8156.49997411
# Iter 2: mu=13.3750, wert_0=-4121.36212337
# ✓ Converged after 25 iterations: mu=1.4635
# Iter 0: mu=50.5000, wert_0=-15699.00000000
# Iter 1: mu=25.7500, wert_0=-7778.99980910
# Iter 2: mu=13.3750, wert_0=-3815.54589050
# ✓ Converged after 27 iterations: mu=1.9022
# Iter 0: mu=50.5000, wert_0=-8984.50000000
# Iter 1: mu=25.7500, wert_0=-4356.24925805
# Iter 2: mu=13.3750, wert_0=-2035.16443861
# ✓ Converged after 25 iterations: mu=3.0461
# Iter 0: mu=50.5000, wert_0=-6758.50000000
# Iter 1: mu=25.7500, wert_0=-3219.24709090
# Iter 2: mu=13.3750, wert_0=-1435.30848131
# ✓ Converged after 27 iterations: mu=3.8483
# Iter 0: mu=50.5000, wert_0=-6605.00000000
# Iter 1: mu=25.7500, wert_0=-3090.48766391
# Iter 2: mu=13.3750, wert_0=-1301.29561360
# ✓ Converged after 26 iterations: mu=4.5983
# Iter 0: mu=50.5000, wert_0=-3883.00000000
# Iter 1: mu=25.7500, wert_0=-1754.47308955
# Iter 2: mu=13.3750, wert_0=-654.90454467
# ✓ Converged after 26 iterations: mu=5.9208
# Iter 0: mu=50.5000, wert_0=-2840.00000000
# Iter 1: mu=25.7500, wert_0=-1255.93745795
# Iter 2: mu=13.3750, wert_0=-420.89221940
# ✓ Converged after 25 iterations: mu=6.5812
# Iter 0: mu=50.5000, wert_0=-2766.00000000
# Iter 1: mu=25.7500, wert_0=-1181.82234650
# Iter 2: mu=13.3750, wert_0=-328.17191095
# ✓ Converged after 24 iterations: mu=7.7407
# Iter 0: mu=50.5000, wert_0=-2170.49999999
# Iter 1: mu=25.7500, wert_0=-907.87552831
# Iter 2: mu=13.3750, wert_0=-208.57168338
# ✓ Converged after 25 iterations: mu=8.4867
# Iter 0: mu=50.5000, wert_0=-1412.99999996
# Iter 1: mu=25.7500, wert_0=-570.85497560
# Iter 2: mu=13.3750, wert_0=-91.59722154
# ✓ Converged after 25 iterations: mu=9.9438
# Iter 0: mu=50.5000, wert_0=-1776.99999983
# Iter 1: mu=25.7500, wert_0=-686.45418360
# Iter 2: mu=13.3750, wert_0=-77.17999384
# ✓ Converged after 25 iterations: mu=10.4958
# Iter 0: mu=50.5000, wert_0=-1145.49999955
# Iter 1: mu=25.7500, wert_0=-425.63987701
# Iter 2: mu=13.3750, wert_0=-26.39040729
# ✓ Converged after 24 iterations: mu=11.5866
# Iter 0: mu=50.5000, wert_0=-735.49999896
# Iter 1: mu=25.7500, wert_0=-262.74565304
# Iter 2: mu=13.3750, wert_0=-8.15973959
# ✓ Converged after 23 iterations: mu=12.2710
# Iter 0: mu=50.5000, wert_0=-742.49999637
# Iter 1: mu=25.7500, wert_0=-267.54709848
# Iter 2: mu=13.3750, wert_0=-7.54946083
# ✓ Converged after 21 iterations: mu=12.0081
# Iter 0: mu=50.5000, wert_0=-528.49999135
# Iter 1: mu=25.7500, wert_0=-152.30470047
# Iter 2: mu=13.3750, wert_0=7.54821636
# ✓ Converged after 23 iterations: mu=15.7729
# Iter 0: mu=50.5000, wert_0=-641.49996716
# Iter 1: mu=25.7500, wert_0=-209.36681339
# Iter 2: mu=13.3750, wert_0=1.09581130
# ✓ Converged after 22 iterations: mu=13.8087
# Iter 0: mu=50.5000, wert_0=-389.49984162
# Iter 1: mu=25.7500, wert_0=-103.15022195
# Iter 2: mu=13.3750, wert_0=1.87199903
# ✓ Converged after 23 iterations: mu=16.1537
# Iter 0: mu=50.5000, wert_0=-365.49789118
# Iter 1: mu=25.7500, wert_0=-66.68567660
# Iter 2: mu=13.3750, wert_0=0.55600196
# ✓ Converged after 22 iterations: mu=17.9108
# Iter 0: mu=50.5000, wert_0=-64.01653021
# Iter 1: mu=25.7500, wert_0=1.36286759
# Iter 2: mu=38.1250, wert_0=-19.22557317
# ✓ Converged after 20 iterations: mu=31.0913
# Iter 0: mu=50.5000, wert_0=-2543.50000000
# Iter 1: mu=25.7500, wert_0=-1281.24999881
# Iter 2: mu=13.3750, wert_0=-650.04850852
# ✓ Converged after 28 iterations: mu=3.0327
# Iter 0: mu=50.5000, wert_0=-15270.00000000
# Iter 1: mu=25.7500, wert_0=-7696.49997357
# Iter 2: mu=13.3750, wert_0=-3908.84249989
# ✓ Converged after 27 iterations: mu=1.5440
# Iter 0: mu=50.5000, wert_0=-15505.50000000
# Iter 1: mu=25.7500, wert_0=-7709.24979614
# Iter 2: mu=13.3750, wert_0=-3807.42846474
# ✓ Converged after 27 iterations: mu=1.9779
# Iter 0: mu=50.5000, wert_0=-9957.50000000
# Iter 1: mu=25.7500, wert_0=-4834.24915033
# Iter 2: mu=13.3750, wert_0=-2264.64682358
# ✓ Converged after 27 iterations: mu=3.0921
# Iter 0: mu=50.5000, wert_0=-5343.50000000
# Iter 1: mu=25.7500, wert_0=-2546.74769768
# Iter 2: mu=13.3750, wert_0=-1137.03166259
# ✓ Converged after 24 iterations: mu=3.8280
# Iter 0: mu=50.5000, wert_0=-4975.50000000
# Iter 1: mu=25.7500, wert_0=-2327.24033973
# Iter 2: mu=13.3750, wert_0=-978.18443099
# ✓ Converged after 26 iterations: mu=4.7563
# Iter 0: mu=50.5000, wert_0=-4685.50000000
# Iter 1: mu=25.7500, wert_0=-2136.21931341
# Iter 2: mu=13.3750, wert_0=-820.25794116
# ✓ Converged after 25 iterations: mu=5.3648
# Iter 0: mu=50.5000, wert_0=-3508.50000000
# Iter 1: mu=25.7500, wert_0=-1553.17014062
# Iter 2: mu=13.3750, wert_0=-520.52364871
# ✓ Converged after 23 iterations: mu=6.6783
# Iter 0: mu=50.5000, wert_0=-2236.50000000
# Iter 1: mu=25.7500, wert_0=-974.09336221
# Iter 2: mu=13.3750, wert_0=-285.62110868
# ✓ Converged after 24 iterations: mu=7.4782
# Iter 0: mu=50.5000, wert_0=-1619.99999999
# Iter 1: mu=25.7500, wert_0=-679.20932340
# Iter 2: mu=13.3750, wert_0=-155.68863682
# ✓ Converged after 25 iterations: mu=8.5878
# Iter 0: mu=50.5000, wert_0=-1929.99999996
# Iter 1: mu=25.7500, wert_0=-790.72489278
# Iter 2: mu=13.3750, wert_0=-146.86353150
# ✓ Converged after 24 iterations: mu=8.9330
# Iter 0: mu=50.5000, wert_0=-1406.99999986
# Iter 1: mu=25.7500, wert_0=-564.17810520
# Iter 2: mu=13.3750, wert_0=-76.48017534
# ✓ Converged after 23 iterations: mu=9.8065
# Iter 0: mu=50.5000, wert_0=-1149.49999955
# Iter 1: mu=25.7500, wert_0=-429.62236519
# Iter 2: mu=13.3750, wert_0=-28.26284614
# ✓ Converged after 24 iterations: mu=11.4605
# Iter 0: mu=50.5000, wert_0=-736.49999895
# Iter 1: mu=25.7500, wert_0=-263.73703485
# Iter 2: mu=13.3750, wert_0=-8.52337343
# ✓ Converged after 23 iterations: mu=12.2220
# Iter 0: mu=50.5000, wert_0=-695.99999658
# Iter 1: mu=25.7500, wert_0=-246.14286391
# Iter 2: mu=13.3750, wert_0=-5.01374665
# ✓ Converged after 23 iterations: mu=12.4197
# Iter 0: mu=50.5000, wert_0=-568.49999026
# Iter 1: mu=25.7500, wert_0=-190.89856484
# Iter 2: mu=13.3750, wert_0=0.88569280
# ✓ Converged after 23 iterations: mu=13.6432
# Iter 0: mu=50.5000, wert_0=-624.49997091
# Iter 1: mu=25.7500, wert_0=-194.05170970
# Iter 2: mu=13.3750, wert_0=1.68955194
# ✓ Converged after 21 iterations: mu=14.1001
# Iter 0: mu=50.5000, wert_0=-474.49993105
# Iter 1: mu=25.7500, wert_0=-140.63704979
# Iter 2: mu=13.3750, wert_0=1.91500618
# ✓ Converged after 23 iterations: mu=14.9125
# Iter 0: mu=50.5000, wert_0=-417.99984286
# Iter 1: mu=25.7500, wert_0=-107.39179882
# Iter 2: mu=13.3750, wert_0=1.90703896
# ✓ Converged after 21 iterations: mu=16.1538
# Iter 0: mu=50.5000, wert_0=-483.99953193
# Iter 1: mu=25.7500, wert_0=-115.81193255
# Iter 2: mu=13.3750, wert_0=1.44237813
# ✓ Converged after 23 iterations: mu=16.3923
# Iter 0: mu=50.5000, wert_0=-142.99960969
# Iter 1: mu=25.7500, wert_0=-33.63653869
# Iter 2: mu=13.3750, wert_0=0.28529871
# ✓ Converged after 18 iterations: mu=16.5528
# Iter 0: mu=50.5000, wert_0=-355.49534723
# Iter 1: mu=25.7500, wert_0=-53.23820773
# Iter 2: mu=13.3750, wert_0=0.35817796
# ✓ Converged after 21 iterations: mu=18.8326
# Iter 0: mu=50.5000, wert_0=-271.49211332
# Iter 1: mu=25.7500, wert_0=-26.55988416
# Iter 2: mu=13.3750, wert_0=0.21532381
# ✓ Converged after 22 iterations: mu=21.0385
# Iter 0: mu=50.5000, wert_0=-5698.00000000
# Iter 1: mu=25.7500, wert_0=-2876.49999842
# Iter 2: mu=13.3750, wert_0=-1465.64862457
# ✓ Converged after 28 iterations: mu=2.2642
# Iter 0: mu=50.5000, wert_0=-15714.00000000
# Iter 1: mu=25.7500, wert_0=-7892.99997400
# Iter 2: mu=13.3750, wert_0=-3981.61050243
# ✓ Converged after 27 iterations: mu=1.5805
# Iter 0: mu=50.5000, wert_0=-14510.50000000
# Iter 1: mu=25.7500, wert_0=-7209.24981482
# Iter 2: mu=13.3750, wert_0=-3555.26647182
# ✓ Converged after 27 iterations: mu=1.9234
# Iter 0: mu=50.5000, wert_0=-8667.50000000
# Iter 1: mu=25.7500, wert_0=-4237.24925938
# Iter 2: mu=13.3750, wert_0=-2015.08295492
# ✓ Converged after 26 iterations: mu=2.8118
# Iter 0: mu=50.5000, wert_0=-5759.50000000
# Iter 1: mu=25.7500, wert_0=-2764.74721325
# Iter 2: mu=13.3750, wert_0=-1253.55059612
# ✓ Converged after 26 iterations: mu=3.9472
# Iter 0: mu=50.5000, wert_0=-5212.50000000
# Iter 1: mu=25.7500, wert_0=-2465.23993669
# Iter 2: mu=13.3750, wert_0=-1065.01366398
# ✓ Converged after 26 iterations: mu=4.3074
# Iter 0: mu=50.5000, wert_0=-4262.50000000
# Iter 1: mu=25.7500, wert_0=-1960.71886016
# Iter 2: mu=13.3750, wert_0=-767.33053959
# ✓ Converged after 26 iterations: mu=5.4753
# Iter 0: mu=50.5000, wert_0=-3173.00000000
# Iter 1: mu=25.7500, wert_0=-1440.42355373
# Iter 2: mu=13.3750, wert_0=-518.20836499
# ✓ Converged after 25 iterations: mu=6.0351
# Iter 0: mu=50.5000, wert_0=-2310.50000000
# Iter 1: mu=25.7500, wert_0=-998.57847908
# Iter 2: mu=13.3750, wert_0=-281.48518420
# ✓ Converged after 25 iterations: mu=7.9692
# Iter 0: mu=50.5000, wert_0=-1674.49999999
# Iter 1: mu=25.7500, wert_0=-708.96632430
# Iter 2: mu=13.3750, wert_0=-172.37295009
# ✓ Converged after 24 iterations: mu=8.0060
# Iter 0: mu=50.5000, wert_0=-1727.49999996
# Iter 1: mu=25.7500, wert_0=-712.07438645
# Iter 2: mu=13.3750, wert_0=-137.87609430
# ✓ Converged after 16 iterations: mu=8.5962
# Iter 0: mu=50.5000, wert_0=-1562.99999983
# Iter 1: mu=25.7500, wert_0=-620.91011886
# Iter 2: mu=13.3750, wert_0=-73.70291740
# ✓ Converged after 24 iterations: mu=10.4779
# Iter 0: mu=50.5000, wert_0=-1151.49999955
# Iter 1: mu=25.7500, wert_0=-431.61360929
# Iter 2: mu=13.3750, wert_0=-29.19906556
# ✓ Converged after 24 iterations: mu=11.3975
# Iter 0: mu=50.5000, wert_0=-644.99999903
# Iter 1: mu=25.7500, wert_0=-246.52651255
# Iter 2: mu=13.3750, wert_0=-14.35323105
# ✓ Converged after 21 iterations: mu=11.1894
# Iter 0: mu=50.5000, wert_0=-468.99999775
# Iter 1: mu=25.7500, wert_0=-169.07823500
# Iter 2: mu=13.3750, wert_0=-5.11020655
# ✓ Converged after 22 iterations: mu=11.8888
# Iter 0: mu=50.5000, wert_0=-344.49999401
# Iter 1: mu=25.7500, wert_0=-117.78492706
# Iter 2: mu=13.3750, wert_0=0.08488109
# ✓ Converged after 22 iterations: mu=13.4172
# Iter 0: mu=50.5000, wert_0=-563.49997210
# Iter 1: mu=25.7500, wert_0=-182.61639006
# Iter 2: mu=13.3750, wert_0=0.76884653
# ✓ Converged after 23 iterations: mu=13.7299
# Iter 0: mu=50.5000, wert_0=-427.99994120
# Iter 1: mu=25.7500, wert_0=-121.07930930
# Iter 2: mu=13.3750, wert_0=2.11054547
# ✓ Converged after 23 iterations: mu=15.3039
# Iter 0: mu=50.5000, wert_0=-283.99986727
# Iter 1: mu=25.7500, wert_0=-74.30008531
# Iter 2: mu=13.3750, wert_0=1.98479901
# ✓ Converged after 22 iterations: mu=16.9739
# Iter 0: mu=50.5000, wert_0=-46.97143754
# Iter 1: mu=25.7500, wert_0=2.47420343
# Iter 2: mu=38.1250, wert_0=-20.38988539
# ✓ Converged after 22 iterations: mu=29.0321
# Iter 0: mu=50.5000, wert_0=-76.28698641
# Iter 1: mu=25.7500, wert_0=0.82115327
# Iter 2: mu=38.1250, wert_0=-32.50993816
# ✓ Converged after 21 iterations: mu=27.4342
# Iter 0: mu=50.5000, wert_0=-51.74028138
# Iter 1: mu=25.7500, wert_0=0.65813719
# Iter 2: mu=38.1250, wert_0=-20.69242756
# ✓ Converged after 18 iterations: mu=28.2522
# Iter 0: mu=50.5000, wert_0=-6349.50000000
# Iter 1: mu=25.7500, wert_0=-3206.24999834
# Iter 2: mu=13.3750, wert_0=-1634.51818589
# ✓ Converged after 29 iterations: mu=2.1771
# Iter 0: mu=50.5000, wert_0=-21765.50000000
# Iter 1: mu=25.7500, wert_0=-10949.74996738
# Iter 2: mu=13.3750, wert_0=-5540.75258383
# ✓ Converged after 27 iterations: mu=1.2857
# Iter 0: mu=50.5000, wert_0=-14125.50000000
# Iter 1: mu=25.7500, wert_0=-6972.74981835
# Iter 2: mu=13.3750, wert_0=-3393.11829674
# ✓ Converged after 27 iterations: mu=2.2238
# Iter 0: mu=50.5000, wert_0=-5417.00000000
# Iter 1: mu=25.7500, wert_0=-2595.49944786
# Iter 2: mu=13.3750, wert_0=-1179.70846861
# ✓ Converged after 24 iterations: mu=4.0694
# Iter 0: mu=50.5000, wert_0=-5382.50000000
# Iter 1: mu=25.7500, wert_0=-2585.74757242
# Iter 2: mu=13.3750, wert_0=-1175.25964450
# ✓ Converged after 26 iterations: mu=3.6708
# Iter 0: mu=50.5000, wert_0=-5112.50000000
# Iter 1: mu=25.7500, wert_0=-2414.74024600
# Iter 2: mu=13.3750, wert_0=-1040.12827982
# ✓ Converged after 26 iterations: mu=4.3116
# Iter 0: mu=50.5000, wert_0=-3436.50000000
# Iter 1: mu=25.7500, wert_0=-1580.22563897
# Iter 2: mu=13.3750, wert_0=-618.78593762
# ✓ Converged after 25 iterations: mu=5.3630
# Iter 0: mu=50.5000, wert_0=-3183.50000000
# Iter 1: mu=25.7500, wert_0=-1426.17661928
# Iter 2: mu=13.3750, wert_0=-495.39795862
# ✓ Converged after 23 iterations: mu=6.3104
# Iter 0: mu=50.5000, wert_0=-2304.00000000
# Iter 1: mu=25.7500, wert_0=-1016.84455833
# Iter 2: mu=13.3750, wert_0=-314.02225691
# ✓ Converged after 24 iterations: mu=6.8527
# Iter 0: mu=50.5000, wert_0=-1621.99999999
# Iter 1: mu=25.7500, wert_0=-681.22052333
# Iter 2: mu=13.3750, wert_0=-159.34490662
# ✓ Converged after 23 iterations: mu=8.3510
# Iter 0: mu=50.5000, wert_0=-1446.99999997
# Iter 1: mu=25.7500, wert_0=-604.85201262
# Iter 2: mu=13.3750, wert_0=-117.39604658
# ✓ Converged after 24 iterations: mu=8.8724
# Iter 0: mu=50.5000, wert_0=-1134.99999989
# Iter 1: mu=25.7500, wert_0=-440.99400885
# Iter 2: mu=13.3750, wert_0=-50.88320027
# ✓ Converged after 24 iterations: mu=10.4202
# Iter 0: mu=50.5000, wert_0=-687.49999969
# Iter 1: mu=25.7500, wert_0=-265.28536429
# Iter 2: mu=13.3750, wert_0=-19.07637363
# ✓ Converged after 23 iterations: mu=11.3559
# Iter 0: mu=50.5000, wert_0=-903.99999860
# Iter 1: mu=25.7500, wert_0=-355.85583045
# Iter 2: mu=13.3750, wert_0=-24.74022788
# ✓ Converged after 22 iterations: mu=10.7051
# Iter 0: mu=50.5000, wert_0=-778.99999621
# Iter 1: mu=25.7500, wert_0=-279.11030567
# Iter 2: mu=13.3750, wert_0=-7.38041322
# ✓ Converged after 23 iterations: mu=12.1009
# Iter 0: mu=50.5000, wert_0=-634.99999031
# Iter 1: mu=25.7500, wert_0=-232.09907306
# Iter 2: mu=13.3750, wert_0=-6.85512576
# ✓ Converged after 19 iterations: mu=11.2510
# Iter 0: mu=50.5000, wert_0=-312.99998317
# Iter 1: mu=25.7500, wert_0=-108.87017396
# Iter 2: mu=13.3750, wert_0=-0.46240693
# ✓ Converged after 18 iterations: mu=13.0051
# Iter 0: mu=50.5000, wert_0=-567.49992340
# Iter 1: mu=25.7500, wert_0=-181.71347282
# Iter 2: mu=13.3750, wert_0=-0.30279905
# ✓ Converged after 13 iterations: mu=13.1514
# Iter 0: mu=50.5000, wert_0=-245.49924273
# Iter 1: mu=25.7500, wert_0=-53.33358300
# Iter 2: mu=13.3750, wert_0=0.81620572
# ✓ Converged after 22 iterations: mu=18.0423
# Iter 0: mu=50.5000, wert_0=-91.47495498
# Iter 1: mu=25.7500, wert_0=-4.19907605
# Iter 2: mu=13.3750, wert_0=0.01122947
# ✓ Converged after 19 iterations: mu=22.5566
# Iter 0: mu=50.5000, wert_0=-6145.50000000
# Iter 1: mu=25.7500, wert_0=-3101.24999846
# Iter 2: mu=13.3750, wert_0=-1579.02609505
# ✓ Converged after 29 iterations: mu=2.1328
# Iter 0: mu=50.5000, wert_0=-21493.00000000
# Iter 1: mu=25.7500, wert_0=-10800.99996812
# Iter 2: mu=13.3750, wert_0=-5453.90460496
# ✓ Converged after 28 iterations: mu=1.3088
# Iter 0: mu=50.5000, wert_0=-12179.00000000
# Iter 1: mu=25.7500, wert_0=-5991.49983657
# Iter 2: mu=13.3750, wert_0=-2894.84118661
# ✓ Converged after 26 iterations: mu=2.4764
# Iter 0: mu=50.5000, wert_0=-6253.50000000
# Iter 1: mu=25.7500, wert_0=-3011.24938607
# Iter 2: mu=13.3750, wert_0=-1384.46998439
# ✓ Converged after 27 iterations: mu=3.7990
# Iter 0: mu=50.5000, wert_0=-5000.00000000
# Iter 1: mu=25.7500, wert_0=-2376.49763585
# Iter 2: mu=13.3750, wert_0=-1053.21920602
# ✓ Converged after 26 iterations: mu=4.2393
# Iter 0: mu=50.5000, wert_0=-5534.50000000
# Iter 1: mu=25.7500, wert_0=-2589.24026542
# Iter 2: mu=13.3750, wert_0=-1091.31233238
# ✓ Converged after 26 iterations: mu=4.3740
# Iter 0: mu=50.5000, wert_0=-4256.50000000
# Iter 1: mu=25.7500, wert_0=-1954.72095205
# Iter 2: mu=13.3750, wert_0=-764.12196794
# ✓ Converged after 24 iterations: mu=5.2534
# Iter 0: mu=50.5000, wert_0=-2898.50000000
# Iter 1: mu=25.7500, wert_0=-1289.67947286
# Iter 2: mu=13.3750, wert_0=-436.25381380
# ✓ Converged after 24 iterations: mu=6.7740
# Iter 0: mu=50.5000, wert_0=-2378.00000000
# Iter 1: mu=25.7500, wert_0=-1041.33894321
# Iter 2: mu=13.3750, wert_0=-313.02356106
# ✓ Converged after 21 iterations: mu=7.1440
# Iter 0: mu=50.5000, wert_0=-1615.99999999
# Iter 1: mu=25.7500, wert_0=-675.22272123
# Iter 2: mu=13.3750, wert_0=-154.67016217
# ✓ Converged after 19 iterations: mu=8.4958
# Iter 0: mu=50.5000, wert_0=-1959.49999995
# Iter 1: mu=25.7500, wert_0=-795.41471035
# Iter 2: mu=13.3750, wert_0=-136.54785847
# ✓ Converged after 22 iterations: mu=9.5035
# Iter 0: mu=50.5000, wert_0=-1422.49999987
# Iter 1: mu=25.7500, wert_0=-555.00721624
# Iter 2: mu=13.3750, wert_0=-66.83574376
# ✓ Converged after 24 iterations: mu=10.2329
# Iter 0: mu=50.5000, wert_0=-938.49999959
# Iter 1: mu=25.7500, wert_0=-367.27726071
# Iter 2: mu=13.3750, wert_0=-30.83781071
# ✓ Converged after 23 iterations: mu=10.9244
# Iter 0: mu=50.5000, wert_0=-930.49999866
# Iter 1: mu=25.7500, wert_0=-357.80912076
# Iter 2: mu=13.3750, wert_0=-23.67134807
# ✓ Converged after 23 iterations: mu=10.7800
# Iter 0: mu=50.5000, wert_0=-605.49999714
# Iter 1: mu=25.7500, wert_0=-230.33863049
# Iter 2: mu=13.3750, wert_0=-11.90592054
# ✓ Converged after 17 iterations: mu=10.5777
# Iter 0: mu=50.5000, wert_0=-577.49996998
# Iter 1: mu=25.7500, wert_0=-195.52448156
# Iter 2: mu=13.3750, wert_0=-0.25035915
# ✓ Converged after 20 iterations: mu=13.2646
# Iter 0: mu=50.5000, wert_0=-653.99990816
# Iter 1: mu=25.7500, wert_0=-192.44325080
# Iter 2: mu=13.3750, wert_0=2.44057898
# ✓ Converged after 22 iterations: mu=14.8322
# Iter 0: mu=50.5000, wert_0=-574.99976566
# Iter 1: mu=25.7500, wert_0=-157.52176017
# Iter 2: mu=13.3750, wert_0=2.30735883
# ✓ Converged after 21 iterations: mu=15.7181
# Iter 0: mu=50.5000, wert_0=-271.99972458
# Iter 1: mu=25.7500, wert_0=-61.80114964
# Iter 2: mu=13.3750, wert_0=1.09485235
# ✓ Converged after 22 iterations: mu=17.2343
# Iter 0: mu=50.5000, wert_0=-420.99891506
# Iter 1: mu=25.7500, wert_0=-95.93813498
# Iter 2: mu=13.3750, wert_0=0.82274830
# ✓ Converged after 21 iterations: mu=16.6111
# Iter 0: mu=50.5000, wert_0=-58.99921683
# Iter 1: mu=25.7500, wert_0=-2.04972544
# Iter 2: mu=13.3750, wert_0=0.49126633
# ✓ Converged after 22 iterations: mu=24.9176
# Iter 0: mu=50.5000, wert_0=-50.50000000
# Iter 1: mu=25.7500, wert_0=-25.74999998
# Iter 2: mu=13.3750, wert_0=-13.37240274
# ✓ Converged after 21 iterations: mu=4.8283
# Iter 0: mu=50.5000, wert_0=-4787.00000000
# Iter 1: mu=25.7500, wert_0=-2410.99999841
# Iter 2: mu=13.3750, wert_0=-1222.89793162
# ✓ Converged after 28 iterations: mu=2.5774
# Iter 0: mu=50.5000, wert_0=-20106.00000000
# Iter 1: mu=25.7500, wert_0=-10106.99997042
# Iter 2: mu=13.3750, wert_0=-5106.48295346
# ✓ Converged after 26 iterations: mu=1.2760
# Iter 0: mu=50.5000, wert_0=-11444.50000000
# Iter 1: mu=25.7500, wert_0=-5628.24984469
# Iter 2: mu=13.3750, wert_0=-2717.36315937
# ✓ Converged after 27 iterations: mu=2.5185
# Iter 0: mu=50.5000, wert_0=-5735.00000000
# Iter 1: mu=25.7500, wert_0=-2764.99944869
# Iter 2: mu=13.3750, wert_0=-1274.90843841
# ✓ Converged after 27 iterations: mu=3.6984
# Iter 0: mu=50.5000, wert_0=-4827.00000000
# Iter 1: mu=25.7500, wert_0=-2302.49766022
# Iter 2: mu=13.3750, wert_0=-1028.77661831
# ✓ Converged after 26 iterations: mu=4.1874
# Iter 0: mu=50.5000, wert_0=-4665.00000000
# Iter 1: mu=25.7500, wert_0=-2189.99101379
# Iter 2: mu=13.3750, wert_0=-929.10530074
# ✓ Converged after 24 iterations: mu=4.5875
# Iter 0: mu=50.5000, wert_0=-3721.50000000
# Iter 1: mu=25.7500, wert_0=-1716.72258097
# Iter 2: mu=13.3750, wert_0=-676.69700279
# ✓ Converged after 24 iterations: mu=5.4067
# Iter 0: mu=50.5000, wert_0=-2470.50000000
# Iter 1: mu=25.7500, wert_0=-1109.19319853
# Iter 2: mu=13.3750, wert_0=-387.95407812
# ✓ Converged after 22 iterations: mu=6.2200
# Iter 0: mu=50.5000, wert_0=-2568.50000000
# Iter 1: mu=25.7500, wert_0=-1108.07995752
# Iter 2: mu=13.3750, wert_0=-317.20414066
# ✓ Converged after 25 iterations: mu=7.5468
# Iter 0: mu=50.5000, wert_0=-2103.99999999
# Iter 1: mu=25.7500, wert_0=-915.61075679
# Iter 2: mu=13.3750, wert_0=-241.43685458
# ✓ Converged after 24 iterations: mu=7.5377
# Iter 0: mu=50.5000, wert_0=-1683.49999996
# Iter 1: mu=25.7500, wert_0=-717.49955597
# Iter 2: mu=13.3750, wert_0=-152.18230881
# ✓ Converged after 23 iterations: mu=8.2289
# Iter 0: mu=50.5000, wert_0=-1330.99999988
# Iter 1: mu=25.7500, wert_0=-537.82293812
# Iter 2: mu=13.3750, wert_0=-79.73456611
# ✓ Converged after 21 iterations: mu=9.2253
# Iter 0: mu=50.5000, wert_0=-1312.99999949
# Iter 1: mu=25.7500, wert_0=-518.48163281
# Iter 2: mu=13.3750, wert_0=-52.66306483
# ✓ Converged after 24 iterations: mu=10.1292
# Iter 0: mu=50.5000, wert_0=-1001.49999852
# Iter 1: mu=25.7500, wert_0=-379.01464361
# Iter 2: mu=13.3750, wert_0=-21.09217327
# ✓ Converged after 23 iterations: mu=11.2839
# Iter 0: mu=50.5000, wert_0=-549.99999723
# Iter 1: mu=25.7500, wert_0=-199.89003519
# Iter 2: mu=13.3750, wert_0=-5.68993710
# ✓ Converged after 22 iterations: mu=12.0108
# Iter 0: mu=50.5000, wert_0=-699.49998837
# Iter 1: mu=25.7500, wert_0=-270.14818548
# Iter 2: mu=13.3750, wert_0=-10.04448207
# ✓ Converged after 21 iterations: mu=10.6724
# Iter 0: mu=50.5000, wert_0=-726.49996190
# Iter 1: mu=25.7500, wert_0=-242.79974173
# Iter 2: mu=13.3750, wert_0=0.50344015
# ✓ Converged after 22 iterations: mu=13.5492
# Iter 0: mu=50.5000, wert_0=-549.49991728
# Iter 1: mu=25.7500, wert_0=-163.67951232
# Iter 2: mu=13.3750, wert_0=2.45955920
# ✓ Converged after 22 iterations: mu=15.0350
# Iter 0: mu=50.5000, wert_0=-253.49990030
# Iter 1: mu=25.7500, wert_0=-70.92638752
# Iter 2: mu=13.3750, wert_0=0.77135961
# ✓ Converged after 22 iterations: mu=15.2193
# Iter 0: mu=50.5000, wert_0=-398.99958092
# Iter 1: mu=25.7500, wert_0=-84.47637781
# Iter 2: mu=13.3750, wert_0=2.07655677
# ✓ Converged after 24 iterations: mu=18.1247
# Iter 0: mu=50.5000, wert_0=-297.49926141
# Iter 1: mu=25.7500, wert_0=-58.12127539
# Iter 2: mu=13.3750, wert_0=0.86664656
# ✓ Converged after 22 iterations: mu=18.1162
# Iter 0: mu=50.5000, wert_0=-4338.50000000
# Iter 1: mu=25.7500, wert_0=-2185.24999852
# Iter 2: mu=13.3750, wert_0=-1108.53021020
# ✓ Converged after 28 iterations: mu=2.6087
# Iter 0: mu=50.5000, wert_0=-18931.00000000
# Iter 1: mu=25.7500, wert_0=-9525.99997145
# Iter 2: mu=13.3750, wert_0=-4822.51760736
# ✓ Converged after 25 iterations: mu=1.2899
# Iter 0: mu=50.5000, wert_0=-11261.50000000
# Iter 1: mu=25.7500, wert_0=-5544.24985126
# Iter 2: mu=13.3750, wert_0=-2682.97295460
# ✓ Converged after 23 iterations: mu=2.4054
# Iter 0: mu=50.5000, wert_0=-6962.00000000
# Iter 1: mu=25.7500, wert_0=-3348.49938487
# Iter 2: mu=13.3750, wert_0=-1536.07809909
# ✓ Converged after 24 iterations: mu=3.5614
# Iter 0: mu=50.5000, wert_0=-4615.00000000
# Iter 1: mu=25.7500, wert_0=-2189.49761862
# Iter 2: mu=13.3750, wert_0=-965.21669594
# ✓ Converged after 27 iterations: mu=4.5750
# Iter 0: mu=50.5000, wert_0=-4995.00000000
# Iter 1: mu=25.7500, wert_0=-2321.99042606
# Iter 2: mu=13.3750, wert_0=-961.09028003
# ✓ Converged after 24 iterations: mu=4.9417
# Iter 0: mu=50.5000, wert_0=-3876.50000000
# Iter 1: mu=25.7500, wert_0=-1772.72310048
# Iter 2: mu=13.3750, wert_0=-684.48709006
# ✓ Converged after 22 iterations: mu=5.4830
# Iter 0: mu=50.5000, wert_0=-3637.50000000
# Iter 1: mu=25.7500, wert_0=-1632.66740184
# Iter 2: mu=13.3750, wert_0=-571.21305993
# ✓ Converged after 25 iterations: mu=6.1750
# Iter 0: mu=50.5000, wert_0=-2352.50000000
# Iter 1: mu=25.7500, wert_0=-1040.57745917
# Iter 2: mu=13.3750, wert_0=-319.07109970
# ✓ Converged after 25 iterations: mu=7.1849
# Iter 0: mu=50.5000, wert_0=-1557.99999999
# Iter 1: mu=25.7500, wert_0=-666.73776749
# Iter 2: mu=13.3750, wert_0=-169.42895003
# ✓ Converged after 24 iterations: mu=7.6052
# Iter 0: mu=50.5000, wert_0=-1648.49999996
# Iter 1: mu=25.7500, wert_0=-682.57326025
# Iter 2: mu=13.3750, wert_0=-132.07723330
# ✓ Converged after 24 iterations: mu=8.7068
# Iter 0: mu=50.5000, wert_0=-944.99999991
# Iter 1: mu=25.7500, wert_0=-399.58002104
# Iter 2: mu=13.3750, wert_0=-69.79526541
# ✓ Converged after 21 iterations: mu=8.3332
# Iter 0: mu=50.5000, wert_0=-1040.99999958
# Iter 1: mu=25.7500, wert_0=-395.52231011
# Iter 2: mu=13.3750, wert_0=-29.60866156
# ✓ Converged after 24 iterations: mu=11.1607
# Iter 0: mu=50.5000, wert_0=-1023.99999858
# Iter 1: mu=25.7500, wert_0=-377.00240668
# Iter 2: mu=13.3750, wert_0=-18.56875812
# ✓ Converged after 23 iterations: mu=11.5086
# Iter 0: mu=50.5000, wert_0=-695.99998842
# Iter 1: mu=25.7500, wert_0=-242.67822495
# Iter 2: mu=13.3750, wert_0=-2.22001768
# ✓ Converged after 23 iterations: mu=12.8042
# Iter 0: mu=50.5000, wert_0=-647.49996389
# Iter 1: mu=25.7500, wert_0=-214.18083776
# Iter 2: mu=13.3750, wert_0=1.94674140
# ✓ Converged after 18 iterations: mu=14.0908
# Iter 0: mu=50.5000, wert_0=-377.99994336
# Iter 1: mu=25.7500, wert_0=-119.96103234
# Iter 2: mu=13.3750, wert_0=0.63861507
# ✓ Converged after 21 iterations: mu=14.0198
# Iter 0: mu=50.5000, wert_0=-483.49979761
# Iter 1: mu=25.7500, wert_0=-142.08548177
# Iter 2: mu=13.3750, wert_0=1.23887944
# ✓ Converged after 23 iterations: mu=14.8760
# Iter 0: mu=50.5000, wert_0=-325.49967596
# Iter 1: mu=25.7500, wert_0=-86.25485057
# Iter 2: mu=13.3750, wert_0=0.56548169
# ✓ Converged after 19 iterations: mu=15.1593
# Iter 0: mu=50.5000, wert_0=-322.99780630
# Iter 1: mu=25.7500, wert_0=-50.40673594
# Iter 2: mu=13.3750, wert_0=0.83377927
# ✓ Converged after 22 iterations: mu=19.8772
# Iter 0: mu=50.5000, wert_0=-160.49504309
# Iter 1: mu=25.7500, wert_0=-19.53806260
# Iter 2: mu=13.3750, wert_0=0.10792681
# ✓ Converged after 20 iterations: mu=19.8453
# Iter 0: mu=50.5000, wert_0=-153.48010255
# Iter 1: mu=25.7500, wert_0=-10.74527133
# Iter 2: mu=13.3750, wert_0=0.03190275
# ✓ Converged after 20 iterations: mu=21.3506
# Iter 0: mu=50.5000, wert_0=-6796.00000000
# Iter 1: mu=25.7500, wert_0=-3429.99999837
# Iter 2: mu=13.3750, wert_0=-1746.89512289
# ✓ Converged after 29 iterations: mu=2.0685
# Iter 0: mu=50.5000, wert_0=-18573.50000000
# Iter 1: mu=25.7500, wert_0=-9341.74997031
# Iter 2: mu=13.3750, wert_0=-4724.85631478
# ✓ Converged after 26 iterations: mu=1.4462
# Iter 0: mu=50.5000, wert_0=-10930.00000000
# Iter 1: mu=25.7500, wert_0=-5385.99985026
# Iter 2: mu=13.3750, wert_0=-2611.32930599
# ✓ Converged after 24 iterations: mu=2.4614
# Iter 0: mu=50.5000, wert_0=-7012.50000000
# Iter 1: mu=25.7500, wert_0=-3374.24931934
# Iter 2: mu=13.3750, wert_0=-1548.86083654
# ✓ Converged after 25 iterations: mu=3.7955
# Iter 0: mu=50.5000, wert_0=-4489.00000000
# Iter 1: mu=25.7500, wert_0=-2112.99780426
# Iter 2: mu=13.3750, wert_0=-914.49395504
# ✓ Converged after 27 iterations: mu=4.6913
# Iter 0: mu=50.5000, wert_0=-5266.00000000
# Iter 1: mu=25.7500, wert_0=-2493.99052242
# Iter 2: mu=13.3750, wert_0=-1082.70105268
# ✓ Converged after 25 iterations: mu=3.9568
# Iter 0: mu=50.5000, wert_0=-4198.00000000
# Iter 1: mu=25.7500, wert_0=-1920.97139711
# Iter 2: mu=13.3750, wert_0=-743.69488236
# ✓ Converged after 26 iterations: mu=5.3845
# Iter 0: mu=50.5000, wert_0=-3090.50000000
# Iter 1: mu=25.7500, wert_0=-1382.67532166
# Iter 2: mu=13.3750, wert_0=-476.10827794
# ✓ Converged after 25 iterations: mu=6.5598
# Iter 0: mu=50.5000, wert_0=-2335.50000000
# Iter 1: mu=25.7500, wert_0=-1023.58206466
# Iter 2: mu=13.3750, wert_0=-305.27697543
# ✓ Converged after 25 iterations: mu=7.3935
# Iter 0: mu=50.5000, wert_0=-2303.49999999
# Iter 1: mu=25.7500, wert_0=-991.32704197
# Iter 2: mu=13.3750, wert_0=-251.19819029
# ✓ Converged after 23 iterations: mu=7.8691
# Iter 0: mu=50.5000, wert_0=-1683.99999996
# Iter 1: mu=25.7500, wert_0=-693.24365907
# Iter 2: mu=13.3750, wert_0=-124.58861520
# ✓ Converged after 22 iterations: mu=9.3434
# Iter 0: mu=50.5000, wert_0=-1548.99999985
# Iter 1: mu=25.7500, wert_0=-607.14892377
# Iter 2: mu=13.3750, wert_0=-75.56994178
# ✓ Converged after 25 iterations: mu=10.0908
# Iter 0: mu=50.5000, wert_0=-1181.49999948
# Iter 1: mu=25.7500, wert_0=-461.24481746
# Iter 2: mu=13.3750, wert_0=-37.39170783
# ✓ Converged after 23 iterations: mu=11.0363
# Iter 0: mu=50.5000, wert_0=-626.99999891
# Iter 1: mu=25.7500, wert_0=-228.35408175
# Iter 2: mu=13.3750, wert_0=-3.61572749
# ✓ Converged after 20 iterations: mu=12.8752
# Iter 0: mu=50.5000, wert_0=-861.99999568
# Iter 1: mu=25.7500, wert_0=-311.89031133
# Iter 2: mu=13.3750, wert_0=-8.50109613
# ✓ Converged after 23 iterations: mu=12.0723
# Iter 0: mu=50.5000, wert_0=-462.99999280
# Iter 1: mu=25.7500, wert_0=-161.11475028
# Iter 2: mu=13.3750, wert_0=-2.32897405
# ✓ Converged after 21 iterations: mu=12.4257
# Iter 0: mu=50.5000, wert_0=-471.49993144
# Iter 1: mu=25.7500, wert_0=-137.84927215
# Iter 2: mu=13.3750, wert_0=2.17242959
# ✓ Converged after 23 iterations: mu=15.1200
# Iter 0: mu=50.5000, wert_0=-215.99991339
# Iter 1: mu=25.7500, wert_0=-59.51696436
# Iter 2: mu=13.3750, wert_0=0.79151960
# ✓ Converged after 18 iterations: mu=15.5482
# Iter 0: mu=50.5000, wert_0=-383.49959500
# Iter 1: mu=25.7500, wert_0=-92.34409028
# Iter 2: mu=13.3750, wert_0=1.37746422
# ✓ Converged after 22 iterations: mu=16.7663
# Iter 0: mu=50.5000, wert_0=-356.99905933
# Iter 1: mu=25.7500, wert_0=-84.39248679
# Iter 2: mu=13.3750, wert_0=0.63130041
# ✓ Converged after 22 iterations: mu=16.2838
# Iter 0: mu=50.5000, wert_0=-354.99794728
# Iter 1: mu=25.7500, wert_0=-77.12639477
# Iter 2: mu=13.3750, wert_0=0.27965629
# ✓ Converged after 19 iterations: mu=15.8623
# Iter 0: mu=50.5000, wert_0=-50.50000000
# Iter 1: mu=25.7500, wert_0=-25.74999998
# Iter 2: mu=13.3750, wert_0=-13.37204951
# ✓ Converged after 24 iterations: mu=4.9558
# Iter 0: mu=50.5000, wert_0=-6546.50000000
# Iter 1: mu=25.7500, wert_0=-3304.24999838
# Iter 2: mu=13.3750, wert_0=-1683.02099350
# ✓ Converged after 28 iterations: mu=2.1086
# Iter 0: mu=50.5000, wert_0=-19130.00000000
# Iter 1: mu=25.7500, wert_0=-9625.99997037
# Iter 2: mu=13.3750, wert_0=-4872.98158497
# ✓ Converged after 27 iterations: mu=1.3533
# Iter 0: mu=50.5000, wert_0=-11352.00000000
# Iter 1: mu=25.7500, wert_0=-5609.99984603
# Iter 2: mu=13.3750, wert_0=-2736.23999368
# ✓ Converged after 26 iterations: mu=2.3185
# Iter 0: mu=50.5000, wert_0=-6797.00000000
# Iter 1: mu=25.7500, wert_0=-3282.49934467
# Iter 2: mu=13.3750, wert_0=-1519.18186994
# ✓ Converged after 26 iterations: mu=3.6455
# Iter 0: mu=50.5000, wert_0=-3868.00000000
# Iter 1: mu=25.7500, wert_0=-1838.49818821
# Iter 2: mu=13.3750, wert_0=-814.90902451
# ✓ Converged after 26 iterations: mu=4.2085
# Iter 0: mu=50.5000, wert_0=-4643.50000000
# Iter 1: mu=25.7500, wert_0=-2193.24127627
# Iter 2: mu=13.3750, wert_0=-945.06699082
# ✓ Converged after 22 iterations: mu=4.2484
# Iter 0: mu=50.5000, wert_0=-4840.50000000
# Iter 1: mu=25.7500, wert_0=-2241.71641261
# Iter 2: mu=13.3750, wert_0=-895.53292078
# ✓ Converged after 24 iterations: mu=4.9970
# Iter 0: mu=50.5000, wert_0=-3263.50000000
# Iter 1: mu=25.7500, wert_0=-1456.67201856
# Iter 2: mu=13.3750, wert_0=-498.55504509
# ✓ Converged after 26 iterations: mu=6.5927
# Iter 0: mu=50.5000, wert_0=-3177.50000000
# Iter 1: mu=25.7500, wert_0=-1420.03563996
# Iter 2: mu=13.3750, wert_0=-456.63004171
# ✓ Converged after 20 iterations: mu=6.3978
# Iter 0: mu=50.5000, wert_0=-1438.49999999
# Iter 1: mu=25.7500, wert_0=-621.50434335
# Iter 2: mu=13.3750, wert_0=-163.09856693
# ✓ Converged after 23 iterations: mu=7.3443
# Iter 0: mu=50.5000, wert_0=-1938.99999996
# Iter 1: mu=25.7500, wert_0=-799.70274791
# Iter 2: mu=13.3750, wert_0=-151.74186479
# ✓ Converged after 24 iterations: mu=8.8418
# Iter 0: mu=50.5000, wert_0=-1642.99999984
# Iter 1: mu=25.7500, wert_0=-651.46678436
# Iter 2: mu=13.3750, wert_0=-82.70996849
# ✓ Converged after 25 iterations: mu=10.0969
# Iter 0: mu=50.5000, wert_0=-1132.99999953
# Iter 1: mu=25.7500, wert_0=-437.71752047
# Iter 2: mu=13.3750, wert_0=-34.99228440
# ✓ Converged after 23 iterations: mu=11.0293
# Iter 0: mu=50.5000, wert_0=-1410.99999799
# Iter 1: mu=25.7500, wert_0=-515.08179707
# Iter 2: mu=13.3750, wert_0=-21.50126133
# ✓ Converged after 24 iterations: mu=11.8468
# Iter 0: mu=50.5000, wert_0=-494.49999763
# Iter 1: mu=25.7500, wert_0=-169.81631205
# Iter 2: mu=13.3750, wert_0=-1.96592097
# ✓ Converged after 22 iterations: mu=12.8442
# Iter 0: mu=50.5000, wert_0=-545.99999109
# Iter 1: mu=25.7500, wert_0=-193.38809276
# Iter 2: mu=13.3750, wert_0=-2.97267884
# ✓ Converged after 21 iterations: mu=12.3778
# Iter 0: mu=50.5000, wert_0=-375.99998189
# Iter 1: mu=25.7500, wert_0=-122.21478074
# Iter 2: mu=13.3750, wert_0=0.19563107
# ✓ Converged after 20 iterations: mu=13.5136
# Iter 0: mu=50.5000, wert_0=-506.99993112
# Iter 1: mu=25.7500, wert_0=-148.49245602
# Iter 2: mu=13.3750, wert_0=1.70295840
# ✓ Converged after 21 iterations: mu=14.7195
# Iter 0: mu=50.5000, wert_0=-270.49989436
# Iter 1: mu=25.7500, wert_0=-86.13895174
# Iter 2: mu=13.3750, wert_0=-0.14255987
# ✓ Converged after 19 iterations: mu=13.0354
# Iter 0: mu=50.5000, wert_0=-578.49944606
# Iter 1: mu=25.7500, wert_0=-133.03584363
# Iter 2: mu=13.3750, wert_0=1.98791278
# ✓ Converged after 19 iterations: mu=16.8333
# Iter 0: mu=50.5000, wert_0=-258.99934820
# Iter 1: mu=25.7500, wert_0=-47.17281589
# Iter 2: mu=13.3750, wert_0=0.89232860
# ✓ Converged after 21 iterations: mu=18.8184
# Iter 0: mu=50.5000, wert_0=-217.99701436
# Iter 1: mu=25.7500, wert_0=-44.14242269
# Iter 2: mu=13.3750, wert_0=0.09092408
# ✓ Converged after 18 iterations: mu=15.7657
# Iter 0: mu=50.5000, wert_0=-57.82748559
# Iter 1: mu=25.7500, wert_0=0.00853363
# Iter 2: mu=38.1250, wert_0=-27.24481819
# ✓ Converged after 19 iterations: mu=25.7737
# Iter 0: mu=50.5000, wert_0=-50.50000000
# Iter 1: mu=25.7500, wert_0=-25.74999998
# Iter 2: mu=13.3750, wert_0=-13.37242352
# ✓ Converged after 23 iterations: mu=4.8203
# Iter 0: mu=50.5000, wert_0=-6390.00000000
# Iter 1: mu=25.7500, wert_0=-3221.99999853
# Iter 2: mu=13.3750, wert_0=-1637.90533841
# ✓ Converged after 27 iterations: mu=2.0395
# Iter 0: mu=50.5000, wert_0=-21548.50000000
# Iter 1: mu=25.7500, wert_0=-10831.74996877
# Iter 2: mu=13.3750, wert_0=-5472.30080186
# ✓ Converged after 25 iterations: mu=1.2417
# Iter 0: mu=50.5000, wert_0=-11731.50000000
# Iter 1: mu=25.7500, wert_0=-5766.74984370
# Iter 2: mu=13.3750, wert_0=-2781.59613719
# ✓ Converged after 27 iterations: mu=2.4910
# Iter 0: mu=50.5000, wert_0=-7878.00000000
# Iter 1: mu=25.7500, wert_0=-3769.49930376
# Iter 2: mu=13.3750, wert_0=-1708.88929582
# ✓ Converged after 23 iterations: mu=3.7598
# Iter 0: mu=50.5000, wert_0=-4319.00000000
# Iter 1: mu=25.7500, wert_0=-2041.99804947
# Iter 2: mu=13.3750, wert_0=-894.06376540
# ✓ Converged after 25 iterations: mu=4.2931
# Iter 0: mu=50.5000, wert_0=-4611.50000000
# Iter 1: mu=25.7500, wert_0=-2161.24097522
# Iter 2: mu=13.3750, wert_0=-912.73958903
# ✓ Converged after 26 iterations: mu=4.7113
# Iter 0: mu=50.5000, wert_0=-4600.00000000
# Iter 1: mu=25.7500, wert_0=-2124.96870697
# Iter 2: mu=13.3750, wert_0=-844.03846063
# ✓ Converged after 22 iterations: mu=5.0083
# Iter 0: mu=50.5000, wert_0=-3246.00000000
# Iter 1: mu=25.7500, wert_0=-1463.92979321
# Iter 2: mu=13.3750, wert_0=-521.81294456
# ✓ Converged after 24 iterations: mu=5.7685
# Iter 0: mu=50.5000, wert_0=-2337.50000000
# Iter 1: mu=25.7500, wert_0=-1025.58411243
# Iter 2: mu=13.3750, wert_0=-307.77639217
# ✓ Converged after 24 iterations: mu=7.2971
# Iter 0: mu=50.5000, wert_0=-2137.49999999
# Iter 1: mu=25.7500, wert_0=-924.37545035
# Iter 2: mu=13.3750, wert_0=-241.75956228
# ✓ Converged after 23 iterations: mu=7.4539
# Iter 0: mu=50.5000, wert_0=-1738.99999996
# Iter 1: mu=25.7500, wert_0=-698.82246029
# Iter 2: mu=13.3750, wert_0=-119.07925649
# ✓ Converged after 25 iterations: mu=9.3923
# Iter 0: mu=50.5000, wert_0=-1086.49999988
# Iter 1: mu=25.7500, wert_0=-417.14338358
# Iter 2: mu=13.3750, wert_0=-37.20624067
# ✓ Converged after 25 iterations: mu=11.3398
# Iter 0: mu=50.5000, wert_0=-1086.49999958
# Iter 1: mu=25.7500, wert_0=-416.24083087
# Iter 2: mu=13.3750, wert_0=-34.99174266
# ✓ Converged after 24 iterations: mu=10.7930
# Iter 0: mu=50.5000, wert_0=-1115.99999847
# Iter 1: mu=25.7500, wert_0=-419.13613362
# Iter 2: mu=13.3750, wert_0=-25.02325869
# ✓ Converged after 22 iterations: mu=11.0328
# Iter 0: mu=50.5000, wert_0=-607.99999020
# Iter 1: mu=25.7500, wert_0=-205.54294255
# Iter 2: mu=13.3750, wert_0=-0.61330189
# ✓ Converged after 23 iterations: mu=13.1925
# Iter 0: mu=50.5000, wert_0=-342.49998187
# Iter 1: mu=25.7500, wert_0=-113.40473093
# Iter 2: mu=13.3750, wert_0=0.53901255
# ✓ Converged after 20 iterations: mu=13.7661
# Iter 0: mu=50.5000, wert_0=-431.99993648
# Iter 1: mu=25.7500, wert_0=-124.14269879
# Iter 2: mu=13.3750, wert_0=2.37622313
# ✓ Converged after 22 iterations: mu=15.4265
# Iter 0: mu=50.5000, wert_0=-585.99978420
# Iter 1: mu=25.7500, wert_0=-169.13691243
# Iter 2: mu=13.3750, wert_0=0.85871956
# ✓ Converged after 22 iterations: mu=14.3263
# Iter 0: mu=50.5000, wert_0=-401.49960690
# Iter 1: mu=25.7500, wert_0=-108.79478359
# Iter 2: mu=13.3750, wert_0=0.50890773
# ✓ Converged after 21 iterations: mu=14.7081
# Iter 0: mu=50.5000, wert_0=-192.99865686
# Iter 1: mu=25.7500, wert_0=-29.33051243
# Iter 2: mu=13.3750, wert_0=0.53076983
# ✓ Converged after 22 iterations: mu=20.1372
# Iter 0: mu=50.5000, wert_0=-11434.50000000
# Iter 1: mu=25.7500, wert_0=-5766.74999809
# Iter 2: mu=13.3750, wert_0=-2932.75225555
# ✓ Converged after 28 iterations: mu=1.5623
# Iter 0: mu=50.5000, wert_0=-18818.50000000
# Iter 1: mu=25.7500, wert_0=-9438.24997110
# Iter 2: mu=13.3750, wert_0=-4747.13617920
# ✓ Converged after 28 iterations: mu=1.4755
# Iter 0: mu=50.5000, wert_0=-11692.00000000
# Iter 1: mu=25.7500, wert_0=-5751.99984401
# Iter 2: mu=13.3750, wert_0=-2779.22299155
# ✓ Converged after 27 iterations: mu=2.4612
# Iter 0: mu=50.5000, wert_0=-5165.50000000
# Iter 1: mu=25.7500, wert_0=-2467.74945662
# Iter 2: mu=13.3750, wert_0=-1113.93824276
# ✓ Converged after 23 iterations: mu=4.2458
# Iter 0: mu=50.5000, wert_0=-5446.50000000
# Iter 1: mu=25.7500, wert_0=-2600.24765702
# Iter 2: mu=13.3750, wert_0=-1165.54035299
# ✓ Converged after 25 iterations: mu=3.7540
# Iter 0: mu=50.5000, wert_0=-4313.00000000
# Iter 1: mu=25.7500, wert_0=-2035.99167668
# Iter 2: mu=13.3750, wert_0=-875.57672242
# ✓ Converged after 26 iterations: mu=4.3796
# Iter 0: mu=50.5000, wert_0=-4472.00000000
# Iter 1: mu=25.7500, wert_0=-2046.46949055
# Iter 2: mu=13.3750, wert_0=-792.35643670
# ✓ Converged after 26 iterations: mu=5.3876
# Iter 0: mu=50.5000, wert_0=-3562.00000000
# Iter 1: mu=25.7500, wert_0=-1581.92047697
# Iter 2: mu=13.3750, wert_0=-536.58185110
# ✓ Converged after 26 iterations: mu=6.4858
# Iter 0: mu=50.5000, wert_0=-2589.50000000
# Iter 1: mu=25.7500, wert_0=-1129.07481356
# Iter 2: mu=13.3750, wert_0=-334.42848410
# ✓ Converged after 25 iterations: mu=7.2859
# Iter 0: mu=50.5000, wert_0=-1595.49999999
# Iter 1: mu=25.7500, wert_0=-679.44729926
# Iter 2: mu=13.3750, wert_0=-163.42705662
# ✓ Converged after 25 iterations: mu=8.3654
# Iter 0: mu=50.5000, wert_0=-1788.99999996
# Iter 1: mu=25.7500, wert_0=-748.79099149
# Iter 2: mu=13.3750, wert_0=-154.54273100
# ✓ Converged after 22 iterations: mu=8.1453
# Iter 0: mu=50.5000, wert_0=-1062.99999990
# Iter 1: mu=25.7500, wert_0=-418.54064196
# Iter 2: mu=13.3750, wert_0=-52.18250245
# ✓ Converged after 24 iterations: mu=10.1296
# Iter 0: mu=50.5000, wert_0=-885.99999959
# Iter 1: mu=25.7500, wert_0=-339.53002233
# Iter 2: mu=13.3750, wert_0=-20.71529937
# ✓ Converged after 25 iterations: mu=11.7371
# Iter 0: mu=50.5000, wert_0=-1151.49999842
# Iter 1: mu=25.7500, wert_0=-429.79348808
# Iter 2: mu=13.3750, wert_0=-24.43235371
# ✓ Converged after 22 iterations: mu=11.1630
# Iter 0: mu=50.5000, wert_0=-616.99999709
# Iter 1: mu=25.7500, wert_0=-217.29926920
# Iter 2: mu=13.3750, wert_0=-4.97496846
# ✓ Converged after 22 iterations: mu=12.2739
# Iter 0: mu=50.5000, wert_0=-671.99998978
# Iter 1: mu=25.7500, wert_0=-219.94422327
# Iter 2: mu=13.3750, wert_0=0.31930621
# ✓ Converged after 23 iterations: mu=13.4636
# Iter 0: mu=50.5000, wert_0=-512.49997436
# Iter 1: mu=25.7500, wert_0=-181.18442470
# Iter 2: mu=13.3750, wert_0=-2.28466206
# ✓ Converged after 20 iterations: mu=12.1788
# Iter 0: mu=50.5000, wert_0=-635.99936556
# Iter 1: mu=25.7500, wert_0=-159.75124848
# Iter 2: mu=13.3750, wert_0=1.61588307
# ✓ Converged after 23 iterations: mu=15.9269
# Iter 0: mu=50.5000, wert_0=-288.49928170
# Iter 1: mu=25.7500, wert_0=-50.95501099
# Iter 2: mu=13.3750, wert_0=1.03474715
# ✓ Converged after 20 iterations: mu=19.0435
# Iter 0: mu=50.5000, wert_0=-199.99877543
# Iter 1: mu=25.7500, wert_0=-36.09620405
# Iter 2: mu=13.3750, wert_0=0.34712096
# ✓ Converged after 20 iterations: mu=18.2892
# Iter 0: mu=50.5000, wert_0=-77.48855420
# Iter 1: mu=25.7500, wert_0=0.61280829
# Iter 2: mu=38.1250, wert_0=-39.03755173
# ✓ Converged after 20 iterations: mu=26.1455
# Iter 0: mu=50.5000, wert_0=-50.50000000
# Iter 1: mu=25.7500, wert_0=-25.74999998
# Iter 2: mu=13.3750, wert_0=-13.37244430
# ✓ Converged after 23 iterations: mu=4.8122
# Iter 0: mu=50.5000, wert_0=-13985.00000000
# Iter 1: mu=25.7500, wert_0=-7054.99999785
# Iter 2: mu=13.3750, wert_0=-3589.86174720
# ✓ Converged after 29 iterations: mu=1.4274
# ...
# Iter 1: mu=25.7500, wert_0=-260.14963434
# Iter 2: mu=13.3750, wert_0=-26.24662616
# ✓ Converged after 24 iterations: mu=10.8763
# Iter 0: mu=50.5000, wert_0=-435.49999930
# Iter 1: mu=25.7500, wert_0=-161.51552232
# Iter 2: mu=13.3750, wert_0=-5.67147324
# ✓ Converged after 19 iterations: mu=12.1749
# Iter 0: mu=50.5000, wert_0=-133.99997870
# Iter 1: mu=25.7500, wert_0=-31.87042504
# Iter 2: mu=13.3750, wert_0=1.85312206
# ✓ Converged after 23 iterations: mu=17.9672
# Iter 0: mu=50.5000, wert_0=-151.50000000
# Iter 1: mu=25.7500, wert_0=-77.24999998
# Iter 2: mu=13.3750, wert_0=-40.12315075
# ✓ Converged after 25 iterations: mu=3.3900
# Iter 0: mu=50.5000, wert_0=-11968.00000000
# Iter 1: mu=25.7500, wert_0=-6027.99999825
# Iter 2: mu=13.3750, wert_0=-3057.88752292
# ✓ Converged after 29 iterations: mu=1.4134
# Iter 0: mu=50.5000, wert_0=-18623.00000000
# Iter 1: mu=25.7500, wert_0=-9316.99997457
# Iter 2: mu=13.3750, wert_0=-4663.13068182
# ✓ Converged after 27 iterations: mu=1.3197
# Iter 0: mu=50.5000, wert_0=-10781.50000000
# Iter 1: mu=25.7500, wert_0=-5262.24986488
# Iter 2: mu=13.3750, wert_0=-2500.24841130
# ✓ Converged after 26 iterations: mu=2.6373
# Iter 0: mu=50.5000, wert_0=-5393.50000000
# Iter 1: mu=25.7500, wert_0=-2596.74953124
# Iter 2: mu=13.3750, wert_0=-1194.04266057
# ✓ Converged after 26 iterations: mu=3.4770
# Iter 0: mu=50.5000, wert_0=-5447.50000000
# Iter 1: mu=25.7500, wert_0=-2601.24773594
# Iter 2: mu=13.3750, wert_0=-1166.90252326
# ✓ Converged after 26 iterations: mu=3.6254
# Iter 0: mu=50.5000, wert_0=-5031.00000000
# Iter 1: mu=25.7500, wert_0=-2357.99091863
# Iter 2: mu=13.3750, wert_0=-997.83032869
# ✓ Converged after 25 iterations: mu=4.4003
# Iter 0: mu=50.5000, wert_0=-3520.00000000
# Iter 1: mu=25.7500, wert_0=-1589.47702657
# Iter 2: mu=13.3750, wert_0=-594.04111705
# ✓ Converged after 22 iterations: mu=5.7218
# Iter 0: mu=50.5000, wert_0=-2894.50000000
# Iter 1: mu=25.7500, wert_0=-1285.68774966
# Iter 2: mu=13.3750, wert_0=-437.86661637
# ✓ Converged after 24 iterations: mu=6.3226
# Iter 0: mu=50.5000, wert_0=-1368.50000000
# Iter 1: mu=25.7500, wert_0=-601.15747642
# Iter 2: mu=13.3750, wert_0=-182.70382545
# ✓ Converged after 24 iterations: mu=7.0272
# Iter 0: mu=50.5000, wert_0=-1488.49999999
# Iter 1: mu=25.7500, wert_0=-622.01012647
# Iter 2: mu=13.3750, wert_0=-145.25381894
# ✓ Converged after 25 iterations: mu=8.2095
# Iter 0: mu=50.5000, wert_0=-1025.49999998
# Iter 1: mu=25.7500, wert_0=-406.35245062
# Iter 2: mu=13.3750, wert_0=-64.03007325
# ✓ Converged after 22 iterations: mu=9.7911
# Iter 0: mu=50.5000, wert_0=-485.99999995
# Iter 1: mu=25.7500, wert_0=-188.54834217
# Iter 2: mu=13.3750, wert_0=-20.54413324
# ✓ Converged after 21 iterations: mu=10.6799
# Iter 0: mu=50.5000, wert_0=-565.99999976
# Iter 1: mu=25.7500, wert_0=-218.36094921
# Iter 2: mu=13.3750, wert_0=-17.26208734
# ✓ Converged after 22 iterations: mu=11.0603
# Iter 0: mu=50.5000, wert_0=-430.49999930
# Iter 1: mu=25.7500, wert_0=-156.55861327
# Iter 2: mu=13.3750, wert_0=-3.85330407
# ✓ Converged after 23 iterations: mu=12.5580
# Iter 0: mu=50.5000, wert_0=-770.99999608
# Iter 1: mu=25.7500, wert_0=-271.05004767
# Iter 2: mu=13.3750, wert_0=-3.97062013
# ✓ Converged after 23 iterations: mu=12.7104
# Iter 0: mu=50.5000, wert_0=-142.99999218
# Iter 1: mu=25.7500, wert_0=-41.54739873
# Iter 2: mu=13.3750, wert_0=1.54180152
# ✓ Converged after 20 iterations: mu=15.8681
# Iter 0: mu=50.5000, wert_0=-505.00000000
# Iter 1: mu=25.7500, wert_0=-257.49999998
# Iter 2: mu=13.3750, wert_0=-133.74796375
# ✓ Converged after 25 iterations: mu=2.2824
# Iter 0: mu=50.5000, wert_0=-14162.00000000
# Iter 1: mu=25.7500, wert_0=-7132.99999813
# Iter 2: mu=13.3750, wert_0=-3618.37945259
# ✓ Converged after 25 iterations: mu=1.2644
# Iter 0: mu=50.5000, wert_0=-17882.50000000
# Iter 1: mu=25.7500, wert_0=-8898.24997550
# Iter 2: mu=13.3750, wert_0=-4405.29541466
# ✓ Converged after 27 iterations: mu=1.5760
# Iter 0: mu=50.5000, wert_0=-9125.00000000
# Iter 1: mu=25.7500, wert_0=-4422.49988157
# Iter 2: mu=13.3750, wert_0=-2069.19365081
# ✓ Converged after 25 iterations: mu=3.0044
# Iter 0: mu=50.5000, wert_0=-4672.50000000
# Iter 1: mu=25.7500, wert_0=-2271.74959569
# Iter 2: mu=13.3750, wert_0=-1067.57112904
# ✓ Converged after 22 iterations: mu=3.0756
# Iter 0: mu=50.5000, wert_0=-7284.00000000
# Iter 1: mu=25.7500, wert_0=-3472.49704183
# Iter 2: mu=13.3750, wert_0=-1552.11742155
# ✓ Converged after 23 iterations: mu=3.6131
# Iter 0: mu=50.5000, wert_0=-3983.00000000
# Iter 1: mu=25.7500, wert_0=-1854.49270709
# Iter 2: mu=13.3750, wert_0=-771.54293490
# ✓ Converged after 25 iterations: mu=4.7173
# Iter 0: mu=50.5000, wert_0=-3571.50000000
# Iter 1: mu=25.7500, wert_0=-1616.22717701
# Iter 2: mu=13.3750, wert_0=-608.40996752
# ✓ Converged after 26 iterations: mu=5.5587
# Iter 0: mu=50.5000, wert_0=-2831.00000000
# Iter 1: mu=25.7500, wert_0=-1246.93947933
# Iter 2: mu=13.3750, wert_0=-413.70198438
# ✓ Converged after 24 iterations: mu=6.6062
# Iter 0: mu=50.5000, wert_0=-1948.50000000
# Iter 1: mu=25.7500, wert_0=-834.62372632
# Iter 2: mu=13.3750, wert_0=-233.58719441
# ✓ Converged after 25 iterations: mu=7.6942
# Iter 0: mu=50.5000, wert_0=-994.50000000
# Iter 1: mu=25.7500, wert_0=-425.08229099
# Iter 2: mu=13.3750, wert_0=-107.46630133
# ✓ Converged after 23 iterations: mu=7.6572
# Iter 0: mu=50.5000, wert_0=-956.49999998
# Iter 1: mu=25.7500, wert_0=-386.85620388
# Iter 2: mu=13.3750, wert_0=-66.34430859
# ✓ Converged after 22 iterations: mu=9.4504
# Iter 0: mu=50.5000, wert_0=-578.99999977
# Iter 1: mu=25.7500, wert_0=-231.36339911
# Iter 2: mu=13.3750, wert_0=-24.81017586
# ✓ Converged after 17 iterations: mu=9.9198
# Iter 0: mu=50.5000, wert_0=-461.99999931
# Iter 1: mu=25.7500, wert_0=-163.35962656
# Iter 2: mu=13.3750, wert_0=-3.20522859
# ✓ Converged after 23 iterations: mu=12.7126
# Iter 0: mu=50.5000, wert_0=-597.49999686
# Iter 1: mu=25.7500, wert_0=-222.09093641
# Iter 2: mu=13.3750, wert_0=-7.25014380
# ✓ Converged after 22 iterations: mu=11.8113
# Iter 0: mu=50.5000, wert_0=-723.49998853
# Iter 1: mu=25.7500, wert_0=-245.65394686
# Iter 2: mu=13.3750, wert_0=-1.40778596
# ✓ Converged after 23 iterations: mu=13.0177
# Iter 0: mu=50.5000, wert_0=-254.49998425
# Iter 1: mu=25.7500, wert_0=-76.19403479
# Iter 2: mu=13.3750, wert_0=3.16431712
# ✓ Converged after 23 iterations: mu=16.0176
# Iter 0: mu=50.5000, wert_0=-215.99996824
# Iter 1: mu=25.7500, wert_0=-62.07134940
# Iter 2: mu=13.3750, wert_0=1.18811156
# ✓ Converged after 22 iterations: mu=15.4265
# Iter 0: mu=50.5000, wert_0=-130.99963674
# Iter 1: mu=25.7500, wert_0=-24.08151950
# Iter 2: mu=13.3750, wert_0=0.50943282
# ✓ Converged after 20 iterations: mu=19.0898
# Iter 0: mu=50.5000, wert_0=-757.50000000
# Iter 1: mu=25.7500, wert_0=-386.24999998
# Iter 2: mu=13.3750, wert_0=-200.62285986
# ✓ Converged after 27 iterations: mu=1.9267
# Iter 0: mu=50.5000, wert_0=-11830.50000000
# Iter 1: mu=25.7500, wert_0=-5964.74999822
# Iter 2: mu=13.3750, wert_0=-3031.76060518
# ✓ Converged after 24 iterations: mu=1.4161
# Iter 0: mu=50.5000, wert_0=-17782.00000000
# Iter 1: mu=25.7500, wert_0=-8871.99997517
# Iter 2: mu=13.3750, wert_0=-4416.15565118
# ✓ Converged after 26 iterations: mu=1.4947
# Iter 0: mu=50.5000, wert_0=-9646.00000000
# Iter 1: mu=25.7500, wert_0=-4695.99987630
# Iter 2: mu=13.3750, wert_0=-2218.83501407
# ✓ Converged after 27 iterations: mu=2.7963
# Iter 0: mu=50.5000, wert_0=-6338.00000000
# Iter 1: mu=25.7500, wert_0=-3070.99945499
# Iter 2: mu=13.3750, wert_0=-1432.40250190
# ✓ Converged after 25 iterations: mu=3.1943
# Iter 0: mu=50.5000, wert_0=-5661.00000000
# Iter 1: mu=25.7500, wert_0=-2690.99771553
# Iter 2: mu=13.3750, wert_0=-1194.76589605
# ✓ Converged after 24 iterations: mu=3.7128
# Iter 0: mu=50.5000, wert_0=-4368.50000000
# Iter 1: mu=25.7500, wert_0=-2017.24153555
# Iter 2: mu=13.3750, wert_0=-820.36524828
# ✓ Converged after 25 iterations: mu=5.2246
# Iter 0: mu=50.5000, wert_0=-3792.00000000
# Iter 1: mu=25.7500, wert_0=-1712.97489479
# Iter 2: mu=13.3750, wert_0=-640.47569675
# ✓ Converged after 25 iterations: mu=5.7603
# Iter 0: mu=50.5000, wert_0=-1689.00000000
# Iter 1: mu=25.7500, wert_0=-748.46335028
# Iter 2: mu=13.3750, wert_0=-252.82010892
# ✓ Converged after 25 iterations: mu=6.4465
# Iter 0: mu=50.5000, wert_0=-1408.00000000
# Iter 1: mu=25.7500, wert_0=-615.91475883
# Iter 2: mu=13.3750, wert_0=-187.87774671
# ✓ Converged after 21 iterations: mu=6.6390
# Iter 0: mu=50.5000, wert_0=-1777.99999999
# Iter 1: mu=25.7500, wert_0=-738.19367696
# Iter 2: mu=13.3750, wert_0=-164.13932635
# ✓ Converged after 24 iterations: mu=8.7125
# Iter 0: mu=50.5000, wert_0=-1140.49999997
# Iter 1: mu=25.7500, wert_0=-471.77896383
# Iter 2: mu=13.3750, wert_0=-90.61776921
# ✓ Converged after 24 iterations: mu=8.7699
# Iter 0: mu=50.5000, wert_0=-822.99999992
# Iter 1: mu=25.7500, wert_0=-327.29022295
# Iter 2: mu=13.3750, wert_0=-45.06449179
# ✓ Converged after 20 iterations: mu=9.5919
# Iter 0: mu=50.5000, wert_0=-507.49999978
# Iter 1: mu=25.7500, wert_0=-184.75870516
# Iter 2: mu=13.3750, wert_0=-7.25624227
# ✓ Converged after 24 iterations: mu=12.3302
# Iter 0: mu=50.5000, wert_0=-623.99999915
# Iter 1: mu=25.7500, wert_0=-225.92586668
# Iter 2: mu=13.3750, wert_0=-9.51165021
# ✓ Converged after 23 iterations: mu=11.8062
# Iter 0: mu=50.5000, wert_0=-350.49999812
# Iter 1: mu=25.7500, wert_0=-125.34425271
# Iter 2: mu=13.3750, wert_0=-1.93708012
# ✓ Converged after 22 iterations: mu=12.6860
# Iter 0: mu=50.5000, wert_0=-149.99959391
# Iter 1: mu=25.7500, wert_0=-39.21029989
# Iter 2: mu=13.3750, wert_0=0.15455381
# ✓ Converged after 19 iterations: mu=15.0906
# Iter 0: mu=50.5000, wert_0=-70.99668476
# Iter 1: mu=25.7500, wert_0=-8.64823176
# Iter 2: mu=13.3750, wert_0=0.08124939
# ✓ Converged after 21 iterations: mu=21.2181
# Iter 0: mu=50.5000, wert_0=-151.50000000
# Iter 1: mu=25.7500, wert_0=-77.24999998
# Iter 2: mu=13.3750, wert_0=-40.12269363
# ✓ Converged after 18 iterations: mu=3.6109
# Iter 0: mu=50.5000, wert_0=-8331.50000000
# Iter 1: mu=25.7500, wert_0=-4198.24999844
# Iter 2: mu=13.3750, wert_0=-2131.52487313
# ✓ Converged after 28 iterations: mu=1.7595
# Iter 0: mu=50.5000, wert_0=-14849.00000000
# Iter 1: mu=25.7500, wert_0=-7423.99997751
# Iter 2: mu=13.3750, wert_0=-3710.73412615
# ✓ Converged after 28 iterations: mu=1.5796
# Iter 0: mu=50.5000, wert_0=-10418.50000000
# Iter 1: mu=25.7500, wert_0=-5097.24986835
# Iter 2: mu=13.3750, wert_0=-2434.29994311
# ✓ Converged after 27 iterations: mu=2.5565
# Iter 0: mu=50.5000, wert_0=-4582.50000000
# Iter 1: mu=25.7500, wert_0=-2181.74956508
# Iter 2: mu=13.3750, wert_0=-977.43995082
# ✓ Converged after 26 iterations: mu=4.1187
# Iter 0: mu=50.5000, wert_0=-6020.50000000
# Iter 1: mu=25.7500, wert_0=-2877.24746241
# Iter 2: mu=13.3750, wert_0=-1293.03591674
# ✓ Converged after 26 iterations: mu=3.6405
# Iter 0: mu=50.5000, wert_0=-4979.50000000
# Iter 1: mu=25.7500, wert_0=-2331.24066804
# Iter 2: mu=13.3750, wert_0=-982.92749712
# ✓ Converged after 25 iterations: mu=4.5890
# Iter 0: mu=50.5000, wert_0=-3596.50000000
# Iter 1: mu=25.7500, wert_0=-1641.22634414
# Iter 2: mu=13.3750, wert_0=-631.66995890
# ✓ Converged after 24 iterations: mu=5.3464
# Iter 0: mu=50.5000, wert_0=-2581.00000000
# Iter 1: mu=25.7500, wert_0=-1145.44320011
# Iter 2: mu=13.3750, wert_0=-388.20792404
# ✓ Converged after 22 iterations: mu=6.4512
# Iter 0: mu=50.5000, wert_0=-1737.00000000
# Iter 1: mu=25.7500, wert_0=-746.87163696
# Iter 2: mu=13.3750, wert_0=-206.69212126
# ✓ Converged after 21 iterations: mu=8.1052
# Iter 0: mu=50.5000, wert_0=-1465.99999999
# Iter 1: mu=25.7500, wert_0=-624.25930226
# Iter 2: mu=13.3750, wert_0=-156.64850853
# ✓ Converged after 23 iterations: mu=7.6508
# Iter 0: mu=50.5000, wert_0=-1250.99999997
# Iter 1: mu=25.7500, wert_0=-507.99602322
# Iter 2: mu=13.3750, wert_0=-90.01947969
# ✓ Converged after 24 iterations: mu=9.2273
# Iter 0: mu=50.5000, wert_0=-1092.49999989
# Iter 1: mu=25.7500, wert_0=-423.25082737
# Iter 2: mu=13.3750, wert_0=-46.35765867
# ✓ Converged after 22 iterations: mu=10.6449
# Iter 0: mu=50.5000, wert_0=-557.99999978
# Iter 1: mu=25.7500, wert_0=-210.45533614
# Iter 2: mu=13.3750, wert_0=-14.97987192
# ✓ Converged after 24 iterations: mu=11.2803
# Iter 0: mu=50.5000, wert_0=-521.49999918
# Iter 1: mu=25.7500, wert_0=-197.70095839
# Iter 2: mu=13.3750, wert_0=-9.94417080
# ✓ Converged after 22 iterations: mu=11.5564
# Iter 0: mu=50.5000, wert_0=-412.49999768
# Iter 1: mu=25.7500, wert_0=-137.45810086
# Iter 2: mu=13.3750, wert_0=2.62223672
# ✓ Converged after 22 iterations: mu=14.1209
# Iter 0: mu=50.5000, wert_0=-298.99999517
# Iter 1: mu=25.7500, wert_0=-97.90953136
# Iter 2: mu=13.3750, wert_0=0.65636006
# ✓ Converged after 22 iterations: mu=13.7661
# Iter 0: mu=50.5000, wert_0=-276.49996052
# Iter 1: mu=25.7500, wert_0=-95.29236619
# Iter 2: mu=13.3750, wert_0=-0.81764588
# ✓ Converged after 19 iterations: mu=12.1528
# Iter 0: mu=50.5000, wert_0=-77.99990086
# Iter 1: mu=25.7500, wert_0=-23.10050992
# Iter 2: mu=13.3750, wert_0=0.16542295
# ✓ Converged after 18 iterations: mu=15.2008
# Iter 0: mu=50.5000, wert_0=-98.49667954
# Iter 1: mu=25.7500, wert_0=-12.22366514
# Iter 2: mu=13.3750, wert_0=0.07284379
# ✓ Converged after 21 iterations: mu=20.0294
# Iter 0: mu=50.5000, wert_0=-252.50000000
# Iter 1: mu=25.7500, wert_0=-128.74999998
# Iter 2: mu=13.3750, wert_0=-66.87304686
# ✓ Converged after 24 iterations: mu=2.9339
# Iter 0: mu=50.5000, wert_0=-10914.50000000
# Iter 1: mu=25.7500, wert_0=-5494.24999831
# Iter 2: mu=13.3750, wert_0=-2784.01613782
# ✓ Converged after 29 iterations: mu=1.5242
# Iter 0: mu=50.5000, wert_0=-14948.50000000
# Iter 1: mu=25.7500, wert_0=-7449.24997795
# Iter 2: mu=13.3750, wert_0=-3698.87776791
# ✓ Converged after 26 iterations: mu=1.6648
# Iter 0: mu=50.5000, wert_0=-10081.00000000
# Iter 1: mu=25.7500, wert_0=-4932.99986988
# Iter 2: mu=13.3750, wert_0=-2356.70240829
# ✓ Converged after 27 iterations: mu=2.6002
# Iter 0: mu=50.5000, wert_0=-5226.00000000
# Iter 1: mu=25.7500, wert_0=-2503.49955059
# Iter 2: mu=13.3750, wert_0=-1138.13315385
# ✓ Converged after 27 iterations: mu=3.6441
# Iter 0: mu=50.5000, wert_0=-5825.50000000
# Iter 1: mu=25.7500, wert_0=-2781.24759912
# Iter 2: mu=13.3750, wert_0=-1247.22265970
# ✓ Converged after 24 iterations: mu=3.6032
# Iter 0: mu=50.5000, wert_0=-4635.00000000
# Iter 1: mu=25.7500, wert_0=-2159.99166344
# Iter 2: mu=13.3750, wert_0=-901.04934269
# ✓ Converged after 25 iterations: mu=4.6165
# Iter 0: mu=50.5000, wert_0=-3625.00000000
# Iter 1: mu=25.7500, wert_0=-1644.97503671
# Iter 2: mu=13.3750, wert_0=-621.84910874
# ✓ Converged after 25 iterations: mu=5.7400
# Iter 0: mu=50.5000, wert_0=-2648.50000000
# Iter 1: mu=25.7500, wert_0=-1188.18805259
# Iter 2: mu=13.3750, wert_0=-413.92630199
# ✓ Converged after 25 iterations: mu=6.3237
# Iter 0: mu=50.5000, wert_0=-1920.00000000
# Iter 1: mu=25.7500, wert_0=-830.87191413
# Iter 2: mu=13.3750, wert_0=-240.19929731
# ✓ Converged after 24 iterations: mu=7.4769
# Iter 0: mu=50.5000, wert_0=-1632.99999999
# Iter 1: mu=25.7500, wert_0=-692.22842640
# Iter 2: mu=13.3750, wert_0=-170.01329309
# ✓ Converged after 24 iterations: mu=7.8739
# Iter 0: mu=50.5000, wert_0=-1145.49999998
# Iter 1: mu=25.7500, wert_0=-476.80235334
# Iter 2: mu=13.3750, wert_0=-96.58757008
# ✓ Converged after 21 iterations: mu=8.2581
# Iter 0: mu=50.5000, wert_0=-793.49999992
# Iter 1: mu=25.7500, wert_0=-322.52009790
# Iter 2: mu=13.3750, wert_0=-48.04602949
# ✓ Converged after 23 iterations: mu=9.2707
# Iter 0: mu=50.5000, wert_0=-725.99999973
# Iter 1: mu=25.7500, wert_0=-279.21262063
# Iter 2: mu=13.3750, wert_0=-25.57067356
# ✓ Converged after 22 iterations: mu=10.4473
# Iter 0: mu=50.5000, wert_0=-261.49999867
# Iter 1: mu=25.7500, wert_0=-86.65963062
# Iter 2: mu=13.3750, wert_0=0.80645986
# ✓ Converged after 21 iterations: mu=13.7635
# Iter 0: mu=50.5000, wert_0=-151.99999730
# Iter 1: mu=25.7500, wert_0=-51.23490816
# Iter 2: mu=13.3750, wert_0=0.36745676
# ✓ Converged after 22 iterations: mu=13.7798
# Iter 0: mu=50.5000, wert_0=-295.99998542
# Iter 1: mu=25.7500, wert_0=-93.09815173
# Iter 2: mu=13.3750, wert_0=0.95079986
# ✓ Converged after 22 iterations: mu=14.2034
# Iter 0: mu=50.5000, wert_0=-330.49995363
# Iter 1: mu=25.7500, wert_0=-99.47403264
# Iter 2: mu=13.3750, wert_0=0.91996217
# ✓ Converged after 22 iterations: mu=14.4730
# Iter 0: mu=50.5000, wert_0=-126.99916547
# Iter 1: mu=25.7500, wert_0=-18.87817758
# Iter 2: mu=13.3750, wert_0=0.33414698
# ✓ Converged after 21 iterations: mu=20.1079
# Successfully estimated μ for 2578 groups

# %%
results = calculate_kpis(df_conrad_uncensored, "Conrad")
# Out:
# Method: Conrad, on Test1/A_20250212_ZQ0.35_ZG0.4_testfile.csv
# - Bias: 0.169 (overestimation)
# - Weighted MAE (α=0): 1.025
# - Weighted MAE (α=0.5): 1.132
# - Weighted MAE (α=1): 1.344
# - Weighted MAE (α=1.5): 1.673
# - Accuracy (exact matches): 0.261
# - Overestimation Rate: 0.471
# - Underestimation Rate: 0.268
# - Gini Coefficient: 0.433
# Overstock: 45203

# %%
df_conrad_uncensored.to_csv(path[:-4] + '_conrad.csv', index=False)

# %%
# # Check mean vs variance by magazine
# print("=== MEAN VS VARIANCE BY MAGAZINE ===")
# good_poisson_count = 0
# total_magazines = 0

# for magazine_id in df['EHASTRA_EH_NUMMER'].unique():
#    mag_data = df[df['EHASTRA_EH_NUMMER'] == magazine_id]['Verkauf']
#    mean_val = mag_data.mean()
#    var_val = mag_data.var()
#    ratio = var_val/mean_val
   
#    if 0.7 <= ratio <= 1.3:
#        good_poisson_count += 1
#    total_magazines += 1
   
#    # print(f"Magazine {magazine_id}: Mean={mean_val:.2f}, Variance={var_val:.2f}, Ratio={ratio:.2f}")

# print(f"\nMagazines with Poisson-like ratio (0.7-1.3): {good_poisson_count}/{total_magazines}")

# # Overall (combined)
# print(f"\nCombined: Mean={df['Verkauf'].mean():.2f}, Variance={df['Verkauf'].var():.2f}, Ratio={df['Verkauf'].var()/df['Verkauf'].mean():.2f}")

# %% [markdown]
# # Nahmias

# %%
import numpy as np
import pandas as pd
from scipy.stats import norm

def compute_mu_sigma_nahmias(sales, S):
    """
    Compute mu and sigma using Nahmias method for censored normal data.
    
    Parameters:
    -----------
    sales : array-like
        Observed sales data (censored at S)
    S : float
        Censoring limit (inventory level)
    
    Returns:
    --------
    tuple: (mu_hat, sigma_hat) or (None, None) if estimation fails
    """
    sales = np.array(sales)
    sales = sales[~np.isnan(sales)]
    
    if len(sales) < 5:  # Need reasonable sample size
        return None, None
    
    # The uncensored observations are those < S
    observed = sales[sales < S]
    n = len(sales)
    r = len(observed)
    
    if r < 2 or r >= n-1:  # Need at least 2 uncensored, 1 censored
        return None, None
        
    p = r / n  # Proportion uncensored
    
    # # Avoid extreme proportions where method is unstable
    # if p < 0.2 or p > 0.8:
    #     return None, None
    
    x_bar = np.mean(observed)
    s2 = np.var(observed, ddof=1)
    
    if s2 <= 1e-6:
        return None, None
    
    try:
        z = norm.ppf(p)
        
        # Check for extreme z values that cause instability
        if abs(z) > 2:
            return None, None
        
        pdf_z = norm.pdf(z)
        
        denominator = 1 - (z * pdf_z / p) - (pdf_z**2 / p**2)
        
        if denominator <= 0.1:  # Need substantial positive denominator
            return None, None
            
        sigma_hat2 = s2 / denominator
        
        if sigma_hat2 <= 0 or sigma_hat2 > 1e6:
            return None, None
            
        sigma_hat = np.sqrt(sigma_hat2)
        mu_hat = x_bar + sigma_hat * pdf_z / p
        
        # Sanity check on estimates
        if abs(mu_hat) > 1e6 or sigma_hat > 1e3:
            return None, None
        
        return mu_hat, sigma_hat
        
    except Exception:
        return None, None

def create_order_specific_nahmias_dict(df):
    """
    Create μ and σ estimates for each (week, order_quantity) combination using Nahmias method.
    Each stockout level gets its own Normal distribution.
    """
    order_specific_mu_dict = {}
    order_specific_sigma_dict = {}

    for (year, week), week_data in df.groupby(['Heftjahr', 'Heftnummer']):
        for bezug_val, group in week_data.groupby('Bezug'):
            n = len(group)
            S = bezug_val
            
            # Count stockouts (sales = order quantity)
            stockouts = (group['Verkauf'] == bezug_val).sum()
            
            if n < 5 or stockouts == 0 or stockouts == n:
                continue  # Not enough variation or unusable

            try:
                mu_est, sigma_est = compute_mu_sigma_nahmias(group['Verkauf'], S)
                if mu_est is not None and sigma_est is not None:
                    # Store with (year, week, order_quantity) key
                    key = (year, week, bezug_val)
                    order_specific_mu_dict[key] = mu_est
                    order_specific_sigma_dict[key] = sigma_est
            except Exception as e:
                print(f"Error in week {week}, Bezug {bezug_val}: {e}")
                continue

    return order_specific_mu_dict, order_specific_sigma_dict

def expected_normal_tail(mu, sigma, S, max_iterations=1000):
    """
    Compute E[X | X >= S] for X ~ Normal(mu, sigma)
    Using numerical integration approximation
    """
    if sigma <= 0:
        return S
    
    # Standardize
    z = (S - mu) / sigma
    
    # If S is way above the mean, just return S (no meaningful tail)
    if z > 6:
        return S
    
    # Use the formula: E[X | X >= S] = mu + sigma * phi(z) / (1 - Phi(z))
    # where phi is PDF and Phi is CDF
    tail_prob = 1 - norm.cdf(z)
    
    if tail_prob < 1e-10:  # Essentially no tail probability
        return S
    
    expected_value = mu + sigma * norm.pdf(z) / tail_prob
    
    return expected_value

def uncensor_dataset_nahmias(df, order_specific_mu_dict, order_specific_sigma_dict):
    """
    Given a DataFrame with Verkauf, Bezug, is_stockout, Heftjahr, Heftnummer,
    replace Verkauf with E[X | X >= Bezug] when censored.
    
    Uses order-quantity-specific Normal(μ, σ) parameters.
    
    Modifies the DataFrame in place by updating the Verkauf column.
    """
    df = df.copy()
    df['Verkauf_Uncensored'] = df['Verkauf'].copy()

    for idx, row in df.iterrows():
        # Skip if no stockout occurred
        if not row['is_stockout']:
            continue
            
        # Get the order-quantity-specific demand parameters
        key = (row['Heftjahr'], row['Heftnummer'], row['Bezug'])
        mu = order_specific_mu_dict.get(key, None)
        sigma = order_specific_sigma_dict.get(key, None)

        if mu is None or sigma is None:
            # no estimate available for this specific (week, order_quantity) — keep original value
            continue

        # POS sold out — uncensor using the specific distribution for this order quantity
        est_demand = expected_normal_tail(mu, sigma, row['Bezug'])
        df.at[idx, 'Verkauf_Uncensored'] = np.round(est_demand)

    return df

# Usage
order_specific_mu_dict, order_specific_sigma_dict = create_order_specific_nahmias_dict(df)
df_nahmias_uncensored = uncensor_dataset_nahmias(df, order_specific_mu_dict, order_specific_sigma_dict)

# %%
df_nahmias_uncensored.to_csv(path[:-4] + '_nahmias.csv', index=False)

# %% [markdown]
# # Testing

# %%
import pandas as pd
import numpy as np

def calculate_kpis(dataframe, method_name):
   """
   Calculate KPIs for demand forecasting evaluation
   
   Parameters:
   - dataframe: pandas DataFrame containing 'Verkauf' (predicted) and 'Verkauf_MBR' (ground truth) columns
   - method_name: string name of the method being evaluated
   - censorship_pct: censorship percentage for display
   - reduction_pct: reduction percentage for display
   - alpha: weight parameter for Weighted MAE (default=1)
            α = 0: standard MAE (no weighting)
            α = 1: linear weighting by true demand
            α > 1: over-proportional penalization of larger errors --> 1.5
            α < 1: emphasis on smaller demands --> 0.5
   """
   df = dataframe.copy()
   censored_df = df[df['Zensiert'] == 1]
   
   # Extract predicted and true values
   y_pred = censored_df['Verkauf_Uncensored'].values  # ŷᵢ (estimated demand)
   y_true = censored_df['Verkauf_MBR'].values  # yᵢ (true demand)
   
   n = len(y_pred)
   
   # 1. Bias calculation
   bias = np.sum(y_pred - y_true) / n
   
   # 2. Accuracy (exact matches)
   exact_matches = np.sum(y_pred == y_true)
   accuracy = exact_matches / n
   
   # 3. Overestimation Rate
   overestimations = np.sum(y_pred > y_true)
   overestimation_rate = overestimations / n
   
   # 4. Underestimation Rate
   underestimations = np.sum(y_pred < y_true)
   underestimation_rate = underestimations / n
   
   # 5. Weighted MAE for different alpha values
   alphas = [0, 0.5, 1, 1.5]
   weighted_maes = {}
   
   for a in alphas:
       if a == 0:
           # Standard MAE (no weighting)
           weighted_maes[a] = np.mean(np.abs(y_pred - y_true))
       else:
           # Weighted MAE with α parameter
           weights = np.power(y_true, a)
           # Handle case where y_true might be 0
           weights = np.where(y_true == 0, 0, weights)
           weighted_maes[a] = np.sum(weights * np.abs(y_pred - y_true)) / np.sum(weights) if np.sum(weights) > 0 else 0
   
   # 6. Gini Coefficient
   abs_errors = np.abs(y_pred - y_true)
   mean_abs_error = np.mean(abs_errors)
   n = len(abs_errors)
   sorted_errors = np.sort(abs_errors)
   
   weighted_sum = 0.0
   total_sum = 0.0

   # 7. Overstock, out of curiosity
   overstock = np.sum(np.maximum(0, y_pred - y_true))
   
   for i in range(n):
       weighted_sum += (i + 1) * sorted_errors[i]
       total_sum += sorted_errors[i]
   
   gini_coefficient = (2 * weighted_sum) / (n * total_sum) - (n + 1) / n
   
   # Determine bias direction
   bias_direction = "overestimation" if bias > 0 else "underestimation" if bias < 0 else "neutral"
   
   # Print results in the specified format
   print(f"Method: {method_name}, on {path}")
   print(f"- Bias: {bias:.3f} ({bias_direction})")
   print(f"- Weighted MAE (α=0): {weighted_maes[0]:.3f}")
   print(f"- Weighted MAE (α=0.5): {weighted_maes[0.5]:.3f}")
   print(f"- Weighted MAE (α=1): {weighted_maes[1]:.3f}")
   print(f"- Weighted MAE (α=1.5): {weighted_maes[1.5]:.3f}")
   print(f"- Accuracy (exact matches): {accuracy:.3f}")
   print(f"- Overestimation Rate: {overestimation_rate:.3f}")
   print(f"- Underestimation Rate: {underestimation_rate:.3f}")
   print(f"- Gini Coefficient: {gini_coefficient:.3f}")
   print(f"Overstock: {int(overstock)}")
   
   return {
       'bias': bias,
       'weighted_mae_0': weighted_maes[0],
       'weighted_mae_0.5': weighted_maes[0.5],
       'weighted_mae_1': weighted_maes[1],
       'weighted_mae_1.5': weighted_maes[1.5],
       'accuracy': accuracy,
       'overestimation_rate': overestimation_rate,
       'underestimation_rate': underestimation_rate,
       'gini_coefficient': gini_coefficient,
       'overstock': overstock
   }

# %%
df['Verkauf_Uncensored'] = df['Verkauf'].copy()
results = calculate_kpis(df, "Baseline")
# Out:
# Method: Baseline, on A_20250212_ZQ0.35_ZG0.4_testfile.csv
# - Bias: -0.953 (underestimation)
# - Weighted MAE (α=0): 0.953
# - Weighted MAE (α=0.5): 1.227
# - Weighted MAE (α=1): 1.625
# - Weighted MAE (α=1.5): 2.143
# - Accuracy (exact matches): 0.404
# - Overestimation Rate: 0.000
# - Underestimation Rate: 0.596
# - Gini Coefficient: 0.578
# Overstock: 0

# %%
results = calculate_kpis(df_n1_uncensored, "N1")
# Out:
# Method: N1, on A_20250212_ZQ0.35_ZG0.4_testfile.csv
# - Bias: -0.480 (underestimation)
# - Weighted MAE (α=0): 1.196
# - Weighted MAE (α=0.5): 1.464
# - Weighted MAE (α=1): 1.847
# - Weighted MAE (α=1.5): 2.368
# - Accuracy (exact matches): 0.308
# - Overestimation Rate: 0.209
# - Underestimation Rate: 0.483
# - Gini Coefficient: 0.524
# Overstock: 27114

# %%
results = calculate_kpis(df_n2_uncensored, "N2")
# Out:
# Method: N2, on A_20250212_ZQ0.35_ZG0.4_testfile.csv
# - Bias: -0.281 (underestimation)
# - Weighted MAE (α=0): 1.273
# - Weighted MAE (α=0.5): 1.495
# - Weighted MAE (α=1): 1.813
# - Weighted MAE (α=1.5): 2.248
# - Accuracy (exact matches): 0.266
# - Overestimation Rate: 0.266
# - Underestimation Rate: 0.468
# - Gini Coefficient: 0.493
# Overstock: 37548

# %%
results = calculate_kpis(df_n3_uncensored, "N3")
# Out:
# Method: N3, on A_20250212_ZQ0.35_ZG0.4_testfile.csv
# - Bias: 0.106 (overestimation)
# - Weighted MAE (α=0): 0.886
# - Weighted MAE (α=0.5): 1.046
# - Weighted MAE (α=1): 1.267
# - Weighted MAE (α=1.5): 1.550
# - Accuracy (exact matches): 0.448
# - Overestimation Rate: 0.266
# - Underestimation Rate: 0.285
# - Gini Coefficient: 0.608
# Overstock: 37548

# %%
results = calculate_kpis(df_em_uncensored, "EM")
# Out:
# Method: EM, on A_20250212_ZQ0.35_ZG0.4_testfile.csv
# - Bias: 1.090 (overestimation)
# - Weighted MAE (α=0): 1.250
# - Weighted MAE (α=0.5): 1.378
# - Weighted MAE (α=1): 1.542
# - Weighted MAE (α=1.5): 1.736
# - Accuracy (exact matches): 0.255
# - Overestimation Rate: 0.686
# - Underestimation Rate: 0.058
# - Gini Coefficient: 0.472
# Overstock: 88579

# %%
results = calculate_kpis(df_projection_uncensored, "PD")
# Out:
# Method: PD, on A_20250212_ZQ0.35_ZG0.4_testfile.csv
# - Bias: 0.043 (overestimation)
# - Weighted MAE (α=0): 1.068
# - Weighted MAE (α=0.5): 1.212
# - Weighted MAE (α=1): 1.424
# - Weighted MAE (α=1.5): 1.701
# - Accuracy (exact matches): 0.386
# - Overestimation Rate: 0.225
# - Underestimation Rate: 0.389
# - Gini Coefficient: 0.599
# Overstock: 42038

# %%
results = calculate_kpis(df_nahmias_uncensored, "Nahmias, Hierarchical")
# Out:
# Method: Nahmias, Hierarchical, on A_20250212_ZQ0.35_ZG0.4_testfile.csv
# - Bias: -0.500 (underestimation)
# - Weighted MAE (α=0): 0.872
# - Weighted MAE (α=0.5): 1.057
# - Weighted MAE (α=1): 1.341
# - Weighted MAE (α=1.5): 1.734
# - Accuracy (exact matches): 0.346
# - Overestimation Rate: 0.171
# - Underestimation Rate: 0.483
# - Gini Coefficient: 0.485
# Overstock: 14069

# %%
results = calculate_kpis(df_conrad_uncensored, "Conrad, Hierarchical")
# Out:
# Method: Conrad, Hierarchical, on A_20250212_ZQ0.35_ZG0.4_testfile.csv
# - Bias: 0.356 (overestimation)
# - Weighted MAE (α=0): 1.135
# - Weighted MAE (α=0.5): 1.269
# - Weighted MAE (α=1): 1.531
# - Weighted MAE (α=1.5): 1.950
# - Accuracy (exact matches): 0.293
# - Overestimation Rate: 0.504
# - Underestimation Rate: 0.204
# - Gini Coefficient: 0.464
# Overstock: 56454

# %%
df_n3_uncensored.to_csv(path[:-4] + '_n3.csv', index=False)
df_n2_uncensored.to_csv(path[:-4] + '_n2.csv', index=False)
df_n1_uncensored.to_csv(path[:-4] + '_n1.csv', index=False)
df_em_uncensored.to_csv(path[:-4] + '_em.csv', index=False)
df_projection_uncensored.to_csv(path[:-4] + '_pd.csv', index=False)
df_conrad_uncensored.to_csv(path[:-4] + '_conrad.csv', index=False)
df_nahmias_uncensored.to_csv(path[:-4] + '_nahmias.csv', index=False)

# %% [markdown]
# # Conrad, No Grouping

# %%
from scipy.stats import poisson
import pandas as pd
import numpy as np

def compute_mu(left, right, n, N, r, x_sum, value_tol=0.01, interval_tol=0.01, max_iterations=1000000000000000):
    iteration = 0

    while iteration < max_iterations and (right - left) > interval_tol:
        mu = (left + right) / 2
        value_0 = (x_sum - mu * n) * (1 - poisson.cdf(N - 1, mu)) + mu * (n - r) * (1 - poisson.cdf(N - 2, mu))

        # if iteration % 10 == 0:
        #     # print(f"Iteration {iteration}: mu={mu:.4f}, value_0={value_0:.6f}")

        if abs(value_0) < value_tol:
            return mu

        if value_0 < 0:
            right = mu
        else:
            left = mu

        iteration += 1

    # print(f"Stopped after {iteration} iterations: mu={mu:.4f}, value_0={value_0:.6f}")
    return mu


def create_order_specific_mu_dict(df):
    """
    Create μ estimates for each order_quantity combination using Conrad's method.
    Each stockout level gets its own Poisson distribution across the entire dataset.
    """
    order_specific_mu_dict = {}
    total_skipped = 0

    for bezug_val, group in df.groupby('Bezug'):
        n = len(group)
        N = bezug_val
        r = (group['Verkauf'] == bezug_val).sum()  # stockouts
        x_sum = np.minimum(group['Verkauf'], N).sum()

        if n < 2:
            # total_skipped += 1
            # print(f"Skipping: n={n} too small")
            continue
        if r == 0:
            # total_skipped += 1
            # print(f"Skipping: no stockouts in group")
            continue
        if r == n:
            # total_skipped += 1
            # print(f"Skipping: all stockouts in group")
            continue
        
        # bounds are problematic
        try:
            mu_est = compute_mu(0.1, 4, n, N, r, x_sum)
            if mu_est:
                # Store with just order_quantity key
                key = bezug_val
                order_specific_mu_dict[key] = mu_est
        except Exception as e:
            # print(f"Error in Bezug {N}: {e}")
            continue
    #print(f"total skipped: {total_skipped}")

    return order_specific_mu_dict

def expected_poisson_tail(mu, N, max_k=200):
    """
    Compute E[X | X >= N] for X ~ Poisson(mu)
    """
    k_vals = np.arange(N, max_k)
    pmf = poisson.pmf(k_vals, mu)
    tail_prob = 1 - poisson.cdf(N - 1, mu)
    if tail_prob < 1e-8:
        return N  # fallback: don't uncensor
    return np.sum(k_vals * pmf) / tail_prob

def uncensor_dataset(df, order_specific_mu_dict):
    """
    Given a DataFrame with Verkauf, Bezug, is_stockout, Heftjahr, Heftnummer,
    replace Verkauf with E[X | X >= Bezug] when censored.
    
    Uses order-quantity-specific Poisson(μ) parameters.
    
    Modifies the DataFrame in place by updating the Verkauf column.
    """
    df = df.copy()

    df['Verkauf_Uncensored'] = df['Verkauf'].copy()

    for idx, row in df.iterrows():
        # Skip if no stockout occurred
        if not row['is_stockout']:
            continue
            
        # Get the order-quantity-specific demand parameter
        key = row['Bezug']
        mu = order_specific_mu_dict.get(key, None)

        if mu is None:
            # no estimate available for this specific order_quantity — keep original value
            continue

        # POS sold out — uncensor using the specific distribution for this order quantity
        est_demand = expected_poisson_tail(mu, row['Bezug'])
        df.at[idx, 'Verkauf_Uncensored'] = np.round(est_demand)

    return df

# Usage
order_specific_mu_dict = create_order_specific_mu_dict(df)
df_conrad_uncensored_ng = uncensor_dataset(df, order_specific_mu_dict)
results = calculate_kpis(df_conrad_uncensored_ng, "Conrad, No Grouping, Altered")
# Out:
# Method: Conrad, No Grouping, Altered, on A_20250212_ZQ0.35_ZG0.4_testfile.csv
# - Bias: 0.481 (overestimation)
# - Weighted MAE (α=0): 1.132
# - Weighted MAE (α=0.5): 1.268
# - Weighted MAE (α=1): 1.531
# - Weighted MAE (α=1.5): 1.950
# - Accuracy (exact matches): 0.334
# - Overestimation Rate: 0.526
# - Underestimation Rate: 0.140
# - Gini Coefficient: 0.490
# Overstock: 61050

# %% [markdown]
# # Nahmias, No Grouping

# %%
import numpy as np
import pandas as pd
from scipy.stats import norm

def compute_mu_sigma_nahmias(sales, S):
    """
    Compute mu and sigma using Nahmias method for censored normal data.
    
    Parameters:
    -----------
    sales : array-like
        Observed sales data (censored at S)
    S : float
        Censoring limit (inventory level)
    
    Returns:
    --------
    tuple: (mu_hat, sigma_hat) or (None, None) if estimation fails
    """
    sales = np.array(sales)
    sales = sales[~np.isnan(sales)]
    
    if len(sales) < 5:  # Need reasonable sample size
        return None, None
    
    # The uncensored observations are those < S
    observed = sales[sales < S]
    n = len(sales)
    r = len(observed)
    
    if r < 2 or r >= n-1:  # Need at least 2 uncensored, 1 censored
        return None, None
        
    p = r / n  # Proportion uncensored
    
    # # Avoid extreme proportions where method is unstable
    # if p < 0.2 or p > 0.8:
    #     return None, None
    
    x_bar = np.mean(observed)
    s2 = np.var(observed, ddof=1)
    
    if s2 <= 1e-6:
        return None, None
    
    try:
        z = norm.ppf(p)
        
        # Check for extreme z values that cause instability
        if abs(z) > 2:
            return None, None
        
        pdf_z = norm.pdf(z)
        
        denominator = 1 - (z * pdf_z / p) - (pdf_z**2 / p**2)
        
        if denominator <= 0.1:  # Need substantial positive denominator
            return None, None
            
        sigma_hat2 = s2 / denominator
        
        if sigma_hat2 <= 0 or sigma_hat2 > 1e6:
            return None, None
            
        sigma_hat = np.sqrt(sigma_hat2)
        mu_hat = x_bar + sigma_hat * pdf_z / p
        
        # Sanity check on estimates
        if abs(mu_hat) > 1e6 or sigma_hat > 1e3:
            return None, None
        
        return mu_hat, sigma_hat
        
    except Exception:
        return None, None

def create_order_specific_nahmias_dict(df):
    """
    Create μ and σ estimates for each order_quantity combination using Nahmias method.
    Each stockout level gets its own Normal distribution across the entire dataset.
    """
    order_specific_mu_dict = {}
    order_specific_sigma_dict = {}

    for bezug_val, group in df.groupby('Bezug'):
        n = len(group)
        S = bezug_val
        
        # Count stockouts (sales = order quantity)
        stockouts = (group['Verkauf'] == bezug_val).sum()
        
        if n < 5 or stockouts == 0 or stockouts == n:
            continue  # Not enough variation or unusable

        try:
            mu_est, sigma_est = compute_mu_sigma_nahmias(group['Verkauf'], S)
            if mu_est is not None and sigma_est is not None:
                # Store with just order_quantity key
                key = bezug_val
                order_specific_mu_dict[key] = mu_est
                order_specific_sigma_dict[key] = sigma_est
        except Exception as e:
            print(f"Error in Bezug {bezug_val}: {e}")
            continue

    return order_specific_mu_dict, order_specific_sigma_dict

def expected_normal_tail(mu, sigma, S, max_iterations=1000):
    """
    Compute E[X | X >= S] for X ~ Normal(mu, sigma)
    Using numerical integration approximation
    """
    if sigma <= 0:
        return S
    
    # Standardize
    z = (S - mu) / sigma
    
    # If S is way above the mean, just return S (no meaningful tail)
    if z > 6:
        return S
    
    # Use the formula: E[X | X >= S] = mu + sigma * phi(z) / (1 - Phi(z))
    # where phi is PDF and Phi is CDF
    tail_prob = 1 - norm.cdf(z)
    
    if tail_prob < 1e-10:  # Essentially no tail probability
        return S
    
    expected_value = mu + sigma * norm.pdf(z) / tail_prob
    
    return expected_value

def uncensor_dataset_nahmias(df, order_specific_mu_dict, order_specific_sigma_dict):
    """
    Given a DataFrame with Verkauf, Bezug, is_stockout, Heftjahr, Heftnummer,
    replace Verkauf with E[X | X >= Bezug] when censored.
    
    Uses order-quantity-specific Normal(μ, σ) parameters.
    
    Modifies the DataFrame in place by updating the Verkauf column.
    """
    df = df.copy()
    df['Verkauf_Uncensored'] = df['Verkauf'].copy()

    for idx, row in df.iterrows():
        # Skip if no stockout occurred
        if not row['is_stockout']:
            continue
            
        # Get the order-quantity-specific demand parameters
        key = row['Bezug']
        mu = order_specific_mu_dict.get(key, None)
        sigma = order_specific_sigma_dict.get(key, None)

        if mu is None or sigma is None:
            # no estimate available for this specific order_quantity — keep original value
            continue

        # POS sold out — uncensor using the specific distribution for this order quantity
        est_demand = expected_normal_tail(mu, sigma, row['Bezug'])
        df.at[idx, 'Verkauf_Uncensored'] = np.round(est_demand)

    return df

# Usage
order_specific_mu_dict, order_specific_sigma_dict = create_order_specific_nahmias_dict(df)
df_nahmias_uncensored_ng = uncensor_dataset_nahmias(df, order_specific_mu_dict, order_specific_sigma_dict)
results = calculate_kpis(df_nahmias_uncensored_ng, "Nahmias, No Grouping")
# Out:
# Method: Nahmias, No Grouping, on A_20250212_ZQ0.35_ZG0.4_testfile.csv
# - Bias: -0.565 (underestimation)
# - Weighted MAE (α=0): 0.852
# - Weighted MAE (α=0.5): 1.034
# - Weighted MAE (α=1): 1.295
# - Weighted MAE (α=1.5): 1.639
# - Accuracy (exact matches): 0.364
# - Overestimation Rate: 0.132
# - Underestimation Rate: 0.504
# - Gini Coefficient: 0.498
# Overstock: 10892

# %% [markdown]
# # Grouping by POS Testing

# %%
import pandas as pd
import numpy as np

def calculate_kpis_grouped_by_pos(df, method_name):
    """
    Calculate KPIs per POS (EHASTRA_EH_NUMMER), then average across POS.
    
    Parameters:
    - df: DataFrame with 'Verkauf_Uncensored', 'Verkauf_MBR', 'Zensiert', 'EHASTRA_EH_NUMMER'
    - method_name: Name of the method for display
    
    Returns:
    - Dictionary of averaged KPIs
    """
    kpi_list = []

    grouped = df[df['Zensiert'] == 1].groupby('EHASTRA_EH_NUMMER')

    for _, group in grouped:
        y_pred = group['Verkauf_Uncensored'].values
        y_true = group['Verkauf_MBR'].values

        if len(y_pred) == 0:
            continue

        n = len(y_pred)
        bias = np.sum(y_pred - y_true) / n
        accuracy = np.mean(y_pred == y_true)
        over_rate = np.mean(y_pred > y_true)
        under_rate = np.mean(y_pred < y_true)

        weighted_maes = {}
        alphas = [0, 0.5, 1, 1.5]
        for a in alphas:
            if a == 0:
                weighted_maes[a] = np.mean(np.abs(y_pred - y_true))
            else:
                weights = np.power(y_true, a)
                weights = np.where(y_true == 0, 0, weights)
                weighted_maes[a] = (
                    np.sum(weights * np.abs(y_pred - y_true)) / np.sum(weights)
                    if np.sum(weights) > 0 else 0
                )

        abs_errors = np.abs(y_pred - y_true)
        sorted_errors = np.sort(abs_errors)
        n_err = len(abs_errors)
        weighted_sum = np.sum((np.arange(1, n_err + 1)) * sorted_errors)
        total_sum = np.sum(sorted_errors)
        gini = (2 * weighted_sum) / (n_err * total_sum) - (n_err + 1) / n_err if total_sum > 0 else 0

        overstock = np.sum(np.maximum(0, y_pred - y_true))

        kpi_list.append({
            'bias': bias,
            'weighted_mae_0': weighted_maes[0],
            'weighted_mae_0.5': weighted_maes[0.5],
            'weighted_mae_1': weighted_maes[1],
            'weighted_mae_1.5': weighted_maes[1.5],
            'accuracy': accuracy,
            'overestimation_rate': over_rate,
            'underestimation_rate': under_rate,
            'gini_coefficient': gini,
            'overstock': overstock
        })

    kpi_df = pd.DataFrame(kpi_list)
    avg_kpis = kpi_df.mean().to_dict()

    print(f"Method: {method_name} (averaged over {len(kpi_list)} POS)")
    print(f"- Bias: {avg_kpis['bias']:.3f}")
    print(f"- Weighted MAE (α=0): {avg_kpis['weighted_mae_0']:.3f}")
    print(f"- Weighted MAE (α=0.5): {avg_kpis['weighted_mae_0.5']:.3f}")
    print(f"- Weighted MAE (α=1): {avg_kpis['weighted_mae_1']:.3f}")
    print(f"- Weighted MAE (α=1.5): {avg_kpis['weighted_mae_1.5']:.3f}")
    print(f"- Accuracy (exact matches): {avg_kpis['accuracy']:.3f}")
    print(f"- Overestimation Rate: {avg_kpis['overestimation_rate']:.3f}")
    print(f"- Underestimation Rate: {avg_kpis['underestimation_rate']:.3f}")
    print(f"- Gini Coefficient: {avg_kpis['gini_coefficient']:.3f}")
    print(f"- Overstock: {int(avg_kpis['overstock'])}")

    return avg_kpis

# %% [markdown]
# # Clausen & Larsen

# %%
import pandas as pd
import numpy as np
from scipy import stats
from scipy.optimize import minimize_scalar, minimize
import warnings
warnings.filterwarnings('ignore')

class ClausenLarsenParameterEstimator:
    """
    Clausen & Larsen parameter estimation for uncensoring censored demand data.
    Uses only the exploration/estimation portion of their algorithm.
    """
    
    def __init__(self, distribution='poisson'):
        """
        Initialize the parameter estimator
        
        Parameters:
        - distribution: 'poisson' or 'negative_binomial'
        """
        self.distribution = distribution
        
    def _poisson_log_likelihood_censored(self, lam, uncensored_obs, censored_obs, censoring_thresholds):
        """
        Log-likelihood function for Poisson with censored observations
        
        Parameters:
        - lam: Poisson parameter (λ)
        - uncensored_obs: array of uncensored demand observations
        - censored_obs: array of censored sales observations  
        - censoring_thresholds: array of order quantities that caused censoring
        """
        if lam <= 0:
            return -np.inf
            
        ll = 0
        
        # Uncensored observations: sum of log(f(x_i))
        if len(uncensored_obs) > 0:
            ll += np.sum(stats.poisson.logpmf(uncensored_obs, lam))
        
        # Censored observations: sum of log(1 - F(threshold_i - 1))
        if len(censored_obs) > 0:
            for threshold in censoring_thresholds:
                # P(D >= threshold) = 1 - P(D <= threshold-1)
                prob_less_than_threshold = stats.poisson.cdf(threshold - 1, lam)
                prob_geq_threshold = 1 - prob_less_than_threshold
                
                if prob_geq_threshold > 0:
                    ll += np.log(prob_geq_threshold)
                else:
                    return -np.inf
                    
        return ll
    
    def _negative_binomial_log_likelihood_censored(self, params, uncensored_obs, censored_obs, censoring_thresholds):
        """
        Log-likelihood function for Negative Binomial with censored observations
        
        Parameters:
        - params: [r, p] where r > 0 and 0 < p < 1
        - uncensored_obs: array of uncensored demand observations
        - censored_obs: array of censored sales observations
        - censoring_thresholds: array of order quantities that caused censoring
        """
        r, p = params
        if r <= 0 or p <= 0 or p >= 1:
            return -np.inf
            
        ll = 0
        
        # Uncensored observations
        if len(uncensored_obs) > 0:
            ll += np.sum(stats.nbinom.logpmf(uncensored_obs, r, p))
        
        # Censored observations
        if len(censored_obs) > 0:
            for threshold in censoring_thresholds:
                prob_less_than_threshold = stats.nbinom.cdf(threshold - 1, r, p)
                prob_geq_threshold = 1 - prob_less_than_threshold
                
                if prob_geq_threshold > 0:
                    ll += np.log(prob_geq_threshold)
                else:
                    return -np.inf
                    
        return ll
    
    def estimate_parameters(self, sales_data, censored_indicators, order_quantities=None):
        """
        Estimate distribution parameters using MLE with censored data
        
        Parameters:
        - sales_data: array of observed sales
        - censored_indicators: binary array (1 = censored, 0 = uncensored)
        - order_quantities: array of order quantities (if None, assume sales = order qty for censored obs)
        
        Returns:
        - Estimated parameters
        """
        
        # Separate uncensored and censored observations
        uncensored_mask = (censored_indicators == 0)
        censored_mask = (censored_indicators == 1)
        
        uncensored_obs = sales_data[uncensored_mask]
        censored_obs = sales_data[censored_mask]
        
        # Determine censoring thresholds
        if order_quantities is not None:
            censoring_thresholds = order_quantities[censored_mask]
        else:
            # Assume sales = order quantity for censored observations
            censoring_thresholds = censored_obs.copy()
        
        print(f"    Uncensored observations: {len(uncensored_obs)}")
        print(f"    Censored observations: {len(censored_obs)}")
        
        if len(uncensored_obs) == 0 and len(censored_obs) == 0:
            return None
        
        try:
            if self.distribution == 'poisson':
                return self._estimate_poisson_parameters(uncensored_obs, censored_obs, censoring_thresholds)
            elif self.distribution == 'negative_binomial':
                return self._estimate_negative_binomial_parameters(uncensored_obs, censored_obs, censoring_thresholds)
        except Exception as e:
            print(f"    Parameter estimation error: {e}")
            return None
    
    def _estimate_poisson_parameters(self, uncensored_obs, censored_obs, censoring_thresholds):
        """Estimate Poisson λ parameter"""
        
        # Initial guess
        if len(uncensored_obs) > 0:
            initial_lambda = max(0.1, np.mean(uncensored_obs))
        else:
            initial_lambda = max(0.1, np.mean(censoring_thresholds))
        
        # Set bounds
        max_val = max(
            np.max(uncensored_obs) if len(uncensored_obs) > 0 else 0,
            np.max(censoring_thresholds) if len(censoring_thresholds) > 0 else 0
        )
        bounds = (0.1, max(max_val * 3, 10))
        
        # Optimize
        result = minimize_scalar(
            lambda lam: -self._poisson_log_likelihood_censored(
                lam, uncensored_obs, censored_obs, censoring_thresholds
            ),
            bounds=bounds,
            method='bounded'
        )
        
        if result.success:
            return max(0.1, result.x)
        else:
            return initial_lambda
    
    def _estimate_negative_binomial_parameters(self, uncensored_obs, censored_obs, censoring_thresholds):
        """Estimate Negative Binomial [r, p] parameters"""
        
        # Method of moments for initial estimates
        if len(uncensored_obs) > 0:
            sample_mean = np.mean(uncensored_obs)
            sample_var = np.var(uncensored_obs) if len(uncensored_obs) > 1 else sample_mean * 2
        else:
            sample_mean = np.mean(censoring_thresholds)
            sample_var = sample_mean * 2  # Rough guess
        
        # Convert to negative binomial parameters
        if sample_var > sample_mean:
            p_init = sample_mean / sample_var
            r_init = sample_mean * p_init / (1 - p_init)
        else:
            # Handle case where variance <= mean
            p_init = 0.5
            r_init = sample_mean
        
        # Ensure bounds
        p_init = max(0.01, min(0.99, p_init))
        r_init = max(0.1, r_init)
        
        # Optimize
        result = minimize(
            lambda params: -self._negative_binomial_log_likelihood_censored(
                params, uncensored_obs, censored_obs, censoring_thresholds
            ),
            x0=[r_init, p_init],
            bounds=[(0.1, 100), (0.01, 0.99)],
            method='L-BFGS-B'
        )
        
        if result.success:
            return result.x
        else:
            return [r_init, p_init]
    
    def generate_uncensored_demand(self, censored_sales, estimated_params, censoring_thresholds=None):
        if censoring_thresholds is None:
            censoring_thresholds = censored_sales.copy()
        
        uncensored_demands = []
        max_k = 200  # cap for the tail sum

        for threshold in censoring_thresholds:
            k_vals = np.arange(threshold, threshold + max_k)

            if self.distribution == 'poisson':
                lam = estimated_params
                pmf_vals = stats.poisson.pmf(k_vals, lam)
                numerator = np.sum(k_vals * pmf_vals)
                denominator = 1 - stats.poisson.cdf(threshold - 1, lam)

            elif self.distribution == 'negative_binomial':
                r, p = estimated_params
                pmf_vals = stats.nbinom.pmf(k_vals, r, p)
                numerator = np.sum(k_vals * pmf_vals)
                denominator = 1 - stats.nbinom.cdf(threshold - 1, r, p)

            # Compute expected value conditional on being >= threshold
            if denominator > 0:
                expected_demand = numerator / denominator
            else:
                expected_demand = threshold  # fallback to threshold if weird case

            uncensored_demands.append(expected_demand)
        
        return np.array(uncensored_demands)


class ClausenLarsenUncensoring:
    """
    Main interface for Clausen & Larsen parameter estimation and uncensoring
    """
    
    def __init__(self, distribution='poisson', min_observations=10):
        """
        Initialize the uncensoring model
        
        Parameters:
        - distribution: 'poisson' or 'negative_binomial'
        - min_observations: minimum observations needed per store
        """
        self.distribution = distribution
        self.min_observations = min_observations
        
    def _create_time_key(self, df):
        """Create a proper time ordering key from year and week"""
        return df['Heftjahr'] * 100 + df['Heftnummer']
    
    def fit_and_uncensor(self, df):
        """
        Main method to uncensor demand data using Clausen & Larsen parameter estimation
        """
        df_result = df.copy()
        df_result['Verkauf_Uncensored'] = df_result['Verkauf'].copy()
        
        estimation_results = {}
        
        # Process each point of sale separately
        for pos in df['EHASTRA_EH_NUMMER'].unique():
            print(f"Processing Point of Sale: {pos}")
            
            pos_data = df[df['EHASTRA_EH_NUMMER'] == pos].copy()
            
            # Check if we have enough data
            if len(pos_data) < self.min_observations:
                print(f"  Skipping POS {pos}: insufficient data ({len(pos_data)} obs, need {self.min_observations})")
                continue
            
            # Sort by time
            pos_data['time_key'] = self._create_time_key(pos_data)
            pos_data = pos_data.sort_values('time_key')
            
            censored_count = (pos_data['Zensiert'] == 1).sum()
            uncensored_count = (pos_data['Zensiert'] == 0).sum()
            
            print(f"  Total observations: {len(pos_data)}")
            print(f"  Uncensored: {uncensored_count}, Censored: {censored_count}")
            
            if censored_count == 0:
                print(f"  No censoring detected for POS {pos}")
                continue
            
            try:
                # Initialize parameter estimator
                estimator = ClausenLarsenParameterEstimator(distribution=self.distribution)
                
                # Estimate parameters
                sales_data = pos_data['Verkauf'].values
                censored_indicators = pos_data['Zensiert'].values
                
                estimated_params = estimator.estimate_parameters(
                    sales_data, 
                    censored_indicators
                )
                
                if estimated_params is not None:
                    print(f"  Estimated parameters: {estimated_params}")
                    
                    # Generate uncensored demands for censored observations
                    censored_mask = pos_data['Zensiert'] == 1
                    if censored_mask.sum() > 0:
                        censored_sales = pos_data[censored_mask]['Verkauf'].values
                        
                        uncensored_demands = estimator.generate_uncensored_demand(
                            censored_sales, 
                            estimated_params
                        )
                        
                        # Update results
                        df_result.loc[pos_data[censored_mask].index, 'Verkauf_Uncensored'] = \
                            uncensored_demands
                        
                        avg_increase = (uncensored_demands - censored_sales).mean()
                        total_increase = (uncensored_demands - censored_sales).sum()
                        
                        print(f"  Average demand increase per censored observation: {avg_increase:.2f}")
                        print(f"  Total estimated lost sales: {total_increase:.0f}")
                        
                        # Store results
                        estimation_results[pos] = {
                            'distribution': self.distribution,
                            'estimated_params': estimated_params,
                            'censored_observations': censored_count,
                            'uncensored_observations': uncensored_count,
                            'avg_increase_per_censored': avg_increase,
                            'total_lost_sales': total_increase
                        }
                else:
                    print(f"  Failed to estimate parameters for POS {pos}")
                    
            except Exception as e:
                print(f"  Error processing POS {pos}: {str(e)}")
                continue
        
        return df_result, estimation_results


def uncensor_demand_data_clausen_larsen(df, distribution='poisson', min_observations=10):
    """
    Main function for Clausen & Larsen parameter estimation and uncensoring
    
    Parameters:
    - df: DataFrame with columns 'Verkauf', 'Zensiert', 'Heftnummer', 'eftjahr', 'EHASTRA_EH_NUMMER'
    - distribution: 'poisson' or 'negative_binomial' 
    - min_observations: minimum observations needed per store
    
    Returns:
    - Tuple: (uncensored_df, estimation_results_dict)
    """
    
    print(f"Starting Clausen & Larsen parameter estimation for uncensoring")
    print(f"Distribution: {distribution}")
    print(f"Minimum observations per store: {min_observations}")
    print(f"Data shape: {df.shape}")
    print(f"Unique points of sale: {df['EHASTRA_EH_NUMMER'].nunique()}")
    print(f"Total censored observations: {(df['Zensiert'] == 1).sum()}")
    print()
    
    # Validate required columns
    required_cols = ['Verkauf', 'Zensiert', 'Heftnummer', 'Heftjahr', 'EHASTRA_EH_NUMMER']
    missing_cols = [col for col in required_cols if col not in df.columns]
    if missing_cols:
        raise ValueError(f"Missing required columns: {missing_cols}")
    
    # Initialize and run the uncensoring model
    model = ClausenLarsenUncensoring(
        distribution=distribution,
        min_observations=min_observations
    )
    
    result_df, estimation_results = model.fit_and_uncensor(df)
    
    print("\nUncensoring complete!")
    print(f"Original total sales: {df['Verkauf'].sum()}")
    print(f"Uncensored total demand: {result_df['Verkauf_Uncensored'].sum()}")
    print(f"Estimated total lost sales: {result_df['Verkauf_Uncensored'].sum() - df['Verkauf'].sum()}")
    
    # Summary statistics
    processed_stores = len(estimation_results)
    if processed_stores > 0:
        avg_params = {}
        if distribution == 'poisson':
            lambdas = [results['estimated_params'] for results in estimation_results.values()]
            avg_params['average_lambda'] = np.mean(lambdas)
        elif distribution == 'negative_binomial':
            r_values = [results['estimated_params'][0] for results in estimation_results.values()]
            p_values = [results['estimated_params'][1] for results in estimation_results.values()]
            avg_params['average_r'] = np.mean(r_values)
            avg_params['average_p'] = np.mean(p_values)
        
        print(f"Processed {processed_stores} stores successfully")
        print(f"Average estimated parameters: {avg_params}")
    
    return result_df, estimation_results

# Example usage:
# uncensored_df, estimation_results = uncensor_demand_data_clausen_larsen(
#     your_df, 
#     distribution='poisson',
#     min_observations=10
# )

# %%
df_clausen_uncensored = uncensor_demand_data_clausen_larsen(df, distribution='negative_binomial')
# Out:
# Starting Clausen & Larsen parameter estimation for uncensoring
# Distribution: negative_binomial
# Minimum observations per store: 10
# Data shape: (277894, 21)
# Unique points of sale: 3053
# Total censored observations: 75700
#
# Processing Point of Sale: EHA0017186
#   Total observations: 36
#   Uncensored: 35, Censored: 1
#     Uncensored observations: 35
#     Censored observations: 1
#   Estimated parameters: [11.2142254  0.99     ]
#   Average demand increase per censored observation: 0.06
#   Total estimated lost sales: 0
# Processing Point of Sale: EHA0021360
#   Total observations: 10
#   Uncensored: 10, Censored: 0
#   No censoring detected for POS EHA0021360
# Processing Point of Sale: EHA0089518
#   Total observations: 128
#   Uncensored: 85, Censored: 43
#     Uncensored observations: 85
#     Censored observations: 43
#   Estimated parameters: [8.49766471 0.74969728]
#   Average demand increase per censored observation: 1.61
#   Total estimated lost sales: 69
# Processing Point of Sale: EHA0101910
#   Total observations: 132
#   Uncensored: 89, Censored: 43
#     Uncensored observations: 89
#     Censored observations: 43
#   Estimated parameters: [100.           0.96443216]
#   Average demand increase per censored observation: 1.88
#   Total estimated lost sales: 81
# Processing Point of Sale: EHA0106382
#   Total observations: 32
#   Uncensored: 22, Censored: 10
#     Uncensored observations: 22
#     Censored observations: 10
#   Estimated parameters: [4.98590759 0.62032039]
#   Average demand increase per censored observation: 1.87
#   Total estimated lost sales: 19
# Processing Point of Sale: EHA0117626
#   Total observations: 10
#   Uncensored: 10, Censored: 0
#   No censoring detected for POS EHA0117626
# Processing Point of Sale: EHA0158067
#   Total observations: 132
#   Uncensored: 89, Censored: 43
#     Uncensored observations: 89
#     Censored observations: 43
#   Estimated parameters: [99.99999935  0.96127135]
#   Average demand increase per censored observation: 2.04
#   Total estimated lost sales: 88
# Processing Point of Sale: EHA0184875
#   Total observations: 132
#   Uncensored: 89, Censored: 43
#     Uncensored observations: 89
#     Censored observations: 43
#   Estimated parameters: [39.99599512  0.91344852]
#   Average demand increase per censored observation: 2.15
#   Total estimated lost sales: 92
# Processing Point of Sale: EHA0231386
#   Total observations: 132
#   Uncensored: 91, Censored: 41
#     Uncensored observations: 91
#     Censored observations: 41
#   Estimated parameters: [100.           0.94563111]
#   Average demand increase per censored observation: 2.49
#   Total estimated lost sales: 102
# Processing Point of Sale: EHA0239697
#   Total observations: 57
#   Uncensored: 38, Censored: 19
#     Uncensored observations: 38
#     Censored observations: 19
#   Estimated parameters: [5.29438403 0.71174946]
#   Average demand increase per censored observation: 1.17
#   Total estimated lost sales: 22
# Processing Point of Sale: EHA0261979
#   Total observations: 132
#   Uncensored: 89, Censored: 43
#     Uncensored observations: 89
#     Censored observations: 43
#   Estimated parameters: [100.           0.96205692]
#   Average demand increase per censored observation: 1.94
#   Total estimated lost sales: 84
# Processing Point of Sale: EHA0307318
#   Total observations: 132
#   Uncensored: 89, Censored: 43
#     Uncensored observations: 89
#     Censored observations: 43
#   Estimated parameters: [12.87923728  0.74581463]
#   Average demand increase per censored observation: 2.13
#   Total estimated lost sales: 91
# Processing Point of Sale: EHA0335024
#   Total observations: 132
#   Uncensored: 87, Censored: 45
#     Uncensored observations: 87
#     Censored observations: 45
#   Estimated parameters: [10.69103177  0.8259056 ]
#   Average demand increase per censored observation: 1.28
#   Total estimated lost sales: 57
# Processing Point of Sale: EHA0372748
#   Total observations: 132
#   Uncensored: 87, Censored: 45
#     Uncensored observations: 87
#     Censored observations: 45
#   Estimated parameters: [100.           0.96732741]
#   Average demand increase per censored observation: 1.77
#   Total estimated lost sales: 80
# Processing Point of Sale: EHA0383908
#   Total observations: 42
#   Uncensored: 42, Censored: 0
#   No censoring detected for POS EHA0383908
# Processing Point of Sale: EHA0385575
#   Total observations: 132
#   Uncensored: 93, Censored: 39
#     Uncensored observations: 93
#     Censored observations: 39
#   Estimated parameters: [100.           0.98240435]
#   Average demand increase per censored observation: 0.88
#   Total estimated lost sales: 34
# Processing Point of Sale: EHA0398972
#   Total observations: 132
#   Uncensored: 86, Censored: 46
#     Uncensored observations: 86
#     Censored observations: 46
#   Estimated parameters: [100.           0.98042092]
#   Average demand increase per censored observation: 1.03
#   Total estimated lost sales: 48
# Processing Point of Sale: EHA0400471
#   Total observations: 132
#   Uncensored: 91, Censored: 41
#     Uncensored observations: 91
#     Censored observations: 41
#   Estimated parameters: [23.77847291  0.80235397]
#   Average demand increase per censored observation: 2.91
#   Total estimated lost sales: 119
# Processing Point of Sale: EHA0424159
#   Total observations: 83
#   Uncensored: 79, Censored: 4
#     Uncensored observations: 79
#     Censored observations: 4
#   Estimated parameters: [11.59562216  0.95417817]
#   Average demand increase per censored observation: 0.30
#   Total estimated lost sales: 1
# Processing Point of Sale: EHA0427039
#   Total observations: 18
#   Uncensored: 17, Censored: 1
#     Uncensored observations: 17
#     Censored observations: 1
#   Estimated parameters: [1.9995705  0.81225688]
#   Average demand increase per censored observation: 0.32
#   Total estimated lost sales: 0
# Processing Point of Sale: EHA0538154
#   Total observations: 121
#   Uncensored: 94, Censored: 27
#     Uncensored observations: 94
#     Censored observations: 27
#   Estimated parameters: [7.80860215 0.84374572]
#   Average demand increase per censored observation: 0.78
#   Total estimated lost sales: 21
# Processing Point of Sale: EHA0545458
#   Total observations: 75
#   Uncensored: 67, Censored: 8
#     Uncensored observations: 67
#     Censored observations: 8
#   Estimated parameters: [36.80049707  0.98228286]
#   Average demand increase per censored observation: 0.35
#   Total estimated lost sales: 3
# Processing Point of Sale: EHA0561956
#   Total observations: 126
#   Uncensored: 97, Censored: 29
#     Uncensored observations: 97
#     Censored observations: 29
#   Estimated parameters: [100.           0.98640847]
#   Average demand increase per censored observation: 0.71
#   Total estimated lost sales: 21
# Processing Point of Sale: EHA0564794
#   Total observations: 23
#   Uncensored: 20, Censored: 3
#     Uncensored observations: 20
#     Censored observations: 3
#   Estimated parameters: [100.           0.98946502]
#   Average demand increase per censored observation: 0.50
#   Total estimated lost sales: 1
# Processing Point of Sale: EHA0596336
#   Skipping POS EHA0596336: insufficient data (4 obs, need 10)
# Processing Point of Sale: EHA0673832
#   Total observations: 132
#   Uncensored: 87, Censored: 45
#     Uncensored observations: 87
#     Censored observations: 45
#   Estimated parameters: [100.           0.97249973]
#   Average demand increase per censored observation: 1.41
#   Total estimated lost sales: 63
# Processing Point of Sale: EHA0692864
#   Total observations: 132
#   Uncensored: 87, Censored: 45
#     Uncensored observations: 87
#     Censored observations: 45
#   Estimated parameters: [53.68354657  0.95849537]
#   Average demand increase per censored observation: 1.17
#   Total estimated lost sales: 53
# Processing Point of Sale: EHA0694591
#   Total observations: 67
#   Uncensored: 46, Censored: 21
#     Uncensored observations: 46
#     Censored observations: 21
#   Estimated parameters: [100.           0.95288214]
#   Average demand increase per censored observation: 2.25
#   Total estimated lost sales: 47
# Processing Point of Sale: EHA0720314
#   Total observations: 131
#   Uncensored: 92, Censored: 39
#     Uncensored observations: 92
#     Censored observations: 39
#   Estimated parameters: [35.71143289  0.80897081]
#   Average demand increase per censored observation: 3.35
#   Total estimated lost sales: 131
# Processing Point of Sale: EHA0777447
#   Total observations: 12
#   Uncensored: 12, Censored: 0
#   No censoring detected for POS EHA0777447
# Processing Point of Sale: EHA0796669
#   Total observations: 132
#   Uncensored: 127, Censored: 5
#     Uncensored observations: 127
#     Censored observations: 5
#   Estimated parameters: [100.           0.98838803]
#   Average demand increase per censored observation: 0.62
#   Total estimated lost sales: 3
# Processing Point of Sale: EHA0916947
#   Total observations: 23
#   Uncensored: 23, Censored: 0
#   No censoring detected for POS EHA0916947
# Processing Point of Sale: EHA0952497
#   Total observations: 19
#   Uncensored: 17, Censored: 2
#     Uncensored observations: 17
#     Censored observations: 2
#   Estimated parameters: [0.21805609 0.23364411]
#   Average demand increase per censored observation: 1.79
#   Total estimated lost sales: 4
# Processing Point of Sale: EHA0989127
#   Total observations: 130
#   Uncensored: 86, Censored: 44
#     Uncensored observations: 86
#     Censored observations: 44
#   Estimated parameters: [100.           0.97290037]
#   Average demand increase per censored observation: 1.43
#   Total estimated lost sales: 63
# Processing Point of Sale: EHA1030471
#   Total observations: 132
#   Uncensored: 90, Censored: 42
#     Uncensored observations: 90
#     Censored observations: 42
#   Estimated parameters: [10.4841045   0.70356035]
#   Average demand increase per censored observation: 2.15
#   Total estimated lost sales: 90
# Processing Point of Sale: EHA1051064
#   Total observations: 47
#   Uncensored: 44, Censored: 3
#     Uncensored observations: 44
#     Censored observations: 3
#   Estimated parameters: [52.13732992  0.99      ]
#   Average demand increase per censored observation: 0.23
#   Total estimated lost sales: 1
# Processing Point of Sale: EHA1057965
#   Total observations: 66
#   Uncensored: 65, Censored: 1
#     Uncensored observations: 65
#     Censored observations: 1
#   Estimated parameters: [100.           0.98988977]
#   Average demand increase per censored observation: 0.41
#   Total estimated lost sales: 0
# Processing Point of Sale: EHA1137229
#   Total observations: 36
#   Uncensored: 35, Censored: 1
#     Uncensored observations: 35
#     Censored observations: 1
#   Estimated parameters: [75.5878948  0.99     ]
#   Average demand increase per censored observation: 0.43
#   Total estimated lost sales: 0
# Processing Point of Sale: EHA1148638
#   Total observations: 132
#   Uncensored: 89, Censored: 43
#     Uncensored observations: 89
#     Censored observations: 43
#   Estimated parameters: [100.           0.96476042]
#   Average demand increase per censored observation: 1.91
#   Total estimated lost sales: 82
# Processing Point of Sale: EHA1177798
#   Total observations: 120
#   Uncensored: 81, Censored: 39
#     Uncensored observations: 81
#     Censored observations: 39
#   Estimated parameters: [100.           0.95846315]
#   Average demand increase per censored observation: 2.05
#   Total estimated lost sales: 80
# Processing Point of Sale: EHA1200602
#   Skipping POS EHA1200602: insufficient data (8 obs, need 10)
# Processing Point of Sale: EHA1226156
#   Total observations: 122
#   Uncensored: 108, Censored: 14
#     Uncensored observations: 108
#     Censored observations: 14
#   Estimated parameters: [6.54982262 0.85780644]
#   Average demand increase per censored observation: 0.60
#   Total estimated lost sales: 8
# Processing Point of Sale: EHA1234526
#   Total observations: 132
#   Uncensored: 93, Censored: 39
#     Uncensored observations: 93
#     Censored observations: 39
#   Estimated parameters: [100.           0.92142295]
#   Average demand increase per censored observation: 3.50
#   Total estimated lost sales: 137
# Processing Point of Sale: EHA1235246
#   Total observations: 132
#   Uncensored: 86, Censored: 46
#     Uncensored observations: 86
#     Censored observations: 46
#   Estimated parameters: [100.           0.98080251]
#   Average demand increase per censored observation: 1.07
#   Total estimated lost sales: 49
# Processing Point of Sale: EHA1291184
#   Skipping POS EHA1291184: insufficient data (7 obs, need 10)
# Processing Point of Sale: EHA1292325
#   Total observations: 132
#   Uncensored: 94, Censored: 38
#     Uncensored observations: 94
#     Censored observations: 38
#   Estimated parameters: [92.44669644  0.90916562]
#   Average demand increase per censored observation: 3.93
#   Total estimated lost sales: 149
# Processing Point of Sale: EHA1306706
#   Total observations: 63
#   Uncensored: 55, Censored: 8
#     Uncensored observations: 55
#     Censored observations: 8
#   Estimated parameters: [94.31806094  0.99      ]
#   Average demand increase per censored observation: 0.49
#   Total estimated lost sales: 4
# Processing Point of Sale: EHA1379010
#   Skipping POS EHA1379010: insufficient data (5 obs, need 10)
# Processing Point of Sale: EHA1425987
#   Total observations: 132
#   Uncensored: 90, Censored: 42
#     Uncensored observations: 90
#     Censored observations: 42
#   Estimated parameters: [100.           0.95603332]
#   Average demand increase per censored observation: 2.17
#   Total estimated lost sales: 91
# Processing Point of Sale: EHA1502158
#   Total observations: 128
#   Uncensored: 87, Censored: 41
#     Uncensored observations: 87
#     Censored observations: 41
#   Estimated parameters: [100.           0.98303481]
#   Average demand increase per censored observation: 0.85
#   Total estimated lost sales: 35
# Processing Point of Sale: EHA1620660
#   Total observations: 66
#   Uncensored: 51, Censored: 15
#     Uncensored observations: 51
#     Censored observations: 15
#   Estimated parameters: [19.69950988  0.93845305]
#   Average demand increase per censored observation: 0.68
#   Total estimated lost sales: 10
# Processing Point of Sale: EHA1680405
#   Total observations: 21
#   Uncensored: 20, Censored: 1
#     Uncensored observations: 20
#     Censored observations: 1
#   Estimated parameters: [68.06517799  0.99      ]
#   Average demand increase per censored observation: 0.39
#   Total estimated lost sales: 0
# Processing Point of Sale: EHA1691847
#   Total observations: 132
#   Uncensored: 89, Censored: 43
#     Uncensored observations: 89
#     Censored observations: 43
#   Estimated parameters: [100.           0.96089642]
#   Average demand increase per censored observation: 2.03
#   Total estimated lost sales: 87
# Processing Point of Sale: EHA1694744
#   Total observations: 117
#   Uncensored: 81, Censored: 36
#     Uncensored observations: 81
#     Censored observations: 36
#   Estimated parameters: [100.          0.9452296]
#   Average demand increase per censored observation: 2.67
#   Total estimated lost sales: 96
# Processing Point of Sale: EHA1719750
#   Total observations: 14
#   Uncensored: 14, Censored: 0
#   No censoring detected for POS EHA1719750
# Processing Point of Sale: EHA1753410
#   Skipping POS EHA1753410: insufficient data (9 obs, need 10)
# Processing Point of Sale: EHA1765650
#   Total observations: 132
#   Uncensored: 87, Censored: 45
#     Uncensored observations: 87
#     Censored observations: 45
#   Estimated parameters: [100.           0.97721232]
#   Average demand increase per censored observation: 1.13
#   Total estimated lost sales: 51
# Processing Point of Sale: EHA1773764
#   Total observations: 18
#   Uncensored: 18, Censored: 0
#   No censoring detected for POS EHA1773764
# Processing Point of Sale: EHA1804454
#   Total observations: 132
#   Uncensored: 91, Censored: 41
#     Uncensored observations: 91
#     Censored observations: 41
#   Estimated parameters: [100.           0.94027115]
#   Average demand increase per censored observation: 2.84
#   Total estimated lost sales: 117
# Processing Point of Sale: EHA1806199
#   Skipping POS EHA1806199: insufficient data (7 obs, need 10)
# Processing Point of Sale: EHA1818452
#   Total observations: 132
#   Uncensored: 92, Censored: 40
#     Uncensored observations: 92
#     Censored observations: 40
#   Estimated parameters: [100.           0.93759169]
#   Average demand increase per censored observation: 2.92
#   Total estimated lost sales: 117
# Processing Point of Sale: EHA1871847
#   Total observations: 132
#   Uncensored: 89, Censored: 43
#     Uncensored observations: 89
#     Censored observations: 43
#   Estimated parameters: [100.           0.95960155]
#   Average demand increase per censored observation: 1.99
#   Total estimated lost sales: 86
# Processing Point of Sale: EHA1885738
#   Total observations: 132
#   Uncensored: 87, Censored: 45
#     Uncensored observations: 87
#     Censored observations: 45
#   Estimated parameters: [15.46597477  0.84436352]
#   Average demand increase per censored observation: 1.61
#   Total estimated lost sales: 72
# Processing Point of Sale: EHA1897860
#   Total observations: 132
#   Uncensored: 90, Censored: 42
#     Uncensored observations: 90
#     Censored observations: 42
#   Estimated parameters: [100.           0.95484619]
#   Average demand increase per censored observation: 2.24
#   Total estimated lost sales: 94
# Processing Point of Sale: EHA1927249
#   Total observations: 100
#   Uncensored: 94, Censored: 6
#     Uncensored observations: 94
#     Censored observations: 6
#   Estimated parameters: [np.float64(0.6063829787234043), 0.5]
#   Average demand increase per censored observation: 0.80
#   Total estimated lost sales: 5
# Processing Point of Sale: EHA1928265
#   Total observations: 21
#   Uncensored: 21, Censored: 0
#   No censoring detected for POS EHA1928265
# Processing Point of Sale: EHA1936789
#   Total observations: 34
#   Uncensored: 32, Censored: 2
#     Uncensored observations: 32
#     Censored observations: 2
#   Estimated parameters: [7.63532492 0.94705963]
#   Average demand increase per censored observation: 0.26
#   Total estimated lost sales: 1
# Processing Point of Sale: EHA1938990
#   Skipping POS EHA1938990: insufficient data (7 obs, need 10)
# Processing Point of Sale: EHA1939155
#   Total observations: 132
#   Uncensored: 98, Censored: 34
#     Uncensored observations: 98
#     Censored observations: 34
#   Estimated parameters: [100.           0.85120432]
#   Average demand increase per censored observation: 6.19
#   Total estimated lost sales: 210
# Processing Point of Sale: EHA1963214
#   Skipping POS EHA1963214: insufficient data (5 obs, need 10)
# Processing Point of Sale: EHA1975291
#   Total observations: 132
#   Uncensored: 96, Censored: 36
#     Uncensored observations: 96
#     Censored observations: 36
#   Estimated parameters: [100.          0.9021664]
#   Average demand increase per censored observation: 4.51
#   Total estimated lost sales: 162
# Processing Point of Sale: EHA2046118
#   Total observations: 132
#   Uncensored: 89, Censored: 43
#     Uncensored observations: 89
#     Censored observations: 43
#   Estimated parameters: [100.           0.96547861]
#   Average demand increase per censored observation: 1.84
#   Total estimated lost sales: 79
# Processing Point of Sale: EHA2128440
#   Total observations: 132
#   Uncensored: 90, Censored: 42
#     Uncensored observations: 90
#     Censored observations: 42
#   Estimated parameters: [100.           0.95271252]
#   Average demand increase per censored observation: 2.39
#   Total estimated lost sales: 100
# Processing Point of Sale: EHA2150179
#   Total observations: 132
#   Uncensored: 92, Censored: 40
#     Uncensored observations: 92
#     Censored observations: 40
#   Estimated parameters: [100.           0.93740526]
#   Average demand increase per censored observation: 2.91
#   Total estimated lost sales: 116
# Processing Point of Sale: EHA2186161
#   Total observations: 132
#   Uncensored: 93, Censored: 39
#     Uncensored observations: 93
#     Censored observations: 39
#   Estimated parameters: [100.           0.92144834]
#   Average demand increase per censored observation: 3.57
#   Total estimated lost sales: 139
# Processing Point of Sale: EHA2227797
#   Total observations: 132
#   Uncensored: 132, Censored: 0
#   No censoring detected for POS EHA2227797
# Processing Point of Sale: EHA2286086
#   Total observations: 132
#   Uncensored: 89, Censored: 43
#     Uncensored observations: 89
#     Censored observations: 43
#   Estimated parameters: [100.           0.96145464]
#   Average demand increase per censored observation: 2.07
#   Total estimated lost sales: 89
# Processing Point of Sale: EHA2335682
#   Total observations: 132
#   Uncensored: 96, Censored: 36
#     Uncensored observations: 96
#     Censored observations: 36
#   Estimated parameters: [99.99995998  0.86906806]
#   Average demand increase per censored observation: 4.99
#   Total estimated lost sales: 180
# Processing Point of Sale: EHA2377166
#   Total observations: 132
#   Uncensored: 93, Censored: 39
#     Uncensored observations: 93
#     Censored observations: 39
#   Estimated parameters: [77.93640239  0.91052892]
#   Average demand increase per censored observation: 3.27
#   Total estimated lost sales: 127
# Processing Point of Sale: EHA2385688
#   Total observations: 132
#   Uncensored: 87, Censored: 45
#     Uncensored observations: 87
#     Censored observations: 45
#   Estimated parameters: [np.float64(2.0114942528735633), 0.5]
#   Average demand increase per censored observation: 1.53
#   Total estimated lost sales: 69
# Processing Point of Sale: EHA2401286
#   Total observations: 132
#   Uncensored: 87, Censored: 45
#     Uncensored observations: 87
#     Censored observations: 45
#   Estimated parameters: [27.01035745  0.90611513]
#   Average demand increase per censored observation: 1.50
#   Total estimated lost sales: 67
# Processing Point of Sale: EHA2460326
#   Total observations: 132
#   Uncensored: 87, Censored: 45
#     Uncensored observations: 87
#     Censored observations: 45
#   Estimated parameters: [99.99999927  0.97838169]
#   Average demand increase per censored observation: 1.10
#   Total estimated lost sales: 50
# Processing Point of Sale: EHA2465161
#   Total observations: 132
#   Uncensored: 86, Censored: 46
#     Uncensored observations: 86
#     Censored observations: 46
#   Estimated parameters: [100.           0.98101619]
#   Average demand increase per censored observation: 1.03
#   Total estimated lost sales: 47
# Processing Point of Sale: EHA2575905
#   Skipping POS EHA2575905: insufficient data (8 obs, need 10)
# Processing Point of Sale: EHA2626154
#   Total observations: 132
#   Uncensored: 90, Censored: 42
#     Uncensored observations: 90
#     Censored observations: 42
#   Estimated parameters: [88.26761715  0.9458906 ]
#   Average demand increase per censored observation: 2.42
#   Total estimated lost sales: 102
# Processing Point of Sale: EHA2669396
#   Total observations: 132
#   Uncensored: 87, Censored: 45
#     Uncensored observations: 87
#     Censored observations: 45
#   Estimated parameters: [100.           0.97577466]
#   Average demand increase per censored observation: 1.28
#   Total estimated lost sales: 58
# Processing Point of Sale: EHA2678607
#   Total observations: 13
#   Uncensored: 12, Censored: 1
#     Uncensored observations: 12
#     Censored observations: 1
#   Estimated parameters: [47.07022094  0.99      ]
#   Average demand increase per censored observation: 0.18
#   Total estimated lost sales: 0
# Processing Point of Sale: EHA2748409
#   Total observations: 118
#   Uncensored: 109, Censored: 9
#     Uncensored observations: 109
#     Censored observations: 9
#   Estimated parameters: [100.           0.98933294]
#   Average demand increase per censored observation: 0.47
#   Total estimated lost sales: 4
# Processing Point of Sale: EHA2768340
#   Total observations: 81
#   Uncensored: 68, Censored: 13
#     Uncensored observations: 68
#     Censored observations: 13
#   Estimated parameters: [52.38866462  0.98265611]
#   Average demand increase per censored observation: 0.38
#   Total estimated lost sales: 5
# Processing Point of Sale: EHA2778448
#   Total observations: 77
#   Uncensored: 73, Censored: 4
#     Uncensored observations: 73
#     Censored observations: 4
#   Estimated parameters: [47.30149458  0.99      ]
#   Average demand increase per censored observation: 0.18
#   Total estimated lost sales: 1
# Processing Point of Sale: EHA2821288
#   Total observations: 12
#   Uncensored: 12, Censored: 0
#   No censoring detected for POS EHA2821288
# Processing Point of Sale: EHA2911592
#   Total observations: 21
#   Uncensored: 21, Censored: 0
#   No censoring detected for POS EHA2911592
# Processing Point of Sale: EHA2944754
#   Total observations: 132
#   Uncensored: 93, Censored: 39
#     Uncensored observations: 93
#     Censored observations: 39
#   Estimated parameters: [84.82543646  0.908013  ]
#   Average demand increase per censored observation: 3.65
#   Total estimated lost sales: 142
# Processing Point of Sale: EHA2973014
#   Total observations: 127
#   Uncensored: 87, Censored: 40
#     Uncensored observations: 87
#     Censored observations: 40
#   Estimated parameters: [100.           0.98419331]
#   Average demand increase per censored observation: 0.80
#   Total estimated lost sales: 32
# Processing Point of Sale: EHA2983155
#   Total observations: 132
#   Uncensored: 91, Censored: 41
#     Uncensored observations: 91
#     Censored observations: 41
#   Estimated parameters: [100.           0.94295869]
#   Average demand increase per censored observation: 2.60
#   Total estimated lost sales: 106
# Processing Point of Sale: EHA3005338
#   Total observations: 132
#   Uncensored: 87, Censored: 45
#     Uncensored observations: 87
#     Censored observations: 45
#   Estimated parameters: [100.           0.97352144]
#   Average demand increase per censored observation: 1.27
#   Total estimated lost sales: 57
# Processing Point of Sale: EHA3018615
#   Total observations: 10
#   Uncensored: 10, Censored: 0
#   No censoring detected for POS EHA3018615
# Processing Point of Sale: EHA3029281
#   Total observations: 132
#   Uncensored: 87, Censored: 45
#     Uncensored observations: 87
#     Censored observations: 45
#   Estimated parameters: [100.           0.97201496]
#   Average demand increase per censored observation: 1.53
#   Total estimated lost sales: 69
# Processing Point of Sale: EHA3180409
#   Total observations: 127
#   Uncensored: 83, Censored: 44
#     Uncensored observations: 83
#     Censored observations: 44
#   Estimated parameters: [6.86574289 0.75350329]
#   Average demand increase per censored observation: 1.26
#   Total estimated lost sales: 55
# Processing Point of Sale: EHA3196678
#   Total observations: 130
#   Uncensored: 91, Censored: 39
#     Uncensored observations: 91
#     Censored observations: 39
#   Estimated parameters: [100.          0.9306563]
#   Average demand increase per censored observation: 3.09
#   Total estimated lost sales: 121
# Processing Point of Sale: EHA3255777
#   Total observations: 93
#   Uncensored: 62, Censored: 31
#     Uncensored observations: 62
#     Censored observations: 31
#   Estimated parameters: [100.           0.97813608]
#   Average demand increase per censored observation: 1.19
#   Total estimated lost sales: 37
# Processing Point of Sale: EHA3294058
#   Total observations: 132
#   Uncensored: 89, Censored: 43
#     Uncensored observations: 89
#     Censored observations: 43
#   Estimated parameters: [100.           0.96673685]
#   Average demand increase per censored observation: 1.79
#   Total estimated lost sales: 77
# Processing Point of Sale: EHA3294086
#   Skipping POS EHA3294086: insufficient data (8 obs, need 10)
# Processing Point of Sale: EHA3306152
#   Total observations: 73
#   Uncensored: 66, Censored: 7
#     Uncensored observations: 66
#     Censored observations: 7
#   Estimated parameters: [80.98115674  0.99      ]
#   Average demand increase per censored observation: 0.38
#   Total estimated lost sales: 3
# Processing Point of Sale: EHA3347179
#   Total observations: 132
#   Uncensored: 91, Censored: 41
#     Uncensored observations: 91
#     Censored observations: 41
#   Estimated parameters: [100.           0.94485016]
#   Average demand increase per censored observation: 2.77
#   Total estimated lost sales: 113
# Processing Point of Sale: EHA3362818
#   Total observations: 132
#   Uncensored: 92, Censored: 40
#     Uncensored observations: 92
#     Censored observations: 40
#   Estimated parameters: [100.           0.93740255]
#   Average demand increase per censored observation: 2.96
#   Total estimated lost sales: 118
# Processing Point of Sale: EHA3408060
#   Total observations: 36
#   Uncensored: 24, Censored: 12
#     Uncensored observations: 24
#     Censored observations: 12
#   Estimated parameters: [1.90327774 0.46303836]
#   Average demand increase per censored observation: 1.70
#   Total estimated lost sales: 20
# Processing Point of Sale: EHA3464096
#   Total observations: 81
#   Uncensored: 70, Censored: 11
#     Uncensored observations: 70
#     Censored observations: 11
#   Estimated parameters: [3.89924954 0.82688577]
#   Average demand increase per censored observation: 0.47
#   Total estimated lost sales: 5
# Processing Point of Sale: EHA3549686
#   Total observations: 132
#   Uncensored: 87, Censored: 45
#     Uncensored observations: 87
#     Censored observations: 45
#   Estimated parameters: [12.14850629  0.79193502]
#   Average demand increase per censored observation: 1.83
#   Total estimated lost sales: 82
# Processing Point of Sale: EHA3564688
#   Total observations: 75
#   Uncensored: 68, Censored: 7
#     Uncensored observations: 68
#     Censored observations: 7
#   Estimated parameters: [93.44444735  0.98980059]
#   Average demand increase per censored observation: 0.46
#   Total estimated lost sales: 3
# Processing Point of Sale: EHA3570057
#   Total observations: 132
#   Uncensored: 87, Censored: 45
#     Uncensored observations: 87
#     Censored observations: 45
#   Estimated parameters: [100.           0.97388936]
#   Average demand increase per censored observation: 1.35
#   Total estimated lost sales: 61
# Processing Point of Sale: EHA3580514
#   Total observations: 69
#   Uncensored: 59, Censored: 10
#     Uncensored observations: 59
#     Censored observations: 10
#   Estimated parameters: [2.37854341 0.743581  ]
#   Average demand increase per censored observation: 0.56
#   Total estimated lost sales: 6
# Processing Point of Sale: EHA3635217
#   Total observations: 121
#   Uncensored: 115, Censored: 6
#     Uncensored observations: 115
#     Censored observations: 6
#   Estimated parameters: [90.55966438  0.98766277]
#   Average demand increase per censored observation: 0.60
#   Total estimated lost sales: 4
# Processing Point of Sale: EHA3650624
#   Total observations: 13
#   Uncensored: 12, Censored: 1
#     Uncensored observations: 12
#     Censored observations: 1
#   Estimated parameters: [78.64570034  0.99      ]
#   Average demand increase per censored observation: 0.31
#   Total estimated lost sales: 0
# Processing Point of Sale: EHA3804289
#   Total observations: 132
#   Uncensored: 89, Censored: 43
#     Uncensored observations: 89
#     Censored observations: 43
#   Estimated parameters: [100.           0.96337857]
#   Average demand increase per censored observation: 1.97
#   Total estimated lost sales: 85
# Processing Point of Sale: EHA3853082
#   Total observations: 132
#   Uncensored: 94, Censored: 38
#     Uncensored observations: 94
#     Censored observations: 38
#   Estimated parameters: [100.           0.91521458]
#   Average demand increase per censored observation: 4.00
#   Total estimated lost sales: 152
# Processing Point of Sale: EHA3908779
#   Skipping POS EHA3908779: insufficient data (9 obs, need 10)
# Processing Point of Sale: EHA3937219
#   Skipping POS EHA3937219: insufficient data (9 obs, need 10)
# Processing Point of Sale: EHA3941757
#   Total observations: 132
#   Uncensored: 90, Censored: 42
#     Uncensored observations: 90
#     Censored observations: 42
#   Estimated parameters: [100.           0.95473124]
#   Average demand increase per censored observation: 2.19
#   Total estimated lost sales: 92
# Processing Point of Sale: EHA3977102
#   Total observations: 23
#   Uncensored: 21, Censored: 2
#     Uncensored observations: 21
#     Censored observations: 2
#   Estimated parameters: [0.31794562 0.37660989]
#   Average demand increase per censored observation: 1.05
#   Total estimated lost sales: 2
# Processing Point of Sale: EHA4038524
#   Total observations: 91
#   Uncensored: 64, Censored: 27
#     Uncensored observations: 64
#     Censored observations: 27
#   Estimated parameters: [100.           0.97917464]
#   Average demand increase per censored observation: 0.98
#   Total estimated lost sales: 27
# Processing Point of Sale: EHA4063921
#   Total observations: 132
#   Uncensored: 87, Censored: 45
#     Uncensored observations: 87
#     Censored observations: 45
#   Estimated parameters: [97.34204611  0.97105296]
#   Average demand increase per censored observation: 1.36
#   Total estimated lost sales: 61
# Processing Point of Sale: EHA4090759
#   Total observations: 95
#   Uncensored: 62, Censored: 33
#     Uncensored observations: 62
#     Censored observations: 33
#   Estimated parameters: [100.           0.98149086]
#   Average demand increase per censored observation: 1.00
#   Total estimated lost sales: 33
# Processing Point of Sale: EHA4104120
#   Total observations: 132
#   Uncensored: 93, Censored: 39
#     Uncensored observations: 93
#     Censored observations: 39
#   Estimated parameters: [100.           0.92783776]
#   Average demand increase per censored observation: 3.27
#   Total estimated lost sales: 128
# Processing Point of Sale: EHA4118250
#   Total observations: 132
#   Uncensored: 92, Censored: 40
#     Uncensored observations: 92
#     Censored observations: 40
#   Estimated parameters: [29.75634286  0.81458903]
#   Average demand increase per censored observation: 2.98
#   Total estimated lost sales: 119
# Processing Point of Sale: EHA4138196
#   Total observations: 132
#   Uncensored: 93, Censored: 39
#     Uncensored observations: 93
#     Censored observations: 39
#   Estimated parameters: [100.           0.92614223]
#   Average demand increase per censored observation: 3.50
#   Total estimated lost sales: 137
# Processing Point of Sale: EHA4150635
#   Total observations: 132
#   Uncensored: 92, Censored: 40
#     Uncensored observations: 92
#     Censored observations: 40
#   Estimated parameters: [100.           0.93177741]
#   Average demand increase per censored observation: 3.54
#   Total estimated lost sales: 141
# Processing Point of Sale: EHA4164254
#   Total observations: 131
#   Uncensored: 90, Censored: 41
#     Uncensored observations: 90
#     Censored observations: 41
#   Estimated parameters: [100.           0.94197637]
#   Average demand increase per censored observation: 2.88
#   Total estimated lost sales: 118
# Processing Point of Sale: EHA4231411
#   Total observations: 132
#   Uncensored: 87, Censored: 45
#     Uncensored observations: 87
#     Censored observations: 45
#   Estimated parameters: [30.8481165   0.90302331]
#   Average demand increase per censored observation: 1.78
#   Total estimated lost sales: 80
# Processing Point of Sale: EHA4327604
#   Total observations: 35
#   Uncensored: 33, Censored: 2
#     Uncensored observations: 33
#     Censored observations: 2
#   Estimated parameters: [52.47664555  0.99      ]
#   Average demand increase per censored observation: 0.25
#   Total estimated lost sales: 0
# Processing Point of Sale: EHA4328012
#   Total observations: 29
#   Uncensored: 27, Censored: 2
#     Uncensored observations: 27
#     Censored observations: 2
#   Estimated parameters: [49.82641086  0.99      ]
#   Average demand increase per censored observation: 0.28
#   Total estimated lost sales: 1
# Processing Point of Sale: EHA4338480
#   Skipping POS EHA4338480: insufficient data (5 obs, need 10)
# Processing Point of Sale: EHA4352486
#   Total observations: 12
#   Uncensored: 12, Censored: 0
#   No censoring detected for POS EHA4352486
# Processing Point of Sale: EHA4382546
#   Skipping POS EHA4382546: insufficient data (5 obs, need 10)
# Processing Point of Sale: EHA4447069
#   Total observations: 48
#   Uncensored: 46, Censored: 2
#     Uncensored observations: 46
#     Censored observations: 2
#   Estimated parameters: [67.42069134  0.99      ]
#   Average demand increase per censored observation: 0.32
#   Total estimated lost sales: 1
# Processing Point of Sale: EHA4453767
#   Total observations: 132
#   Uncensored: 89, Censored: 43
#     Uncensored observations: 89
#     Censored observations: 43
#   Estimated parameters: [100.           0.95781884]
#   Average demand increase per censored observation: 2.29
#   Total estimated lost sales: 98
# Processing Point of Sale: EHA4470379
#   Total observations: 59
#   Uncensored: 41, Censored: 18
#     Uncensored observations: 41
#     Censored observations: 18
#   Estimated parameters: [100.           0.98254378]
#   Average demand increase per censored observation: 0.99
#   Total estimated lost sales: 18
# Processing Point of Sale: EHA4586551
#   Total observations: 38
#   Uncensored: 32, Censored: 6
#     Uncensored observations: 32
#     Censored observations: 6
#   Estimated parameters: [3.74240747 0.80191447]
#   Average demand increase per censored observation: 0.52
#   Total estimated lost sales: 3
# Processing Point of Sale: EHA4589487
#   Skipping POS EHA4589487: insufficient data (4 obs, need 10)
# Processing Point of Sale: EHA4591588
#   Total observations: 61
#   Uncensored: 57, Censored: 4
#     Uncensored observations: 57
#     Censored observations: 4
#   Estimated parameters: [79.09088887  0.99      ]
#   Average demand increase per censored observation: 0.42
#   Total estimated lost sales: 2
# Processing Point of Sale: EHA4614957
#   Total observations: 131
#   Uncensored: 88, Censored: 43
#     Uncensored observations: 88
#     Censored observations: 43
#   Estimated parameters: [100.           0.95814987]
#   Average demand increase per censored observation: 2.10
#   Total estimated lost sales: 90
# Processing Point of Sale: EHA4633424
#   Total observations: 61
#   Uncensored: 57, Censored: 4
#     Uncensored observations: 57
#     Censored observations: 4
#   Estimated parameters: [7.25056455 0.88751146]
#   Average demand increase per censored observation: 0.51
#   Total estimated lost sales: 2
# Processing Point of Sale: EHA4718606
#   Total observations: 132
#   Uncensored: 96, Censored: 36
#     Uncensored observations: 96
#     Censored observations: 36
#   Estimated parameters: [45.82104518  0.75909194]
#   Average demand increase per censored observation: 4.93
#   Total estimated lost sales: 178
# Processing Point of Sale: EHA4797238
#   Total observations: 131
#   Uncensored: 89, Censored: 42
#     Uncensored observations: 89
#     Censored observations: 42
#   Estimated parameters: [100.           0.95380038]
#   Average demand increase per censored observation: 2.13
#   Total estimated lost sales: 90
# Processing Point of Sale: EHA4818152
#   Total observations: 132
#   Uncensored: 90, Censored: 42
#     Uncensored observations: 90
#     Censored observations: 42
#   Estimated parameters: [100.           0.95126765]
#   Average demand increase per censored observation: 2.43
#   Total estimated lost sales: 102
# Processing Point of Sale: EHA4882454
#   Total observations: 129
#   Uncensored: 85, Censored: 44
#     Uncensored observations: 85
#     Censored observations: 44
#   Estimated parameters: [100.           0.96909172]
#   Average demand increase per censored observation: 1.71
#   Total estimated lost sales: 75
# Processing Point of Sale: EHA4912485
#   Skipping POS EHA4912485: insufficient data (5 obs, need 10)
# Processing Point of Sale: EHA4914477
#   Total observations: 132
#   Uncensored: 113, Censored: 19
#     Uncensored observations: 113
#     Censored observations: 19
#   Estimated parameters: [100.           0.98757348]
#   Average demand increase per censored observation: 0.64
#   Total estimated lost sales: 12
# Processing Point of Sale: EHA4923117
#   Total observations: 132
#   Uncensored: 86, Censored: 46
#     Uncensored observations: 86
#     Censored observations: 46
#   Estimated parameters: [100.           0.97837907]
#   Average demand increase per censored observation: 1.28
#   Total estimated lost sales: 59
# Processing Point of Sale: EHA5117042
#   Total observations: 66
#   Uncensored: 63, Censored: 3
#     Uncensored observations: 63
#     Censored observations: 3
#   Estimated parameters: [87.44148222  0.99      ]
#   Average demand increase per censored observation: 0.40
#   Total estimated lost sales: 1
# Processing Point of Sale: EHA5143800
#   Total observations: 132
#   Uncensored: 88, Censored: 44
#     Uncensored observations: 88
#     Censored observations: 44
#   Estimated parameters: [99.99999996  0.98132276]
#   Average demand increase per censored observation: 0.94
#   Total estimated lost sales: 41
# Processing Point of Sale: EHA5155466
#   Total observations: 131
#   Uncensored: 87, Censored: 44
#     Uncensored observations: 87
#     Censored observations: 44
#   Estimated parameters: [6.93275493 0.74799727]
#   Average demand increase per censored observation: 1.34
#   Total estimated lost sales: 59
# Processing Point of Sale: EHA5158185
#   Total observations: 132
#   Uncensored: 89, Censored: 43
#     Uncensored observations: 89
#     Censored observations: 43
#   Estimated parameters: [78.71887983  0.94715942]
#   Average demand increase per censored observation: 2.20
#   Total estimated lost sales: 95
# Processing Point of Sale: EHA5161977
#   Total observations: 25
#   Uncensored: 22, Censored: 3
#     Uncensored observations: 22
#     Censored observations: 3
#   Estimated parameters: [0.90794442 0.73914439]
#   Average demand increase per censored observation: 0.34
#   Total estimated lost sales: 1
# Processing Point of Sale: EHA5202840
#   Total observations: 132
#   Uncensored: 91, Censored: 41
#     Uncensored observations: 91
#     Censored observations: 41
#   Estimated parameters: [5.09772094 0.75112477]
#   Average demand increase per censored observation: 1.02
#   Total estimated lost sales: 42
# Processing Point of Sale: EHA5285910
#   Total observations: 13
#   Uncensored: 13, Censored: 0
#   No censoring detected for POS EHA5285910
# Processing Point of Sale: EHA5377291
#   Total observations: 47
#   Uncensored: 43, Censored: 4
#     Uncensored observations: 43
#     Censored observations: 4
#   Estimated parameters: [66.42564533  0.99      ]
#   Average demand increase per censored observation: 0.38
#   Total estimated lost sales: 2
# Processing Point of Sale: EHA5378685
#   Total observations: 132
#   Uncensored: 110, Censored: 22
#     Uncensored observations: 110
#     Censored observations: 22
#   Estimated parameters: [100.           0.98571674]
#   Average demand increase per censored observation: 0.69
#   Total estimated lost sales: 15
# Processing Point of Sale: EHA5384959
#   Total observations: 131
#   Uncensored: 89, Censored: 42
#     Uncensored observations: 89
#     Censored observations: 42
#   Estimated parameters: [100.           0.95019396]
#   Average demand increase per censored observation: 2.52
#   Total estimated lost sales: 106
# Processing Point of Sale: EHA5422065
#   Total observations: 132
#   Uncensored: 123, Censored: 9
#     Uncensored observations: 123
#     Censored observations: 9
#   Estimated parameters: [100.           0.98822241]
#   Average demand increase per censored observation: 0.59
#   Total estimated lost sales: 5
# Processing Point of Sale: EHA5443009
#   Total observations: 108
#   Uncensored: 80, Censored: 28
#     Uncensored observations: 80
#     Censored observations: 28
#   Estimated parameters: [100.           0.98102925]
#   Average demand increase per censored observation: 0.89
#   Total estimated lost sales: 25
# Processing Point of Sale: EHA5505765
#   Total observations: 43
#   Uncensored: 34, Censored: 9
#     Uncensored observations: 34
#     Censored observations: 9
#   Estimated parameters: [0.26637563 0.20129701]
#   Average demand increase per censored observation: 2.38
#   Total estimated lost sales: 21
# Processing Point of Sale: EHA5649855
#   Total observations: 119
#   Uncensored: 79, Censored: 40
#     Uncensored observations: 79
#     Censored observations: 40
#   Estimated parameters: [100.           0.97101003]
#   Average demand increase per censored observation: 1.63
#   Total estimated lost sales: 65
# Processing Point of Sale: EHA5656077
#   Skipping POS EHA5656077: insufficient data (4 obs, need 10)
# Processing Point of Sale: EHA5675534
#   Total observations: 132
#   Uncensored: 87, Censored: 45
#     Uncensored observations: 87
#     Censored observations: 45
#   Estimated parameters: [100.           0.97223379]
#   Average demand increase per censored observation: 1.40
#   Total estimated lost sales: 63
# Processing Point of Sale: EHA5678847
#   Total observations: 132
#   Uncensored: 93, Censored: 39
#     Uncensored observations: 93
#     Censored observations: 39
#   Estimated parameters: [93.39229433  0.92399388]
#   Average demand increase per censored observation: 3.20
#   Total estimated lost sales: 125
# Processing Point of Sale: EHA5770352
#   Total observations: 100
#   Uncensored: 88, Censored: 12
#     Uncensored observations: 88
#     Censored observations: 12
#   Estimated parameters: [100.           0.98918362]
#   Average demand increase per censored observation: 0.53
#   Total estimated lost sales: 6
# Processing Point of Sale: EHA5784386
#   Total observations: 132
#   Uncensored: 87, Censored: 45
#     Uncensored observations: 87
#     Censored observations: 45
#   Estimated parameters: [27.60120247  0.92143988]
#   Average demand increase per censored observation: 1.26
#   Total estimated lost sales: 57
# Processing Point of Sale: EHA5869442
#   Total observations: 132
#   Uncensored: 87, Censored: 45
#     Uncensored observations: 87
#     Censored observations: 45
#   Estimated parameters: [29.38455342  0.92241062]
#   Average demand increase per censored observation: 1.29
#   Total estimated lost sales: 58
# Processing Point of Sale: EHA5892019
#   Total observations: 132
#   Uncensored: 94, Censored: 38
#     Uncensored observations: 94
#     Censored observations: 38
#   Estimated parameters: [100.           0.91906298]
#   Average demand increase per censored observation: 3.43
#   Total estimated lost sales: 130
# Processing Point of Sale: EHA5910032
#   Skipping POS EHA5910032: insufficient data (5 obs, need 10)
# Processing Point of Sale: EHA5950789
#   Total observations: 132
#   Uncensored: 92, Censored: 40
#     Uncensored observations: 92
#     Censored observations: 40
#   Estimated parameters: [100.           0.93682594]
#   Average demand increase per censored observation: 2.83
#   Total estimated lost sales: 113
# Processing Point of Sale: EHA5993428
#   Total observations: 132
#   Uncensored: 89, Censored: 43
#     Uncensored observations: 89
#     Censored observations: 43
#   Estimated parameters: [100.           0.96683503]
#   Average demand increase per censored observation: 1.83
#   Total estimated lost sales: 79
# Processing Point of Sale: EHA6006525
#   Skipping POS EHA6006525: insufficient data (7 obs, need 10)
# Processing Point of Sale: EHA6122522
#   Total observations: 132
#   Uncensored: 94, Censored: 38
#     Uncensored observations: 94
#     Censored observations: 38
#   Estimated parameters: [14.06145745  0.5953155 ]
#   Average demand increase per censored observation: 4.49
#   Total estimated lost sales: 171
# Processing Point of Sale: EHA6130858
#   Total observations: 111
#   Uncensored: 73, Censored: 38
#     Uncensored observations: 73
#     Censored observations: 38
#   Estimated parameters: [100.           0.98089243]
#   Average demand increase per censored observation: 1.06
#   Total estimated lost sales: 40
# Processing Point of Sale: EHA6136639
#   Total observations: 81
#   Uncensored: 55, Censored: 26
#     Uncensored observations: 55
#     Censored observations: 26
#   Estimated parameters: [96.77631359  0.98477781]
#   Average demand increase per censored observation: 0.74
#   Total estimated lost sales: 19
# Processing Point of Sale: EHA6187800
#   Total observations: 18
#   Uncensored: 16, Censored: 2
#     Uncensored observations: 16
#     Censored observations: 2
#   Estimated parameters: [1.32190982 0.78178455]
#   Average demand increase per censored observation: 0.32
#   Total estimated lost sales: 1
# Processing Point of Sale: EHA6222229
#   Total observations: 132
#   Uncensored: 87, Censored: 45
#     Uncensored observations: 87
#     Censored observations: 45
#   Estimated parameters: [15.02199074  0.83647332]
#   Average demand increase per censored observation: 1.61
#   Total estimated lost sales: 73
# Processing Point of Sale: EHA6246781
#   Total observations: 132
#   Uncensored: 91, Censored: 41
#     Uncensored observations: 91
#     Censored observations: 41
#   Estimated parameters: [100.           0.93944667]
#   Average demand increase per censored observation: 2.87
#   Total estimated lost sales: 118
# Processing Point of Sale: EHA6247287
#   Total observations: 132
#   Uncensored: 87, Censored: 45
#     Uncensored observations: 87
#     Censored observations: 45
#   Estimated parameters: [4.55055902 0.6639899 ]
#   Average demand increase per censored observation: 1.40
#   Total estimated lost sales: 63
# Processing Point of Sale: EHA6261777
#   Total observations: 50
#   Uncensored: 33, Censored: 17
#     Uncensored observations: 33
#     Censored observations: 17
# ...
#   Total estimated lost sales: 59
# Processing Point of Sale: EHJ8387732
#   Total observations: 110
#   Uncensored: 110, Censored: 0
#   No censoring detected for POS EHJ8387732
# Processing Point of Sale: EHJ8395348
#   Total observations: 113
#   Uncensored: 87, Censored: 26
#     Uncensored observations: 87
#     Censored observations: 26
#   Estimated parameters: [100.           0.98590189]
#   Average demand increase per censored observation: 0.75
#   Total estimated lost sales: 20
# Processing Point of Sale: EHJ8442241
#   Total observations: 131
#   Uncensored: 92, Censored: 39
#     Uncensored observations: 92
#     Censored observations: 39
#   Estimated parameters: [100.           0.98365251]
#   Average demand increase per censored observation: 0.79
#   Total estimated lost sales: 31
# Processing Point of Sale: EHJ8462204
#   Total observations: 10
#   Uncensored: 10, Censored: 0
#   No censoring detected for POS EHJ8462204
# Processing Point of Sale: EHJ8465970
#   Total observations: 132
#   Uncensored: 116, Censored: 16
#     Uncensored observations: 116
#     Censored observations: 16
#   Estimated parameters: [100.           0.98521538]
#   Average demand increase per censored observation: 0.76
#   Total estimated lost sales: 12
# Processing Point of Sale: EHJ8498097
#   Total observations: 132
#   Uncensored: 87, Censored: 45
#     Uncensored observations: 87
#     Censored observations: 45
#   Estimated parameters: [99.86940604  0.96863593]
#   Average demand increase per censored observation: 1.69
#   Total estimated lost sales: 76
# Processing Point of Sale: EHJ8527291
#   Total observations: 132
#   Uncensored: 96, Censored: 36
#     Uncensored observations: 96
#     Censored observations: 36
#   Estimated parameters: [100.           0.87741617]
#   Average demand increase per censored observation: 4.73
#   Total estimated lost sales: 170
# Processing Point of Sale: EHJ8531161
#   Skipping POS EHJ8531161: insufficient data (7 obs, need 10)
# Processing Point of Sale: EHJ8537846
#   Total observations: 67
#   Uncensored: 59, Censored: 8
#     Uncensored observations: 59
#     Censored observations: 8
#   Estimated parameters: [47.41133489  0.98081184]
#   Average demand increase per censored observation: 0.39
#   Total estimated lost sales: 3
# Processing Point of Sale: EHJ8542976
#   Total observations: 65
#   Uncensored: 62, Censored: 3
#     Uncensored observations: 62
#     Censored observations: 3
#   Estimated parameters: [45.38803343  0.99      ]
#   Average demand increase per censored observation: 0.25
#   Total estimated lost sales: 1
# Processing Point of Sale: EHJ8544450
#   Total observations: 132
#   Uncensored: 89, Censored: 43
#     Uncensored observations: 89
#     Censored observations: 43
#   Estimated parameters: [100.           0.96399921]
#   Average demand increase per censored observation: 1.88
#   Total estimated lost sales: 81
# Processing Point of Sale: EHJ8596501
#   Total observations: 101
#   Uncensored: 84, Censored: 17
#     Uncensored observations: 84
#     Censored observations: 17
#   Estimated parameters: [100.           0.98835596]
#   Average demand increase per censored observation: 0.53
#   Total estimated lost sales: 9
# Processing Point of Sale: EHJ8600055
#   Total observations: 16
#   Uncensored: 16, Censored: 0
#   No censoring detected for POS EHJ8600055
# Processing Point of Sale: EHJ8614815
#   Total observations: 132
#   Uncensored: 87, Censored: 45
#     Uncensored observations: 87
#     Censored observations: 45
#   Estimated parameters: [100.           0.97420739]
#   Average demand increase per censored observation: 1.37
#   Total estimated lost sales: 61
# Processing Point of Sale: EHJ8615311
#   Total observations: 129
#   Uncensored: 90, Censored: 39
#     Uncensored observations: 90
#     Censored observations: 39
#   Estimated parameters: [100.           0.93270799]
#   Average demand increase per censored observation: 3.04
#   Total estimated lost sales: 119
# Processing Point of Sale: EHJ8619541
#   Total observations: 132
#   Uncensored: 89, Censored: 43
#     Uncensored observations: 89
#     Censored observations: 43
#   Estimated parameters: [21.15168668  0.85950452]
#   Average demand increase per censored observation: 1.78
#   Total estimated lost sales: 76
# Processing Point of Sale: EHJ8626759
#   Total observations: 104
#   Uncensored: 71, Censored: 33
#     Uncensored observations: 71
#     Censored observations: 33
#   Estimated parameters: [100.           0.95486104]
#   Average demand increase per censored observation: 2.44
#   Total estimated lost sales: 81
# Processing Point of Sale: EHJ8642246
#   Total observations: 132
#   Uncensored: 90, Censored: 42
#     Uncensored observations: 90
#     Censored observations: 42
#   Estimated parameters: [100.           0.95494535]
#   Average demand increase per censored observation: 2.30
#   Total estimated lost sales: 97
# Processing Point of Sale: EHJ8664206
#   Total observations: 132
#   Uncensored: 87, Censored: 45
#     Uncensored observations: 87
#     Censored observations: 45
#   Estimated parameters: [100.           0.97586187]
#   Average demand increase per censored observation: 1.37
#   Total estimated lost sales: 62
# Processing Point of Sale: EHJ8667825
#   Total observations: 127
#   Uncensored: 86, Censored: 41
#     Uncensored observations: 86
#     Censored observations: 41
#   Estimated parameters: [100.           0.98360084]
#   Average demand increase per censored observation: 0.82
#   Total estimated lost sales: 34
# Processing Point of Sale: EHJ8735430
#   Total observations: 128
#   Uncensored: 84, Censored: 44
#     Uncensored observations: 84
#     Censored observations: 44
#   Estimated parameters: [100.           0.98268505]
#   Average demand increase per censored observation: 0.94
#   Total estimated lost sales: 42
# Processing Point of Sale: EHJ8746500
#   Total observations: 12
#   Uncensored: 12, Censored: 0
#   No censoring detected for POS EHJ8746500
# Processing Point of Sale: EHJ8802387
#   Total observations: 114
#   Uncensored: 76, Censored: 38
#     Uncensored observations: 76
#     Censored observations: 38
#   Estimated parameters: [100.           0.98478649]
#   Average demand increase per censored observation: 0.82
#   Total estimated lost sales: 31
# Processing Point of Sale: EHJ8877841
#   Skipping POS EHJ8877841: insufficient data (4 obs, need 10)
# Processing Point of Sale: EHJ8879818
#   Total observations: 129
#   Uncensored: 92, Censored: 37
#     Uncensored observations: 92
#     Censored observations: 37
#   Estimated parameters: [100.           0.91438236]
#   Average demand increase per censored observation: 3.54
#   Total estimated lost sales: 131
# Processing Point of Sale: EHJ8928210
#   Total observations: 131
#   Uncensored: 88, Censored: 43
#     Uncensored observations: 88
#     Censored observations: 43
#   Estimated parameters: [100.           0.95929079]
#   Average demand increase per censored observation: 2.14
#   Total estimated lost sales: 92
# Processing Point of Sale: EHJ8949866
#   Total observations: 13
#   Uncensored: 13, Censored: 0
#   No censoring detected for POS EHJ8949866
# Processing Point of Sale: EHJ9090058
#   Total observations: 34
#   Uncensored: 34, Censored: 0
#   No censoring detected for POS EHJ9090058
# Processing Point of Sale: EHJ9129332
#   Total observations: 132
#   Uncensored: 86, Censored: 46
#     Uncensored observations: 86
#     Censored observations: 46
#   Estimated parameters: [100.           0.97887845]
#   Average demand increase per censored observation: 1.10
#   Total estimated lost sales: 51
# Processing Point of Sale: EHJ9147332
#   Total observations: 132
#   Uncensored: 93, Censored: 39
#     Uncensored observations: 93
#     Censored observations: 39
#   Estimated parameters: [100.           0.92263047]
#   Average demand increase per censored observation: 3.69
#   Total estimated lost sales: 144
# Processing Point of Sale: EHJ9164097
#   Total observations: 132
#   Uncensored: 87, Censored: 45
#     Uncensored observations: 87
#     Censored observations: 45
#   Estimated parameters: [31.04846579  0.91067625]
#   Average demand increase per censored observation: 1.60
#   Total estimated lost sales: 72
# Processing Point of Sale: EHJ9197040
#   Total observations: 18
#   Uncensored: 18, Censored: 0
#   No censoring detected for POS EHJ9197040
# Processing Point of Sale: EHJ9197629
#   Total observations: 130
#   Uncensored: 91, Censored: 39
#     Uncensored observations: 91
#     Censored observations: 39
#   Estimated parameters: [100.           0.98278968]
#   Average demand increase per censored observation: 0.94
#   Total estimated lost sales: 37
# Processing Point of Sale: EHJ9222434
#   Total observations: 35
#   Uncensored: 35, Censored: 0
#   No censoring detected for POS EHJ9222434
# Processing Point of Sale: EHJ9253699
#   Total observations: 132
#   Uncensored: 96, Censored: 36
#     Uncensored observations: 96
#     Censored observations: 36
#   Estimated parameters: [12.01941113  0.51533581]
#   Average demand increase per censored observation: 5.14
#   Total estimated lost sales: 185
# Processing Point of Sale: EHJ9258147
#   Skipping POS EHJ9258147: insufficient data (8 obs, need 10)
# Processing Point of Sale: EHJ9286819
#   Total observations: 132
#   Uncensored: 91, Censored: 41
#     Uncensored observations: 91
#     Censored observations: 41
#   Estimated parameters: [10.86917963  0.66170629]
#   Average demand increase per censored observation: 2.87
#   Total estimated lost sales: 117
# Processing Point of Sale: EHJ9301437
#   Total observations: 80
#   Uncensored: 75, Censored: 5
#     Uncensored observations: 75
#     Censored observations: 5
#   Estimated parameters: [1.75898113 0.74870108]
#   Average demand increase per censored observation: 0.45
#   Total estimated lost sales: 2
# Processing Point of Sale: EHJ9376531
#   Total observations: 112
#   Uncensored: 102, Censored: 10
#     Uncensored observations: 102
#     Censored observations: 10
#   Estimated parameters: [87.03325869  0.99      ]
#   Average demand increase per censored observation: 0.43
#   Total estimated lost sales: 4
# Processing Point of Sale: EHJ9386449
#   Total observations: 132
#   Uncensored: 94, Censored: 38
#     Uncensored observations: 94
#     Censored observations: 38
#   Estimated parameters: [14.19619826  0.90929282]
#   Average demand increase per censored observation: 0.74
#   Total estimated lost sales: 28
# Processing Point of Sale: EHJ9400946
#   Total observations: 131
#   Uncensored: 87, Censored: 44
#     Uncensored observations: 87
#     Censored observations: 44
#   Estimated parameters: [100.           0.97556913]
#   Average demand increase per censored observation: 1.36
#   Total estimated lost sales: 60
# Processing Point of Sale: EHJ9403784
#   Total observations: 14
#   Uncensored: 13, Censored: 1
#     Uncensored observations: 13
#     Censored observations: 1
#   Estimated parameters: [43.60020555  0.99      ]
#   Average demand increase per censored observation: 0.16
#   Total estimated lost sales: 0
# Processing Point of Sale: EHJ9411960
#   Total observations: 132
#   Uncensored: 92, Censored: 40
#     Uncensored observations: 92
#     Censored observations: 40
#   Estimated parameters: [100.           0.93502511]
#   Average demand increase per censored observation: 3.46
#   Total estimated lost sales: 138
# Processing Point of Sale: EHJ9443516
#   Total observations: 132
#   Uncensored: 90, Censored: 42
#     Uncensored observations: 90
#     Censored observations: 42
#   Estimated parameters: [100.           0.95797279]
#   Average demand increase per censored observation: 2.05
#   Total estimated lost sales: 86
# Processing Point of Sale: EHJ9451498
#   Total observations: 132
#   Uncensored: 87, Censored: 45
#     Uncensored observations: 87
#     Censored observations: 45
#   Estimated parameters: [100.           0.97215108]
#   Average demand increase per censored observation: 1.56
#   Total estimated lost sales: 70
# Processing Point of Sale: EHJ9478858
#   Total observations: 34
#   Uncensored: 33, Censored: 1
#     Uncensored observations: 33
#     Censored observations: 1
#   Estimated parameters: [10.31443565  0.94513645]
#   Average demand increase per censored observation: 0.36
#   Total estimated lost sales: 0
# Processing Point of Sale: EHJ9589136
#   Total observations: 120
#   Uncensored: 78, Censored: 42
#     Uncensored observations: 78
#     Censored observations: 42
#   Estimated parameters: [8.7344643  0.81056719]
#   Average demand increase per censored observation: 1.17
#   Total estimated lost sales: 49
# Processing Point of Sale: EHJ9606686
#   Total observations: 132
#   Uncensored: 91, Censored: 41
#     Uncensored observations: 91
#     Censored observations: 41
#   Estimated parameters: [100.           0.94176477]
#   Average demand increase per censored observation: 2.69
#   Total estimated lost sales: 110
# Processing Point of Sale: EHJ9634167
#   Total observations: 56
#   Uncensored: 47, Censored: 9
#     Uncensored observations: 47
#     Censored observations: 9
#   Estimated parameters: [18.0747209   0.92616288]
#   Average demand increase per censored observation: 0.63
#   Total estimated lost sales: 6
# Processing Point of Sale: EHJ9657567
#   Total observations: 132
#   Uncensored: 86, Censored: 46
#     Uncensored observations: 86
#     Censored observations: 46
#   Estimated parameters: [21.08349417  0.9081816 ]
#   Average demand increase per censored observation: 1.09
#   Total estimated lost sales: 50
# Processing Point of Sale: EHJ9705298
#   Total observations: 26
#   Uncensored: 24, Censored: 2
#     Uncensored observations: 24
#     Censored observations: 2
#   Estimated parameters: [47.83175319  0.99      ]
#   Average demand increase per censored observation: 0.27
#   Total estimated lost sales: 1
# Processing Point of Sale: EHJ9789150
#   Total observations: 132
#   Uncensored: 89, Censored: 43
#     Uncensored observations: 89
#     Censored observations: 43
#   Estimated parameters: [100.           0.96568969]
#   Average demand increase per censored observation: 1.88
#   Total estimated lost sales: 81
# Processing Point of Sale: EHJ9790755
#   Total observations: 30
#   Uncensored: 21, Censored: 9
#     Uncensored observations: 21
#     Censored observations: 9
#   Estimated parameters: [100.           0.96833549]
#   Average demand increase per censored observation: 1.57
#   Total estimated lost sales: 14
# Processing Point of Sale: EHJ9798482
#   Total observations: 124
#   Uncensored: 90, Censored: 34
#     Uncensored observations: 90
#     Censored observations: 34
#   Estimated parameters: [8.62687006 0.85519623]
#   Average demand increase per censored observation: 0.77
#   Total estimated lost sales: 26
# Processing Point of Sale: EHJ9816001
#   Total observations: 132
#   Uncensored: 86, Censored: 46
#     Uncensored observations: 86
#     Censored observations: 46
#   Estimated parameters: [13.11721383  0.86609721]
#   Average demand increase per censored observation: 1.08
#   Total estimated lost sales: 50
# Processing Point of Sale: EHJ9836864
#   Total observations: 132
#   Uncensored: 90, Censored: 42
#     Uncensored observations: 90
#     Censored observations: 42
#   Estimated parameters: [16.4290979   0.90632978]
#   Average demand increase per censored observation: 0.84
#   Total estimated lost sales: 35
# Processing Point of Sale: EHJ9839758
#   Total observations: 56
#   Uncensored: 45, Censored: 11
#     Uncensored observations: 45
#     Censored observations: 11
#   Estimated parameters: [3.30085509 0.71500066]
#   Average demand increase per censored observation: 0.79
#   Total estimated lost sales: 9
# Processing Point of Sale: EHJ9881629
#   Total observations: 132
#   Uncensored: 91, Censored: 41
#     Uncensored observations: 91
#     Censored observations: 41
#   Estimated parameters: [100.           0.94784687]
#   Average demand increase per censored observation: 2.52
#   Total estimated lost sales: 103
# Processing Point of Sale: EHJ9923970
#   Total observations: 132
#   Uncensored: 96, Censored: 36
#     Uncensored observations: 96
#     Censored observations: 36
#   Estimated parameters: [100.           0.90397231]
#   Average demand increase per censored observation: 3.70
#   Total estimated lost sales: 133
#
# Uncensoring complete!
# Original total sales: 1079507.0
# Uncensored total demand: 1242666.6311039538
# Estimated total lost sales: 163159.6311039538
# Processed 2550 stores successfully
# Average estimated parameters: {'average_r': np.float64(74.03656730777783), 'average_p': np.float64(0.9001180642904948)}

# %% [markdown]
# # Grouping by Bezug

# %%
def calculate_kpis_by_bezug_average(dataframe, method_name):
    """
    Calculate KPIs for demand forecasting evaluation, averaged over 'Bezug' groups.
    """
    grouped = dataframe.groupby('Bezug')

    results = []

    for _, group in grouped:
        df = group.copy()
        censored_df = df[df['Zensiert'] == 1]

        if censored_df.empty:
            continue

        y_pred = censored_df['Verkauf_Uncensored'].values
        y_true = censored_df['Verkauf_MBR'].values
        n = len(y_pred)

        bias = np.sum(y_pred - y_true) / n
        accuracy = np.sum(y_pred == y_true) / n
        overestimation_rate = np.sum(y_pred > y_true) / n
        underestimation_rate = np.sum(y_pred < y_true) / n

        alphas = [0, 0.5, 1, 1.5]
        weighted_maes = {}
        for a in alphas:
            if a == 0:
                weighted_maes[a] = np.mean(np.abs(y_pred - y_true))
            else:
                weights = np.power(y_true, a)
                weights = np.where(y_true == 0, 0, weights)
                weighted_maes[a] = np.sum(weights * np.abs(y_pred - y_true)) / np.sum(weights) if np.sum(weights) > 0 else 0

        abs_errors = np.abs(y_pred - y_true)
        sorted_errors = np.sort(abs_errors)
        weighted_sum = np.sum((i + 1) * sorted_errors[i] for i in range(n))
        total_sum = np.sum(abs_errors)
        gini = (2 * weighted_sum) / (n * total_sum) - (n + 1) / n if total_sum > 0 else 0
        overstock = np.sum(np.maximum(0, y_pred - y_true))

        results.append({
            'bias': bias,
            'accuracy': accuracy,
            'overestimation_rate': overestimation_rate,
            'underestimation_rate': underestimation_rate,
            'weighted_mae_0': weighted_maes[0],
            'weighted_mae_0.5': weighted_maes[0.5],
            'weighted_mae_1': weighted_maes[1],
            'weighted_mae_1.5': weighted_maes[1.5],
            'gini_coefficient': gini,
            'overstock': overstock
        })

    if not results:
        print(f"No valid (Zensiert == 1) rows found for method {method_name}")
        return {}

    avg_results = pd.DataFrame(results).mean()

    bias = avg_results['bias']
    bias_direction = "overestimation" if bias > 0 else "underestimation" if bias < 0 else "neutral"

    print(f"Method: {method_name} (averaged by Bezug)")
    print(f"- Bias: {bias:.3f} ({bias_direction})")
    print(f"- Weighted MAE (α=0): {avg_results['weighted_mae_0']:.3f}")
    print(f"- Weighted MAE (α=0.5): {avg_results['weighted_mae_0.5']:.3f}")
    print(f"- Weighted MAE (α=1): {avg_results['weighted_mae_1']:.3f}")
    print(f"- Weighted MAE (α=1.5): {avg_results['weighted_mae_1.5']:.3f}")
    print(f"- Accuracy (exact matches): {avg_results['accuracy']:.3f}")
    print(f"- Overestimation Rate: {avg_results['overestimation_rate']:.3f}")
    print(f"- Underestimation Rate: {avg_results['underestimation_rate']:.3f}")
    print(f"- Gini Coefficient: {avg_results['gini_coefficient']:.3f}")
    print(f"Overstock: {int(avg_results['overstock'])}")

    return avg_results.to_dict()

# %% [markdown]
# # Grouping by Heftnummer, Heftjahr Testing

# %%
def calculate_kpis_by_issue_average(dataframe, method_name):
    """
    Calculate KPIs for demand forecasting evaluation, averaged over (Heftnummer, Heftjahr) groups.
    """
    grouped = dataframe.groupby(['Heftnummer', 'Heftjahr'])

    results = []

    for _, group in grouped:
        df = group.copy()
        censored_df = df[df['Zensiert'] == 1]

        if censored_df.empty:
            continue
        
        y_pred = censored_df['Verkauf_Uncensored'].values
        y_true = censored_df['Verkauf_MBR'].values
        n = len(y_pred)

        bias = np.sum(y_pred - y_true) / n
        accuracy = np.sum(y_pred == y_true) / n
        overestimation_rate = np.sum(y_pred > y_true) / n
        underestimation_rate = np.sum(y_pred < y_true) / n

        alphas = [0, 0.5, 1, 1.5]
        weighted_maes = {}
        for a in alphas:
            if a == 0:
                weighted_maes[a] = np.mean(np.abs(y_pred - y_true))
            else:
                weights = np.power(y_true, a)
                weights = np.where(y_true == 0, 0, weights)
                weighted_maes[a] = np.sum(weights * np.abs(y_pred - y_true)) / np.sum(weights) if np.sum(weights) > 0 else 0

        abs_errors = np.abs(y_pred - y_true)
        sorted_errors = np.sort(abs_errors)
        weighted_sum = np.sum((i + 1) * sorted_errors[i] for i in range(n))
        total_sum = np.sum(abs_errors)
        gini = (2 * weighted_sum) / (n * total_sum) - (n + 1) / n if total_sum > 0 else 0
        overstock = np.sum(np.maximum(0, y_pred - y_true))

        results.append({
            'bias': bias,
            'accuracy': accuracy,
            'overestimation_rate': overestimation_rate,
            'underestimation_rate': underestimation_rate,
            'weighted_mae_0': weighted_maes[0],
            'weighted_mae_0.5': weighted_maes[0.5],
            'weighted_mae_1': weighted_maes[1],
            'weighted_mae_1.5': weighted_maes[1.5],
            'gini_coefficient': gini,
            'overstock': overstock
        })

    if not results:
        print(f"No valid (Zensiert == 1) rows found for method {method_name}")
        return {}

    avg_results = pd.DataFrame(results).mean()

    bias = avg_results['bias']
    bias_direction = "overestimation" if bias > 0 else "underestimation" if bias < 0 else "neutral"

    print(f"Method: {method_name} (averaged by Heftnummer & Heftjahr)")
    print(f"- Bias: {bias:.3f} ({bias_direction})")
    print(f"- Weighted MAE (α=0): {avg_results['weighted_mae_0']:.3f}")
    print(f"- Weighted MAE (α=0.5): {avg_results['weighted_mae_0.5']:.3f}")
    print(f"- Weighted MAE (α=1): {avg_results['weighted_mae_1']:.3f}")
    print(f"- Weighted MAE (α=1.5): {avg_results['weighted_mae_1.5']:.3f}")
    print(f"- Accuracy (exact matches): {avg_results['accuracy']:.3f}")
    print(f"- Overestimation Rate: {avg_results['overestimation_rate']:.3f}")
    print(f"- Underestimation Rate: {avg_results['underestimation_rate']:.3f}")
    print(f"- Gini Coefficient: {avg_results['gini_coefficient']:.3f}")
    print(f"Overstock: {int(avg_results['overstock'])}")

    return avg_results.to_dict()
