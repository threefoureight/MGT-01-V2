# %% [markdown]
# # Conrad

# %%
from scipy.stats import poisson
import pandas as pd
import numpy as np

def compute_mu(left, right, n, N, r, x_sum, value_tol=0.01, interval_tol=0.01, max_iterations=1000000000000000):
    iteration = 0

    while iteration < max_iterations and (right - left) > interval_tol:
        mu = (left + right) / 2
        value_0 = (x_sum - mu * n) * (1 - poisson.cdf(N - 1, mu)) + mu * (n - r) * (1 - poisson.cdf(N - 2, mu))

        if iteration % 10 == 0:
            print(f"Iteration {iteration}: mu={mu:.4f}, value_0={value_0:.6f}")

        if abs(value_0) < value_tol:
            print(f"Converged after {iteration} iterations: mu={mu:.4f}")
            return mu

        if value_0 < 0:
            right = mu
        else:
            left = mu

        iteration += 1

    print(f"Stopped after {iteration} iterations: mu={mu:.4f}, value_0={value_0:.6f}")
    return mu


def create_order_specific_mu_dict(df):
    """
    Create μ estimates for each (week, order_quantity) combination using Conrad's method.
    Each stockout level gets its own Poisson distribution.
    """
    order_specific_mu_dict = {}
    total_skipped = 0

    for (year, week), week_data in df.groupby(['Heftjahr', 'Heftnummer']):
        for bezug_val, group in week_data.groupby('Bezug'):
            n = len(group)
            N = bezug_val
            r = (group['Verkauf'] == bezug_val).sum()  # stockouts
            x_sum = np.minimum(group['Verkauf'], N).sum()

            if n < 2:
                # total_skipped += 1
                # print(f"Skipping: n={n} too small")
                continue
            if r == 0:
                # total_skipped += 1
                # print(f"Skipping: no stockouts in group")
                continue
            if r == n:
                # total_skipped += 1
                # print(f"Skipping: all stockouts in group")
                continue
            
            # bounds are problematic
            try:
                mu_est = compute_mu(0.1, 4, n, N, r, x_sum)
                if mu_est:
                    # Store with (year, week, order_quantity) key
                    key = (year, week, bezug_val)
                    order_specific_mu_dict[key] = mu_est
            except Exception as e:
                print(f"Error in week {week}, Bezug {N}: {e}")
                continue
    #print(f"total skipped: {total_skipped}")

    return order_specific_mu_dict

def expected_poisson_tail(mu, N, max_k=200):
    """
    Compute E[X | X >= N] for X ~ Poisson(mu)
    """
    k_vals = np.arange(N, max_k)
    pmf = poisson.pmf(k_vals, mu)
    tail_prob = 1 - poisson.cdf(N - 1, mu)
    if tail_prob < 1e-8:
        return N  # fallback: don't uncensor
    return np.sum(k_vals * pmf) / tail_prob

def apply_conrad_uncensoring_1(df, order_specific_mu_dict):
    """
    Given a DataFrame with Verkauf, Bezug, is_stockout, Heftjahr, Heftnummer,
    replace Verkauf with E[X | X >= Bezug] when censored.
    
    Uses order-quantity-specific Poisson(μ) parameters.
    
    Modifies the DataFrame in place by updating the Verkauf column.
    """
    df = df.copy()

    df['Verkauf_Uncensored'] = df['Verkauf'].copy()

    for idx, row in df.iterrows():
        # Skip if no stockout occurred
        if row['Zensiert'] == 0:
            continue
            
        # Get the order-quantity-specific demand parameter
        key = (row['Heftjahr'], row['Heftnummer'], row['Bezug'])
        mu = order_specific_mu_dict.get(key, None)

        if mu is None:
            # no estimate available for this specific (week, order_quantity) — keep original value
            continue

        # POS sold out — uncensor using the specific distribution for this order quantity
        est_demand = expected_poisson_tail(mu, row['Bezug'])
        df.at[idx, 'Verkauf_Uncensored'] = np.round(est_demand)

    return df

def apply_conrad_uncensoring(df):
    """
    WRAPPER FUNCTION: This is what gets called by the main processing loop
    """
    # Step 1: Create mu dictionary from the dataset
    order_specific_mu_dict = create_order_specific_mu_dict(df)
    
    # Step 2: Apply uncensoring using the mu dictionary  
    return apply_conrad_uncensoring_1(df, order_specific_mu_dict)

# Usage
# order_specific_mu_dict = create_order_specific_mu_dict(df)
# df_conrad_uncensored = apply_conrad_uncensoring_1(df, order_specific_mu_dict)
# results = calculate_kpis(df_conrad_uncensored, "Conrad, Altered")

# %% [markdown]
# # Nahmias

# %%
import numpy as np
import pandas as pd
from scipy.stats import norm

def compute_mu_sigma_nahmias(sales, S):
    """
    Compute mu and sigma using Nahmias method for censored normal data.
    
    Parameters:
    -----------
    sales : array-like
        Observed sales data (censored at S)
    S : float
        Censoring limit (inventory level)
    
    Returns:
    --------
    tuple: (mu_hat, sigma_hat) or (None, None) if estimation fails
    """
    sales = np.array(sales)
    sales = sales[~np.isnan(sales)]
    
    if len(sales) < 5:  # Need reasonable sample size
        return None, None
    
    # The uncensored observations are those < S
    observed = sales[sales < S]
    n = len(sales)
    r = len(observed)
    
    if r < 2 or r >= n-1:  # Need at least 2 uncensored, 1 censored
        return None, None
        
    p = r / n  # Proportion uncensored
    
    # # Avoid extreme proportions where method is unstable
    # if p < 0.2 or p > 0.8:
    #     return None, None
    
    x_bar = np.mean(observed)
    s2 = np.var(observed, ddof=1)
    
    if s2 <= 1e-6:
        return None, None
    
    try:
        z = norm.ppf(p)
        
        # Check for extreme z values that cause instability
        if abs(z) > 2:
            return None, None
        
        pdf_z = norm.pdf(z)
        
        denominator = 1 - (z * pdf_z / p) - (pdf_z**2 / p**2)
        
        if denominator <= 0.1:  # Need substantial positive denominator
            return None, None
            
        sigma_hat2 = s2 / denominator
        
        if sigma_hat2 <= 0 or sigma_hat2 > 1e6:
            return None, None
            
        sigma_hat = np.sqrt(sigma_hat2)
        mu_hat = x_bar + sigma_hat * pdf_z / p
        
        # Sanity check on estimates
        if abs(mu_hat) > 1e6 or sigma_hat > 1e3:
            return None, None
        
        return mu_hat, sigma_hat
        
    except Exception:
        return None, None

def create_order_specific_nahmias_dict(df):
    """
    Create μ and σ estimates for each (week, order_quantity) combination using Nahmias method.
    Each stockout level gets its own Normal distribution.
    """
    order_specific_mu_dict = {}
    order_specific_sigma_dict = {}

    for (year, week), week_data in df.groupby(['Heftjahr', 'Heftnummer']):
        for bezug_val, group in week_data.groupby('Bezug'):
            n = len(group)
            S = bezug_val
            
            # Count stockouts (sales = order quantity)
            stockouts = (group['Verkauf'] == bezug_val).sum()
            
            if n < 5 or stockouts == 0 or stockouts == n:
                continue  # Not enough variation or unusable

            try:
                mu_est, sigma_est = compute_mu_sigma_nahmias(group['Verkauf'], S)
                if mu_est is not None and sigma_est is not None:
                    # Store with (year, week, order_quantity) key
                    key = (year, week, bezug_val)
                    order_specific_mu_dict[key] = mu_est
                    order_specific_sigma_dict[key] = sigma_est
            except Exception as e:
                print(f"Error in week {week}, Bezug {bezug_val}: {e}")
                continue

    return order_specific_mu_dict, order_specific_sigma_dict

def expected_normal_tail(mu, sigma, S, max_iterations=1000):
    """
    Compute E[X | X >= S] for X ~ Normal(mu, sigma)
    Using numerical integration approximation
    """
    if sigma <= 0:
        return S
    
    # Standardize
    z = (S - mu) / sigma
    
    # If S is way above the mean, just return S (no meaningful tail)
    if z > 6:
        return S
    
    # Use the formula: E[X | X >= S] = mu + sigma * phi(z) / (1 - Phi(z))
    # where phi is PDF and Phi is CDF
    tail_prob = 1 - norm.cdf(z)
    
    if tail_prob < 1e-10:  # Essentially no tail probability
        return S
    
    expected_value = mu + sigma * norm.pdf(z) / tail_prob
    
    return expected_value

def apply_nahmias_uncensoring_1(df, order_specific_mu_dict, order_specific_sigma_dict):
    """
    Given a DataFrame with Verkauf, Bezug, is_stockout, Heftjahr, Heftnummer,
    replace Verkauf with E[X | X >= Bezug] when censored.
    
    Uses order-quantity-specific Normal(μ, σ) parameters.
    
    Modifies the DataFrame in place by updating the Verkauf column.
    """
    df = df.copy()
    df['Verkauf_Uncensored'] = df['Verkauf'].copy()

    for idx, row in df.iterrows():
        # Skip if no stockout occurred
        if row['Zensiert'] == 0:
            continue
            
        # Get the order-quantity-specific demand parameters
        key = (row['Heftjahr'], row['Heftnummer'], row['Bezug'])
        mu = order_specific_mu_dict.get(key, None)
        sigma = order_specific_sigma_dict.get(key, None)

        if mu is None or sigma is None:
            # no estimate available for this specific (week, order_quantity) — keep original value
            continue

        # POS sold out — uncensor using the specific distribution for this order quantity
        est_demand = expected_normal_tail(mu, sigma, row['Bezug'])
        df.at[idx, 'Verkauf_Uncensored'] = np.round(est_demand)

    return df

def apply_nahmias_uncensoring(df):
    """
    WRAPPER FUNCTION: This is what gets called by the main processing loop
    """
    # Step 1: Create mu dictionary from the dataset
    order_specific_mu_dict, compute_mu_sigma_nahmias = create_order_specific_nahmias_dict(df)
    
    # Step 2: Apply uncensoring using the mu dictionary  
    return apply_nahmias_uncensoring_1(df, order_specific_mu_dict, compute_mu_sigma_nahmias)


# Usage
# order_specific_mu_dict, order_specific_sigma_dict = create_order_specific_nahmias_dict(df)
# df_nahmias_uncensored = apply_nahmias_uncensoring_1(df, order_specific_mu_dict, order_specific_sigma_dict)

# %% [markdown]
# # Baseline

# %%
def apply_baseline_uncensoring(df):
    df_result = df.copy()
    df_result['Verkauf_Uncensored'] = df_result['Verkauf'] 
    return df_result

# %% [markdown]
# # N1, N2, N3, EM, PD

# %%
import pandas as pd
import numpy as np
from scipy.stats import poisson

def apply_n1_uncensoring(df):
    df = df.copy()
    df['Verkauf_Uncensored'] = df['Verkauf'].copy()
    
    # Use transform to get group means - NO MERGE!
    group_means = df.groupby('EHASTRA_EH_NUMMER')['Verkauf'].transform('mean')
    
    # Replace censored with group means
    censored_mask = (df['Zensiert'] == 1)
    df.loc[censored_mask, 'Verkauf_Uncensored'] = group_means[censored_mask]
    
    return df

def apply_n2_uncensoring(df):
    df = df.copy()
    df['Verkauf_Uncensored'] = df['Verkauf'].copy()
    
    # Calculate uncensored means per group - NO MERGE!
    uncensored_means = (
        df[df['Zensiert'] == 0]
        .groupby('EHASTRA_EH_NUMMER')['Verkauf']
        .transform('mean')
    )
    
    # Map to all rows using the POS ID
    df['group_uncensored_mean'] = df.groupby('EHASTRA_EH_NUMMER')['EHASTRA_EH_NUMMER'].transform(
        lambda group: df[df['Zensiert'] == 0].groupby('EHASTRA_EH_NUMMER')['Verkauf'].mean().get(group.iloc[0], 0)
    )
    
    # Replace censored values
    censored_mask = (df['Zensiert'] == 1)
    df.loc[censored_mask, 'Verkauf_Uncensored'] = df.loc[censored_mask, 'group_uncensored_mean']
    
    return df.drop('group_uncensored_mean', axis=1)

def apply_n3_uncensoring(df):
    df = df.copy()
    df['Verkauf_Uncensored'] = df['Verkauf'].copy()
    
    # Calculate uncensored means per group - NO MERGE!
    uncensored_group_means = (
        df[df['Zensiert'] == 0]
        .groupby('EHASTRA_EH_NUMMER')['Verkauf']
        .mean()
    )
    
    # Map means to each row based on POS ID
    df['group_mean'] = df['EHASTRA_EH_NUMMER'].map(uncensored_group_means).fillna(0)
    
    # For censored: max(observed, group_mean)
    censored_mask = (df['Zensiert'] == 1)
    df.loc[censored_mask, 'Verkauf_Uncensored'] = np.maximum(
        df.loc[censored_mask, 'Verkauf'],
        df.loc[censored_mask, 'group_mean']
    )
    
    return df.drop('group_mean', axis=1)

def apply_em_uncensoring(df, max_iter=30, tolerance=1e-6):
    """Your EM method with syntax fix"""
    df = df.copy()
    df['Verkauf_Uncensored'] = df['Verkauf'].copy()
    
    # Direct boolean indexing without extra columns
    stockout_condition = (df['Zensiert'] == 1)
    
    # Process groups with minimal overhead
    for (pos,), group in df.groupby(['EHASTRA_EH_NUMMER']):
        try:
            group_stockout = stockout_condition.loc[group.index]
            
            if not group_stockout.any():
                continue
            
            sales = group['Verkauf_Uncensored'].values
            is_stockout = group_stockout.values
            
            uncensored = sales[~is_stockout]
            censored = sales[is_stockout]
            
            # Skip if no uncensored data - but keep original values
            if len(uncensored) == 0:
                continue
            
            # Quick lambda initialization
            lambda_est = np.mean(uncensored) if len(uncensored) > 0 else np.mean(sales) * 1.5
            lambda_est = max(lambda_est, 0.1)
            
            # Fast EM loop - FIXED SYNTAX
            for iteration in range(max_iter):  # Fixed: was "for * in range(max*iter)"
                lambda_old = lambda_est
                
                # Batch E-step
                surv_prob = 1 - poisson.cdf(censored - 1, lambda_est)
                exact_prob = poisson.pmf(censored, lambda_est)
                surv_prob = np.maximum(surv_prob, 1e-12)
                
                expected = lambda_est + censored * exact_prob / surv_prob
                expected = np.maximum(expected, censored.astype(float))
                
                # M-step
                lambda_est = max(np.mean(np.concatenate([uncensored, expected])), 0.1)
                
                if abs(lambda_est - lambda_old) < tolerance:
                    break
            
            # Final update
            surv_prob = 1 - poisson.cdf(censored - 1, lambda_est)
            exact_prob = poisson.pmf(censored, lambda_est)
            surv_prob = np.maximum(surv_prob, 1e-12)
            
            final_expected = lambda_est + censored * exact_prob / surv_prob
            final_expected = np.maximum(final_expected, censored.astype(float))
            
            # Update original dataframe
            stockout_indices = group.index[is_stockout]
            df.loc[stockout_indices, 'Verkauf_Uncensored'] = final_expected.round()
            
        except Exception as e:
            print(f"EM error for POS {pos}: {e}")
            # Fill with original Verkauf values for this POS when error occurs
            group_stockout_indices = group.index[stockout_condition.loc[group.index]]
            df.loc[group_stockout_indices, 'Verkauf_Uncensored'] = df.loc[group_stockout_indices, 'Verkauf']
            continue
    
    return df

def apply_pd_uncensoring(df, tau=0.5, max_iter=20, tolerance=1e-4):
    """PD with skip for invalid POS groups and fallback to original Verkauf"""
    df = df.copy()
    df["is_closed"] = (df["Zensiert"] == 1)
    df['Verkauf_Uncensored'] = df['Verkauf'].copy().astype(float)

    def compute_pd_projection1(obs_val, lambda_est, tau):
        """Your PD projection with NaN protection"""
        try:
            # Check for NaN inputs
            if pd.isna(obs_val) or pd.isna(lambda_est) or lambda_est <= 0:
                return float(obs_val) if not pd.isna(obs_val) else 0.0
            
            obs_val = int(round(obs_val))
            
            def objective(k_proj):
                k_proj = int(round(k_proj))
                
                if k_proj < obs_val:
                    return float('inf')
                
                # Area A: P(obs_val <= X <= k_proj)
                area_A = poisson.cdf(k_proj, lambda_est) - poisson.cdf(obs_val - 1, lambda_est)
                
                # Area B: P(X > k_proj)
                area_B = 1 - poisson.cdf(k_proj, lambda_est)
                
                if area_B > 1e-10:
                    ratio = area_A / area_B
                    target_ratio = (1 - tau) / tau
                    return abs(ratio - target_ratio)
                else:
                    return abs(area_A - (1 - tau))
            
            # Search for optimal projection
            upper_bound = int(obs_val + max(10, int(3 * np.sqrt(lambda_est))))
            
            best_k = obs_val
            best_objective = float('inf')
            
            for k in range(int(obs_val), upper_bound + 1):
                obj_val = objective(k)
                if obj_val < best_objective:
                    best_objective = obj_val
                    best_k = k
            
            return float(best_k)
            
        except Exception:
            # Silent fallback to original value
            return float(obs_val) if not pd.isna(obs_val) else 0.0
    
    # Process groups
    grouped = df.groupby('EHASTRA_EH_NUMMER')
    
    for pos, group in grouped:
        try:
            open_mask = ~group['is_closed']
            closed_mask = group['is_closed']
            
            open_sales = group.loc[open_mask, 'Verkauf_Uncensored'].values
            closed_sales = group.loc[closed_mask, 'Verkauf_Uncensored'].values
            
            # SKIP POS WITHOUT VALID UNCENSORED DATA
            if len(open_sales) == 0 or np.all(pd.isna(open_sales)):
                print(f"Skipping POS {pos}: no valid uncensored data")
                continue
            
            # Initialize lambda parameter
            lambda_est = np.mean(open_sales[~pd.isna(open_sales)])
            
            # SKIP IF LAMBDA IS INVALID
            if pd.isna(lambda_est) or lambda_est <= 0:
                print(f"Skipping POS {pos}: invalid lambda {lambda_est}")
                continue
            
            lambda_est = max(lambda_est, 0.1)
            closed_indices = group[closed_mask].index.values
            
            # Iterative process
            for iteration in range(max_iter):
                lambda_old = lambda_est
                
                # Project closed observations
                projected_values = np.array([
                    compute_pd_projection1(obs, lambda_est, tau) 
                    for obs in closed_sales
                ])
                
                # Re-estimate lambda
                all_values = np.concatenate([open_sales, projected_values])
                lambda_est = np.mean(all_values)
                lambda_est = max(lambda_est, 0.1)
                
                # Check convergence
                if abs(lambda_est - lambda_old) < tolerance:
                    break
            
            # Final projection
            final_projections = np.array([
                compute_pd_projection1(obs, lambda_est, tau) 
                for obs in closed_sales
            ])
            
            # Update dataframe
            df.loc[closed_indices, 'Verkauf_Uncensored'] = final_projections.round()
            
        except Exception as e:
            print(f"PD error for POS {pos}: {e}")
            # FALLBACK: Keep original values for this POS
            continue
    
    # FINAL FALLBACK: Any remaining NaN values get original Verkauf
    nan_mask = df['Verkauf_Uncensored'].isna()
    df.loc[nan_mask, 'Verkauf_Uncensored'] = df.loc[nan_mask, 'Verkauf']
    
    return df.drop('is_closed', axis=1)

# %% [markdown]
# # Script for creating csv of all features for all mags

# %%
import pandas as pd
import numpy as np
import os
import glob
from pathlib import Path

def calculate_kpis_for_pos_fast(pos_uncensored_data, pos_censored_data, method_name, magazine_name, pos_id):
    """
    Fast KPI calculation using pre-filtered data
    
    Parameters:
    - pos_uncensored_data: Pre-filtered uncensored data for this POS
    - pos_censored_data: Pre-filtered censored data for this POS  
    - method_name: string name of the method being evaluated
    - magazine_name: string name of the magazine
    - pos_id: EHASTRA_EH_NUMMER for this POS
    """
    
    if len(pos_censored_data) == 0:
        # Return empty KPIs if no censored data for this POS
        return {
            'bias': 0,
            'weighted_mae_0': 0,
            'weighted_mae_0.5': 0,
            'weighted_mae_1': 0,
            'weighted_mae_1.5': 0,
            'accuracy': 0,
            'overestimation_rate': 0,
            'underestimation_rate': 0,
            'gini_coefficient': 0,
            'overstock': 0,
            'n_censored_observations': 0
        }
    
    # Extract values directly (already filtered)
    y_pred = pos_uncensored_data['Verkauf_Uncensored'].values
    y_true = pos_censored_data['Verkauf_MBR'].values
    
    n = len(y_pred)
    
    # Vectorized calculations for speed
    errors = y_pred - y_true
    abs_errors = np.abs(errors)
    
    # 1. Bias calculation
    bias = np.mean(errors)
    
    # 2. Accuracy (exact matches)
    accuracy = np.mean(y_pred == y_true)
    
    # 3. Overestimation Rate
    overestimation_rate = np.mean(y_pred > y_true)
    
    # 4. Underestimation Rate  
    underestimation_rate = np.mean(y_pred < y_true)
    
    # 5. Weighted MAE for different alpha values (vectorized)
    alphas = [0, 0.5, 1, 1.5]
    weighted_maes = {}
    
    for a in alphas:
        if a == 0:
            weighted_maes[a] = np.mean(abs_errors)
        else:
            weights = np.power(y_true, a)
            weights = np.where(y_true == 0, 0, weights)
            weighted_maes[a] = np.sum(weights * abs_errors) / np.sum(weights) if np.sum(weights) > 0 else 0
    
    # 6. Gini Coefficient (optimized)
    sorted_errors = np.sort(abs_errors)
    total_sum = np.sum(sorted_errors)
    
    if total_sum > 0:
        indices = np.arange(1, n + 1)
        weighted_sum = np.sum(indices * sorted_errors)
        gini_coefficient = (2 * weighted_sum) / (n * total_sum) - (n + 1) / n
    else:
        gini_coefficient = 0
    
    # 7. Overstock
    overstock = np.sum(np.maximum(0, errors))
    
    return {
        'bias': bias,
        'weighted_mae_0': weighted_maes[0],
        'weighted_mae_0.5': weighted_maes[0.5],
        'weighted_mae_1': weighted_maes[1],
        'weighted_mae_1.5': weighted_maes[1.5],
        'accuracy': accuracy,
        'overestimation_rate': overestimation_rate,
        'underestimation_rate': underestimation_rate,
        'gini_coefficient': gini_coefficient,
        'overstock': overstock,
        'n_censored_observations': n
    }

def calculate_pos_features(df, magazine_name):
    """
    Calculate features for each POS (EHASTRA_EH_NUMMER)
    
    Parameters:
    df (DataFrame): Input dataframe with 'EHASTRA_EH_NUMMER', 'Verkauf', and 'Laenge' columns
    magazine_name (str): Name of the magazine
    
    Returns:
    DataFrame: DataFrame with EHASTRA_EH_NUMMER and calculated features
    """
    
    results = []
    
    for pos_id, pos_data in df.groupby('EHASTRA_EH_NUMMER'):
        
        verkauf = pos_data['Verkauf'].dropna()
        
        if len(verkauf) == 0:
            continue
        
        features = {
            'EHASTRA_EH_NUMMER': pos_id,
            'magazine': magazine_name
        }
        
        # 1. Data Sparsity
        actual_data_points = len(pos_data)
        laenge = pos_data['Laenge'].iloc[0] if 'Laenge' in pos_data.columns else actual_data_points
        
        features['data_sparsity'] = laenge / actual_data_points if actual_data_points > 0 else 0
        
        # 2. Stockout Rate
        if 'Zensiert' in pos_data.columns:
            features['stockout_rate'] = (pos_data['Zensiert'] == 1).sum() / len(pos_data['Zensiert'])
        else:
            features['stockout_rate'] = 0
        
        # 3. Verkauf Variance
        features['verkauf_variance'] = verkauf.var()
        
        # 4. Verkauf Mean
        features['verkauf_mean'] = verkauf.mean()
        
        # 5. Coefficient of Variation
        if features['verkauf_mean'] > 0:
            features['coefficient_of_variation'] = verkauf.std() / features['verkauf_mean']
        else:
            features['coefficient_of_variation'] = 0
        
        # 6. Number of unique order quantities
        features['unique_quantities'] = verkauf.nunique()
        
        # 7. Variance to Mean Ratio
        if features['verkauf_mean'] > 0:
            features['variance_to_mean_ratio'] = features['verkauf_variance'] / features['verkauf_mean']
        else:
            features['variance_to_mean_ratio'] = 0
        
        # 8. Verkauf autocorrelation
        if len(verkauf) > 1:
            try:
                autocorr = verkauf.autocorr(lag=1)
                features['verkauf_autocorr'] = autocorr if not pd.isna(autocorr) else 0
            except:
                features['verkauf_autocorr'] = 0
        else:
            features['verkauf_autocorr'] = 0
        
        # 9. ADI (Average Inter-demand Interval)
        non_zero_periods = (verkauf > 0).sum()
        if non_zero_periods > 0:
            features['adi'] = len(verkauf) / non_zero_periods
        else:
            features['adi'] = len(verkauf)
        
        results.append(features)
    
    return pd.DataFrame(results)

def parse_filename(filename):
    """
    Parse filename to extract magazine letter and parameters
    
    Example: A_20250212_ZQ0.35_ZG0.4_testfile.csv -> ('A', '20250212', 'ZQ0.35', 'ZG0.4')
    """
    parts = filename.split('_')
    if len(parts) >= 4:
        magazine = parts[0]
        date = parts[1]
        zq = parts[2]
        zg = parts[3]
        return magazine, date, zq, zg
    return None, None, None, None

def process_all_datasets(data_directory, output_filename='combined_kpis_features_pivoted.csv'):
    """
    Process specific datasets and create a combined CSV with KPIs and POS features
    Each row represents one POS/Magazine combination with methods as column prefixes
    Only processes files with ZQ0.35_ZG0.4 pattern
    
    Parameters:
    - data_directory: path to directory containing CSV files
    - output_filename: name of the output file
    """
    
    # Method mapping
    method_functions = {
        'N1': apply_n1_uncensoring,
        'N2': apply_n2_uncensoring,
        'N3': apply_n3_uncensoring,
        'EM': apply_em_uncensoring,
        'PD': apply_pd_uncensoring,
        'Nahmias': apply_nahmias_uncensoring,
        'Conrad': apply_conrad_uncensoring,
        #'Nahmias_NG': apply_nahmias_ng_uncensoring,
        #'Conrad_NG': apply_conrad_ng_uncensoring,
        'Baseline': apply_baseline_uncensoring
    }
    
    # Find only the specific files with ZQ0.35_ZG0.4 pattern
    pattern = os.path.join(data_directory, "*_20250212_ZQ0.35_ZG0.4_testfile.csv")
    csv_files = glob.glob(pattern)
    
    if not csv_files:
        print(f"No CSV files found matching pattern *_20250212_ZQ0.35_ZG0.4_testfile.csv in {data_directory}")
        return
    
    print(f"Found {len(csv_files)} CSV files to process (ZQ0.35_ZG0.4 only)")
    
    all_results = []
    
    for csv_file in csv_files:
        filename = os.path.basename(csv_file)
        magazine, date, zq, zg = parse_filename(filename)
        
        if not magazine:
            print(f"Could not parse filename: {filename}")
            continue
            
        print(f"Processing {filename}...")
        
        try:
            # Read the original CSV file
            original_df = pd.read_csv(csv_file)
            
            # Filter out POS locations with less than 3 censored data points
            censored_counts = original_df[original_df['Zensiert'] == 1].groupby('EHASTRA_EH_NUMMER').size()
            valid_pos_ids = censored_counts[censored_counts >= 3].index
            original_df = original_df[original_df['EHASTRA_EH_NUMMER'].isin(valid_pos_ids)]
            
            if len(original_df) == 0:
                print(f"  No POS locations with >= 3 censored data points in {filename}")
                continue
            
            # Calculate POS features once for this magazine (they don't depend on uncensoring method)
            pos_features = calculate_pos_features(original_df, magazine)
            
            # Get unique POS IDs and convert to numpy array for faster iteration
            pos_ids = original_df['EHASTRA_EH_NUMMER'].unique()
            
            # Pre-filter censored data by POS to avoid repeated filtering
            censored_mask = original_df['Zensiert'] == 1
            censored_data = original_df[censored_mask]
            pos_censored_groups = censored_data.groupby('EHASTRA_EH_NUMMER')
            
            # Convert pos_features to dictionary for faster lookup
            pos_features_dict = pos_features.set_index('EHASTRA_EH_NUMMER').to_dict('index')
            
            # Initialize results dictionary for each POS
            pos_results = {}
            
            # Process each uncensoring method
            for method_name, method_function in method_functions.items():
                print(f"  Applying {method_name} uncensoring...")
                
                try:
                    # Apply the uncensoring method to the entire dataset
                    uncensored_df = method_function(original_df)
                    
                    # Pre-calculate uncensored values for censored data only
                    uncensored_censored = uncensored_df[censored_mask]
                    uncensored_groups = uncensored_censored.groupby('EHASTRA_EH_NUMMER')
                    
                    # Process all POS locations for this method
                    for pos_id in pos_ids:
                        if pos_id in pos_censored_groups.groups and pos_id in pos_features_dict:
                            # Get pre-filtered censored data for this POS
                            pos_censored = pos_censored_groups.get_group(pos_id)
                            pos_uncensored = uncensored_groups.get_group(pos_id) if pos_id in uncensored_groups.groups else None
                            
                            if pos_uncensored is not None and len(pos_uncensored) > 0:
                                # Calculate KPIs using pre-filtered data
                                kpis = calculate_kpis_for_pos_fast(pos_uncensored, pos_censored, method_name, magazine, pos_id)
                                
                                # Initialize POS entry if it doesn't exist
                                if pos_id not in pos_results:
                                    pos_results[pos_id] = {
                                        'EHASTRA_EH_NUMMER': pos_id,
                                        'magazine': magazine,
                                        'date': date,
                                        'zq_parameter': zq,
                                        'zg_parameter': zg,
                                        'filename': filename,
                                        **pos_features_dict[pos_id]  # Add POS features
                                    }
                                
                                # Add method-specific KPIs with method prefix
                                for kpi_name, kpi_value in kpis.items():
                                    column_name = f"{method_name}_{kpi_name}"
                                    pos_results[pos_id][column_name] = kpi_value
                
                except Exception as e:
                    print(f"    Error applying {method_name}: {str(e)}")
                    continue
            
            # Add all POS results from this file to main results
            all_results.extend(list(pos_results.values()))
            
        except Exception as e:
            print(f"Error processing {filename}: {str(e)}")
            continue
    
    if all_results:
        # Create final DataFrame
        final_df = pd.DataFrame(all_results)
        
        # Save to CSV
        output_path = os.path.join(data_directory, output_filename)
        final_df.to_csv(output_path, index=False)
        
        print(f"\nProcessing complete!")
        print(f"Combined dataset saved as: {output_path}")
        print(f"Total rows: {len(final_df)}")
        print(f"Magazines processed: {final_df['magazine'].nunique()}")
        print(f"POS locations: {final_df['EHASTRA_EH_NUMMER'].nunique()}")
        
        return final_df
    else:
        print("No data was processed successfully.")
        return None

# Usage
data_directory = "Test1"  # Change this to your actual directory path
result_df = process_all_datasets(data_directory, 'combined_magazine_kpis_features_attempt1.csv')
# Out:
# Found 9 CSV files to process (ZQ0.35_ZG0.4 only)
# Processing E_20250212_ZQ0.35_ZG0.4_testfile.csv...
#   Applying N1 uncensoring...
#   Applying N2 uncensoring...
#   Applying N3 uncensoring...
#   Applying EM uncensoring...
#   Applying PD uncensoring...
#   Applying Nahmias uncensoring...
#   Applying Conrad uncensoring...
# Iteration 0: mu=2.0500, value_0=92.754876
# Stopped after 9 iterations: mu=2.9412, value_0=0.102319
# Iteration 0: mu=2.0500, value_0=162.029989
# Stopped after 9 iterations: mu=3.9924, value_0=149.865032
# Iteration 0: mu=2.0500, value_0=86.865115
# Stopped after 9 iterations: mu=3.9924, value_0=199.975926
# Iteration 0: mu=2.0500, value_0=31.437679
# Stopped after 9 iterations: mu=3.9924, value_0=139.699725
# Iteration 0: mu=2.0500, value_0=11.711235
# Stopped after 9 iterations: mu=3.9924, value_0=99.483920
# Iteration 0: mu=2.0500, value_0=3.045318
# Stopped after 9 iterations: mu=3.9924, value_0=51.044867
# Iteration 0: mu=2.0500, value_0=1.038310
# Stopped after 9 iterations: mu=3.9924, value_0=33.861286
# Iteration 0: mu=2.0500, value_0=0.146744
# Stopped after 9 iterations: mu=3.9924, value_0=9.230632
# Iteration 0: mu=2.0500, value_0=0.031966
# Stopped after 9 iterations: mu=3.9924, value_0=3.916397
# Iteration 0: mu=2.0500, value_0=0.004343
# Converged after 0 iterations: mu=2.0500
# Iteration 0: mu=2.0500, value_0=0.000852
# Converged after 0 iterations: mu=2.0500
# Iteration 0: mu=2.0500, value_0=0.000133
# Converged after 0 iterations: mu=2.0500
# Iteration 0: mu=2.0500, value_0=0.000000
# Converged after 0 iterations: mu=2.0500
# Iteration 0: mu=2.0500, value_0=0.000000
# Converged after 0 iterations: mu=2.0500
# Iteration 0: mu=2.0500, value_0=50.432705
# Stopped after 9 iterations: mu=2.4842, value_0=0.621667
# Iteration 0: mu=2.0500, value_0=144.982098
# Stopped after 9 iterations: mu=3.9924, value_0=124.371799
# Iteration 0: mu=2.0500, value_0=95.321077
# Stopped after 9 iterations: mu=3.9924, value_0=226.235180
# Iteration 0: mu=2.0500, value_0=28.597486
# Stopped after 9 iterations: mu=3.9924, value_0=128.486037
# Iteration 0: mu=2.0500, value_0=10.702870
# Stopped after 9 iterations: mu=3.9924, value_0=95.432919
# Iteration 0: mu=2.0500, value_0=3.505766
# Stopped after 9 iterations: mu=3.9924, value_0=59.163730
# Iteration 0: mu=2.0500, value_0=0.730649
# Stopped after 9 iterations: mu=3.9924, value_0=23.696539
# Iteration 0: mu=2.0500, value_0=0.149292
# Stopped after 9 iterations: mu=3.9924, value_0=9.448139
# Iteration 0: mu=2.0500, value_0=0.023819
# Stopped after 9 iterations: mu=3.9924, value_0=2.895083
# Iteration 0: mu=2.0500, value_0=0.006049
# Converged after 0 iterations: mu=2.0500
# Iteration 0: mu=2.0500, value_0=0.000728
# Converged after 0 iterations: mu=2.0500
# Iteration 0: mu=2.0500, value_0=0.000145
# Converged after 0 iterations: mu=2.0500
# Iteration 0: mu=2.0500, value_0=0.000013
# Converged after 0 iterations: mu=2.0500
# Iteration 0: mu=2.0500, value_0=71.710669
# Stopped after 9 iterations: mu=2.7279, value_0=-0.363594
# Iteration 0: mu=2.0500, value_0=178.525897
# Stopped after 9 iterations: mu=3.9924, value_0=184.973528
# Iteration 0: mu=2.0500, value_0=93.187475
# Stopped after 9 iterations: mu=3.9924, value_0=226.144165
# Iteration 0: mu=2.0500, value_0=27.919833
# Stopped after 9 iterations: mu=3.9924, value_0=124.341182
# Iteration 0: mu=2.0500, value_0=8.787775
# Stopped after 9 iterations: mu=3.9924, value_0=76.422328
# Iteration 0: mu=2.0500, value_0=3.102467
# Stopped after 9 iterations: mu=3.9924, value_0=51.964467
# Iteration 0: mu=2.0500, value_0=0.867747
# Stopped after 9 iterations: mu=3.9924, value_0=28.490722
# Iteration 0: mu=2.0500, value_0=0.173272
# Stopped after 9 iterations: mu=3.9924, value_0=10.920342
# Iteration 0: mu=2.0500, value_0=0.032148
# Stopped after 9 iterations: mu=3.9924, value_0=3.868618
# Iteration 0: mu=2.0500, value_0=0.000715
# Converged after 0 iterations: mu=2.0500
# Iteration 0: mu=2.0500, value_0=0.000118
# Converged after 0 iterations: mu=2.0500
# Iteration 0: mu=2.0500, value_0=0.000017
# Converged after 0 iterations: mu=2.0500
# Iteration 0: mu=2.0500, value_0=0.000001
# Converged after 0 iterations: mu=2.0500
# Iteration 0: mu=2.0500, value_0=0.000000
# Converged after 0 iterations: mu=2.0500
# Iteration 0: mu=2.0500, value_0=29.930781
# Stopped after 9 iterations: mu=2.3166, value_0=0.391973
# Iteration 0: mu=2.0500, value_0=116.015944
# Stopped after 9 iterations: mu=3.9924, value_0=70.854189
# Iteration 0: mu=2.0500, value_0=89.014909
# Stopped after 9 iterations: mu=3.9924, value_0=207.340483
# Iteration 0: mu=2.0500, value_0=37.530662
# Stopped after 9 iterations: mu=3.9924, value_0=162.817425
# Iteration 0: mu=2.0500, value_0=9.534340
# Stopped after 9 iterations: mu=3.9924, value_0=82.744739
# Iteration 0: mu=2.0500, value_0=2.627435
# Stopped after 9 iterations: mu=3.9924, value_0=45.046911
# Iteration 0: mu=2.0500, value_0=0.519426
# Stopped after 9 iterations: mu=3.9924, value_0=16.636434
# Iteration 0: mu=2.0500, value_0=0.131166
# Stopped after 9 iterations: mu=3.9924, value_0=8.152296
# Iteration 0: mu=2.0500, value_0=0.037335
# Stopped after 9 iterations: mu=3.9924, value_0=4.472271
# Iteration 0: mu=2.0500, value_0=0.004219
# Converged after 0 iterations: mu=2.0500
# Iteration 0: mu=2.0500, value_0=0.000703
# Converged after 0 iterations: mu=2.0500
# Iteration 0: mu=2.0500, value_0=0.000110
# Converged after 0 iterations: mu=2.0500
# Iteration 0: mu=2.0500, value_0=0.000000
# Converged after 0 iterations: mu=2.0500
# Iteration 0: mu=2.0500, value_0=0.000000
# Converged after 0 iterations: mu=2.0500
# Iteration 0: mu=2.0500, value_0=0.000000
# Converged after 0 iterations: mu=2.0500
# Iteration 0: mu=2.0500, value_0=0.000000
# Converged after 0 iterations: mu=2.0500
# Iteration 0: mu=2.0500, value_0=44.730170
# Stopped after 9 iterations: mu=2.5146, value_0=-0.021548
# Iteration 0: mu=2.0500, value_0=98.528613
# Stopped after 9 iterations: mu=3.9924, value_0=36.095793
# Iteration 0: mu=2.0500, value_0=74.616509
# Stopped after 9 iterations: mu=3.9924, value_0=160.716440
# Iteration 0: mu=2.0500, value_0=45.801341
# Stopped after 9 iterations: mu=3.9924, value_0=202.807268
# Iteration 0: mu=2.0500, value_0=9.420726
# Stopped after 9 iterations: mu=3.9924, value_0=82.488048
# Iteration 0: mu=2.0500, value_0=2.690691
# Stopped after 9 iterations: mu=3.9924, value_0=44.273895
# Iteration 0: mu=2.0500, value_0=0.712670
# Stopped after 9 iterations: mu=3.9924, value_0=22.886023
# Iteration 0: mu=2.0500, value_0=0.179354
# Stopped after 9 iterations: mu=3.9924, value_0=11.147850
# Iteration 0: mu=2.0500, value_0=0.020263
# Stopped after 9 iterations: mu=3.9924, value_0=2.448905
# Iteration 0: mu=2.0500, value_0=0.006316
# Converged after 0 iterations: mu=2.0500
# Iteration 0: mu=2.0500, value_0=0.000089
# Converged after 0 iterations: mu=2.0500
# Iteration 0: mu=2.0500, value_0=0.000020
# Converged after 0 iterations: mu=2.0500
# Iteration 0: mu=2.0500, value_0=0.000002
# Converged after 0 iterations: mu=2.0500
# Iteration 0: mu=2.0500, value_0=0.000000
# Converged after 0 iterations: mu=2.0500
# Iteration 0: mu=2.0500, value_0=0.000000
# Converged after 0 iterations: mu=2.0500
# Iteration 0: mu=2.0500, value_0=0.000000
# Converged after 0 iterations: mu=2.0500
# Iteration 0: mu=2.0500, value_0=0.000000
# Converged after 0 iterations: mu=2.0500
# Iteration 0: mu=2.0500, value_0=0.000000
# Converged after 0 iterations: mu=2.0500
# Iteration 0: mu=2.0500, value_0=0.000000
# Converged after 0 iterations: mu=2.0500
# Iteration 0: mu=2.0500, value_0=59.092157
# Stopped after 9 iterations: mu=2.5756, value_0=-0.195961
# Iteration 0: mu=2.0500, value_0=112.699205
# Stopped after 9 iterations: mu=3.9924, value_0=87.672160
# Iteration 0: mu=2.0500, value_0=93.949658
# Stopped after 9 iterations: mu=3.9924, value_0=215.964201
# Iteration 0: mu=2.0500, value_0=32.450402
# Stopped after 9 iterations: mu=3.9924, value_0=143.853028
# Iteration 0: mu=2.0500, value_0=10.000556
# Stopped after 9 iterations: mu=3.9924, value_0=85.977866
# Iteration 0: mu=2.0500, value_0=2.150983
# Stopped after 9 iterations: mu=3.9924, value_0=35.799743
# Iteration 0: mu=2.0500, value_0=0.763743
# Stopped after 9 iterations: mu=3.9924, value_0=24.352291
# Iteration 0: mu=2.0500, value_0=0.128218
# Stopped after 9 iterations: mu=3.9924, value_0=8.000946
# Iteration 0: mu=2.0500, value_0=0.033194
# Stopped after 9 iterations: mu=3.9924, value_0=3.985641
# Iteration 0: mu=2.0500, value_0=0.001019
# Converged after 0 iterations: mu=2.0500
# Iteration 0: mu=2.0500, value_0=0.000000
# Converged after 0 iterations: mu=2.0500
# Iteration 0: mu=2.0500, value_0=0.000000
# Converged after 0 iterations: mu=2.0500
# Iteration 0: mu=2.0500, value_0=65.813677
# Stopped after 9 iterations: mu=2.6213, value_0=0.801988
# Iteration 0: mu=2.0500, value_0=213.009061
# Stopped after 9 iterations: mu=3.9924, value_0=211.713598
# Iteration 0: mu=2.0500, value_0=109.919327
# Stopped after 9 iterations: mu=3.9924, value_0=273.758153
# Iteration 0: mu=2.0500, value_0=32.905382
# Stopped after 9 iterations: mu=3.9924, value_0=152.565503
# Iteration 0: mu=2.0500, value_0=8.779706
# Stopped after 9 iterations: mu=3.9924, value_0=77.254008
# Iteration 0: mu=2.0500, value_0=2.892488
# Stopped after 9 iterations: mu=3.9924, value_0=48.270186
# Iteration 0: mu=2.0500, value_0=0.822371
# Stopped after 9 iterations: mu=3.9924, value_0=27.091705
# Iteration 0: mu=2.0500, value_0=0.142302
# Stopped after 9 iterations: mu=3.9924, value_0=8.988762
# Iteration 0: mu=2.0500, value_0=0.025404
# Stopped after 9 iterations: mu=3.9924, value_0=3.052281
# Iteration 0: mu=2.0500, value_0=0.004591
# Converged after 0 iterations: mu=2.0500
# Iteration 0: mu=2.0500, value_0=0.000777
# Converged after 0 iterations: mu=2.0500
# Iteration 0: mu=2.0500, value_0=0.000136
# Converged after 0 iterations: mu=2.0500
# Iteration 0: mu=2.0500, value_0=0.000017
# Converged after 0 iterations: mu=2.0500
# Iteration 0: mu=2.0500, value_0=0.000001
# Converged after 0 iterations: mu=2.0500
# Iteration 0: mu=2.0500, value_0=0.000000
# Converged after 0 iterations: mu=2.0500
# Iteration 0: mu=2.0500, value_0=0.000000
# Converged after 0 iterations: mu=2.0500
# Iteration 0: mu=2.0500, value_0=41.279454
# Stopped after 9 iterations: mu=2.4842, value_0=0.196903
# Iteration 0: mu=2.0500, value_0=169.177426
# Stopped after 9 iterations: mu=3.9924, value_0=143.993128
# Iteration 0: mu=2.0500, value_0=116.833689
# Stopped after 9 iterations: mu=3.9924, value_0=293.814359
# Iteration 0: mu=2.0500, value_0=49.925896
# Stopped after 9 iterations: mu=3.9924, value_0=229.254258
# Iteration 0: mu=2.0500, value_0=12.212010
# Stopped after 9 iterations: mu=3.9924, value_0=109.858649
# Iteration 0: mu=2.0500, value_0=3.907339
# Stopped after 9 iterations: mu=3.9924, value_0=67.869517
# Iteration 0: mu=2.0500, value_0=0.961414
# Stopped after 9 iterations: mu=3.9924, value_0=31.669782
# Iteration 0: mu=2.0500, value_0=0.188989
# Stopped after 9 iterations: mu=3.9924, value_0=12.022881
# Iteration 0: mu=2.0500, value_0=0.046687
# Stopped after 9 iterations: mu=3.9924, value_0=5.769329
# Iteration 0: mu=2.0500, value_0=0.006360
# Converged after 0 iterations: mu=2.0500
# Iteration 0: mu=2.0500, value_0=0.000842
# Converged after 0 iterations: mu=2.0500
# Iteration 0: mu=2.0500, value_0=0.000147
# Converged after 0 iterations: mu=2.0500
# Iteration 0: mu=2.0500, value_0=0.000020
# Converged after 0 iterations: mu=2.0500
# Iteration 0: mu=2.0500, value_0=0.000002
# Converged after 0 iterations: mu=2.0500
# Iteration 0: mu=2.0500, value_0=0.000000
# Converged after 0 iterations: mu=2.0500
# Iteration 0: mu=2.0500, value_0=0.000000
# Converged after 0 iterations: mu=2.0500
# Iteration 0: mu=2.0500, value_0=0.000000
# Converged after 0 iterations: mu=2.0500
# Iteration 0: mu=2.0500, value_0=55.288255
# Stopped after 9 iterations: mu=2.5604, value_0=0.065547
# Iteration 0: mu=2.0500, value_0=161.483111
# Stopped after 9 iterations: mu=3.9924, value_0=150.330791
# Iteration 0: mu=2.0500, value_0=90.175700
# Stopped after 9 iterations: mu=3.9924, value_0=209.302486
# Iteration 0: mu=2.0500, value_0=43.277288
# Stopped after 9 iterations: mu=3.9924, value_0=195.693473
# Iteration 0: mu=2.0500, value_0=13.186730
# Stopped after 9 iterations: mu=3.9924, value_0=119.790399
# Iteration 0: mu=2.0500, value_0=2.980836
# Stopped after 9 iterations: mu=3.9924, value_0=50.215224
# Iteration 0: mu=2.0500, value_0=0.941003
# Stopped after 9 iterations: mu=3.9924, value_0=30.959857
# Iteration 0: mu=2.0500, value_0=0.192560
# Stopped after 9 iterations: mu=3.9924, value_0=12.186494
# Iteration 0: mu=2.0500, value_0=0.033507
# Stopped after 9 iterations: mu=3.9924, value_0=4.069632
# Iteration 0: mu=2.0500, value_0=0.005911
# Converged after 0 iterations: mu=2.0500
# Iteration 0: mu=2.0500, value_0=0.001023
# Converged after 0 iterations: mu=2.0500
# Iteration 0: mu=2.0500, value_0=0.000140
# Converged after 0 iterations: mu=2.0500
# Iteration 0: mu=2.0500, value_0=0.000002
# Converged after 0 iterations: mu=2.0500
# Iteration 0: mu=2.0500, value_0=0.000000
# Converged after 0 iterations: mu=2.0500
# Iteration 0: mu=2.0500, value_0=0.000000
# Converged after 0 iterations: mu=2.0500
# Iteration 0: mu=2.0500, value_0=0.000000
# Converged after 0 iterations: mu=2.0500
# Iteration 0: mu=2.0500, value_0=15.982716
# Stopped after 9 iterations: mu=2.1947, value_0=0.357867
# Iteration 0: mu=2.0500, value_0=155.239312
# Stopped after 9 iterations: mu=3.9924, value_0=131.282550
# Iteration 0: mu=2.0500, value_0=102.633841
# Stopped after 9 iterations: mu=3.9924, value_0=245.264561
# Iteration 0: mu=2.0500, value_0=39.622182
# Stopped after 9 iterations: mu=3.9924, value_0=183.220776
# Iteration 0: mu=2.0500, value_0=11.568576
# Stopped after 9 iterations: mu=3.9924, value_0=103.231307
# Iteration 0: mu=2.0500, value_0=2.823771
# Stopped after 9 iterations: mu=3.9924, value_0=48.140000
# Iteration 0: mu=2.0500, value_0=0.700124
# Stopped after 9 iterations: mu=3.9924, value_0=22.902794
# Iteration 0: mu=2.0500, value_0=0.246084
# Stopped after 9 iterations: mu=3.9924, value_0=15.613674
# Iteration 0: mu=2.0500, value_0=0.046092
# Stopped after 9 iterations: mu=3.9924, value_0=5.661181
# Iteration 0: mu=2.0500, value_0=0.008076
# Converged after 0 iterations: mu=2.0500
# Iteration 0: mu=2.0500, value_0=0.000197
# Converged after 0 iterations: mu=2.0500
# Iteration 0: mu=2.0500, value_0=0.000025
# Converged after 0 iterations: mu=2.0500
# Iteration 0: mu=2.0500, value_0=0.000002
# Converged after 0 iterations: mu=2.0500
# Iteration 0: mu=2.0500, value_0=0.000000
# Converged after 0 iterations: mu=2.0500
# Iteration 0: mu=2.0500, value_0=0.000000
# Converged after 0 iterations: mu=2.0500
# Iteration 0: mu=2.0500, value_0=0.000000
# Converged after 0 iterations: mu=2.0500
# Iteration 0: mu=2.0500, value_0=11.013605
# Stopped after 9 iterations: mu=2.1490, value_0=-0.132709
# Iteration 0: mu=2.0500, value_0=137.510312
# Stopped after 9 iterations: mu=3.9924, value_0=82.746130
# Iteration 0: mu=2.0500, value_0=101.607723
# Stopped after 9 iterations: mu=3.9924, value_0=232.670718
# Iteration 0: mu=2.0500, value_0=34.509675
# Stopped after 9 iterations: mu=3.9924, value_0=154.776719
# Iteration 0: mu=2.0500, value_0=8.308194
# Stopped after 9 iterations: mu=3.9924, value_0=71.834119
# Iteration 0: mu=2.0500, value_0=1.798265
# Stopped after 9 iterations: mu=3.9924, value_0=28.610005
# Iteration 0: mu=2.0500, value_0=0.713780
# Stopped after 9 iterations: mu=3.9924, value_0=22.401486
# Iteration 0: mu=2.0500, value_0=0.187492
# Stopped after 9 iterations: mu=3.9924, value_0=11.535424
# Iteration 0: mu=2.0500, value_0=0.041919
# Stopped after 9 iterations: mu=3.9924, value_0=5.038775
# Iteration 0: mu=2.0500, value_0=0.000848
# Converged after 0 iterations: mu=2.0500
# Iteration 0: mu=2.0500, value_0=0.000143
# Converged after 0 iterations: mu=2.0500
# Iteration 0: mu=2.0500, value_0=0.000022
# Converged after 0 iterations: mu=2.0500
# Iteration 0: mu=2.0500, value_0=0.000002
# Converged after 0 iterations: mu=2.0500
# Iteration 0: mu=2.0500, value_0=0.000000
# Converged after 0 iterations: mu=2.0500
# Iteration 0: mu=2.0500, value_0=18.718126
# Stopped after 9 iterations: mu=2.2252, value_0=-0.345147
# Iteration 0: mu=2.0500, value_0=127.583317
# Stopped after 9 iterations: mu=3.9924, value_0=86.335848
# Iteration 0: mu=2.0500, value_0=91.152678
# Stopped after 9 iterations: mu=3.9924, value_0=196.787263
# Iteration 0: mu=2.0500, value_0=34.875132
# Stopped after 9 iterations: mu=3.9924, value_0=153.639858
# Iteration 0: mu=2.0500, value_0=9.956428
# Stopped after 9 iterations: mu=3.9924, value_0=82.996015
# Iteration 0: mu=2.0500, value_0=2.098539
# Stopped after 9 iterations: mu=3.9924, value_0=34.404952
# Iteration 0: mu=2.0500, value_0=0.536008
# Stopped after 9 iterations: mu=3.9924, value_0=16.954959
# Iteration 0: mu=2.0500, value_0=0.029700
# Stopped after 9 iterations: mu=3.9924, value_0=3.503556
# Iteration 0: mu=2.0500, value_0=0.005774
# Converged after 0 iterations: mu=2.0500
# Iteration 0: mu=2.0500, value_0=0.000901
# Converged after 0 iterations: mu=2.0500
# Iteration 0: mu=2.0500, value_0=0.000000
# Converged after 0 iterations: mu=2.0500
# Iteration 0: mu=2.0500, value_0=-79.713175
# Stopped after 9 iterations: mu=1.0217, value_0=-0.117637
# Iteration 0: mu=2.0500, value_0=73.184151
# Stopped after 9 iterations: mu=2.8498, value_0=-0.298438
# Iteration 0: mu=2.0500, value_0=209.270744
# Stopped after 9 iterations: mu=3.9924, value_0=202.020372
# Iteration 0: mu=2.0500, value_0=130.471886
# Stopped after 9 iterations: mu=3.9924, value_0=316.761360
# Iteration 0: mu=2.0500, value_0=41.558106
# Stopped after 9 iterations: mu=3.9924, value_0=196.039051
# Iteration 0: mu=2.0500, value_0=9.128275
# Stopped after 9 iterations: mu=3.9924, value_0=81.313840
# Iteration 0: mu=2.0500, value_0=3.060743
# Stopped after 9 iterations: mu=3.9924, value_0=52.243345
# Iteration 0: mu=2.0500, value_0=0.792709
# Stopped after 9 iterations: mu=3.9924, value_0=26.214425
# Iteration 0: mu=2.0500, value_0=0.133035
# Stopped after 9 iterations: mu=3.9924, value_0=8.387553
# Iteration 0: mu=2.0500, value_0=0.029821
# Stopped after 9 iterations: mu=3.9924, value_0=3.647258
# Iteration 0: mu=2.0500, value_0=0.005606
# Converged after 0 iterations: mu=2.0500
# Iteration 0: mu=2.0500, value_0=0.000098
# Converged after 0 iterations: mu=2.0500
# Iteration 0: mu=2.0500, value_0=0.000002
# Converged after 0 iterations: mu=2.0500
# Iteration 0: mu=2.0500, value_0=-81.155817
# Converged after 8 iterations: mu=1.0064
# Iteration 0: mu=2.0500, value_0=97.087282
# Stopped after 9 iterations: mu=3.0174, value_0=0.542474
# Iteration 0: mu=2.0500, value_0=152.530187
# Stopped after 9 iterations: mu=3.9924, value_0=133.883038
# Iteration 0: mu=2.0500, value_0=127.771475
# Stopped after 9 iterations: mu=3.9924, value_0=318.640287
# Iteration 0: mu=2.0500, value_0=39.867896
# Stopped after 9 iterations: mu=3.9924, value_0=186.092820
# Iteration 0: mu=2.0500, value_0=12.353171
# Stopped after 9 iterations: mu=3.9924, value_0=110.774446
# Iteration 0: mu=2.0500, value_0=3.936481
# Stopped after 9 iterations: mu=3.9924, value_0=68.800355
# Iteration 0: mu=2.0500, value_0=0.800653
# Stopped after 9 iterations: mu=3.9924, value_0=26.683064
# Iteration 0: mu=2.0500, value_0=0.182961
# Stopped after 9 iterations: mu=3.9924, value_0=11.566891
# Iteration 0: mu=2.0500, value_0=0.005579
# Converged after 0 iterations: mu=2.0500
# Iteration 0: mu=2.0500, value_0=0.000143
# Converged after 0 iterations: mu=2.0500
# Iteration 0: mu=2.0500, value_0=0.000009
# Converged after 0 iterations: mu=2.0500
# Iteration 0: mu=2.0500, value_0=0.000000
# Converged after 0 iterations: mu=2.0500
# Iteration 0: mu=2.0500, value_0=0.000000
# Converged after 0 iterations: mu=2.0500
# Iteration 0: mu=2.0500, value_0=82.513995
# Stopped after 9 iterations: mu=2.8193, value_0=-0.063587
# Iteration 0: mu=2.0500, value_0=185.312236
# Stopped after 9 iterations: mu=3.9924, value_0=184.857914
# Iteration 0: mu=2.0500, value_0=108.514279
# Stopped after 9 iterations: mu=3.9924, value_0=260.382848
# Iteration 0: mu=2.0500, value_0=43.133389
# Stopped after 9 iterations: mu=3.9924, value_0=197.376537
# Iteration 0: mu=2.0500, value_0=12.970447
# Stopped after 9 iterations: mu=3.9924, value_0=116.568573
# Iteration 0: mu=2.0500, value_0=3.327539
# Stopped after 9 iterations: mu=3.9924, value_0=57.507133
# Iteration 0: mu=2.0500, value_0=0.839840
# Stopped after 9 iterations: mu=3.9924, value_0=28.018994
# Iteration 0: mu=2.0500, value_0=0.198692
# Stopped after 9 iterations: mu=3.9924, value_0=12.711545
# Iteration 0: mu=2.0500, value_0=0.036362
# Stopped after 9 iterations: mu=3.9924, value_0=4.459296
# Iteration 0: mu=2.0500, value_0=0.004166
# Converged after 0 iterations: mu=2.0500
# Iteration 0: mu=2.0500, value_0=0.000614
# Converged after 0 iterations: mu=2.0500
# Iteration 0: mu=2.0500, value_0=-69.650063
# Stopped after 9 iterations: mu=1.0217, value_0=0.034991
# Iteration 0: mu=2.0500, value_0=98.855512
# Stopped after 9 iterations: mu=2.9564, value_0=0.249987
# Iteration 0: mu=2.0500, value_0=237.546601
# Stopped after 9 iterations: mu=3.9924, value_0=261.586466
# Iteration 0: mu=2.0500, value_0=98.868216
# Stopped after 9 iterations: mu=3.9924, value_0=239.264869
# Iteration 0: mu=2.0500, value_0=24.607812
# Stopped after 9 iterations: mu=3.9924, value_0=111.060676
# Iteration 0: mu=2.0500, value_0=15.847476
# Stopped after 9 iterations: mu=3.9924, value_0=140.402026
# Iteration 0: mu=2.0500, value_0=4.288516
# Stopped after 9 iterations: mu=3.9924, value_0=73.742867
# Iteration 0: mu=2.0500, value_0=0.935409
# Stopped after 9 iterations: mu=3.9924, value_0=30.402261
# Iteration 0: mu=2.0500, value_0=0.023283
# Stopped after 9 iterations: mu=3.9924, value_0=2.870912
# Iteration 0: mu=2.0500, value_0=0.004401
# Converged after 0 iterations: mu=2.0500
# Iteration 0: mu=2.0500, value_0=0.000669
# Converged after 0 iterations: mu=2.0500
# Iteration 0: mu=2.0500, value_0=0.000045
# Converged after 0 iterations: mu=2.0500
# Iteration 0: mu=2.0500, value_0=0.000000
# Converged after 0 iterations: mu=2.0500
# Iteration 0: mu=2.0500, value_0=0.000000
# Converged after 0 iterations: mu=2.0500
# Iteration 0: mu=2.0500, value_0=-49.875477
# Stopped after 9 iterations: mu=1.1740, value_0=-0.318367
# Iteration 0: mu=2.0500, value_0=161.690580
# Stopped after 9 iterations: mu=3.5658, value_0=-0.385535
# Iteration 0: mu=2.0500, value_0=199.918445
# Stopped after 9 iterations: mu=3.9924, value_0=219.622404
# Iteration 0: mu=2.0500, value_0=127.275359
# Stopped after 9 iterations: mu=3.9924, value_0=316.638401
# Iteration 0: mu=2.0500, value_0=48.317045
# Stopped after 9 iterations: mu=3.9924, value_0=228.394471
# Iteration 0: mu=2.0500, value_0=13.242961
# Stopped after 9 iterations: mu=3.9924, value_0=120.857172
# Iteration 0: mu=2.0500, value_0=3.149339
# Stopped after 9 iterations: mu=3.9924, value_0=54.768116
# Iteration 0: mu=2.0500, value_0=0.699802
# Stopped after 9 iterations: mu=3.9924, value_0=23.442176
# Iteration 0: mu=2.0500, value_0=0.026089
# Stopped after 9 iterations: mu=3.9924, value_0=3.224608
# Iteration 0: mu=2.0500, value_0=0.000052
# Converged after 0 iterations: mu=2.0500
# Iteration 0: mu=2.0500, value_0=-67.010998
# Stopped after 9 iterations: mu=1.0979, value_0=-0.260158
# Iteration 0: mu=2.0500, value_0=140.534088
# Stopped after 9 iterations: mu=3.4287, value_0=0.447693
# Iteration 0: mu=2.0500, value_0=259.870090
# Stopped after 9 iterations: mu=3.9924, value_0=318.722768
# Iteration 0: mu=2.0500, value_0=115.761814
# Stopped after 9 iterations: mu=3.9924, value_0=297.515000
# Iteration 0: mu=2.0500, value_0=50.848519
# Stopped after 9 iterations: mu=3.9924, value_0=249.254375
# Iteration 0: mu=2.0500, value_0=14.504023
# Stopped after 9 iterations: mu=3.9924, value_0=133.162537
# Iteration 0: mu=2.0500, value_0=3.135207
# Stopped after 9 iterations: mu=3.9924, value_0=54.664271
# Iteration 0: mu=2.0500, value_0=0.858815
# Stopped after 9 iterations: mu=3.9924, value_0=28.828251
# Iteration 0: mu=2.0500, value_0=0.146622
# Stopped after 9 iterations: mu=3.9924, value_0=9.345196
# Iteration 0: mu=2.0500, value_0=0.000000
# Converged after 0 iterations: mu=2.0500
# Iteration 0: mu=2.0500, value_0=0.000000
# Converged after 0 iterations: mu=2.0500
# Iteration 0: mu=2.0500, value_0=-63.633280
# Stopped after 9 iterations: mu=1.0369, value_0=0.146508
# Iteration 0: mu=2.0500, value_0=99.864289
# Stopped after 9 iterations: mu=3.0326, value_0=-0.119516
# Iteration 0: mu=2.0500, value_0=215.531386
# Stopped after 9 iterations: mu=3.9924, value_0=252.138835
# Iteration 0: mu=2.0500, value_0=89.145210
# Stopped after 9 iterations: mu=3.9924, value_0=216.134579
# Iteration 0: mu=2.0500, value_0=41.268782
# Stopped after 9 iterations: mu=3.9924, value_0=185.484066
# Iteration 0: mu=2.0500, value_0=14.450906
# Stopped after 9 iterations: mu=3.9924, value_0=131.921746
# Iteration 0: mu=2.0500, value_0=3.594861
# Stopped after 9 iterations: mu=3.9924, value_0=62.847967
# Iteration 0: mu=2.0500, value_0=0.882465
# Stopped after 9 iterations: mu=3.9924, value_0=29.013719
# Iteration 0: mu=2.0500, value_0=0.144468
# Stopped after 9 iterations: mu=3.9924, value_0=9.088801
# Iteration 0: mu=2.0500, value_0=0.021471
# Stopped after 9 iterations: mu=3.9924, value_0=2.601957
# Iteration 0: mu=2.0500, value_0=0.000076
# Converged after 0 iterations: mu=2.0500
# Iteration 0: mu=2.0500, value_0=36.877126
# Stopped after 9 iterations: mu=2.4842, value_0=-0.266752
# Iteration 0: mu=2.0500, value_0=128.251667
# Stopped after 9 iterations: mu=3.9924, value_0=87.921104
# Iteration 0: mu=2.0500, value_0=103.868348
# Stopped after 9 iterations: mu=3.9924, value_0=250.637657
# Iteration 0: mu=2.0500, value_0=51.758478
# Stopped after 9 iterations: mu=3.9924, value_0=237.957315
# Iteration 0: mu=2.0500, value_0=15.044904
# Stopped after 9 iterations: mu=3.9924, value_0=136.341006
# Iteration 0: mu=2.0500, value_0=3.026675
# Stopped after 9 iterations: mu=3.9924, value_0=52.143165
# Iteration 0: mu=2.0500, value_0=1.113558
# Stopped after 9 iterations: mu=3.9924, value_0=36.327902
# Iteration 0: mu=2.0500, value_0=0.151660
# Stopped after 9 iterations: mu=3.9924, value_0=9.713569
# Iteration 0: mu=2.0500, value_0=0.021487
# Stopped after 9 iterations: mu=3.9924, value_0=2.641718
# Iteration 0: mu=2.0500, value_0=0.006520
# Converged after 0 iterations: mu=2.0500
# Iteration 0: mu=2.0500, value_0=0.000148
# Converged after 0 iterations: mu=2.0500
# Iteration 0: mu=2.0500, value_0=0.000009
# Converged after 0 iterations: mu=2.0500
# Iteration 0: mu=2.0500, value_0=0.000000
# Converged after 0 iterations: mu=2.0500
# Iteration 0: mu=2.0500, value_0=95.477782
# Stopped after 9 iterations: mu=3.0479, value_0=0.158292
# Iteration 0: mu=2.0500, value_0=225.001075
# Stopped after 9 iterations: mu=3.9924, value_0=256.529987
# Iteration 0: mu=2.0500, value_0=98.696839
# Stopped after 9 iterations: mu=3.9924, value_0=247.092510
# Iteration 0: mu=2.0500, value_0=27.405958
# Stopped after 9 iterations: mu=3.9924, value_0=125.317072
# Iteration 0: mu=2.0500, value_0=13.596945
# Stopped after 9 iterations: mu=3.9924, value_0=119.654163
# Iteration 0: mu=2.0500, value_0=2.602722
# Stopped after 9 iterations: mu=3.9924, value_0=44.143569
# Iteration 0: mu=2.0500, value_0=0.945971
# Stopped after 9 iterations: mu=3.9924, value_0=31.192918
# Iteration 0: mu=2.0500, value_0=0.153832
# Stopped after 9 iterations: mu=3.9924, value_0=9.786340
# Iteration 0: mu=2.0500, value_0=0.029324
# Stopped after 9 iterations: mu=3.9924, value_0=3.614732
# Iteration 0: mu=2.0500, value_0=0.003850
# Converged after 0 iterations: mu=2.0500
# Iteration 0: mu=2.0500, value_0=0.000373
# Converged after 0 iterations: mu=2.0500
# Iteration 0: mu=2.0500, value_0=39.212139
# Stopped after 9 iterations: mu=2.6213, value_0=0.160170
# Iteration 0: mu=2.0500, value_0=159.745759
# Stopped after 9 iterations: mu=3.9924, value_0=161.331595
# Iteration 0: mu=2.0500, value_0=99.565378
# Stopped after 9 iterations: mu=3.9924, value_0=238.405975
# Iteration 0: mu=2.0500, value_0=32.301482
# Stopped after 9 iterations: mu=3.9924, value_0=148.636275
# Iteration 0: mu=2.0500, value_0=10.761055
# Stopped after 9 iterations: mu=3.9924, value_0=94.197197
# Iteration 0: mu=2.0500, value_0=3.159754
# Stopped after 9 iterations: mu=3.9924, value_0=53.758240
# Iteration 0: mu=2.0500, value_0=0.778863
# Stopped after 9 iterations: mu=3.9924, value_0=25.368538
# Iteration 0: mu=2.0500, value_0=0.196040
# Stopped after 9 iterations: mu=3.9924, value_0=12.424977
# Iteration 0: mu=2.0500, value_0=0.031941
# Stopped after 9 iterations: mu=3.9924, value_0=3.888568
# Iteration 0: mu=2.0500, value_0=0.006968
# Converged after 0 iterations: mu=2.0500
# Iteration 0: mu=2.0500, value_0=0.000806
# Converged after 0 iterations: mu=2.0500
# Iteration 0: mu=2.0500, value_0=0.000140
# Converged after 0 iterations: mu=2.0500
# Iteration 0: mu=2.0500, value_0=0.000019
# Converged after 0 iterations: mu=2.0500
# Iteration 0: mu=2.0500, value_0=0.000002
# Converged after 0 iterations: mu=2.0500
# Iteration 0: mu=2.0500, value_0=0.000000
# Converged after 0 iterations: mu=2.0500
# Iteration 0: mu=2.0500, value_0=0.000000
# Converged after 0 iterations: mu=2.0500
# Iteration 0: mu=2.0500, value_0=0.000000
# Converged after 0 iterations: mu=2.0500
# Iteration 0: mu=2.0500, value_0=34.093484
# Stopped after 9 iterations: mu=2.3623, value_0=0.694406
# Iteration 0: mu=2.0500, value_0=129.332663
# Stopped after 9 iterations: mu=3.9924, value_0=124.640574
# Iteration 0: mu=2.0500, value_0=73.807526
# Stopped after 9 iterations: mu=3.9924, value_0=167.901455
# Iteration 0: mu=2.0500, value_0=27.135473
# Stopped after 9 iterations: mu=3.9924, value_0=120.288792
# Iteration 0: mu=2.0500, value_0=9.110300
# Stopped after 9 iterations: mu=3.9924, value_0=77.830094
# Iteration 0: mu=2.0500, value_0=3.010540
# Stopped after 9 iterations: mu=3.9924, value_0=49.779882
# Iteration 0: mu=2.0500, value_0=0.950578
# Stopped after 9 iterations: mu=3.9924, value_0=30.587829
# Iteration 0: mu=2.0500, value_0=0.151936
# Stopped after 9 iterations: mu=3.9924, value_0=9.563508
# Iteration 0: mu=2.0500, value_0=0.026504
# Stopped after 9 iterations: mu=3.9924, value_0=3.161333
# Iteration 0: mu=2.0500, value_0=0.005245
# Converged after 0 iterations: mu=2.0500
# Iteration 0: mu=2.0500, value_0=0.000778
# Converged after 0 iterations: mu=2.0500
# Iteration 0: mu=2.0500, value_0=0.000011
# Converged after 0 iterations: mu=2.0500
# Iteration 0: mu=2.0500, value_0=0.000000
# Converged after 0 iterations: mu=2.0500
# Iteration 0: mu=2.0500, value_0=0.000000
# Converged after 0 iterations: mu=2.0500
# Iteration 0: mu=2.0500, value_0=-64.425000
# Stopped after 9 iterations: mu=1.0217, value_0=-0.249552
# Iteration 0: mu=2.0500, value_0=73.559795
# Stopped after 9 iterations: mu=2.7889, value_0=0.667204
# Iteration 0: mu=2.0500, value_0=200.415558
# Stopped after 9 iterations: mu=3.9924, value_0=241.866772
# Iteration 0: mu=2.0500, value_0=96.449280
# Stopped after 9 iterations: mu=3.9924, value_0=244.382290
# Iteration 0: mu=2.0500, value_0=27.077862
# Stopped after 9 iterations: mu=3.9924, value_0=123.215262
# Iteration 0: mu=2.0500, value_0=9.697273
# Stopped after 9 iterations: mu=3.9924, value_0=85.693251
# Iteration 0: mu=2.0500, value_0=2.271683
# Stopped after 9 iterations: mu=3.9924, value_0=38.990678
# Iteration 0: mu=2.0500, value_0=0.572314
# Stopped after 9 iterations: mu=3.9924, value_0=18.728908
# Iteration 0: mu=2.0500, value_0=0.136455
# Stopped after 9 iterations: mu=3.9924, value_0=8.683317
# Iteration 0: mu=2.0500, value_0=0.031622
# Stopped after 9 iterations: mu=3.9924, value_0=3.832514
# Iteration 0: mu=2.0500, value_0=0.004426
# Converged after 0 iterations: mu=2.0500
# Iteration 0: mu=2.0500, value_0=0.000762
# Converged after 0 iterations: mu=2.0500
# Iteration 0: mu=2.0500, value_0=0.000000
# Converged after 0 iterations: mu=2.0500
# Iteration 0: mu=2.0500, value_0=-66.254657
# Stopped after 9 iterations: mu=1.0217, value_0=-0.277303
# Iteration 0: mu=2.0500, value_0=123.624766
# Stopped after 9 iterations: mu=3.4439, value_0=0.035421
# Iteration 0: mu=2.0500, value_0=218.358665
# Stopped after 9 iterations: mu=3.9924, value_0=269.234485
# Iteration 0: mu=2.0500, value_0=97.095116
# Stopped after 9 iterations: mu=3.9924, value_0=239.102543
# Iteration 0: mu=2.0500, value_0=37.972569
# Stopped after 9 iterations: mu=3.9924, value_0=178.641803
# Iteration 0: mu=2.0500, value_0=9.541714
# Stopped after 9 iterations: mu=3.9924, value_0=86.150602
# Iteration 0: mu=2.0500, value_0=2.033189
# Stopped after 9 iterations: mu=3.9924, value_0=34.508974
# Iteration 0: mu=2.0500, value_0=0.565401
# Stopped after 9 iterations: mu=3.9924, value_0=18.711953
# Iteration 0: mu=2.0500, value_0=0.089159
# Stopped after 9 iterations: mu=3.9924, value_0=5.679049
# Iteration 0: mu=2.0500, value_0=0.002925
# Converged after 0 iterations: mu=2.0500
# Iteration 0: mu=2.0500, value_0=-53.358614
# Stopped after 9 iterations: mu=1.2654, value_0=0.061265
# Iteration 0: mu=2.0500, value_0=238.368318
# Stopped after 9 iterations: mu=3.9924, value_0=53.094351
# Iteration 0: mu=2.0500, value_0=231.931087
# Stopped after 9 iterations: mu=3.9924, value_0=319.026372
# Iteration 0: mu=2.0500, value_0=123.585791
# Stopped after 9 iterations: mu=3.9924, value_0=314.213426
# Iteration 0: mu=2.0500, value_0=31.933831
# Stopped after 9 iterations: mu=3.9924, value_0=156.805317
# Iteration 0: mu=2.0500, value_0=8.234451
# Stopped after 9 iterations: mu=3.9924, value_0=72.314509
# Iteration 0: mu=2.0500, value_0=1.979306
# Stopped after 9 iterations: mu=3.9924, value_0=33.757215
# Iteration 0: mu=2.0500, value_0=0.504513
# Stopped after 9 iterations: mu=3.9924, value_0=16.854772
# Iteration 0: mu=2.0500, value_0=0.086168
# Stopped after 9 iterations: mu=3.9924, value_0=5.401357
# Iteration 0: mu=2.0500, value_0=0.015502
# Stopped after 9 iterations: mu=3.9924, value_0=1.905929
# Iteration 0: mu=2.0500, value_0=0.002023
# Converged after 0 iterations: mu=2.0500
# Iteration 0: mu=2.0500, value_0=0.000251
# Converged after 0 iterations: mu=2.0500
# Iteration 0: mu=2.0500, value_0=0.000001
# Converged after 0 iterations: mu=2.0500
# Iteration 0: mu=2.0500, value_0=0.000000
# Converged after 0 iterations: mu=2.0500
# Iteration 0: mu=2.0500, value_0=-50.702575
# Stopped after 9 iterations: mu=1.0217, value_0=-0.041424
# Iteration 0: mu=2.0500, value_0=180.787922
# Stopped after 9 iterations: mu=3.9010, value_0=0.041898
# Iteration 0: mu=2.0500, value_0=279.026127
# Stopped after 9 iterations: mu=3.9924, value_0=375.647764
# Iteration 0: mu=2.0500, value_0=121.366551
# Stopped after 9 iterations: mu=3.9924, value_0=321.328430
# Iteration 0: mu=2.0500, value_0=-47.922711
# Stopped after 9 iterations: mu=1.1436, value_0=0.255978
# Iteration 0: mu=2.0500, value_0=199.078601
# Stopped after 9 iterations: mu=3.9924, value_0=16.194767
# Iteration 0: mu=2.0500, value_0=267.737169
# Stopped after 9 iterations: mu=3.9924, value_0=375.795280
# Iteration 0: mu=2.0500, value_0=116.443672
# Stopped after 9 iterations: mu=3.9924, value_0=309.770649
# Iteration 0: mu=2.0500, value_0=67.052594
# Stopped after 9 iterations: mu=3.9924, value_0=339.485017
# Iteration 0: mu=2.0500, value_0=1.592935
# Stopped after 9 iterations: mu=3.9924, value_0=28.856403
# Iteration 0: mu=2.0500, value_0=-38.334345
# Stopped after 9 iterations: mu=1.3264, value_0=-0.143817
# Iteration 0: mu=2.0500, value_0=235.571151
# Stopped after 9 iterations: mu=3.9924, value_0=47.589543
# Iteration 0: mu=2.0500, value_0=268.160789
# Stopped after 9 iterations: mu=3.9924, value_0=364.782886
# Iteration 0: mu=2.0500, value_0=103.899792
# Stopped after 9 iterations: mu=3.9924, value_0=274.430197
# Iteration 0: mu=2.0500, value_0=38.037191
# Stopped after 9 iterations: mu=3.9924, value_0=184.787510
# Iteration 0: mu=2.0500, value_0=12.182631
# Stopped after 9 iterations: mu=3.9924, value_0=113.688524
# Iteration 0: mu=2.0500, value_0=2.731779
# Stopped after 9 iterations: mu=3.9924, value_0=48.481061
# Iteration 0: mu=2.0500, value_0=0.782983
# Stopped after 9 iterations: mu=3.9924, value_0=26.616788
# Iteration 0: mu=2.0500, value_0=0.117023
# Stopped after 9 iterations: mu=3.9924, value_0=7.720515
# Iteration 0: mu=2.0500, value_0=20.352380
# Stopped after 9 iterations: mu=2.3166, value_0=0.450695
# Iteration 0: mu=2.0500, value_0=100.683969
# Stopped after 9 iterations: mu=3.9924, value_0=89.719964
# Iteration 0: mu=2.0500, value_0=102.157878
# Stopped after 9 iterations: mu=3.9924, value_0=226.723191
# Iteration 0: mu=2.0500, value_0=18.098287
# Stopped after 9 iterations: mu=3.9924, value_0=74.073472
# Iteration 0: mu=2.0500, value_0=10.136186
# Stopped after 9 iterations: mu=3.9924, value_0=84.339265
# Iteration 0: mu=2.0500, value_0=3.102412
# Stopped after 9 iterations: mu=3.9924, value_0=49.860656
# Iteration 0: mu=2.0500, value_0=0.885749
# Stopped after 9 iterations: mu=3.9924, value_0=27.778261
# Iteration 0: mu=2.0500, value_0=0.038737
# Stopped after 9 iterations: mu=3.9924, value_0=4.581614
# Iteration 0: mu=2.0500, value_0=0.004578
# Converged after 0 iterations: mu=2.0500
# Iteration 0: mu=2.0500, value_0=0.000791
# Converged after 0 iterations: mu=2.0500
# Iteration 0: mu=2.0500, value_0=34.560232
# Stopped after 9 iterations: mu=2.3928, value_0=0.326444
# Iteration 0: mu=2.0500, value_0=102.754347
# Stopped after 9 iterations: mu=3.9924, value_0=78.953451
# Iteration 0: mu=2.0500, value_0=84.721520
# Stopped after 9 iterations: mu=3.9924, value_0=184.328065
# Iteration 0: mu=2.0500, value_0=19.836270
# Stopped after 9 iterations: mu=3.9924, value_0=82.450062
# Iteration 0: mu=2.0500, value_0=9.808819
# Stopped after 9 iterations: mu=3.9924, value_0=81.770312
# Iteration 0: mu=2.0500, value_0=4.228710
# Stopped after 9 iterations: mu=3.9924, value_0=69.251802
# Iteration 0: mu=2.0500, value_0=0.745004
# Stopped after 9 iterations: mu=3.9924, value_0=23.134964
# Iteration 0: mu=2.0500, value_0=0.163146
# Stopped after 9 iterations: mu=3.9924, value_0=10.084521
# Iteration 0: mu=2.0500, value_0=0.029575
# Stopped after 9 iterations: mu=3.9924, value_0=3.559367
# Iteration 0: mu=2.0500, value_0=29.381862
# Stopped after 9 iterations: mu=2.4232, value_0=0.038184
# Iteration 0: mu=2.0500, value_0=121.511008
# Stopped after 9 iterations: mu=3.9924, value_0=110.819312
# Iteration 0: mu=2.0500, value_0=95.041737
# Stopped after 9 iterations: mu=3.9924, value_0=209.991520
# Iteration 0: mu=2.0500, value_0=25.488928
# Stopped after 9 iterations: mu=3.9924, value_0=111.602816
# Iteration 0: mu=2.0500, value_0=15.832276
# Stopped after 9 iterations: mu=3.9924, value_0=133.899837
# Iteration 0: mu=2.0500, value_0=4.414344
# Stopped after 9 iterations: mu=3.9924, value_0=74.218260
# Iteration 0: mu=2.0500, value_0=0.608251
# Stopped after 9 iterations: mu=3.9924, value_0=19.537964
# Iteration 0: mu=2.0500, value_0=0.113658
# Stopped after 9 iterations: mu=3.9924, value_0=7.094454
# Iteration 0: mu=2.0500, value_0=0.031131
# Stopped after 9 iterations: mu=3.9924, value_0=3.752363
# Iteration 0: mu=2.0500, value_0=0.005344
# Converged after 0 iterations: mu=2.0500
# Iteration 0: mu=2.0500, value_0=0.000055
# Converged after 0 iterations: mu=2.0500
# Iteration 0: mu=2.0500, value_0=0.000001
# Converged after 0 iterations: mu=2.0500
# Iteration 0: mu=2.0500, value_0=22.439856
# Stopped after 9 iterations: mu=2.4080, value_0=0.425866
# Iteration 0: mu=2.0500, value_0=141.023293
# Stopped after 9 iterations: mu=3.9924, value_0=121.114407
# Iteration 0: mu=2.0500, value_0=98.303440
# Stopped after 9 iterations: mu=3.9924, value_0=221.645250
# Iteration 0: mu=2.0500, value_0=32.710769
# Stopped after 9 iterations: mu=3.9924, value_0=147.111598
# Iteration 0: mu=2.0500, value_0=14.953193
# Stopped after 9 iterations: mu=3.9924, value_0=127.706897
# Iteration 0: mu=2.0500, value_0=2.395814
# Stopped after 9 iterations: mu=3.9924, value_0=39.890177
# Iteration 0: mu=2.0500, value_0=0.717412
# Stopped after 9 iterations: mu=3.9924, value_0=23.287798
# Iteration 0: mu=2.0500, value_0=0.149942
# Stopped after 9 iterations: mu=3.9924, value_0=9.346162
# Iteration 0: mu=2.0500, value_0=0.030325
# Stopped after 9 iterations: mu=3.9924, value_0=3.671537
# Iteration 0: mu=2.0500, value_0=0.003537
# Converged after 0 iterations: mu=2.0500
# Iteration 0: mu=2.0500, value_0=0.000054
# Converged after 0 iterations: mu=2.0500
#   Applying Baseline uncensoring...
# Processing C_20250212_ZQ0.35_ZG0.4_testfile.csv...
#   Applying N1 uncensoring...
#   Applying N2 uncensoring...
#   Applying N3 uncensoring...
#   Applying EM uncensoring...
#   Applying PD uncensoring...
#   Applying Nahmias uncensoring...
#   Applying Conrad uncensoring...
# Iteration 0: mu=2.0500, value_0=-58.267419
# Stopped after 9 iterations: mu=1.0674, value_0=0.018829
# Iteration 0: mu=2.0500, value_0=149.825652
# Stopped after 9 iterations: mu=3.2611, value_0=1.081665
# Iteration 0: mu=2.0500, value_0=167.007522
# Stopped after 9 iterations: mu=3.9924, value_0=204.183802
# Iteration 0: mu=2.0500, value_0=84.000927
# Stopped after 9 iterations: mu=3.9924, value_0=210.808270
# Iteration 0: mu=2.0500, value_0=30.667304
# Stopped after 9 iterations: mu=3.9924, value_0=142.626150
# Iteration 0: mu=2.0500, value_0=13.817374
# Stopped after 9 iterations: mu=3.9924, value_0=128.274719
# Iteration 0: mu=2.0500, value_0=2.815044
# Stopped after 9 iterations: mu=3.9924, value_0=49.086577
# Iteration 0: mu=2.0500, value_0=0.743020
# Stopped after 9 iterations: mu=3.9924, value_0=25.233080
# Iteration 0: mu=2.0500, value_0=0.126267
# Stopped after 9 iterations: mu=3.9924, value_0=8.108410
# Iteration 0: mu=2.0500, value_0=0.018130
# Stopped after 9 iterations: mu=3.9924, value_0=2.263466
# Iteration 0: mu=2.0500, value_0=0.000648
# Converged after 0 iterations: mu=2.0500
# Iteration 0: mu=2.0500, value_0=0.000062
# Converged after 0 iterations: mu=2.0500
# Iteration 0: mu=2.0500, value_0=0.000004
# Converged after 0 iterations: mu=2.0500
# Iteration 0: mu=2.0500, value_0=0.000000
# Converged after 0 iterations: mu=2.0500
# Iteration 0: mu=2.0500, value_0=-61.416608
# Stopped after 9 iterations: mu=1.0217, value_0=0.159868
# Iteration 0: mu=2.0500, value_0=142.314567
# Stopped after 9 iterations: mu=3.3068, value_0=0.250140
# Iteration 0: mu=2.0500, value_0=183.526399
# Stopped after 9 iterations: mu=3.9924, value_0=212.896761
# Iteration 0: mu=2.0500, value_0=82.579738
# Stopped after 9 iterations: mu=3.9924, value_0=204.426867
# Iteration 0: mu=2.0500, value_0=34.426624
# Stopped after 9 iterations: mu=3.9924, value_0=162.139243
# Iteration 0: mu=2.0500, value_0=13.929950
# Stopped after 9 iterations: mu=3.9924, value_0=128.589416
# Iteration 0: mu=2.0500, value_0=2.919130
# Stopped after 9 iterations: mu=3.9924, value_0=52.301800
# Iteration 0: mu=2.0500, value_0=0.598892
# Stopped after 9 iterations: mu=3.9924, value_0=19.980633
# Iteration 0: mu=2.0500, value_0=0.156663
# Stopped after 9 iterations: mu=3.9924, value_0=10.126801
# Iteration 0: mu=2.0500, value_0=0.019050
# Stopped after 9 iterations: mu=3.9924, value_0=2.380044
# Iteration 0: mu=2.0500, value_0=0.003908
# Converged after 0 iterations: mu=2.0500
# Iteration 0: mu=2.0500, value_0=0.000425
# Converged after 0 iterations: mu=2.0500
# Iteration 0: mu=2.0500, value_0=0.000050
# Converged after 0 iterations: mu=2.0500
# Iteration 0: mu=2.0500, value_0=0.000007
# Converged after 0 iterations: mu=2.0500
# Iteration 0: mu=2.0500, value_0=0.000001
# Converged after 0 iterations: mu=2.0500
# Iteration 0: mu=2.0500, value_0=0.000000
# Converged after 0 iterations: mu=2.0500
# Iteration 0: mu=2.0500, value_0=0.000000
# Converged after 0 iterations: mu=2.0500
# Iteration 0: mu=2.0500, value_0=0.000000
# Converged after 0 iterations: mu=2.0500
# Iteration 0: mu=2.0500, value_0=-59.446154
# Stopped after 9 iterations: mu=1.0521, value_0=0.297868
# Iteration 0: mu=2.0500, value_0=154.523749
# Stopped after 9 iterations: mu=3.5201, value_0=0.885244
# Iteration 0: mu=2.0500, value_0=189.192441
# Stopped after 9 iterations: mu=3.9924, value_0=219.113062
# Iteration 0: mu=2.0500, value_0=76.131192
# Stopped after 9 iterations: mu=3.9924, value_0=188.453837
# Iteration 0: mu=2.0500, value_0=40.265971
# Stopped after 9 iterations: mu=3.9924, value_0=187.944011
# Iteration 0: mu=2.0500, value_0=12.571870
# Stopped after 9 iterations: mu=3.9924, value_0=116.724686
# Iteration 0: mu=2.0500, value_0=3.323876
# Stopped after 9 iterations: mu=3.9924, value_0=58.497223
# Iteration 0: mu=2.0500, value_0=0.547031
# Stopped after 9 iterations: mu=3.9924, value_0=18.459520
# Iteration 0: mu=2.0500, value_0=0.129472
# Stopped after 9 iterations: mu=3.9924, value_0=8.395139
# Iteration 0: mu=2.0500, value_0=0.014730
# Stopped after 9 iterations: mu=3.9924, value_0=1.821310
# Iteration 0: mu=2.0500, value_0=0.003878
# Converged after 0 iterations: mu=2.0500
# Iteration 0: mu=2.0500, value_0=-59.023760
# Stopped after 9 iterations: mu=1.1436, value_0=0.077798
# Iteration 0: mu=2.0500, value_0=138.836801
# Stopped after 9 iterations: mu=3.3525, value_0=0.370255
# Iteration 0: mu=2.0500, value_0=193.831844
# Stopped after 9 iterations: mu=3.9924, value_0=223.238125
# Iteration 0: mu=2.0500, value_0=84.645824
# Stopped after 9 iterations: mu=3.9924, value_0=192.823486
# Iteration 0: mu=2.0500, value_0=38.809184
# Stopped after 9 iterations: mu=3.9924, value_0=186.164050
# Iteration 0: mu=2.0500, value_0=12.979549
# Stopped after 9 iterations: mu=3.9924, value_0=121.309640
# Iteration 0: mu=2.0500, value_0=3.383184
# Stopped after 9 iterations: mu=3.9924, value_0=59.577791
# Iteration 0: mu=2.0500, value_0=0.639840
# Stopped after 9 iterations: mu=3.9924, value_0=21.602437
# Iteration 0: mu=2.0500, value_0=0.146110
# Stopped after 9 iterations: mu=3.9924, value_0=9.573193
# Iteration 0: mu=2.0500, value_0=0.021126
# Stopped after 9 iterations: mu=3.9924, value_0=2.617392
# Iteration 0: mu=2.0500, value_0=0.000231
# Converged after 0 iterations: mu=2.0500
# Iteration 0: mu=2.0500, value_0=0.000000
# Converged after 0 iterations: mu=2.0500
# Iteration 0: mu=2.0500, value_0=0.000000
# Converged after 0 iterations: mu=2.0500
# Iteration 0: mu=2.0500, value_0=-68.031246
# Converged after 7 iterations: mu=1.1512
# Iteration 0: mu=2.0500, value_0=123.486197
# Stopped after 9 iterations: mu=3.0783, value_0=-0.255636
# Iteration 0: mu=2.0500, value_0=160.871414
# Stopped after 9 iterations: mu=3.9924, value_0=154.935982
# Iteration 0: mu=2.0500, value_0=91.612193
# Stopped after 9 iterations: mu=3.9924, value_0=224.519839
# Iteration 0: mu=2.0500, value_0=35.538503
# Stopped after 9 iterations: mu=3.9924, value_0=165.267584
# Iteration 0: mu=2.0500, value_0=13.301958
# Stopped after 9 iterations: mu=3.9924, value_0=123.201144
# Iteration 0: mu=2.0500, value_0=3.435102
# Stopped after 9 iterations: mu=3.9924, value_0=60.895536
# Iteration 0: mu=2.0500, value_0=0.982904
# Stopped after 9 iterations: mu=3.9924, value_0=33.291402
# Iteration 0: mu=2.0500, value_0=0.098413
# Stopped after 9 iterations: mu=3.9924, value_0=6.436613
# Iteration 0: mu=2.0500, value_0=0.020250
# Stopped after 9 iterations: mu=3.9924, value_0=2.504776
# Iteration 0: mu=2.0500, value_0=0.002890
# Converged after 0 iterations: mu=2.0500
# Iteration 0: mu=2.0500, value_0=0.000001
# Converged after 0 iterations: mu=2.0500
# Iteration 0: mu=2.0500, value_0=0.000000
# Converged after 0 iterations: mu=2.0500
# Iteration 0: mu=2.0500, value_0=-65.304450
# Stopped after 9 iterations: mu=1.1131, value_0=0.080301
# Iteration 0: mu=2.0500, value_0=148.014805
# Converged after 8 iterations: mu=3.3678
# Iteration 0: mu=2.0500, value_0=176.499413
# Stopped after 9 iterations: mu=3.9924, value_0=210.027017
# Iteration 0: mu=2.0500, value_0=81.417802
# Stopped after 9 iterations: mu=3.9924, value_0=198.541526
# Iteration 0: mu=2.0500, value_0=34.915263
# Stopped after 9 iterations: mu=3.9924, value_0=160.755870
# Iteration 0: mu=2.0500, value_0=14.097266
# Stopped after 9 iterations: mu=3.9924, value_0=129.003317
# Iteration 0: mu=2.0500, value_0=3.187383
# Stopped after 9 iterations: mu=3.9924, value_0=56.200942
# Iteration 0: mu=2.0500, value_0=0.781287
# Stopped after 9 iterations: mu=3.9924, value_0=26.431890
# Iteration 0: mu=2.0500, value_0=0.111374
# Stopped after 9 iterations: mu=3.9924, value_0=7.183524
# Iteration 0: mu=2.0500, value_0=0.002531
# Converged after 0 iterations: mu=2.0500
# Iteration 0: mu=2.0500, value_0=0.000000
# Converged after 0 iterations: mu=2.0500
# Iteration 0: mu=2.0500, value_0=-75.631468
# Stopped after 9 iterations: mu=1.0979, value_0=-0.179796
# Iteration 0: mu=2.0500, value_0=120.040075
# Stopped after 9 iterations: mu=3.0479, value_0=0.840719
# Iteration 0: mu=2.0500, value_0=163.124510
# Stopped after 9 iterations: mu=3.9924, value_0=180.194832
# Iteration 0: mu=2.0500, value_0=79.586084
# Stopped after 9 iterations: mu=3.9924, value_0=190.635266
# Iteration 0: mu=2.0500, value_0=35.705480
# Stopped after 9 iterations: mu=3.9924, value_0=167.828719
# Iteration 0: mu=2.0500, value_0=12.638245
# Stopped after 9 iterations: mu=3.9924, value_0=115.508656
# Iteration 0: mu=2.0500, value_0=3.708789
# Stopped after 9 iterations: mu=3.9924, value_0=64.762680
# Iteration 0: mu=2.0500, value_0=0.775884
# Stopped after 9 iterations: mu=3.9924, value_0=26.177224
# Iteration 0: mu=2.0500, value_0=0.140670
# Stopped after 9 iterations: mu=3.9924, value_0=9.072507
# Iteration 0: mu=2.0500, value_0=0.002985
# Converged after 0 iterations: mu=2.0500
# Iteration 0: mu=2.0500, value_0=0.000007
# Converged after 0 iterations: mu=2.0500
# ...
# Stopped after 9 iterations: mu=3.9924, value_0=16.581119
# Iteration 0: mu=2.0500, value_0=0.127654
# Stopped after 9 iterations: mu=3.9924, value_0=4.323899
# Iteration 0: mu=2.0500, value_0=-25.826033
# Converged after 6 iterations: mu=1.2883
# Iteration 0: mu=2.0500, value_0=77.496397
# Stopped after 9 iterations: mu=3.5354, value_0=0.411158
# Iteration 0: mu=2.0500, value_0=97.716844
# Stopped after 9 iterations: mu=3.9924, value_0=128.756643
# Iteration 0: mu=2.0500, value_0=70.448110
# Stopped after 9 iterations: mu=3.9924, value_0=175.169507
# Iteration 0: mu=2.0500, value_0=24.017115
# Stopped after 9 iterations: mu=3.9924, value_0=115.927940
# Iteration 0: mu=2.0500, value_0=4.315993
# Stopped after 9 iterations: mu=3.9924, value_0=39.591133
# Iteration 0: mu=2.0500, value_0=0.000115
# Converged after 0 iterations: mu=2.0500
# Iteration 0: mu=2.0500, value_0=0.000000
# Converged after 0 iterations: mu=2.0500
# Iteration 0: mu=2.0500, value_0=-23.116926
# Converged after 7 iterations: mu=1.1207
# Iteration 0: mu=2.0500, value_0=127.305921
# Stopped after 9 iterations: mu=3.9924, value_0=8.929149
# Iteration 0: mu=2.0500, value_0=67.559961
# Stopped after 9 iterations: mu=3.9924, value_0=76.688273
# Iteration 0: mu=2.0500, value_0=72.728154
# Stopped after 9 iterations: mu=3.9924, value_0=177.060716
# Iteration 0: mu=2.0500, value_0=18.023492
# Stopped after 9 iterations: mu=3.9924, value_0=86.941743
# Iteration 0: mu=2.0500, value_0=4.758586
# Stopped after 9 iterations: mu=3.9924, value_0=44.235720
# Iteration 0: mu=2.0500, value_0=-27.814177
# Stopped after 9 iterations: mu=1.1436, value_0=0.052295
# Iteration 0: mu=2.0500, value_0=102.213847
# Stopped after 9 iterations: mu=3.9619, value_0=0.072598
# Iteration 0: mu=2.0500, value_0=91.690725
# Stopped after 9 iterations: mu=3.9924, value_0=109.534837
# Iteration 0: mu=2.0500, value_0=65.562089
# Stopped after 9 iterations: mu=3.9924, value_0=165.317272
# Iteration 0: mu=2.0500, value_0=24.675094
# Stopped after 9 iterations: mu=3.9924, value_0=122.786453
# Iteration 0: mu=2.0500, value_0=4.193621
# Stopped after 9 iterations: mu=3.9924, value_0=38.772913
# Iteration 0: mu=2.0500, value_0=0.148996
# Stopped after 9 iterations: mu=3.9924, value_0=4.931588
# Iteration 0: mu=2.0500, value_0=0.000074
# Converged after 0 iterations: mu=2.0500
# Iteration 0: mu=2.0500, value_0=-31.086475
# Stopped after 9 iterations: mu=1.1131, value_0=-0.173682
# Iteration 0: mu=2.0500, value_0=93.995368
# Stopped after 9 iterations: mu=3.5201, value_0=0.322207
# Iteration 0: mu=2.0500, value_0=90.660767
# Stopped after 9 iterations: mu=3.9924, value_0=125.088722
# Iteration 0: mu=2.0500, value_0=45.101829
# Stopped after 9 iterations: mu=3.9924, value_0=103.528786
# Iteration 0: mu=2.0500, value_0=26.911554
# Stopped after 9 iterations: mu=3.9924, value_0=128.422841
# Iteration 0: mu=2.0500, value_0=6.161259
# Stopped after 9 iterations: mu=3.9924, value_0=57.147346
# Iteration 0: mu=2.0500, value_0=0.156674
# Stopped after 9 iterations: mu=3.9924, value_0=5.235677
# Iteration 0: mu=2.0500, value_0=-31.755086
# Stopped after 9 iterations: mu=1.0217, value_0=-0.117839
# Iteration 0: mu=2.0500, value_0=112.625708
# Stopped after 9 iterations: mu=3.9924, value_0=4.769314
# Iteration 0: mu=2.0500, value_0=65.059328
# Stopped after 9 iterations: mu=3.9924, value_0=78.652410
# Iteration 0: mu=2.0500, value_0=51.112620
# Stopped after 9 iterations: mu=3.9924, value_0=119.758120
# Iteration 0: mu=2.0500, value_0=23.927797
# Stopped after 9 iterations: mu=3.9924, value_0=115.596073
# Iteration 0: mu=2.0500, value_0=1.019436
# Stopped after 9 iterations: mu=3.9924, value_0=17.528355
# Iteration 0: mu=2.0500, value_0=0.026478
# Stopped after 9 iterations: mu=3.9924, value_0=1.692452
# Iteration 0: mu=2.0500, value_0=0.004780
# Converged after 0 iterations: mu=2.0500
# Iteration 0: mu=2.0500, value_0=-31.878194
# Stopped after 9 iterations: mu=1.0674, value_0=-0.123214
# Iteration 0: mu=2.0500, value_0=103.926956
# Stopped after 9 iterations: mu=3.6420, value_0=0.321576
# Iteration 0: mu=2.0500, value_0=67.686792
# Stopped after 9 iterations: mu=3.9924, value_0=78.675590
# Iteration 0: mu=2.0500, value_0=54.395980
# Stopped after 9 iterations: mu=3.9924, value_0=130.865842
# Iteration 0: mu=2.0500, value_0=24.543524
# Stopped after 9 iterations: mu=3.9924, value_0=115.979827
# Iteration 0: mu=2.0500, value_0=6.094428
# Stopped after 9 iterations: mu=3.9924, value_0=56.002689
# Iteration 0: mu=2.0500, value_0=0.713978
# Stopped after 9 iterations: mu=3.9924, value_0=12.345140
# Iteration 0: mu=2.0500, value_0=0.118344
# Stopped after 9 iterations: mu=3.9924, value_0=3.935890
# Iteration 0: mu=2.0500, value_0=-31.350381
# Stopped after 9 iterations: mu=1.0979, value_0=-0.150170
# Iteration 0: mu=2.0500, value_0=98.958865
# Stopped after 9 iterations: mu=3.7791, value_0=-0.214911
# Iteration 0: mu=2.0500, value_0=87.630099
# Stopped after 9 iterations: mu=3.9924, value_0=99.479920
# Iteration 0: mu=2.0500, value_0=48.402577
# Stopped after 9 iterations: mu=3.9924, value_0=118.150339
# Iteration 0: mu=2.0500, value_0=26.764791
# Stopped after 9 iterations: mu=3.9924, value_0=129.369372
# Iteration 0: mu=2.0500, value_0=5.925156
# Stopped after 9 iterations: mu=3.9924, value_0=56.556173
# Iteration 0: mu=2.0500, value_0=0.034534
# Stopped after 9 iterations: mu=3.9924, value_0=2.224278
# Iteration 0: mu=2.0500, value_0=-27.550270
# Stopped after 9 iterations: mu=1.1588, value_0=0.041676
# Iteration 0: mu=2.0500, value_0=83.012131
# Stopped after 9 iterations: mu=3.3982, value_0=0.520830
# Iteration 0: mu=2.0500, value_0=107.383032
# Stopped after 9 iterations: mu=3.9924, value_0=142.314833
# Iteration 0: mu=2.0500, value_0=47.589376
# Stopped after 9 iterations: mu=3.9924, value_0=121.712145
# Iteration 0: mu=2.0500, value_0=29.356573
# Stopped after 9 iterations: mu=3.9924, value_0=149.687413
# Iteration 0: mu=2.0500, value_0=8.592459
# Stopped after 9 iterations: mu=3.9924, value_0=82.624722
# Iteration 0: mu=2.0500, value_0=1.303566
# Stopped after 9 iterations: mu=3.9924, value_0=23.571854
# Iteration 0: mu=2.0500, value_0=-30.558662
# Stopped after 9 iterations: mu=1.1283, value_0=0.161119
# Iteration 0: mu=2.0500, value_0=93.623042
# Stopped after 9 iterations: mu=3.5201, value_0=0.137194
# Iteration 0: mu=2.0500, value_0=109.320199
# Stopped after 9 iterations: mu=3.9924, value_0=148.386498
# Iteration 0: mu=2.0500, value_0=45.861930
# Stopped after 9 iterations: mu=3.9924, value_0=120.621431
# Iteration 0: mu=2.0500, value_0=24.659529
# Stopped after 9 iterations: mu=3.9924, value_0=122.670214
# Iteration 0: mu=2.0500, value_0=7.502630
# Stopped after 9 iterations: mu=3.9924, value_0=70.133600
# Iteration 0: mu=2.0500, value_0=-31.086475
# Stopped after 9 iterations: mu=1.1131, value_0=-0.173682
# Iteration 0: mu=2.0500, value_0=88.190500
# Stopped after 9 iterations: mu=3.5811, value_0=0.450154
# Iteration 0: mu=2.0500, value_0=97.552245
# Stopped after 9 iterations: mu=3.9924, value_0=114.125510
# Iteration 0: mu=2.0500, value_0=45.982393
# Stopped after 9 iterations: mu=3.9924, value_0=112.760028
# Iteration 0: mu=2.0500, value_0=21.375068
# Stopped after 9 iterations: mu=3.9924, value_0=104.312402
# Iteration 0: mu=2.0500, value_0=5.408012
# Stopped after 9 iterations: mu=3.9924, value_0=50.147394
# Iteration 0: mu=2.0500, value_0=0.132072
# Stopped after 9 iterations: mu=3.9924, value_0=4.340468
# Iteration 0: mu=2.0500, value_0=-37.877288
# Stopped after 9 iterations: mu=1.1131, value_0=-0.049746
# Iteration 0: mu=2.0500, value_0=85.702627
# Stopped after 9 iterations: mu=3.3525, value_0=-0.094571
# Iteration 0: mu=2.0500, value_0=58.202812
# Stopped after 9 iterations: mu=3.9924, value_0=53.416694
# Iteration 0: mu=2.0500, value_0=50.083326
# Stopped after 9 iterations: mu=3.9924, value_0=122.830501
# Iteration 0: mu=2.0500, value_0=20.593777
# Stopped after 9 iterations: mu=3.9924, value_0=96.153009
# Iteration 0: mu=2.0500, value_0=6.131301
# Stopped after 9 iterations: mu=3.9924, value_0=56.430049
# Iteration 0: mu=2.0500, value_0=1.052849
# Stopped after 9 iterations: mu=3.9924, value_0=18.567540
# Iteration 0: mu=2.0500, value_0=-38.405102
# Stopped after 9 iterations: mu=1.0826, value_0=0.162937
# Iteration 0: mu=2.0500, value_0=90.246588
# Stopped after 9 iterations: mu=3.6420, value_0=-0.013260
# Iteration 0: mu=2.0500, value_0=90.330547
# Stopped after 9 iterations: mu=3.9924, value_0=114.588253
# Iteration 0: mu=2.0500, value_0=66.164714
# Stopped after 9 iterations: mu=3.9924, value_0=167.713935
# Iteration 0: mu=2.0500, value_0=22.339106
# Stopped after 9 iterations: mu=3.9924, value_0=110.305632
# Iteration 0: mu=2.0500, value_0=0.006323
# Converged after 0 iterations: mu=2.0500
# Iteration 0: mu=2.0500, value_0=-23.363144
# Converged after 7 iterations: mu=1.2121
# Iteration 0: mu=2.0500, value_0=89.584107
# Stopped after 9 iterations: mu=3.5658, value_0=-0.227103
# Iteration 0: mu=2.0500, value_0=64.094190
# Stopped after 9 iterations: mu=3.9924, value_0=60.512404
# Iteration 0: mu=2.0500, value_0=56.144041
# Stopped after 9 iterations: mu=3.9924, value_0=134.071608
# Iteration 0: mu=2.0500, value_0=24.160847
# Stopped after 9 iterations: mu=3.9924, value_0=115.892948
# Iteration 0: mu=2.0500, value_0=4.517989
# Stopped after 9 iterations: mu=3.9924, value_0=41.032144
# Iteration 0: mu=2.0500, value_0=1.461368
# Stopped after 9 iterations: mu=3.9924, value_0=25.729464
# Iteration 0: mu=2.0500, value_0=0.020340
# Stopped after 9 iterations: mu=3.9924, value_0=1.296487
# Iteration 0: mu=2.0500, value_0=0.000015
# Converged after 0 iterations: mu=2.0500
# Iteration 0: mu=2.0500, value_0=-19.844628
# Stopped after 9 iterations: mu=1.1740, value_0=0.017819
# Iteration 0: mu=2.0500, value_0=100.521154
# Stopped after 9 iterations: mu=3.7486, value_0=-0.053671
# Iteration 0: mu=2.0500, value_0=87.213114
# Stopped after 9 iterations: mu=3.9924, value_0=100.752623
# Iteration 0: mu=2.0500, value_0=54.204978
# Stopped after 9 iterations: mu=3.9924, value_0=141.600421
# Iteration 0: mu=2.0500, value_0=23.754013
# Stopped after 9 iterations: mu=3.9924, value_0=113.480228
# Iteration 0: mu=2.0500, value_0=5.615653
# Stopped after 9 iterations: mu=3.9924, value_0=52.323952
# Iteration 0: mu=2.0500, value_0=1.717583
# Stopped after 9 iterations: mu=3.9924, value_0=30.193755
# Iteration 0: mu=2.0500, value_0=0.237458
# Stopped after 9 iterations: mu=3.9924, value_0=8.039235
# Iteration 0: mu=2.0500, value_0=0.030451
# Stopped after 9 iterations: mu=3.9924, value_0=1.988378
# Iteration 0: mu=2.0500, value_0=0.003508
# Converged after 0 iterations: mu=2.0500
# Iteration 0: mu=2.0500, value_0=-34.622679
# Stopped after 9 iterations: mu=1.0521, value_0=0.145968
# Iteration 0: mu=2.0500, value_0=75.185117
# Stopped after 9 iterations: mu=3.4135, value_0=-0.406510
# Iteration 0: mu=2.0500, value_0=87.570894
# Stopped after 9 iterations: mu=3.9924, value_0=112.641455
# Iteration 0: mu=2.0500, value_0=58.121313
# Stopped after 9 iterations: mu=3.9924, value_0=145.340469
# Iteration 0: mu=2.0500, value_0=24.163878
# Stopped after 9 iterations: mu=3.9924, value_0=114.981410
# Iteration 0: mu=2.0500, value_0=6.278910
# Stopped after 9 iterations: mu=3.9924, value_0=57.655753
# Iteration 0: mu=2.0500, value_0=-42.469119
# Stopped after 9 iterations: mu=1.0217, value_0=0.083453
# Iteration 0: mu=2.0500, value_0=74.645129
# Stopped after 9 iterations: mu=3.3982, value_0=-0.189977
# Iteration 0: mu=2.0500, value_0=96.490899
# Stopped after 9 iterations: mu=3.9924, value_0=98.210085
# Iteration 0: mu=2.0500, value_0=31.860890
# Stopped after 9 iterations: mu=3.9924, value_0=75.631623
# Iteration 0: mu=2.0500, value_0=19.816967
# Stopped after 9 iterations: mu=3.9924, value_0=93.033115
# Iteration 0: mu=2.0500, value_0=7.862837
# Stopped after 9 iterations: mu=3.9924, value_0=74.213310
# Iteration 0: mu=2.0500, value_0=1.455944
# Stopped after 9 iterations: mu=3.9924, value_0=25.400656
# Iteration 0: mu=2.0500, value_0=-23.908646
# Stopped after 9 iterations: mu=1.0674, value_0=-0.092410
# Iteration 0: mu=2.0500, value_0=93.558988
# Stopped after 9 iterations: mu=3.3678, value_0=0.315270
# Iteration 0: mu=2.0500, value_0=66.272004
# Stopped after 9 iterations: mu=3.9924, value_0=69.569428
# Iteration 0: mu=2.0500, value_0=38.000889
# Stopped after 9 iterations: mu=3.9924, value_0=89.048668
# Iteration 0: mu=2.0500, value_0=26.647540
# Stopped after 9 iterations: mu=3.9924, value_0=126.245415
# Iteration 0: mu=2.0500, value_0=5.240240
# Stopped after 9 iterations: mu=3.9924, value_0=47.372806
# Iteration 0: mu=2.0500, value_0=0.864124
# Stopped after 9 iterations: mu=3.9924, value_0=14.881806
# Iteration 0: mu=2.0500, value_0=0.003394
# Converged after 0 iterations: mu=2.0500
# Iteration 0: mu=2.0500, value_0=0.000015
# Converged after 0 iterations: mu=2.0500
# Iteration 0: mu=2.0500, value_0=-23.380833
# Stopped after 9 iterations: mu=1.0979, value_0=0.070487
# Iteration 0: mu=2.0500, value_0=94.593794
# Stopped after 9 iterations: mu=3.7639, value_0=0.297616
# Iteration 0: mu=2.0500, value_0=66.185238
# Stopped after 9 iterations: mu=3.9924, value_0=81.342601
# Iteration 0: mu=2.0500, value_0=41.897702
# Stopped after 9 iterations: mu=3.9924, value_0=102.280049
# Iteration 0: mu=2.0500, value_0=29.708788
# Stopped after 9 iterations: mu=3.9924, value_0=142.949524
# Iteration 0: mu=2.0500, value_0=6.094545
# Stopped after 9 iterations: mu=3.9924, value_0=55.518950
# Iteration 0: mu=2.0500, value_0=0.774337
# Stopped after 9 iterations: mu=3.9924, value_0=13.579801
# Iteration 0: mu=2.0500, value_0=-39.073713
# Stopped after 9 iterations: mu=1.0064, value_0=0.192026
# Iteration 0: mu=2.0500, value_0=105.371091
# Stopped after 9 iterations: mu=3.7029, value_0=0.071565
# Iteration 0: mu=2.0500, value_0=75.373706
# Stopped after 9 iterations: mu=3.9924, value_0=80.370756
# Iteration 0: mu=2.0500, value_0=41.438445
# Stopped after 9 iterations: mu=3.9924, value_0=101.983709
# Iteration 0: mu=2.0500, value_0=23.835614
# Stopped after 9 iterations: mu=3.9924, value_0=114.527672
# Iteration 0: mu=2.0500, value_0=4.022737
# Stopped after 9 iterations: mu=3.9924, value_0=37.507454
# Iteration 0: mu=2.0500, value_0=0.038562
# Stopped after 9 iterations: mu=3.9924, value_0=2.490192
# Iteration 0: mu=2.0500, value_0=-30.840257
# Stopped after 9 iterations: mu=1.0217, value_0=-0.103963
# Iteration 0: mu=2.0500, value_0=99.722656
# Stopped after 9 iterations: mu=3.8857, value_0=-0.431254
# Iteration 0: mu=2.0500, value_0=84.584374
# Stopped after 9 iterations: mu=3.9924, value_0=110.405434
# Iteration 0: mu=2.0500, value_0=48.972613
# Stopped after 9 iterations: mu=3.9924, value_0=114.781618
# Iteration 0: mu=2.0500, value_0=24.364887
# Stopped after 9 iterations: mu=3.9924, value_0=115.316093
# Iteration 0: mu=2.0500, value_0=0.023641
# Stopped after 9 iterations: mu=3.9924, value_0=1.481077
# Iteration 0: mu=2.0500, value_0=-29.661522
# Stopped after 9 iterations: mu=1.0369, value_0=-0.050998
# Iteration 0: mu=2.0500, value_0=97.657637
# Stopped after 9 iterations: mu=3.6725, value_0=-0.017358
# Iteration 0: mu=2.0500, value_0=69.118678
# Stopped after 9 iterations: mu=3.9924, value_0=68.828858
# Iteration 0: mu=2.0500, value_0=43.090979
# Stopped after 9 iterations: mu=3.9924, value_0=103.423042
# Iteration 0: mu=2.0500, value_0=23.651417
# Stopped after 9 iterations: mu=3.9924, value_0=110.742797
# Iteration 0: mu=2.0500, value_0=4.259995
# Stopped after 9 iterations: mu=3.9924, value_0=37.556882
# Iteration 0: mu=2.0500, value_0=-32.406008
# Stopped after 9 iterations: mu=1.0369, value_0=-0.122477
# Iteration 0: mu=2.0500, value_0=81.015759
# Stopped after 9 iterations: mu=3.3982, value_0=-0.327653
# Iteration 0: mu=2.0500, value_0=73.364318
# Stopped after 9 iterations: mu=3.9924, value_0=86.471351
# Iteration 0: mu=2.0500, value_0=39.070372
# Stopped after 9 iterations: mu=3.9924, value_0=92.867448
# Iteration 0: mu=2.0500, value_0=27.579537
# Stopped after 9 iterations: mu=3.9924, value_0=132.276453
# Iteration 0: mu=2.0500, value_0=7.636184
# Stopped after 9 iterations: mu=3.9924, value_0=68.611011
# Iteration 0: mu=2.0500, value_0=0.751514
# Stopped after 9 iterations: mu=3.9924, value_0=12.979306
# Iteration 0: mu=2.0500, value_0=0.000818
# Converged after 0 iterations: mu=2.0500
#   Applying Baseline uncensoring...
#
# Processing complete!
# Combined dataset saved as: Test1/combined_magazine_kpis_features_attempt1.csv
# Total rows: 10685
# Magazines processed: 9
# POS locations: 5897

# %% [markdown]
# # Cleaning & Merging with Agrawal + Bayesian

# %%
import pandas as pd

def merge_all_methods_data(pivoted_csv_path, bayesian_csv_path, agrawal_csv_path, output_csv_path):
    """
    Simply add Bayesian and Agrawal columns to the pivoted dataset
    
    Parameters:
    - pivoted_csv_path: path to the pivoted CSV with method-prefixed columns
    - bayesian_csv_path: path to Bayesian results CSV
    - agrawal_csv_path: path to Agrawal results CSV  
    - output_csv_path: path for the merged output CSV
    """
    
    # Read all datasets
    print("Reading datasets...")
    pivoted_df = pd.read_csv(pivoted_csv_path)
    bayesian_df = pd.read_csv(bayesian_csv_path)
    agrawal_df = pd.read_csv(agrawal_csv_path)
    
    print(f"Pivoted data shape: {pivoted_df.shape}")
    print(f"Bayesian data shape: {bayesian_df.shape}")
    print(f"Agrawal data shape: {agrawal_df.shape}")
    
    # Merge Bayesian data (POS -> EHASTRA_EH_NUMMER, Magazine -> magazine)
    print("Merging Bayesian data...")
    merged_df = pivoted_df.merge(
        bayesian_df, 
        left_on=['EHASTRA_EH_NUMMER', 'magazine'], 
        right_on=['POS', 'Magazine'], 
        how='left'
    )
    
    # Drop the duplicate columns from Bayesian
    columns_to_drop = ['POS', 'Magazine']
    for col in columns_to_drop:
        if col in merged_df.columns:
            merged_df = merged_df.drop(col, axis=1)
    
    # Merge Agrawal data (POS -> EHASTRA_EH_NUMMER, Magazine -> magazine)  
    print("Merging Agrawal data...")
    merged_df = merged_df.merge(
        agrawal_df, 
        left_on=['EHASTRA_EH_NUMMER', 'magazine'], 
        right_on=['POS', 'Magazine'], 
        how='left',
        suffixes=('', '_agrawal_dup')
    )
    
    # Drop the duplicate columns from Agrawal
    columns_to_drop = ['POS', 'Magazine']
    for col in columns_to_drop:
        if col in merged_df.columns:
            merged_df = merged_df.drop(col, axis=1)
    
    print(f"Final merged dataset shape: {merged_df.shape}")
    
    # Check merge success
    bayesian_cols = [col for col in merged_df.columns if col.startswith('Bayesian_')]
    agrawal_cols = [col for col in merged_df.columns if col.startswith('Agrawal_')]
    
    if bayesian_cols:
        bayesian_matches = merged_df[bayesian_cols[0]].notna().sum()
        print(f"Successful Bayesian merges: {bayesian_matches}/{len(merged_df)}")
    
    if agrawal_cols:
        agrawal_matches = merged_df[agrawal_cols[0]].notna().sum() 
        print(f"Successful Agrawal merges: {agrawal_matches}/{len(merged_df)}")
    
    # Save the merged dataset
    merged_df.to_csv(output_csv_path, index=False)
    print(f"Final dataset saved to: {output_csv_path}")
    
    # Show column summary
    all_method_cols = [col for col in merged_df.columns if any(method in col for method in [
        'N1_', 'N2_', 'N3_', 'EM_', 'PD_', 'Nahmias_', 'Conrad_', 'Baseline_', 'Bayesian_', 'Agrawal_'
    ])]
    
    print(f"Total method-specific columns: {len(all_method_cols)}")
    
    return merged_df

# Example usage
if __name__ == "__main__":
    # Replace with your actual file paths
    pivoted_file = "combined_magazine_kpis_features_attempt1.csv"
    bayesian_file = "bayesian_results.csv"  # Update with actual filename
    agrawal_file = "agrawal_results.csv"    # Update with actual filename
    output_file = "final_merged_all_methods.csv"
    
    # Merge all datasets
    merged_df = merge_all_methods_data(
        pivoted_file, 
        bayesian_file, 
        agrawal_file, 
        output_file
    )
    
    print(f"\nFinal dataset: {len(merged_df)} rows, {len(merged_df.columns)} columns")
    print("All methods combined - ready for analysis!")
# Out:
# Reading datasets...
# Pivoted data shape: (10685, 103)
# Bayesian data shape: (10685, 14)
# Agrawal data shape: (10685, 14)
# Merging Bayesian data...
# Merging Agrawal data...
# Final merged dataset shape: (10685, 127)
# Successful Bayesian merges: 10685/10685
# Successful Agrawal merges: 10685/10685
# Final dataset saved to: final_merged_all_methods.csv
# Total method-specific columns: 110
#
# Final dataset: 10685 rows, 127 columns
# All methods combined - ready for analysis!

# %% [markdown]
# # Adding best method

# %%
import pandas as pd
import numpy as np

def add_best_method_column_pivoted(df, primary_kpi, tiebreaker_kpi):
    """
    Add a column showing which method performs best for each POS+Magazine combination
    
    Parameters:
    - primary_kpi: The main KPI to optimize (e.g., 'weighted_mae_0')
    - tiebreaker_kpi: KPI to use for breaking ties (e.g., 'accuracy')
    
    Returns:
    - DataFrame with new column 'best_method_{primary_kpi}'
    
    """
    
    # Define which KPIs should be minimized vs maximized
    minimize_kpis = [
        'bias', 'weighted_mae_0', 'weighted_mae_0.5', 'weighted_mae_1', 'weighted_mae_1.5',
        'gini_coefficient', 'overstock', 'overestimation_rate', 'underestimation_rate'
    ]
    
    maximize_kpis = [
        'accuracy'
    ]
    
    
    # Determine optimization direction for primary and tiebreaker KPIs
    primary_minimize = primary_kpi in minimize_kpis
    tiebreaker_minimize = tiebreaker_kpi in minimize_kpis
    
    primary_kpi_cols = [col for col in df.columns if col.endswith(f'_{primary_kpi}') and not col.startswith('best_')]
    tiebreaker_kpi_cols = [col for col in df.columns if col.endswith(f'_{tiebreaker_kpi}') and not col.startswith('best_')]
    
    if not primary_kpi_cols:
        raise ValueError(f"No columns found ending with '_{primary_kpi}'")
    if not tiebreaker_kpi_cols:
        raise ValueError(f"No columns found ending with '_{tiebreaker_kpi}'")
    
    print(f"Found {len(primary_kpi_cols)} methods for {primary_kpi}: {[col.split('_')[0] for col in primary_kpi_cols]}")
    print(f"Found {len(tiebreaker_kpi_cols)} methods for {tiebreaker_kpi}: {[col.split('_')[0] for col in tiebreaker_kpi_cols]}")
    
    # Create the new column name
    new_column_name = f'best_method_{primary_kpi}'
    
    df_copy = df.copy()
    best_methods = []
    
    # For each row, find the best method
    for idx, row in df_copy.iterrows():
        # Get primary KPI values for all methods
        primary_values = {}
        for col in primary_kpi_cols:
            method_name = col.split('_')[0]  # Extract method name (e.g., 'N1' from 'N1_weighted_mae_0')
            if pd.notna(row[col]):
                primary_values[method_name] = row[col]
        
        if not primary_values:
            best_methods.append(None)
            continue
        
        # Find the best primary KPI value
        if primary_minimize:
            best_primary_value = min(primary_values.values())
            best_methods_primary = [method for method, value in primary_values.items() if value == best_primary_value]
        else:
            best_primary_value = max(primary_values.values())
            best_methods_primary = [method for method, value in primary_values.items() if value == best_primary_value]
        
        # If there's only one best method, use it
        if len(best_methods_primary) == 1:
            best_method = best_methods_primary[0]
        else:
            # Use tiebreaker KPI to resolve ties
            tiebreaker_values = {}
            for method in best_methods_primary:
                tiebreaker_col = f"{method}_{tiebreaker_kpi}"
                if tiebreaker_col in df.columns and pd.notna(row[tiebreaker_col]):
                    tiebreaker_values[method] = row[tiebreaker_col]
            
            if not tiebreaker_values:
                # If no tiebreaker values available, pick the first method alphabetically
                best_method = sorted(best_methods_primary)[0]
            else:
                if tiebreaker_minimize:
                    best_tiebreaker_value = min(tiebreaker_values.values())
                    best_method = [method for method, value in tiebreaker_values.items() if value == best_tiebreaker_value][0]
                else:
                    best_tiebreaker_value = max(tiebreaker_values.values())
                    best_method = [method for method, value in tiebreaker_values.items() if value == best_tiebreaker_value][0]
        
        best_methods.append(best_method)
    
    # Add the best method column
    df_copy[new_column_name] = best_methods
    
    return df_copy

def add_multiple_best_method_columns_pivoted(df, kpi_configs):
    """
    Add multiple best method columns for different KPI combinations
    Works with pivoted data
    
    Parameters:
    - df: DataFrame with pivoted KPI results
    - kpi_configs: List of tuples [(primary_kpi, tiebreaker_kpi), ...]
    
    Example:
    kpi_configs = [
        ('weighted_mae_0', 'accuracy'),
        ('weighted_mae_1', 'accuracy'),
        ('accuracy', 'weighted_mae_0'),
        ('bias', 'weighted_mae_0')
    ]
    """
    result_df = df.copy()
    
    for primary_kpi, tiebreaker_kpi in kpi_configs:
        print(f"\nAdding best method column for {primary_kpi} (tiebreaker: {tiebreaker_kpi})")
        result_df = add_best_method_column_pivoted(result_df, primary_kpi, tiebreaker_kpi)
    
    return result_df

def analyze_best_methods(df, kpi_name):
    """
    Analyze and display summary statistics for best methods
    """
    best_method_col = f'best_method_{kpi_name}'
    
    if best_method_col not in df.columns:
        print(f"Column {best_method_col} not found in DataFrame")
        return
    
    print(f"\n=== Best Method Analysis for {kpi_name.upper()} ===")
    
    # Overall best method counts
    print(f"\nOverall best method distribution:")
    method_counts = df[best_method_col].value_counts()
    print(method_counts)
    
    # Best methods by magazine
    print(f"\nBest methods by magazine:")
    magazine_summary = df.groupby(['magazine', best_method_col]).size().unstack(fill_value=0)
    print(magazine_summary)
    
    # Calculate percentages
    print(f"\nBest method percentages:")
    percentages = (method_counts / len(df) * 100).round(2)
    for method, pct in percentages.items():
        print(f"  {method}: {pct}%")

# Usage
if __name__ == "__main__":
    # Load the pivoted CSV file
    df = pd.read_csv("final_merged_all_methods.csv")
    
    print(f"Loaded dataset with {len(df)} rows and {len(df.columns)} columns")
    print(f"Magazines: {df['magazine'].unique()}")
    
    # Define KPI configurations for analysis
    kpi_configs = [
        ('weighted_mae_0', 'accuracy'),      # Best for unweighted MAE with accuracy tiebreaker
        ('weighted_mae_1', 'accuracy'),      # Best for weighted MAE (α=1) with accuracy tiebreaker
        ('weighted_mae_1.5', 'accuracy'),    # Best for weighted MAE (α=1.5) with accuracy tiebreaker
        ('accuracy', 'weighted_mae_0'),      # Best for accuracy with MAE tiebreaker
        ('bias', 'weighted_mae_0'),          # Best for bias with MAE tiebreaker
        ('overstock', 'accuracy'),           # Best for overstock with accuracy tiebreaker
    ]
    
    # Add all best method columns
    print("Adding best method columns...")
    df_with_best = add_multiple_best_method_columns_pivoted(df, kpi_configs)
    
    # Save results
    output_filename = "final_merged_with_best_methods.csv"
    df_with_best.to_csv(output_filename, index=False)
    print(f"\nResults saved to: {output_filename}")
    
    # Analyze results for key KPIs
    key_kpis = ['weighted_mae_0', 'weighted_mae_1', 'accuracy', 'bias']
    
    for kpi in key_kpis:
        if f'best_method_{kpi}' in df_with_best.columns:
            analyze_best_methods(df_with_best, kpi)
    
    print(f"\nFinal dataset: {len(df_with_best)} rows, {len(df_with_best.columns)} columns")
    
    # Show sample of the new columns
    best_method_cols = [col for col in df_with_best.columns if col.startswith('best_method_')]
    print(f"\nBest method columns added: {len(best_method_cols)}")
    print("Sample of best method assignments:")
    sample_cols = ['EHASTRA_EH_NUMMER', 'magazine'] + best_method_cols[:3]
    print(df_with_best[sample_cols].head())
# Out:
# Loaded dataset with 10685 rows and 127 columns
# Magazines: ['E' 'C' 'H' 'D' 'B' 'I' 'G' 'A' 'F']
# Adding best method columns...
#
# Adding best method column for weighted_mae_0 (tiebreaker: accuracy)
# Found 10 methods for weighted_mae_0: ['N1', 'N2', 'N3', 'EM', 'PD', 'Nahmias', 'Conrad', 'Baseline', 'Bayesian', 'Agrawal']
# Found 10 methods for accuracy: ['N1', 'N2', 'N3', 'EM', 'PD', 'Nahmias', 'Conrad', 'Baseline', 'Bayesian', 'Agrawal']
#
# Adding best method column for weighted_mae_1 (tiebreaker: accuracy)
# Found 10 methods for weighted_mae_1: ['N1', 'N2', 'N3', 'EM', 'PD', 'Nahmias', 'Conrad', 'Baseline', 'Bayesian', 'Agrawal']
# Found 10 methods for accuracy: ['N1', 'N2', 'N3', 'EM', 'PD', 'Nahmias', 'Conrad', 'Baseline', 'Bayesian', 'Agrawal']
#
# Adding best method column for weighted_mae_1.5 (tiebreaker: accuracy)
# Found 10 methods for weighted_mae_1.5: ['N1', 'N2', 'N3', 'EM', 'PD', 'Nahmias', 'Conrad', 'Baseline', 'Bayesian', 'Agrawal']
# Found 10 methods for accuracy: ['N1', 'N2', 'N3', 'EM', 'PD', 'Nahmias', 'Conrad', 'Baseline', 'Bayesian', 'Agrawal']
#
# Adding best method column for accuracy (tiebreaker: weighted_mae_0)
# Found 10 methods for accuracy: ['N1', 'N2', 'N3', 'EM', 'PD', 'Nahmias', 'Conrad', 'Baseline', 'Bayesian', 'Agrawal']
# Found 10 methods for weighted_mae_0: ['N1', 'N2', 'N3', 'EM', 'PD', 'Nahmias', 'Conrad', 'Baseline', 'Bayesian', 'Agrawal']
#
# Adding best method column for bias (tiebreaker: weighted_mae_0)
# Found 10 methods for bias: ['N1', 'N2', 'N3', 'EM', 'PD', 'Nahmias', 'Conrad', 'Baseline', 'Bayesian', 'Agrawal']
# Found 10 methods for weighted_mae_0: ['N1', 'N2', 'N3', 'EM', 'PD', 'Nahmias', 'Conrad', 'Baseline', 'Bayesian', 'Agrawal']
#
# Adding best method column for overstock (tiebreaker: accuracy)
# Found 10 methods for overstock: ['N1', 'N2', 'N3', 'EM', 'PD', 'Nahmias', 'Conrad', 'Baseline', 'Bayesian', 'Agrawal']
# Found 10 methods for accuracy: ['N1', 'N2', 'N3', 'EM', 'PD', 'Nahmias', 'Conrad', 'Baseline', 'Bayesian', 'Agrawal']
#
# Results saved to: final_merged_with_best_methods.csv
#
# === Best Method Analysis for WEIGHTED_MAE_0 ===
#
# Overall best method distribution:
# best_method_weighted_mae_0
# N3          5084
# PD          1791
# Conrad      1622
# Nahmias     1117
# EM           674
# Baseline     310
# N1            51
# N2            20
# Bayesian      10
# Agrawal        6
# Name: count, dtype: int64
#
# Best methods by magazine:
# best_method_weighted_mae_0  Agrawal  Baseline  Bayesian  Conrad   EM  N1  N2  \
# magazine
# A                                 3        56         1     375   63  14   2
# B                                 0        36         5     359   31  10   1
# C                                 0        37         0     211   57   4   1
# D                                 0        21         0     103  101   1   2
# E                                 2        63         2     232   73   3   3
# F                                 0        16         0      89   73   3   0
# G                                 0         0         1      58   73   0   0
# H                                 0        19         0      75   76   3   4
# I                                 1        62         1     120  127  13   7
#
# best_method_weighted_mae_0    N3  Nahmias   PD
# magazine
# A                           1031      298  485
# B                            768      138  308
# C                            761       62  282
# D                            561       67  128
# E                            676      306  212
# F                            384       23  114
# G                            336        6   47
# H                            249       50   69
# I                            318      167  146
#
# Best method percentages:
#   N3: 47.58%
#   PD: 16.76%
#   Conrad: 15.18%
#   Nahmias: 10.45%
#   EM: 6.31%
#   Baseline: 2.9%
#   N1: 0.48%
#   N2: 0.19%
#   Bayesian: 0.09%
#   Agrawal: 0.06%
#
# === Best Method Analysis for WEIGHTED_MAE_1 ===
#
# Overall best method distribution:
# best_method_weighted_mae_1
# N3          4918
# PD          1726
# Conrad      1700
# Nahmias     1282
# EM           863
# Baseline     110
# N1            48
# N2            24
# Bayesian       8
# Agrawal        6
# Name: count, dtype: int64
#
# Best methods by magazine:
# best_method_weighted_mae_1  Agrawal  Baseline  Bayesian  Conrad   EM  N1  N2  \
# magazine
# A                                 5        15         1     379   96  11   3
# B                                 0         1         4     339   41   7   1
# C                                 0         0         0     213   83   3   2
# D                                 0        10         0     109  121   1   2
# E                                 1        31         1     278  106   3   4
# F                                 0         2         0     104   91   2   1
# G                                 0         0         1      61   83   0   0
# H                                 0         8         0      87   89   3   3
# I                                 0        43         1     130  153  18   8
#
# best_method_weighted_mae_1    N3  Nahmias   PD
# magazine
# A                           1017      279  522
# B                            772      139  352
# C                            761       67  286
# D                            558       74  109
# E                            589      417  142
# F                            372       30  100
# G                            332        7   37
# H                            227       73   55
# I                            290      196  123
#
# Best method percentages:
#   N3: 46.03%
#   PD: 16.15%
#   Conrad: 15.91%
#   Nahmias: 12.0%
#   EM: 8.08%
#   Baseline: 1.03%
#   N1: 0.45%
#   N2: 0.22%
#   Bayesian: 0.07%
#   Agrawal: 0.06%
#
# === Best Method Analysis for ACCURACY ===
#
# Overall best method distribution:
# best_method_accuracy
# N3          3981
# PD          2197
# Conrad      1876
# Nahmias      938
# EM           850
# Baseline     775
# Bayesian      22
# N1            21
# N2            16
# Agrawal        9
# Name: count, dtype: int64
#
# Best methods by magazine:
# best_method_accuracy  Agrawal  Baseline  Bayesian  Conrad   EM  N1  N2   N3  \
# magazine
# A                           3       241         5     357  113   4   1  756
# B                           1       144         8     420   51   3   0  538
# C                           0       103         0     313   89   1   1  531
# D                           0        44         0     142  111   0   2  465
# E                           3       107         6     233   86   3   2  601
# F                           1        24         0     123   88   0   0  303
# G                           0         3         1      83   87   0   0  281
# H                           0        25         0      77   84   2   3  225
# I                           1        84         2     128  141   8   7  281
#
# best_method_accuracy  Nahmias   PD
# magazine
# A                         219  629
# B                         128  363
# C                          40  337
# D                          73  147
# E                         238  293
# F                          31  132
# G                          11   55
# H                          50   79
# I                         148  162
#
# Best method percentages:
#   N3: 37.26%
#   PD: 20.56%
#   Conrad: 17.56%
#   Nahmias: 8.78%
#   EM: 7.96%
#   Baseline: 7.25%
#   Bayesian: 0.21%
#   N1: 0.2%
#   N2: 0.15%
#   Agrawal: 0.08%
#
# === Best Method Analysis for BIAS ===
#
# Overall best method distribution:
# best_method_bias
# N2          4124
# Agrawal     3944
# Bayesian    2525
# PD            78
# Baseline       7
# N1             4
# Nahmias        3
# Name: count, dtype: int64
#
# Best methods by magazine:
# best_method_bias  Agrawal  Baseline  Bayesian  N1   N2  Nahmias  PD
# magazine
# A                    1051         5       352   0  889        0  31
# B                     849         0       224   0  579        1   3
# C                     326         0       551   0  535        0   3
# D                     377         0       110   0  493        1   3
# E                     570         0       371   0  620        0  11
# F                      10         0       485   0  206        0   1
# G                      85         0       163   0  273        0   0
# H                     209         0        96   0  235        1   4
# I                     467         2       173   4  294        0  22
#
# Best method percentages:
#   N2: 38.6%
#   Agrawal: 36.91%
#   Bayesian: 23.63%
#   PD: 0.73%
#   Baseline: 0.07%
#   N1: 0.04%
#   Nahmias: 0.03%
#
# Final dataset: 10685 rows, 133 columns
#
# Best method columns added: 6
# Sample of best method assignments:
#   EHASTRA_EH_NUMMER magazine best_method_weighted_mae_0  \
# 0        EHA0086402        E                         PD
# 1        EHA0089037        E                    Nahmias
# 2        EHA0089518        E                    Nahmias
# 3        EHA0092474        E                         N3
# 4        EHA0225854        E                         N3
#
#   best_method_weighted_mae_1 best_method_weighted_mae_1.5
# 0                    Nahmias                      Nahmias
# 1                         EM                           EM
# 2                    Nahmias                      Nahmias
# 3                         N3                           N3
# 4                         N3                           N3

# %% [markdown]
# # Merging Sofortremission

# %%
import pandas as pd

# Read the files
best_methods_df = pd.read_csv("final_merged_with_best_methods.csv")
sofortremission_df = pd.read_csv("sofortremissionFeatures3007.csv")

# Fix the EHASTRA_EH_NUMMER format - add "EH" prefix to sofortremission
sofortremission_df['EHASTRA_EH_NUMMER'] = 'EH' + sofortremission_df['EHASTRA_EH_NUMMER'].astype(str)

# Merge
merged_df = best_methods_df.merge(
    sofortremission_df, 
    left_on=['EHASTRA_EH_NUMMER', 'magazine'], 
    right_on=['EHASTRA_EH_NUMMER', 'VDZ'], 
    how='left'
).drop('VDZ', axis=1)

# Sort by magazine
merged_df = merged_df.sort_values('magazine')

# Save
merged_df.to_csv("Input_DT_All_Mags.csv", index=False)

print(f"Done! {len(merged_df)} rows, {len(merged_df.columns)} columns")
# Out:
# Done! 10685 rows, 140 columns
