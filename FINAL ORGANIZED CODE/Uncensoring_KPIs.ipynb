# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ## Uncensoring KPIs

# %%
def uncensoring_KPI(dataframe, method_name):
    """
    Calculate KPIs for demand forecasting evaluation
    
    Parameters:
    - dataframe: pandas DataFrame containing 'Verkauf' (predicted) and 'Verkauf_MBR' (ground truth) columns
    - method_name: string name of the method being evaluated
    - censorship_pct: censorship percentage for display
    - reduction_pct: reduction percentage for display
    - alpha: weight parameter for Weighted MAE (default=1)
            α = 0: standard MAE (no weighting)
            α = 1: linear weighting by true demand
            α > 1: over-proportional penalization of larger errors
            α < 1: emphasis on smaller demands
    """
    df = dataframe[dataframe['Zensiert']==1]
    censored_fraction = len(df)/len(dataframe)
    
    # Extract predicted and true values
    y_pred = df[method_name + "_Demand"].values  # ŷᵢ (estimated demand)
    y_true = df['Verkauf_MBR'].values  # yᵢ (true demand)
    
    n = len(y_pred)
    if n == 0: return
    
    # 1. Bias calculation
    bias = np.sum(y_pred - y_true) / n
    
    # 2. Accuracy (exact matches)
    exact_matches = np.sum(y_pred == y_true)
    accuracy = exact_matches / n
    
    # 3. Overestimation Rate
    overestimations = np.sum(y_pred > y_true)
    overestimation_rate = overestimations / n
    
    # 4. Underestimation Rate
    underestimations = np.sum(y_pred < y_true)
    underestimation_rate = underestimations / n
    
    # 5. Weighted MAE
    alphas = [0, 0.5, 1, 1.5]
    weighted_maes = {}
    for a in alphas:
        if a == 0:
            # Standard MAE (no weighting)
            weighted_maes[a] = np.mean(np.abs(y_pred - y_true))
        else:
            # Weighted MAE with α parameter
            weights = np.power(y_true, a)
            # Handle case where y_true might be 0
            weights = np.where(y_true == 0, 0, weights)
            weighted_maes[a] = np.sum(weights * np.abs(y_pred - y_true)) / np.sum(weights) if np.sum(weights) > 0 else 0

    # 6. Gini Coefficient
    abs_errors = np.abs(y_pred - y_true)
    mean_abs_error = np.mean(abs_errors)
    n = len(abs_errors)
    sorted_errors = np.sort(abs_errors)
    
    weighted_sum = 0.0
    total_sum = 0.0
    
    for i in range(n):
        weighted_sum += (i + 1) * sorted_errors[i]
        total_sum += sorted_errors[i]
    
    gini_coefficient = (2 * weighted_sum) / (n * total_sum) - (n + 1) / n
    
    # 7. Overstock, out of curiosity
    overstock = np.sum(np.maximum(0, y_pred - y_true))

    for i in range(n):
        weighted_sum += (i + 1) * sorted_errors[i]
        total_sum += sorted_errors[i]

    gini_coefficient = (2 * weighted_sum) / (n * total_sum) - (n + 1) / n

    # Determine bias direction
    bias_direction = "overestimation" if bias > 0 else "underestimation" if bias < 0 else "neutral"
    
    return {
        method_name+'_bias': bias,
        method_name+'_weighted_mae_0': weighted_maes[0],
        method_name+'_weighted_mae_0.5': weighted_maes[0.5],
        method_name+'_weighted_mae_1': weighted_maes[1],
        method_name+'_weighted_mae_1.5': weighted_maes[1.5],
        method_name+'_censored_fraction': censored_fraction,
        method_name+'_accuracy': accuracy,
        method_name+'_overestimation_rate': overestimation_rate,
        method_name+'_underestimation_rate': underestimation_rate,
        method_name+'_gini_coefficient': gini_coefficient,
        method_name+'_overstock': overstock
        }

def uncensoring_KPI_POS(dataframe, methods, magazines):
    '''
    dataframe: df containing all uncensored results and original data columns
    Calculate uncensoring KPIs grouped by POS.
    Returns dataframe with KPI of each method per magazine and POS
    '''
    df = dataframe.copy()
    df=df.dropna(subset=['Verkauf', 'Bezug'])
    
    df_KPIs = pd.DataFrame() #initialize final output KPI dataframe
    for letter in magazines:
        print('-'*10+ f'Magazine {letter} KPIs' + '-'*10)
        df_magazine = df[df['Magazine']==letter]
        df_magazine_KPIs = None #initialize KPI dataframe for this magazine

        for method in methods:
            method_KPIs = [] #initialize KPIs for this magazine and method
            
            for pos, group in df_magazine.groupby('EHASTRA_EH_NUMMER'):
                #do not calculate KPI for POS with less than 3 uncensored points
                if len(group[group['Zensiert']==1])<3: continue
                pos_result = uncensoring_KPI(group, method)

                #catch None output
                if pos_result is not None:
                    pos_result['EHASTRA_EH_NUMMER'] = pos
                    method_KPIs.append(pos_result)
            df_method_KPIs = pd.DataFrame(method_KPIs)
            if len(df_method_KPIs)==0: continue
            df_method_KPIs['Magazine']=letter

            print('-'*10)
            kpi_cols = [c for c in df_method_KPIs.columns if c not in ['Magazine', 'EHASTRA_EH_NUMMER']]
            for col in kpi_cols:
                print(f'{col}: {df_method_KPIs[col].mean():.3f}')

            if df_magazine_KPIs is None: df_magazine_KPIs = df_method_KPIs
            else:
                new_cols = [c for c in df_method_KPIs if c not in df_magazine_KPIs or c in ['EHASTRA_EH_NUMMER']]
                df_magazine_KPIs = pd.merge(df_magazine_KPIs, df_method_KPIs[new_cols], how = 'outer', on = ['EHASTRA_EH_NUMMER'])
        df_KPIs = pd.concat([df_KPIs, df_magazine_KPIs])

    #move magazine and pos columns to the front
    df_KPIs.set_index(['Magazine', 'EHASTRA_EH_NUMMER'], inplace=True)
    df_KPIs.reset_index(inplace=True)
    return df_KPIs

# %%
df = pd.read_csv('Uncensoring_results.csv')
uncensoring_methods = ['N1', 'N2', 'N3', 'EM', 'PD', 'Nahmias', 'Conrad', 'Baseline', 'Bayesian']
magazine_letters = [letter for letter in 'ABCDEFGHI']
df_KPIs = uncensoring_KPI_POS(df, uncensoring_methods, magazine_letters)
df_KPIs.to_csv('Uncensoring_KPIs.csv', index=False) #adjust accordingly
# Out:
# ----------Magazine A KPIs----------
# ----------
# N1_bias: -0.577
# N1_weighted_mae_0: 0.859
# N1_weighted_mae_0.5: 0.898
# N1_weighted_mae_1: 0.955
# N1_weighted_mae_1.5: 1.029
# N1_censored_fraction: 0.298
# N1_accuracy: 0.320
# N1_overestimation_rate: 0.091
# N1_underestimation_rate: 0.589
# N1_gini_coefficient: 0.406
# N1_overstock: 5.833
# ----------
# N2_bias: -0.577
# N2_weighted_mae_0: 1.042
# N2_weighted_mae_0.5: 1.059
# N2_weighted_mae_1: 1.096
# N2_weighted_mae_1.5: 1.153
# N2_censored_fraction: 0.298
# N2_accuracy: 0.195
# N2_overestimation_rate: 0.141
# N2_underestimation_rate: 0.664
# N2_gini_coefficient: 0.318
# N2_overstock: 9.500
# ----------
# N3_bias: -0.218
# N3_weighted_mae_0: 0.683
# N3_weighted_mae_0.5: 0.659
# N3_weighted_mae_1: 0.645
# N3_weighted_mae_1.5: 0.640
# N3_censored_fraction: 0.298
# N3_accuracy: 0.425
# N3_overestimation_rate: 0.141
# N3_underestimation_rate: 0.434
# N3_gini_coefficient: 0.471
# N3_overstock: 9.500
# ----------
# EM_bias: -0.195
# EM_weighted_mae_0: 0.646
# EM_weighted_mae_0.5: 0.664
# EM_weighted_mae_1: 0.680
# EM_weighted_mae_1.5: 0.694
# EM_censored_fraction: 0.298
# EM_accuracy: 0.439
# EM_overestimation_rate: 0.225
# EM_underestimation_rate: 0.336
# EM_gini_coefficient: 0.479
# EM_overstock: 8.333
# ----------
# PD_bias: -0.655
# PD_weighted_mae_0: 0.728
# PD_weighted_mae_0.5: 0.765
# PD_weighted_mae_1: 0.807
# PD_weighted_mae_1.5: 0.854
# PD_censored_fraction: 0.298
# PD_accuracy: 0.394
# PD_overestimation_rate: 0.004
# PD_underestimation_rate: 0.603
# PD_gini_coefficient: 0.459
# PD_overstock: 1.667
# ----------
# Nahmias_bias: -0.672
# Nahmias_weighted_mae_0: 0.694
# Nahmias_weighted_mae_0.5: 0.716
# Nahmias_weighted_mae_1: 0.736
# Nahmias_weighted_mae_1.5: 0.754
# Nahmias_censored_fraction: 0.298
# Nahmias_accuracy: 0.391
# Nahmias_overestimation_rate: 0.011
# Nahmias_underestimation_rate: 0.598
# Nahmias_gini_coefficient: 0.433
# Nahmias_overstock: 0.500
# ----------
# Conrad_bias: -0.549
# Conrad_weighted_mae_0: 0.716
# Conrad_weighted_mae_0.5: 0.729
# Conrad_weighted_mae_1: 0.740
# Conrad_weighted_mae_1.5: 0.750
# Conrad_censored_fraction: 0.298
# Conrad_accuracy: 0.353
# Conrad_overestimation_rate: 0.084
# Conrad_underestimation_rate: 0.564
# Conrad_gini_coefficient: 0.390
# Conrad_overstock: 3.500
# ----------
# Baseline_bias: -0.692
# Baseline_weighted_mae_0: 0.692
# Baseline_weighted_mae_0.5: 0.713
# Baseline_weighted_mae_1: 0.732
# Baseline_weighted_mae_1.5: 0.750
# Baseline_censored_fraction: 0.298
# Baseline_accuracy: 0.397
# Baseline_overestimation_rate: 0.000
# Baseline_underestimation_rate: 0.603
# Baseline_gini_coefficient: 0.441
# Baseline_overstock: 0.000
# ----------
# Bayesian_bias: 0.775
# Bayesian_weighted_mae_0: 0.829
# Bayesian_weighted_mae_0.5: 0.784
# Bayesian_weighted_mae_1: 0.745
# Bayesian_weighted_mae_1.5: 0.712
# Bayesian_censored_fraction: 0.298
# Bayesian_accuracy: 0.357
# Bayesian_overestimation_rate: 0.616
# Bayesian_underestimation_rate: 0.027
# Bayesian_gini_coefficient: 0.414
# Bayesian_overstock: 31.667
# ----------Magazine B KPIs----------
# ----------
# N1_bias: -0.028
# N1_weighted_mae_0: 0.894
# N1_weighted_mae_0.5: 0.917
# N1_weighted_mae_1: 0.967
# N1_weighted_mae_1.5: 1.040
# N1_censored_fraction: 0.327
# N1_accuracy: 0.371
# N1_overestimation_rate: 0.333
# N1_underestimation_rate: 0.296
# N1_gini_coefficient: 0.507
# N1_overstock: 18.000
# ----------
# N2_bias: 0.472
# N2_weighted_mae_0: 1.069
# N2_weighted_mae_0.5: 1.038
# N2_weighted_mae_1: 1.033
# N2_weighted_mae_1.5: 1.052
# N2_censored_fraction: 0.327
# N2_accuracy: 0.333
# N2_overestimation_rate: 0.471
# N2_underestimation_rate: 0.196
# N2_gini_coefficient: 0.489
# N2_overstock: 31.500
# ----------
# N3_bias: 0.664
# N3_weighted_mae_0: 0.878
# N3_weighted_mae_0.5: 0.793
# N3_weighted_mae_1: 0.724
# N3_weighted_mae_1.5: 0.671
# N3_censored_fraction: 0.327
# N3_accuracy: 0.435
# N3_overestimation_rate: 0.471
# N3_underestimation_rate: 0.094
# N3_gini_coefficient: 0.534
# N3_overstock: 31.500
# ----------
# EM_bias: -0.025
# EM_weighted_mae_0: 1.025
# EM_weighted_mae_0.5: 1.044
# EM_weighted_mae_1: 1.062
# EM_weighted_mae_1.5: 1.078
# EM_censored_fraction: 0.327
# EM_accuracy: 0.244
# EM_overestimation_rate: 0.456
# EM_underestimation_rate: 0.300
# EM_gini_coefficient: 0.340
# EM_overstock: 22.500
# ----------
# PD_bias: -0.525
# PD_weighted_mae_0: 0.614
# PD_weighted_mae_0.5: 0.651
# PD_weighted_mae_1: 0.688
# PD_weighted_mae_1.5: 0.726
# PD_censored_fraction: 0.327
# PD_accuracy: 0.611
# PD_overestimation_rate: 0.044
# PD_underestimation_rate: 0.344
# PD_gini_coefficient: 0.670
# PD_overstock: 2.000
# ----------
# Nahmias_bias: -0.792
# Nahmias_weighted_mae_0: 0.792
# Nahmias_weighted_mae_0.5: 0.820
# Nahmias_weighted_mae_1: 0.847
# Nahmias_weighted_mae_1.5: 0.872
# Nahmias_censored_fraction: 0.327
# Nahmias_accuracy: 0.444
# Nahmias_overestimation_rate: 0.000
# Nahmias_underestimation_rate: 0.556
# Nahmias_gini_coefficient: 0.514
# Nahmias_overstock: 0.000
# ----------
# Conrad_bias: -0.792
# Conrad_weighted_mae_0: 0.792
# Conrad_weighted_mae_0.5: 0.820
# Conrad_weighted_mae_1: 0.847
# Conrad_weighted_mae_1.5: 0.872
# Conrad_censored_fraction: 0.327
# Conrad_accuracy: 0.444
# Conrad_overestimation_rate: 0.000
# Conrad_underestimation_rate: 0.556
# Conrad_gini_coefficient: 0.514
# Conrad_overstock: 0.000
# ----------
# Baseline_bias: -0.792
# Baseline_weighted_mae_0: 0.792
# Baseline_weighted_mae_0.5: 0.820
# Baseline_weighted_mae_1: 0.847
# Baseline_weighted_mae_1.5: 0.872
# Baseline_censored_fraction: 0.327
# Baseline_accuracy: 0.444
# Baseline_overestimation_rate: 0.000
# Baseline_underestimation_rate: 0.556
# Baseline_gini_coefficient: 0.514
# Baseline_overstock: 0.000
# ----------
# Bayesian_bias: 1.324
# Bayesian_weighted_mae_0: 1.399
# Bayesian_weighted_mae_0.5: 1.320
# Bayesian_weighted_mae_1: 1.247
# Bayesian_weighted_mae_1.5: 1.180
# Bayesian_censored_fraction: 0.327
# Bayesian_accuracy: 0.082
# Bayesian_overestimation_rate: 0.881
# Bayesian_underestimation_rate: 0.037
# Bayesian_gini_coefficient: 0.236
# Bayesian_overstock: 57.000
# ----------Magazine C KPIs----------
# ----------
# N1_bias: -0.684
# N1_weighted_mae_0: 1.474
# N1_weighted_mae_0.5: 1.483
# N1_weighted_mae_1: 1.514
# N1_weighted_mae_1.5: 1.562
# N1_censored_fraction: 0.297
# N1_accuracy: 0.184
# N1_overestimation_rate: 0.184
# N1_underestimation_rate: 0.632
# N1_gini_coefficient: 0.415
# N1_overstock: 15.000
# ----------
# N2_bias: 0.316
# N2_weighted_mae_0: 1.211
# N2_weighted_mae_0.5: 1.130
# N2_weighted_mae_1: 1.082
# N2_weighted_mae_1.5: 1.061
# N2_censored_fraction: 0.297
# N2_accuracy: 0.342
# N2_overestimation_rate: 0.368
# N2_underestimation_rate: 0.289
# N2_gini_coefficient: 0.547
# N2_overstock: 29.000
# ----------
# N3_bias: 0.316
# N3_weighted_mae_0: 1.211
# N3_weighted_mae_0.5: 1.130
# N3_weighted_mae_1: 1.082
# N3_weighted_mae_1.5: 1.061
# N3_censored_fraction: 0.297
# N3_accuracy: 0.342
# N3_overestimation_rate: 0.368
# N3_underestimation_rate: 0.289
# N3_gini_coefficient: 0.547
# N3_overstock: 29.000
# ----------
# EM_bias: -1.842
# EM_weighted_mae_0: 1.842
# EM_weighted_mae_0.5: 1.906
# EM_weighted_mae_1: 1.969
# EM_weighted_mae_1.5: 2.032
# EM_censored_fraction: 0.297
# EM_accuracy: 0.158
# EM_overestimation_rate: 0.000
# EM_underestimation_rate: 0.842
# EM_gini_coefficient: 0.365
# EM_overstock: 0.000
# ----------
# PD_bias: -1.842
# PD_weighted_mae_0: 1.842
# PD_weighted_mae_0.5: 1.906
# PD_weighted_mae_1: 1.969
# PD_weighted_mae_1.5: 2.032
# PD_censored_fraction: 0.297
# PD_accuracy: 0.158
# PD_overestimation_rate: 0.000
# PD_underestimation_rate: 0.842
# PD_gini_coefficient: 0.365
# PD_overstock: 0.000
# ----------
# Nahmias_bias: -1.842
# Nahmias_weighted_mae_0: 1.842
# Nahmias_weighted_mae_0.5: 1.906
# Nahmias_weighted_mae_1: 1.969
# Nahmias_weighted_mae_1.5: 2.032
# Nahmias_censored_fraction: 0.297
# Nahmias_accuracy: 0.158
# Nahmias_overestimation_rate: 0.000
# Nahmias_underestimation_rate: 0.842
# Nahmias_gini_coefficient: 0.365
# Nahmias_overstock: 0.000
# ----------
# Conrad_bias: -1.842
# Conrad_weighted_mae_0: 1.842
# Conrad_weighted_mae_0.5: 1.906
# Conrad_weighted_mae_1: 1.969
# Conrad_weighted_mae_1.5: 2.032
# Conrad_censored_fraction: 0.297
# Conrad_accuracy: 0.158
# Conrad_overestimation_rate: 0.000
# Conrad_underestimation_rate: 0.842
# Conrad_gini_coefficient: 0.365
# Conrad_overstock: 0.000
# ----------
# Baseline_bias: -1.842
# Baseline_weighted_mae_0: 1.842
# Baseline_weighted_mae_0.5: 1.906
# Baseline_weighted_mae_1: 1.969
# Baseline_weighted_mae_1.5: 2.032
# Baseline_censored_fraction: 0.297
# Baseline_accuracy: 0.158
# Baseline_overestimation_rate: 0.000
# Baseline_underestimation_rate: 0.842
# Baseline_gini_coefficient: 0.365
# Baseline_overstock: 0.000
# ----------
# Bayesian_bias: 1.447
# Bayesian_weighted_mae_0: 1.711
# Bayesian_weighted_mae_0.5: 1.596
# Bayesian_weighted_mae_1: 1.503
# Bayesian_weighted_mae_1.5: 1.429
# Bayesian_censored_fraction: 0.297
# Bayesian_accuracy: 0.105
# Bayesian_overestimation_rate: 0.789
# Bayesian_underestimation_rate: 0.105
# Bayesian_gini_coefficient: 0.346
# Bayesian_overstock: 60.000
# ----------Magazine D KPIs----------
# ----------
# N1_bias: -1.000
# N1_weighted_mae_0: 1.000
# N1_weighted_mae_0.5: 1.000
# N1_weighted_mae_1: 1.000
# N1_weighted_mae_1.5: 1.000
# N1_censored_fraction: 0.242
# N1_accuracy: 0.000
# N1_overestimation_rate: 0.000
# N1_underestimation_rate: 1.000
# N1_gini_coefficient: 0.000
# N1_overstock: 0.000
# ----------
# N2_bias: -1.000
# N2_weighted_mae_0: 1.000
# N2_weighted_mae_0.5: 1.000
# N2_weighted_mae_1: 1.000
# N2_weighted_mae_1.5: 1.000
# N2_censored_fraction: 0.242
# N2_accuracy: 0.000
# N2_overestimation_rate: 0.000
# N2_underestimation_rate: 1.000
# N2_gini_coefficient: 0.000
# N2_overstock: 0.000
# ----------
# N3_bias: -0.500
# N3_weighted_mae_0: 0.500
# N3_weighted_mae_0.5: 0.500
# N3_weighted_mae_1: 0.500
# N3_weighted_mae_1.5: 0.500
# N3_censored_fraction: 0.242
# N3_accuracy: 0.500
# N3_overestimation_rate: 0.000
# N3_underestimation_rate: 0.500
# N3_gini_coefficient: 0.500
# N3_overstock: 0.000
# ----------
# EM_bias: -0.500
# EM_weighted_mae_0: 0.500
# EM_weighted_mae_0.5: 0.500
# EM_weighted_mae_1: 0.500
# EM_weighted_mae_1.5: 0.500
# EM_censored_fraction: 0.242
# EM_accuracy: 0.500
# EM_overestimation_rate: 0.000
# EM_underestimation_rate: 0.500
# EM_gini_coefficient: 0.500
# EM_overstock: 0.000
# ----------
# PD_bias: -0.500
# PD_weighted_mae_0: 0.500
# PD_weighted_mae_0.5: 0.500
# PD_weighted_mae_1: 0.500
# PD_weighted_mae_1.5: 0.500
# PD_censored_fraction: 0.242
# PD_accuracy: 0.500
# PD_overestimation_rate: 0.000
# PD_underestimation_rate: 0.500
# PD_gini_coefficient: 0.500
# PD_overstock: 0.000
# ----------
# Nahmias_bias: -0.500
# Nahmias_weighted_mae_0: 0.500
# Nahmias_weighted_mae_0.5: 0.500
# Nahmias_weighted_mae_1: 0.500
# Nahmias_weighted_mae_1.5: 0.500
# Nahmias_censored_fraction: 0.242
# Nahmias_accuracy: 0.500
# Nahmias_overestimation_rate: 0.000
# Nahmias_underestimation_rate: 0.500
# Nahmias_gini_coefficient: 0.500
# Nahmias_overstock: 0.000
# ----------
# Conrad_bias: -0.500
# Conrad_weighted_mae_0: 0.500
# Conrad_weighted_mae_0.5: 0.500
# Conrad_weighted_mae_1: 0.500
# Conrad_weighted_mae_1.5: 0.500
# Conrad_censored_fraction: 0.242
# Conrad_accuracy: 0.500
# Conrad_overestimation_rate: 0.000
# Conrad_underestimation_rate: 0.500
# Conrad_gini_coefficient: 0.500
# Conrad_overstock: 0.000
# ----------
# Baseline_bias: -0.500
# Baseline_weighted_mae_0: 0.500
# Baseline_weighted_mae_0.5: 0.500
# Baseline_weighted_mae_1: 0.500
# Baseline_weighted_mae_1.5: 0.500
# Baseline_censored_fraction: 0.242
# Baseline_accuracy: 0.500
# Baseline_overestimation_rate: 0.000
# Baseline_underestimation_rate: 0.500
# Baseline_gini_coefficient: 0.500
# Baseline_overstock: 0.000
# ----------
# Bayesian_bias: 0.500
# Bayesian_weighted_mae_0: 0.500
# Bayesian_weighted_mae_0.5: 0.500
# Bayesian_weighted_mae_1: 0.500
# Bayesian_weighted_mae_1.5: 0.500
# Bayesian_censored_fraction: 0.242
# Bayesian_accuracy: 0.500
# Bayesian_overestimation_rate: 0.500
# Bayesian_underestimation_rate: 0.000
# Bayesian_gini_coefficient: 0.500
# Bayesian_overstock: 4.000
# ----------Magazine E KPIs----------
# ----------
# N1_bias: -1.636
# N1_weighted_mae_0: 1.636
# N1_weighted_mae_0.5: 2.274
# N1_weighted_mae_1: 3.000
# N1_weighted_mae_1.5: 3.721
# N1_censored_fraction: 0.333
# N1_accuracy: 0.455
# N1_overestimation_rate: 0.000
# N1_underestimation_rate: 0.545
# N1_gini_coefficient: 0.667
# N1_overstock: 0.000
# ----------
# N2_bias: -1.636
# N2_weighted_mae_0: 1.636
# N2_weighted_mae_0.5: 2.274
# N2_weighted_mae_1: 3.000
# N2_weighted_mae_1.5: 3.721
# N2_censored_fraction: 0.333
# N2_accuracy: 0.455
# N2_overestimation_rate: 0.000
# N2_underestimation_rate: 0.545
# N2_gini_coefficient: 0.667
# N2_overstock: 0.000
# ----------
# N3_bias: -0.636
# N3_weighted_mae_0: 0.636
# N3_weighted_mae_0.5: 0.923
# N3_weighted_mae_1: 1.250
# N3_weighted_mae_1.5: 1.573
# N3_censored_fraction: 0.333
# N3_accuracy: 0.727
# N3_overestimation_rate: 0.000
# N3_underestimation_rate: 0.273
# N3_gini_coefficient: 0.753
# N3_overstock: 0.000
# ----------
# EM_bias: 0.364
# EM_weighted_mae_0: 1.091
# EM_weighted_mae_0.5: 1.140
# EM_weighted_mae_1: 1.200
# EM_weighted_mae_1.5: 1.263
# EM_censored_fraction: 0.333
# EM_accuracy: 0.000
# EM_overestimation_rate: 0.727
# EM_underestimation_rate: 0.273
# EM_gini_coefficient: 0.076
# EM_overstock: 8.000
# ----------
# PD_bias: -0.636
# PD_weighted_mae_0: 0.636
# PD_weighted_mae_0.5: 0.923
# PD_weighted_mae_1: 1.250
# PD_weighted_mae_1.5: 1.573
# PD_censored_fraction: 0.333
# PD_accuracy: 0.727
# PD_overestimation_rate: 0.000
# PD_underestimation_rate: 0.273
# PD_gini_coefficient: 0.753
# PD_overstock: 0.000
# ----------
# Nahmias_bias: -0.818
# Nahmias_weighted_mae_0: 0.818
# Nahmias_weighted_mae_0.5: 1.064
# Nahmias_weighted_mae_1: 1.350
# Nahmias_weighted_mae_1.5: 1.638
# Nahmias_censored_fraction: 0.333
# Nahmias_accuracy: 0.545
# Nahmias_overestimation_rate: 0.000
# Nahmias_underestimation_rate: 0.455
# Nahmias_gini_coefficient: 0.646
# Nahmias_overstock: 0.000
# ----------
# Conrad_bias: -0.818
# Conrad_weighted_mae_0: 0.818
# Conrad_weighted_mae_0.5: 1.064
# Conrad_weighted_mae_1: 1.350
# Conrad_weighted_mae_1.5: 1.638
# Conrad_censored_fraction: 0.333
# Conrad_accuracy: 0.545
# Conrad_overestimation_rate: 0.000
# Conrad_underestimation_rate: 0.455
# Conrad_gini_coefficient: 0.646
# Conrad_overstock: 0.000
# ----------
# Baseline_bias: -0.818
# Baseline_weighted_mae_0: 0.818
# Baseline_weighted_mae_0.5: 1.064
# Baseline_weighted_mae_1: 1.350
# Baseline_weighted_mae_1.5: 1.638
# Baseline_censored_fraction: 0.333
# Baseline_accuracy: 0.545
# Baseline_overestimation_rate: 0.000
# Baseline_underestimation_rate: 0.455
# Baseline_gini_coefficient: 0.646
# Baseline_overstock: 0.000
# ----------
# Bayesian_bias: 1.182
# Bayesian_weighted_mae_0: 1.727
# Bayesian_weighted_mae_0.5: 1.638
# Bayesian_weighted_mae_1: 1.550
# Bayesian_weighted_mae_1.5: 1.478
# Bayesian_censored_fraction: 0.333
# Bayesian_accuracy: 0.091
# Bayesian_overestimation_rate: 0.727
# Bayesian_underestimation_rate: 0.182
# Bayesian_gini_coefficient: 0.134
# Bayesian_overstock: 16.000
# ----------Magazine F KPIs----------
# ----------Magazine G KPIs----------
# ----------
# N1_bias: -1.000
# N1_weighted_mae_0: 1.000
# N1_weighted_mae_0.5: 1.000
# N1_weighted_mae_1: 1.000
# N1_weighted_mae_1.5: 1.000
# N1_censored_fraction: 0.255
# N1_accuracy: 0.000
# N1_overestimation_rate: 0.000
# N1_underestimation_rate: 1.000
# N1_gini_coefficient: 0.000
# N1_overstock: 0.000
# ----------
# N2_bias: -1.000
# N2_weighted_mae_0: 1.000
# N2_weighted_mae_0.5: 1.000
# N2_weighted_mae_1: 1.000
# N2_weighted_mae_1.5: 1.000
# N2_censored_fraction: 0.255
# N2_accuracy: 0.000
# N2_overestimation_rate: 0.000
# N2_underestimation_rate: 1.000
# N2_gini_coefficient: 0.000
# N2_overstock: 0.000
# ----------
# N3_bias: -0.462
# N3_weighted_mae_0: 0.462
# N3_weighted_mae_0.5: 0.462
# N3_weighted_mae_1: 0.462
# N3_weighted_mae_1.5: 0.462
# N3_censored_fraction: 0.255
# N3_accuracy: 0.538
# N3_overestimation_rate: 0.000
# N3_underestimation_rate: 0.462
# N3_gini_coefficient: 0.538
# N3_overstock: 0.000
# ----------
# EM_bias: -0.462
# EM_weighted_mae_0: 0.462
# EM_weighted_mae_0.5: 0.462
# EM_weighted_mae_1: 0.462
# EM_weighted_mae_1.5: 0.462
# EM_censored_fraction: 0.255
# EM_accuracy: 0.538
# EM_overestimation_rate: 0.000
# EM_underestimation_rate: 0.462
# EM_gini_coefficient: 0.538
# EM_overstock: 0.000
# ----------
# PD_bias: -0.462
# PD_weighted_mae_0: 0.462
# PD_weighted_mae_0.5: 0.462
# PD_weighted_mae_1: 0.462
# PD_weighted_mae_1.5: 0.462
# PD_censored_fraction: 0.255
# PD_accuracy: 0.538
# PD_overestimation_rate: 0.000
# PD_underestimation_rate: 0.462
# PD_gini_coefficient: 0.538
# PD_overstock: 0.000
# ----------
# Nahmias_bias: -0.462
# Nahmias_weighted_mae_0: 0.462
# Nahmias_weighted_mae_0.5: 0.462
# Nahmias_weighted_mae_1: 0.462
# Nahmias_weighted_mae_1.5: 0.462
# Nahmias_censored_fraction: 0.255
# Nahmias_accuracy: 0.538
# Nahmias_overestimation_rate: 0.000
# Nahmias_underestimation_rate: 0.462
# Nahmias_gini_coefficient: 0.538
# Nahmias_overstock: 0.000
# ----------
# Conrad_bias: -0.462
# Conrad_weighted_mae_0: 0.462
# Conrad_weighted_mae_0.5: 0.462
# Conrad_weighted_mae_1: 0.462
# Conrad_weighted_mae_1.5: 0.462
# Conrad_censored_fraction: 0.255
# Conrad_accuracy: 0.538
# Conrad_overestimation_rate: 0.000
# Conrad_underestimation_rate: 0.462
# Conrad_gini_coefficient: 0.538
# Conrad_overstock: 0.000
# ----------
# Baseline_bias: -0.462
# Baseline_weighted_mae_0: 0.462
# Baseline_weighted_mae_0.5: 0.462
# Baseline_weighted_mae_1: 0.462
# Baseline_weighted_mae_1.5: 0.462
# Baseline_censored_fraction: 0.255
# Baseline_accuracy: 0.538
# Baseline_overestimation_rate: 0.000
# Baseline_underestimation_rate: 0.462
# Baseline_gini_coefficient: 0.538
# Baseline_overstock: 0.000
# ----------
# Bayesian_bias: 0.308
# Bayesian_weighted_mae_0: 0.308
# Bayesian_weighted_mae_0.5: 0.308
# Bayesian_weighted_mae_1: 0.308
# Bayesian_weighted_mae_1.5: 0.308
# Bayesian_censored_fraction: 0.255
# Bayesian_accuracy: 0.692
# Bayesian_overestimation_rate: 0.308
# Bayesian_underestimation_rate: 0.000
# Bayesian_gini_coefficient: 0.692
# Bayesian_overstock: 4.000
# ----------Magazine H KPIs----------
# ----------
# N1_bias: -0.444
# N1_weighted_mae_0: 0.444
# N1_weighted_mae_0.5: 0.535
# N1_weighted_mae_1: 0.636
# N1_weighted_mae_1.5: 0.746
# N1_censored_fraction: 0.333
# N1_accuracy: 0.667
# N1_overestimation_rate: 0.000
# N1_underestimation_rate: 0.333
# N1_gini_coefficient: 0.722
# N1_overstock: 0.000
# ----------
# N2_bias: -0.444
# N2_weighted_mae_0: 0.444
# N2_weighted_mae_0.5: 0.535
# N2_weighted_mae_1: 0.636
# N2_weighted_mae_1.5: 0.746
# N2_censored_fraction: 0.333
# N2_accuracy: 0.667
# N2_overestimation_rate: 0.000
# N2_underestimation_rate: 0.333
# N2_gini_coefficient: 0.722
# N2_overstock: 0.000
# ----------
# N3_bias: -0.333
# N3_weighted_mae_0: 0.333
# N3_weighted_mae_0.5: 0.392
# N3_weighted_mae_1: 0.455
# N3_weighted_mae_1.5: 0.520
# N3_censored_fraction: 0.333
# N3_accuracy: 0.667
# N3_overestimation_rate: 0.000
# N3_underestimation_rate: 0.333
# N3_gini_coefficient: 0.667
# N3_overstock: 0.000
# ----------
# EM_bias: -0.778
# EM_weighted_mae_0: 0.778
# EM_weighted_mae_0.5: 0.797
# EM_weighted_mae_1: 0.818
# EM_weighted_mae_1.5: 0.840
# EM_censored_fraction: 0.333
# EM_accuracy: 0.222
# EM_overestimation_rate: 0.000
# EM_underestimation_rate: 0.778
# EM_gini_coefficient: 0.222
# EM_overstock: 0.000
# ----------
# PD_bias: -0.778
# PD_weighted_mae_0: 0.778
# PD_weighted_mae_0.5: 0.797
# PD_weighted_mae_1: 0.818
# PD_weighted_mae_1.5: 0.840
# PD_censored_fraction: 0.333
# PD_accuracy: 0.222
# PD_overestimation_rate: 0.000
# PD_underestimation_rate: 0.778
# PD_gini_coefficient: 0.222
# PD_overstock: 0.000
# ----------
# Nahmias_bias: -0.778
# Nahmias_weighted_mae_0: 0.778
# Nahmias_weighted_mae_0.5: 0.797
# Nahmias_weighted_mae_1: 0.818
# Nahmias_weighted_mae_1.5: 0.840
# Nahmias_censored_fraction: 0.333
# Nahmias_accuracy: 0.222
# Nahmias_overestimation_rate: 0.000
# Nahmias_underestimation_rate: 0.778
# Nahmias_gini_coefficient: 0.222
# Nahmias_overstock: 0.000
# ----------
# Conrad_bias: -0.778
# Conrad_weighted_mae_0: 0.778
# Conrad_weighted_mae_0.5: 0.797
# Conrad_weighted_mae_1: 0.818
# Conrad_weighted_mae_1.5: 0.840
# Conrad_censored_fraction: 0.333
# Conrad_accuracy: 0.222
# Conrad_overestimation_rate: 0.000
# Conrad_underestimation_rate: 0.778
# Conrad_gini_coefficient: 0.222
# Conrad_overstock: 0.000
# ----------
# Baseline_bias: -0.778
# Baseline_weighted_mae_0: 0.778
# Baseline_weighted_mae_0.5: 0.797
# Baseline_weighted_mae_1: 0.818
# Baseline_weighted_mae_1.5: 0.840
# Baseline_censored_fraction: 0.333
# Baseline_accuracy: 0.222
# Baseline_overestimation_rate: 0.000
# Baseline_underestimation_rate: 0.778
# Baseline_gini_coefficient: 0.222
# Baseline_overstock: 0.000
# ----------
# Bayesian_bias: 0.778
# Bayesian_weighted_mae_0: 0.778
# Bayesian_weighted_mae_0.5: 0.732
# Bayesian_weighted_mae_1: 0.682
# Bayesian_weighted_mae_1.5: 0.627
# Bayesian_censored_fraction: 0.333
# Bayesian_accuracy: 0.222
# Bayesian_overestimation_rate: 0.778
# Bayesian_underestimation_rate: 0.000
# Bayesian_gini_coefficient: 0.222
# Bayesian_overstock: 7.000
# ----------Magazine I KPIs----------
# ----------
# N1_bias: -0.600
# N1_weighted_mae_0: 1.000
# N1_weighted_mae_0.5: 1.029
# N1_weighted_mae_1: 1.062
# N1_weighted_mae_1.5: 1.100
# N1_censored_fraction: 0.278
# N1_accuracy: 0.100
# N1_overestimation_rate: 0.200
# N1_underestimation_rate: 0.700
# N1_gini_coefficient: 0.160
# N1_overstock: 1.000
# ----------
# N2_bias: -0.600
# N2_weighted_mae_0: 1.000
# N2_weighted_mae_0.5: 1.029
# N2_weighted_mae_1: 1.062
# N2_weighted_mae_1.5: 1.100
# N2_censored_fraction: 0.278
# N2_accuracy: 0.100
# N2_overestimation_rate: 0.200
# N2_underestimation_rate: 0.700
# N2_gini_coefficient: 0.160
# N2_overstock: 1.000
# ----------
# N3_bias: -0.100
# N3_weighted_mae_0: 0.500
# N3_weighted_mae_0.5: 0.461
# N3_weighted_mae_1: 0.425
# N3_weighted_mae_1.5: 0.394
# N3_censored_fraction: 0.278
# N3_accuracy: 0.500
# N3_overestimation_rate: 0.200
# N3_underestimation_rate: 0.300
# N3_gini_coefficient: 0.500
# N3_overstock: 1.000
# ----------
# EM_bias: 0.900
# EM_weighted_mae_0: 0.900
# EM_weighted_mae_0.5: 0.861
# EM_weighted_mae_1: 0.825
# EM_weighted_mae_1.5: 0.794
# EM_censored_fraction: 0.278
# EM_accuracy: 0.300
# EM_overestimation_rate: 0.700
# EM_underestimation_rate: 0.000
# EM_gini_coefficient: 0.386
# EM_overstock: 4.500
# ----------
# PD_bias: -0.100
# PD_weighted_mae_0: 0.500
# PD_weighted_mae_0.5: 0.461
# PD_weighted_mae_1: 0.425
# PD_weighted_mae_1.5: 0.394
# PD_censored_fraction: 0.278
# PD_accuracy: 0.500
# PD_overestimation_rate: 0.200
# PD_underestimation_rate: 0.300
# PD_gini_coefficient: 0.500
# PD_overstock: 1.000
# ----------
# Nahmias_bias: -0.400
# Nahmias_weighted_mae_0: 0.400
# Nahmias_weighted_mae_0.5: 0.398
# Nahmias_weighted_mae_1: 0.394
# Nahmias_weighted_mae_1.5: 0.387
# Nahmias_censored_fraction: 0.278
# Nahmias_accuracy: 0.600
# Nahmias_overestimation_rate: 0.000
# Nahmias_underestimation_rate: 0.400
# Nahmias_gini_coefficient: 0.600
# Nahmias_overstock: 0.000
# ----------
# Conrad_bias: -0.400
# Conrad_weighted_mae_0: 0.400
# Conrad_weighted_mae_0.5: 0.398
# Conrad_weighted_mae_1: 0.394
# Conrad_weighted_mae_1.5: 0.387
# Conrad_censored_fraction: 0.278
# Conrad_accuracy: 0.600
# Conrad_overestimation_rate: 0.000
# Conrad_underestimation_rate: 0.400
# Conrad_gini_coefficient: 0.600
# Conrad_overstock: 0.000
# ----------
# Baseline_bias: -0.400
# Baseline_weighted_mae_0: 0.400
# Baseline_weighted_mae_0.5: 0.398
# Baseline_weighted_mae_1: 0.394
# Baseline_weighted_mae_1.5: 0.387
# Baseline_censored_fraction: 0.278
# Baseline_accuracy: 0.600
# Baseline_overestimation_rate: 0.000
# Baseline_underestimation_rate: 0.400
# Baseline_gini_coefficient: 0.600
# Baseline_overstock: 0.000
# ----------
# Bayesian_bias: 1.000
# Bayesian_weighted_mae_0: 1.000
# Bayesian_weighted_mae_0.5: 0.941
# Bayesian_weighted_mae_1: 0.887
# Bayesian_weighted_mae_1.5: 0.841
# Bayesian_censored_fraction: 0.278
# Bayesian_accuracy: 0.300
# Bayesian_overestimation_rate: 0.700
# Bayesian_underestimation_rate: 0.000
# Bayesian_gini_coefficient: 0.425
# Bayesian_overstock: 5.000
