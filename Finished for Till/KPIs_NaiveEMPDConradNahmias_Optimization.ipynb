# %% [markdown]
# # N3

# %%
def apply_n3_uncensoring(df):
    """
    N3: replace censored values with max(current value, average of non-censored values) within each POS.
    """
    df = df.copy()
    df['Verkauf_Uncensored'] = df['Verkauf'].copy()
    
    # Compute open group means and merge back
    open_means = (
        df[df['Zensiert'] == 0]
        .groupby('EHASTRA_EH_NUMMER')['Verkauf']
        .mean()
        .reset_index()
        .rename(columns={'Verkauf': 'open_mean'})
        .round()
    )
    
    df = df.merge(open_means, on='EHASTRA_EH_NUMMER', how='left')
    
    # CREATE MASK AFTER MERGE - this is the key fix
    mask = (df['Zensiert'] == 1) & df['open_mean'].notna()
    df.loc[mask, 'Verkauf_Uncensored'] = np.maximum(
        df.loc[mask, 'Verkauf'], 
        df.loc[mask, 'open_mean']
    )
    
    return df.drop('open_mean', axis=1)

# %% [markdown]
# # N2

# %%
def apply_n2_uncensoring(df):
    """
    N2: replace censored values with mean of uncensored values within each POS.
    """
    df = df.copy()
    df['Verkauf_Uncensored'] = df['Verkauf'].copy()
    
    # Calculate mean of uncensored observations for each group
    uncensored_means = (
        df[df['Zensiert'] == 0]
        .groupby(['EHASTRA_EH_NUMMER'])['Verkauf']
        .mean()
        .rename('uncensored_mean')
        .reset_index()
        .round()
    )
    
    # Merge back to original DataFrame
    df = df.merge(uncensored_means, on=['EHASTRA_EH_NUMMER'], how='left')
    
    # CREATE MASK AFTER MERGE - this is the key fix
    mask = (df['Zensiert'] == 1) & df['uncensored_mean'].notna()
    df.loc[mask, 'Verkauf_Uncensored'] = df.loc[mask, 'uncensored_mean']
    
    return df.drop('uncensored_mean', axis=1)

# %% [markdown]
# # N1

# %%
def apply_n1_uncensoring(df):
    """
    N1: replace censored values with mean of all values within each POS.
    """
    df = df.copy()
    df['Verkauf_Uncensored'] = df['Verkauf'].copy()

    # Identify closed observations
    is_closed = (df["Zensiert"] == 1)

    # Compute mean Verkauf per group and broadcast using transform
    group_means = df.groupby(['EHASTRA_EH_NUMMER'])['Verkauf_Uncensored'].transform('mean').round()
    
    # Replace closed observations
    df.loc[is_closed, 'Verkauf_Uncensored'] = group_means[is_closed]
    
    return df

# %% [markdown]
# # EM

# %%
def apply_em_uncensoring(df, max_iter=30, tolerance=1e-6):
    """    
    Parameters:
    - max_iter: Maximum number of iterations
    - tolerance: Convergence tolerance
    """
    
    df = df.copy()
    df['Verkauf_Uncensored'] = df['Verkauf'].copy()
    
    stockout_condition = (df['Zensiert'] == 1)
    
    for (pos,), group in df.groupby(['EHASTRA_EH_NUMMER']):
        try:
            group_stockout = stockout_condition.loc[group.index]
            
            if not group_stockout.any():
                continue
            
            sales = group['Verkauf_Uncensored'].values
            is_stockout = group_stockout.values
            
            uncensored = sales[~is_stockout]
            censored = sales[is_stockout]
            
            # Skip if no uncensored data - but keep original values
            if len(uncensored) == 0:
                continue
            
            # Quick lambda initialization
            lambda_est = np.mean(uncensored) if len(uncensored) > 0 else np.mean(sales) * 1.5
            lambda_est = max(lambda_est, 0.1)
            
            # Fast EM loop
            for iteration in range(max_iter):
                lambda_old = lambda_est
                
                # Batch E-step
                surv_prob = 1 - poisson.cdf(censored - 1, lambda_est)
                exact_prob = poisson.pmf(censored, lambda_est)
                surv_prob = np.maximum(surv_prob, 1e-12)
                
                expected = lambda_est + censored * exact_prob / surv_prob
                expected = np.maximum(expected, censored.astype(float))
                
                # M-step
                lambda_est = max(np.mean(np.concatenate([uncensored, expected])), 0.1)
                
                if abs(lambda_est - lambda_old) < tolerance:
                    break
            
            # Final update
            surv_prob = 1 - poisson.cdf(censored - 1, lambda_est)
            exact_prob = poisson.pmf(censored, lambda_est)
            surv_prob = np.maximum(surv_prob, 1e-12)
            
            final_expected = lambda_est + censored * exact_prob / surv_prob
            final_expected = np.maximum(final_expected, censored.astype(float))
            
            # Update original dataframe
            stockout_indices = group.index[is_stockout]
            df.loc[stockout_indices, 'Verkauf_Uncensored'] = final_expected.round()
            
        except Exception as e:
            print(f"EM error for POS {pos}: {e}")
            # Fill with original Verkauf values for this POS when error occurs
            group_stockout_indices = group.index[stockout_condition.loc[group.index]]
            df.loc[group_stockout_indices, 'Verkauf_Uncensored'] = df.loc[group_stockout_indices, 'Verkauf']
            continue
    
    # Replace any NaN values with original Verkauf
    nan_mask = df['Verkauf_Uncensored'].isna()
    df.loc[nan_mask, 'Verkauf_Uncensored'] = df.loc[nan_mask, 'Verkauf']
    
    return df

# %% [markdown]
# # PD

# %%
def apply_pd_uncensoring(df, tau=0.5, max_iter=20, tolerance=1e-4):
    """PD with skip for invalid POS groups and fallback to original Verkauf"""
    df = df.copy()
    df["is_closed"] = (df["Zensiert"] == 1)
    df['Verkauf_Uncensored'] = df['Verkauf'].copy().astype(float)

    def compute_pd_projection1(obs_val, lambda_est, tau):
        """
        Compute the PD projection for a single observation using Poisson distribution.
        This balances area A (original to new estimate) with area B (new estimate to infinity)
        weighted by parameter tau.
        """
        try:
            # Check for NaN inputs
            if pd.isna(obs_val) or pd.isna(lambda_est) or lambda_est <= 0:
                return float(obs_val) if not pd.isna(obs_val) else 0.0
            
            obs_val = int(round(obs_val))
            
            def objective(k_proj):
                k_proj = int(round(k_proj))
                
                if k_proj < obs_val:
                    return float('inf')
                
                # Area A: P(obs_val <= X <= k_proj)
                area_A = poisson.cdf(k_proj, lambda_est) - poisson.cdf(obs_val - 1, lambda_est)
                
                # Area B: P(X > k_proj)
                area_B = 1 - poisson.cdf(k_proj, lambda_est)
                
                if area_B > 1e-10: # Avoid division by zero
                    ratio = area_A / area_B
                    target_ratio = (1 - tau) / tau
                    return abs(ratio - target_ratio)
                else:
                    return abs(area_A - (1 - tau))
            
            # Search for optimal projection
            upper_bound = int(obs_val + max(10, int(3 * np.sqrt(lambda_est))))
            
            best_k = obs_val
            best_objective = float('inf')
            
            # Discrete search
            for k in range(int(obs_val), upper_bound + 1):
                obj_val = objective(k)
                if obj_val < best_objective:
                    best_objective = obj_val
                    best_k = k
            
            return float(best_k)
            
        except Exception:
            # Fallback to original value
            return float(obs_val) if not pd.isna(obs_val) else 0.0
    
    # Process groups
    grouped = df.groupby('EHASTRA_EH_NUMMER')
    
    for pos, group in grouped:
        try:
            open_mask = ~group['is_closed']
            closed_mask = group['is_closed']
            
            open_sales = group.loc[open_mask, 'Verkauf_Uncensored'].values
            closed_sales = group.loc[closed_mask, 'Verkauf_Uncensored'].values
            
            # SKIP POS WITHOUT VALID UNCENSORED DATA
            if len(open_sales) == 0 or np.all(pd.isna(open_sales)):
                # print(f"Skipping POS {pos}: no valid uncensored data")
                continue
            
            # Initialize lambda parameter
            lambda_est = np.mean(open_sales[~pd.isna(open_sales)])
            
            # SKIP IF LAMBDA IS INVALID
            if pd.isna(lambda_est) or lambda_est <= 0:
                print(f"Skipping POS {pos}: invalid lambda {lambda_est}")
                continue
            
            lambda_est = max(lambda_est, 0.1)
            closed_indices = group[closed_mask].index.values
            
            # Iterative process
            for iteration in range(max_iter):
                lambda_old = lambda_est
                
                # Project closed observations
                projected_values = np.array([
                    compute_pd_projection1(obs, lambda_est, tau) 
                    for obs in closed_sales
                ])
                
                # Re-estimate lambda
                all_values = np.concatenate([open_sales, projected_values])
                lambda_est = np.mean(all_values)
                lambda_est = max(lambda_est, 0.1)
                
                # Check convergence
                if abs(lambda_est - lambda_old) < tolerance:
                    break
            
            # Final projection
            final_projections = np.array([
                compute_pd_projection1(obs, lambda_est, tau) 
                for obs in closed_sales
            ])
            
            # Update dataframe
            df.loc[closed_indices, 'Verkauf_Uncensored'] = final_projections.round()
            
        except Exception as e:
            print(f"PD error for POS {pos}: {e}")
            # FALLBACK: Keep original values for this POS
            continue
    
    # FINAL FALLBACK: Any remaining NaN values get original Verkauf
    nan_mask = df['Verkauf_Uncensored'].isna()
    df.loc[nan_mask, 'Verkauf_Uncensored'] = df.loc[nan_mask, 'Verkauf']
    
    return df.drop('is_closed', axis=1)

# %% [markdown]
# # Conrad

# %%
from scipy.stats import poisson
import pandas as pd
import numpy as np

def berechnung(links, rechts, n, N, r, x_summe, value_tol=0.00001, max_iterations=1000):
    """
    Till's Code
    """
    iteration = 0
    
    while iteration < max_iterations:
        mu = (links + rechts) / 2
        wert_0 = (x_summe - mu * n) * (1 - poisson.cdf(N-1, mu)) + mu * (n - r) * (1 - poisson.cdf(N-2, mu))
        
        if iteration < 3:
            print(f"Iter {iteration}: mu={mu:.4f}, wert_0={wert_0:.8f}")
        
        if abs(wert_0) < value_tol:
            print(f"Converged after {iteration} iterations: mu={mu:.4f}, wert_0={wert_0:.8f}")
            return mu
        elif wert_0 < 0:  
            rechts = mu
        elif wert_0 > 0:
            links = mu
            
        iteration += 1
    
    print(f"✗ Max iterations reached: mu={mu:.4f}")
    return mu

def test_conrad_example():
    links = 1
    rechts = 100
    n = 13
    N = 10
    r = 7
    x_summe = 58
    
    print(f"links={links}, rechts={rechts}")
    print(f"n={n}, N={N}, r={r}, x_summe={x_summe}")
    
    result = berechnung(links, rechts, n, N, r, x_summe)
    print(f"Result: μ = {result:.4f}")
    print(f"Expected: μ ≈ 10.18")
    
    return result

def create_order_specific_mu_dict(df):

    order_specific_mu_dict = {}
    
    for (year, week), week_data in df.groupby(['Heftjahr', 'Heftnummer']):
        for bezug_val, group in week_data.groupby('Bezug'):
            n = len(group)
            N = bezug_val
            
            # Count non-stockouts
            stockouts_mask = (group['Zensiert'] == 1)
            r = n - stockouts_mask.sum()  # r = number of NON-stockouts
            
            # x_summe = sum of UNCENSORED observations only
            uncensored_sales = group[~stockouts_mask]['Verkauf']
            x_summe = uncensored_sales.sum()
            
            # Skip problematic cases
            if n < 3:
                continue
            if r == n:  # No stockouts = no censoring information
                continue
            if r == 0:  # All stockouts = no uncensored observations
                continue
            
            try:
                links = 1
                rechts = 100
                mu_est = berechnung(links, rechts, n, N, r, x_summe)
                if mu_est:
                    key = (year, week, bezug_val)
                    order_specific_mu_dict[key] = mu_est
            except Exception as e:
                print(f"Error in week {week}, Bezug {N}: {e}")
                continue

    print(f"Successfully estimated μ for {len(order_specific_mu_dict)} groups")
    return order_specific_mu_dict

def expected_poisson_tail(mu, N, max_k=200):
    """
    Compute E[X | X >= N] for X ~ Poisson(mu)
    """
    k_vals = np.arange(N, max_k)
    pmf = poisson.pmf(k_vals, mu)
    tail_prob = 1 - poisson.cdf(N - 1, mu)
    if tail_prob < 1e-8:
        return N  # fallback: don't uncensor
    return np.sum(k_vals * pmf) / tail_prob

# Internal function 
def apply_conrad_uncensoring_1(df, order_specific_mu_dict):
    """
    Given a DataFrame with Verkauf, Bezug, is_stockout, Heftjahr, Heftnummer,
    replace Verkauf with E[X | X >= Bezug] when censored.
    """
    df = df.copy()
    df['Verkauf_Uncensored'] = df['Verkauf'].copy()

    for idx, row in df.iterrows():
        # Skip if no stockout occurred
        if row['Zensiert'] == 0:
            continue
            
        # Get the order-quantity-specific demand parameter
        key = (row['Heftjahr'], row['Heftnummer'], row['Bezug'])
        mu = order_specific_mu_dict.get(key, None)

        if mu is None:
            # no estimate available for this specific (week, order_quantity) — keep original value
            continue

        # POS sold out — uncensor using the specific distribution for this order quantity
        est_demand = expected_poisson_tail(mu, row['Bezug'])
        df.at[idx, 'Verkauf_Uncensored'] = np.round(est_demand)

    return df

# Wrapper function for script
def apply_conrad_uncensoring(df):
    """
    WRAPPER FUNCTION: This is what gets called by the main processing loop
    """
    # Step 1: Create mu dictionary from the dataset
    order_specific_mu_dict = create_order_specific_mu_dict(df)
    
    # Step 2: Apply uncensoring using the mu dictionary  
    return apply_conrad_uncensoring_1(df, order_specific_mu_dict)

# print("\nRunning on actual data:")
# order_specific_mu_dict = create_order_specific_mu_dict(df)
# df_conrad_uncensored = apply_conrad_uncensoring(df, order_specific_mu_dict)

# %% [markdown]
# # Nahmias

# %%
import numpy as np
import pandas as pd
from scipy.stats import norm

def nahmias_estimation(sales, S):
    """
    Nahmias method for censored normal data
    """
    sales = np.array(sales)
    n = len(sales)
    
    observed = sales[sales < S]
    r = len(observed)
    p = r / n
    
    if r < 2 or r >= n-1 or p <= 0 or p >= 1:
        return None, None
    
    try:
        x_bar = np.mean(observed)
        s2 = np.var(observed, ddof=1)
        z = norm.ppf(p)
        
        sigma_hat2 = s2 / (1 - (z * norm.pdf(z) / p) - (norm.pdf(z)**2 / p**2))
        sigma_hat = np.sqrt(sigma_hat2)
        mu_hat = x_bar + sigma_hat * norm.pdf(z) / p
        
        if not np.isfinite(mu_hat) or not np.isfinite(sigma_hat) or sigma_hat <= 0:
            return None, None
            
        return mu_hat, sigma_hat
        
    except Exception:
        return None, None

def create_order_specific_nahmias_dict(df):
    """
    Create μ and σ estimates for each (week, order_quantity) combination
    """
    order_specific_mu_dict = {}
    order_specific_sigma_dict = {}

    for (year, week), week_data in df.groupby(['Heftjahr', 'Heftnummer']):
        for bezug_val, group in week_data.groupby('Bezug'):
            n = len(group)
            S = bezug_val
            
            if n < 5:
                continue
            
            sales = group['Verkauf'].values
            
            try:
                mu_est, sigma_est = nahmias_estimation(sales, S)
                if mu_est is not None and sigma_est is not None:
                    key = (year, week, bezug_val)
                    order_specific_mu_dict[key] = mu_est
                    order_specific_sigma_dict[key] = sigma_est
            except Exception as e:
                continue

    # print(f"Successfully estimated μ,σ for {len(order_specific_mu_dict)} groups")
    return order_specific_mu_dict, order_specific_sigma_dict

def expected_normal_tail(mu, sigma, S):
    """
    Compute E[X | X >= S] for X ~ Normal(mu, sigma)
    """
    if sigma <= 0:
        return S
    
    z = (S - mu) / sigma
    
    if z > 6:
        return S
    
    tail_prob = 1 - norm.cdf(z)
    
    if tail_prob < 1e-10:
        return S
    
    expected_value = mu + sigma * norm.pdf(z) / tail_prob
    
    return expected_value

def apply_nahmias_uncensoring_1(df, order_specific_mu_dict, order_specific_sigma_dict):
    """
    Uncensor dataset using Nahmias estimates
    """
    df = df.copy()
    df['Verkauf_Uncensored'] = df['Verkauf'].copy()

    for idx, row in df.iterrows():
        if row['Zensiert'] == 0:
            continue
            
        key = (row['Heftjahr'], row['Heftnummer'], row['Bezug'])
        mu = order_specific_mu_dict.get(key, None)
        sigma = order_specific_sigma_dict.get(key, None)

        if mu is None or sigma is None:
            continue

        est_demand = expected_normal_tail(mu, sigma, row['Bezug'])
        df.at[idx, 'Verkauf_Uncensored'] = np.round(est_demand)

    return df

def test_nahmias():
    """Test implementation"""
    mu_true = 100
    sigma_true = 30
    S = 110
    n = 100
    
    np.random.seed(42)
    demand = np.random.normal(mu_true, sigma_true, n)
    sales = np.minimum(demand, S)
    
    print("Testing Nahmias implementation:")
    print(f"True μ: {mu_true}, True σ: {sigma_true}")
    print(f"S (censoring limit): {S}")
    print(f"Sample size: {n}")
    
    mu_hat, sigma_hat = nahmias_estimation(sales, S)
    
    naive_mean = np.mean(sales)
    naive_std = np.std(sales, ddof=1)
    
    print(f"True mean: {mu_true}")
    print(f"Naive mean (sales): {naive_mean:.2f}")
    print(f"Corrected estimator (Nahmias): {mu_hat:.2f}")
    print(f"True Std.Dev.: {sigma_true}")
    print(f"Corrected Std.Dev.: {sigma_hat:.2f}")
    print(f"Naive Std.Dev. (sales): {naive_std:.2f}")
    
    return mu_hat, sigma_hat

def apply_nahmias_uncensoring(df):
    """
    WRAPPER FUNCTION: This is what gets called by the main processing loop
    """
    # Step 1: Create mu dictionary from the dataset
    order_specific_mu_dict, compute_mu_sigma_nahmias = create_order_specific_nahmias_dict(df)
    
    # Step 2: Apply uncensoring using the mu dictionary  
    return apply_nahmias_uncensoring_1(df, order_specific_mu_dict, compute_mu_sigma_nahmias)

# %% [markdown]
# # Baseline

# %%
def apply_baseline_uncensoring(df):
    df_result = df.copy()
    df_result['Verkauf_Uncensored'] = df_result['Verkauf'] 
    return df_result

# %% [markdown]
# # Script for creating csv of all features and optimization KPIs for all mags

# %% [markdown]
# Loops through all magazines and applies uncensoring methods (n1,n2,n3,em,pd,conrad,nahmias), evaluates optimization KPIs

# %%
import pandas as pd
import numpy as np
import os
import glob
from pathlib import Path

def build_empirical(df_counts):
    '''
    Given a value counts dataframe, return a dataframe indexed by demand and containing columns count, pmf value, and cmf value
    '''
    demand_distribution = pd.DataFrame(df_counts)
    demand_distribution.sort_index(inplace=True)
    demand_distribution['pmf'] = demand_distribution['count']/demand_distribution['count'].sum()
    demand_distribution['cmf'] = demand_distribution['pmf'].cumsum()
    return demand_distribution

def update_empirical(empirical, demand):
    '''
    Update empirical demand distribution with new uncensored demand
    '''
    # Safety check: ensure empirical is not empty
    if empirical.empty:
        # Create new empirical from this single observation
        empirical = build_empirical(pd.Series([demand]).value_counts())
        return empirical
    
    if demand in empirical.index: 
        empirical.loc[demand, 'count'] += 1
    else:
        empirical.loc[demand, 'count'] = 1
        empirical.sort_index(inplace=True)
    
    # Recalculate PMF and CMF
    total_count = empirical['count'].sum()
    if total_count > 0:
        empirical['pmf'] = empirical['count'] / total_count
        empirical['cmf'] = empirical['pmf'].cumsum()
        
    return empirical

def calculate_optimal_inventory(empirical, service_level=0.9):
    '''
    Calculate optimal inventory using newsvendor model with safety checks
    '''
    if empirical.empty or len(empirical) == 0:
        return 0  # Default to 0 if no data
    
    candidates = (empirical['cmf'] >= service_level)
    if not candidates.any():
        # If no demand level meets service level, return highest demand
        return empirical.index.max()
    
    return candidates.idxmax()

def calculate_pinball_loss(q_ordered, demand_actual, alpha=0.9):
    '''
    Calculate pinball loss for a single observation
    alpha: service level (e.g., 0.9 for 90% service level)
    '''
    if q_ordered >= demand_actual:
        # Overstock cost
        return (1 - alpha) * (q_ordered - demand_actual)
    else:
        # Understock cost
        return alpha * (demand_actual - q_ordered)

def calculate_inventory_kpis_for_pos(pos_data, method_name, pos_id):
    """
    Calculate inventory KPIs for a single POS
    
    Returns:
    - pinball_loss: Average pinball loss across all periods
    - oos_rate_by_hf: Out-of-stock rate for each Heftnummer
    - alpha_service_level_by_hf: Alpha service level for each Heftnummer  
    - beta_fill_rate_by_hf: Beta fill rate for each Heftnummer
    """
    
    if len(pos_data) == 0:
        return {
            'pinball_loss': 0,
            'avg_oos_rate': 0,
            'avg_alpha_service_level': 0,
            'avg_beta_fill_rate': 0,
        }
    
    # Calculate pinball loss for each period
    pinball_losses = []
    for _, row in pos_data.iterrows():
        q_ordered = row[f'{method_name}_Q']
        demand_actual = row['Verkauf_MBR']
        if pd.notna(q_ordered) and pd.notna(demand_actual):
            loss = calculate_pinball_loss(q_ordered, demand_actual, alpha=0.9)
            pinball_losses.append(loss)
    
    avg_pinball_loss = np.mean(pinball_losses) if pinball_losses else 0
    
    # Calculate KPIs by Heftnummer (HF)
    hf_kpis = []
    
    for hf, hf_data in pos_data.groupby('Heftnummer'):
        if len(hf_data) == 0:
            continue
            
        # Out-of-stock events (demand > ordered quantity)
        oos_events = (hf_data['Verkauf_MBR'] > hf_data[f'{method_name}_Q']).sum()
        total_periods = len(hf_data)
        
        # OOS Rate
        oos_rate = oos_events / total_periods if total_periods > 0 else 0
        
        # Alpha Service Level (1 - OOS Rate)
        alpha_service_level = 1 - oos_rate
        
        # Beta Fill Rate (units satisfied / total demand)
        total_demand = hf_data['Verkauf_MBR'].sum()
        units_satisfied = np.minimum(hf_data[f'{method_name}_Q'], hf_data['Verkauf_MBR']).sum()
        beta_fill_rate = units_satisfied / total_demand if total_demand > 0 else 1
        
        hf_kpis.append({
            'heftnummer': hf,
            'oos_rate': oos_rate,
            'alpha_service_level': alpha_service_level,
            'beta_fill_rate': beta_fill_rate
        })
    
    # Average across all Heftnummers
    if hf_kpis:
        avg_oos_rate = np.mean([kpi['oos_rate'] for kpi in hf_kpis])
        avg_alpha_service_level = np.mean([kpi['alpha_service_level'] for kpi in hf_kpis])
        avg_beta_fill_rate = np.mean([kpi['beta_fill_rate'] for kpi in hf_kpis])
    else:
        avg_oos_rate = 0
        avg_alpha_service_level = 0
        avg_beta_fill_rate = 0
    
    return {
        'pinball_loss': avg_pinball_loss,
        'avg_oos_rate': avg_oos_rate,
        'avg_alpha_service_level': avg_alpha_service_level,
        'avg_beta_fill_rate': avg_beta_fill_rate,
    }

def generate_inventory_recommendations(df, method_name):
    """
    Generate inventory recommendations for all POS using empirical demand distribution
    """
    inventory_recommendations = []
    
    for pos_id, pos_group in df.groupby('EHASTRA_EH_NUMMER'):
        try:
            # Step 1: Initialize empirical demand distribution from 2022-2023 data
            df_train = pos_group[pos_group['Heftjahr'] < 2024]
            if df_train.empty: 
                continue
                
            # Use the uncensored demand column (standardized across all methods)
            if 'Verkauf_Uncensored' not in df_train.columns:
                continue
            
            # Get valid uncensored values for training
            uncensored_values = df_train['Verkauf_Uncensored'].dropna()
            
            if len(uncensored_values) == 0:
                continue
                
            # Check for all-zero demand case
            if (uncensored_values == 0).all():
                # Create minimal distribution with 0 and 1
                empirical = build_empirical(pd.Series([0, 1]).value_counts())
            else:
                value_counts = uncensored_values.value_counts()
                empirical = build_empirical(value_counts)
            
            # Step 2: Use newsvendor model to calculate optimal inventory for 2024
            df_test = pos_group[pos_group['Heftjahr'] == 2024]
            df_test = df_test.sort_values(['Period'])
            
            for _, row in df_test.iterrows():
                # Calculate optimal order quantity
                optimal_q = calculate_optimal_inventory(empirical, service_level=0.9)
                
                inventory_recommendations.append({
                    'EHASTRA_EH_NUMMER': pos_id,
                    'Period': row.Period,
                    'Heftnummer': row.Heftnummer if 'Heftnummer' in row else None,
                    'Verkauf_MBR': row.Verkauf_MBR if 'Verkauf_MBR' in row else None,
                    f'{method_name}_Q': optimal_q
                })
                
                # Update empirical distribution with new observation
                if pd.notna(row['Verkauf_Uncensored']) and row['Verkauf_Uncensored'] >= 0:
                    empirical = update_empirical(empirical, row['Verkauf_Uncensored'])
                    
        except Exception as e:
            # Only print errors, not debug info
            print(f"    Error in POS {pos_id}: {str(e)}")
            continue
    
    return pd.DataFrame(inventory_recommendations)

def parse_filename(filename):
    """
    Parse filename to extract magazine letter and parameters
    """
    parts = filename.split('_')
    if len(parts) >= 4:
        magazine = parts[0]
        date = parts[1]
        zq = parts[2]
        zg = parts[3]
        return magazine, date, zq, zg
    return None, None, None, None

def process_inventory_optimization(data_directory, output_filename='inventory_optimization_results_wide.csv'):
    """
    Process all datasets and generate inventory optimization results in wide format
    where each row is a unique EHASTRA_EH_NUMMER + Magazine combination,
    and columns contain KPIs for each method (e.g., N1_pinball_loss, N2_pinball_loss, etc.)
    """
    
    # Method mapping to function names (you'll need to import these functions)
    method_functions = {
        'N1': apply_n1_uncensoring,
        'N2': apply_n2_uncensoring,
        'N3': apply_n3_uncensoring,
        'EM': apply_em_uncensoring,
        'PD': apply_pd_uncensoring,
        'Nahmias': apply_nahmias_uncensoring,
        'Conrad': apply_conrad_uncensoring,
        'Baseline': apply_baseline_uncensoring
    }
    
    # Find original files with ZQ0.35_ZG0.4 pattern (without method names)
    pattern = os.path.join(data_directory, "*_20250212_ZQ0.35_ZG0.4_testfile.csv")
    csv_files = glob.glob(pattern)
    
    if not csv_files:
        print(f"No original CSV files found matching pattern *_20250212_ZQ0.35_ZG0.4_testfile.csv in {data_directory}")
        return
    
    print(f"Found {len(csv_files)} original CSV files to process")
    
    # Dictionary to store results by POS + Magazine combination
    results_by_pos_magazine = {}
    
    for csv_file in csv_files:
        filename = os.path.basename(csv_file)
        magazine, date, zq, zg = parse_filename(filename)
        
        if not magazine:
            print(f"Could not parse filename: {filename}")
            continue
            
        print(f"Processing {filename}...")
        
        try:
            # Read the original CSV file
            original_df = pd.read_csv(csv_file)
            
            # Filter out POS locations with insufficient data
            pos_counts = original_df.groupby('EHASTRA_EH_NUMMER').size()
            valid_pos_ids = pos_counts[pos_counts >= 3].index
            original_df = original_df[original_df['EHASTRA_EH_NUMMER'].isin(valid_pos_ids)]
            
            if len(original_df) == 0:
                print(f"  No valid POS locations in {filename}")
                continue
            
            # Filter to keep only POS that exist in both training (2022-2023) and test (2024) periods
            pos_in_train = original_df[original_df['Heftjahr'] < 2024]['EHASTRA_EH_NUMMER'].unique()
            pos_in_test = original_df[original_df['Heftjahr'] == 2024]['EHASTRA_EH_NUMMER'].unique()
            valid_pos_both_periods = set(pos_in_train) & set(pos_in_test)
            
            original_df = original_df[original_df['EHASTRA_EH_NUMMER'].isin(valid_pos_both_periods)]
            
            if len(original_df) == 0:
                print(f"  No POS locations exist in both training and test periods")
                continue
            
            print(f"  Found {len(valid_pos_both_periods)} POS locations with both training and test data")
            
            # Process each uncensoring method
            for method_name, method_function in method_functions.items():
                print(f"  Applying {method_name} uncensoring...")
                
                try:
                    # Apply the uncensoring method to get Verkauf_Uncensored column
                    uncensored_df = method_function(original_df.copy())
                    
                    # Handle NaN values in Verkauf_Uncensored by imputing with original Verkauf
                    nan_mask = uncensored_df['Verkauf_Uncensored'].isna()
                    uncensored_df.loc[nan_mask, 'Verkauf_Uncensored'] = uncensored_df.loc[nan_mask, 'Verkauf']
                    
                    # Generate inventory recommendations using uncensored data
                    inventory_df = generate_inventory_recommendations(uncensored_df, method_name)
                    
                    if inventory_df.empty:
                        print(f"    No inventory recommendations generated for {method_name}")
                        continue
                    
                    # Calculate KPIs for each POS
                    for pos_id, pos_data in inventory_df.groupby('EHASTRA_EH_NUMMER'):
                        kpis = calculate_inventory_kpis_for_pos(pos_data, method_name, pos_id)
                        
                        # Create unique key for POS + Magazine
                        pos_mag_key = (pos_id, magazine)
                        
                        # Initialize the result dictionary for this POS+Magazine if it doesn't exist
                        if pos_mag_key not in results_by_pos_magazine:
                            results_by_pos_magazine[pos_mag_key] = {
                                'EHASTRA_EH_NUMMER': pos_id,
                                'magazine': magazine,
                                'date': date,
                                'zq_parameter': zq,
                                'zg_parameter': zg,
                                'filename': filename
                            }
                        
                        # Add method-specific KPIs
                        for kpi_name, kpi_value in kpis.items():
                            #if kpi_name != 'n_periods':
                            column_name = f"{method_name}_{kpi_name}"
                            results_by_pos_magazine[pos_mag_key][column_name] = kpi_value
                        
                except Exception as e:
                    print(f"    Error applying {method_name}: {str(e)}")
                    continue
                
        except Exception as e:
            print(f"Error processing {filename}: {str(e)}")
            continue
    
    if results_by_pos_magazine:
        # Convert dictionary to DataFrame
        final_df = pd.DataFrame.from_dict(results_by_pos_magazine, orient='index')
        
        # Reset index since we used tuples as keys
        final_df.reset_index(drop=True, inplace=True)
        
        # Save to CSV
        output_path = output_filename 
        final_df.to_csv(output_path, index=False)
        
        print(f"\nInventory optimization processing complete!")
        print(f"Results saved as: {output_path}")
        print(f"Total rows: {len(final_df)}")
        print(f"Magazines processed: {final_df['magazine'].nunique()}")
        print(f"POS locations: {final_df['EHASTRA_EH_NUMMER'].nunique()}")
        
        # Print column names to show the wide format structure
        kpi_columns = [col for col in final_df.columns if any(method in col for method in method_functions.keys())]
        print(f"Method-specific KPI columns created: {len(kpi_columns)}")
        print(f"Sample KPI columns: {kpi_columns[:10]}")  # Show first 10 columns
        
        # Print summary statistics for one method as example
        if f'N1_pinball_loss' in final_df.columns:
            print(f"\nSample statistics (N1 method):")
            print(f"Average N1 Pinball Loss: {final_df['N1_pinball_loss'].mean():.4f}")
            print(f"Average N1 OOS Rate: {final_df['N1_avg_oos_rate'].mean():.4f}")
        
        return final_df
    else:
        print("No data was processed successfully.")
        return None

# Usage
if __name__ == "__main__":
    data_directory = "Test1"  # Change this to your actual directory path
    result_df = process_inventory_optimization(
        data_directory, 
        'NaiveEMPDConradNahmias_Optimization_KPIs_FeaturesNOTFINAL.csv'
    )
# Out:
# Found 9 original CSV files to process
# Processing E_20250212_ZQ0.35_ZG0.4_testfile.csv...
#   Found 3152 POS locations with both training and test data
#   Applying N1 uncensoring...
#   Applying N2 uncensoring...
#   Applying N3 uncensoring...
#   Applying EM uncensoring...
#   Applying PD uncensoring...
# Skipping POS EHA0231386: invalid lambda 0.0
# Skipping POS EHA0746295: invalid lambda 0.0
# Skipping POS EHA1036501: invalid lambda 0.0
# Skipping POS EHA1177140: invalid lambda 0.0
# Skipping POS EHA1266585: invalid lambda 0.0
# Skipping POS EHA1490641: invalid lambda 0.0
# Skipping POS EHA1603545: invalid lambda 0.0
# Skipping POS EHA1765650: invalid lambda 0.0
# Skipping POS EHA1928265: invalid lambda 0.0
# Skipping POS EHA1938990: invalid lambda 0.0
# Skipping POS EHA2425406: invalid lambda 0.0
# Skipping POS EHA2876191: invalid lambda 0.0
# Skipping POS EHA3557085: invalid lambda 0.0
# Skipping POS EHA3946814: invalid lambda 0.0
# Skipping POS EHA4243527: invalid lambda 0.0
# Skipping POS EHA4376715: invalid lambda 0.0
# Skipping POS EHA4384768: invalid lambda 0.0
# Skipping POS EHA4955804: invalid lambda 0.0
# Skipping POS EHA5422065: invalid lambda 0.0
# Skipping POS EHA5537834: invalid lambda 0.0
# Skipping POS EHA5913015: invalid lambda 0.0
# Skipping POS EHA6098278: invalid lambda 0.0
# Skipping POS EHA6144960: invalid lambda 0.0
# Skipping POS EHA6281234: invalid lambda 0.0
# Skipping POS EHA6299847: invalid lambda 0.0
# Skipping POS EHA6359877: invalid lambda 0.0
# Skipping POS EHA6649424: invalid lambda 0.0
# Skipping POS EHA6983518: invalid lambda 0.0
# Skipping POS EHA6993632: invalid lambda 0.0
# Skipping POS EHA7187119: invalid lambda 0.0
# Skipping POS EHA7922882: invalid lambda 0.0
# Skipping POS EHA8162068: invalid lambda 0.0
# Skipping POS EHA8366970: invalid lambda 0.0
# Skipping POS EHA8370224: invalid lambda 0.0
# Skipping POS EHA8697056: invalid lambda 0.0
# Skipping POS EHA9231405: invalid lambda 0.0
# Skipping POS EHA9346502: invalid lambda 0.0
# Skipping POS EHA9359449: invalid lambda 0.0
# Skipping POS EHA9403305: invalid lambda 0.0
# Skipping POS EHB0024268: invalid lambda 0.0
# Skipping POS EHB0437517: invalid lambda 0.0
# Skipping POS EHB0497938: invalid lambda 0.0
# Skipping POS EHB0866516: invalid lambda 0.0
# Skipping POS EHB1079636: invalid lambda 0.0
# Skipping POS EHB1133954: invalid lambda 0.0
# Skipping POS EHB1609652: invalid lambda 0.0
# Skipping POS EHB2239047: invalid lambda 0.0
# Skipping POS EHB2304716: invalid lambda 0.0
# Skipping POS EHB3120330: invalid lambda 0.0
# Skipping POS EHB3121604: invalid lambda 0.0
# Skipping POS EHB3260985: invalid lambda 0.0
# Skipping POS EHB3285002: invalid lambda 0.0
# Skipping POS EHB3636182: invalid lambda 0.0
# Skipping POS EHB3681182: invalid lambda 0.0
# Skipping POS EHB3772436: invalid lambda 0.0
# Skipping POS EHB4826761: invalid lambda 0.0
# Skipping POS EHB4924712: invalid lambda 0.0
# Skipping POS EHB5452832: invalid lambda 0.0
# Skipping POS EHB5586178: invalid lambda 0.0
# Skipping POS EHB5605922: invalid lambda 0.0
# Skipping POS EHB5899887: invalid lambda 0.0
# Skipping POS EHB6179666: invalid lambda 0.0
# Skipping POS EHB6815128: invalid lambda 0.0
# Skipping POS EHB6974864: invalid lambda 0.0
# Skipping POS EHB7189874: invalid lambda 0.0
# Skipping POS EHB7675485: invalid lambda 0.0
# Skipping POS EHB8375126: invalid lambda 0.0
# Skipping POS EHB8843299: invalid lambda 0.0
# Skipping POS EHB9210975: invalid lambda 0.0
# Skipping POS EHB9383479: invalid lambda 0.0
# Skipping POS EHB9398239: invalid lambda 0.0
# Skipping POS EHB9816379: invalid lambda 0.0
# Skipping POS EHB9877065: invalid lambda 0.0
# Skipping POS EHC0100500: invalid lambda 0.0
# Skipping POS EHC0162837: invalid lambda 0.0
# Skipping POS EHC0430857: invalid lambda 0.0
# Skipping POS EHC0555392: invalid lambda 0.0
# Skipping POS EHC0683115: invalid lambda 0.0
# Skipping POS EHC0935310: invalid lambda 0.0
# Skipping POS EHC1604010: invalid lambda 0.0
# Skipping POS EHC2065558: invalid lambda 0.0
# Skipping POS EHC2399430: invalid lambda 0.0
# Skipping POS EHC2402996: invalid lambda 0.0
# Skipping POS EHC2422436: invalid lambda 0.0
# Skipping POS EHC2480055: invalid lambda 0.0
# Skipping POS EHC2730872: invalid lambda 0.0
# Skipping POS EHC2779125: invalid lambda 0.0
# Skipping POS EHC2802705: invalid lambda 0.0
# Skipping POS EHC2810654: invalid lambda 0.0
# Skipping POS EHC2925182: invalid lambda 0.0
# Skipping POS EHC3470728: invalid lambda 0.0
# Skipping POS EHC3800128: invalid lambda 0.0
# Skipping POS EHC4058580: invalid lambda 0.0
# Skipping POS EHC4477515: invalid lambda 0.0
# Skipping POS EHC4931431: invalid lambda 0.0
# Skipping POS EHC5411100: invalid lambda 0.0
# Skipping POS EHC5544079: invalid lambda 0.0
# Skipping POS EHC6112725: invalid lambda 0.0
# Skipping POS EHC6365162: invalid lambda 0.0
# Skipping POS EHC6375014: invalid lambda 0.0
# Skipping POS EHC6991922: invalid lambda 0.0
# Skipping POS EHC7011182: invalid lambda 0.0
# Skipping POS EHC7850612: invalid lambda 0.0
# Skipping POS EHC9000207: invalid lambda 0.0
# Skipping POS EHC9219782: invalid lambda 0.0
# Skipping POS EHC9310890: invalid lambda 0.0
# Skipping POS EHD0202471: invalid lambda 0.0
# Skipping POS EHD0213045: invalid lambda 0.0
# Skipping POS EHD0310620: invalid lambda 0.0
# Skipping POS EHD0521636: invalid lambda 0.0
# Skipping POS EHD0840357: invalid lambda 0.0
# Skipping POS EHD1286546: invalid lambda 0.0
# Skipping POS EHD2742254: invalid lambda 0.0
# Skipping POS EHD2955630: invalid lambda 0.0
# Skipping POS EHD3173700: invalid lambda 0.0
# Skipping POS EHD3313082: invalid lambda 0.0
# Skipping POS EHD3443486: invalid lambda 0.0
# Skipping POS EHD3813147: invalid lambda 0.0
# Skipping POS EHD4034280: invalid lambda 0.0
# Skipping POS EHD4925277: invalid lambda 0.0
# Skipping POS EHD5090551: invalid lambda 0.0
# Skipping POS EHD5291822: invalid lambda 0.0
# Skipping POS EHD5787632: invalid lambda 0.0
# Skipping POS EHD5837126: invalid lambda 0.0
# Skipping POS EHD5957774: invalid lambda 0.0
# Skipping POS EHD6196167: invalid lambda 0.0
# Skipping POS EHD6206697: invalid lambda 0.0
# Skipping POS EHD6240255: invalid lambda 0.0
# Skipping POS EHD6700201: invalid lambda 0.0
# Skipping POS EHD6786117: invalid lambda 0.0
# Skipping POS EHD7069274: invalid lambda 0.0
# Skipping POS EHD7156951: invalid lambda 0.0
# Skipping POS EHD7479297: invalid lambda 0.0
# Skipping POS EHD7941956: invalid lambda 0.0
# Skipping POS EHD8231908: invalid lambda 0.0
# Skipping POS EHD8454841: invalid lambda 0.0
# Skipping POS EHD9028076: invalid lambda 0.0
# Skipping POS EHD9039525: invalid lambda 0.0
# Skipping POS EHD9125774: invalid lambda 0.0
# Skipping POS EHD9425432: invalid lambda 0.0
# Skipping POS EHD9606177: invalid lambda 0.0
# Skipping POS EHD9876180: invalid lambda 0.0
# Skipping POS EHE0096656: invalid lambda 0.0
# Skipping POS EHE0992578: invalid lambda 0.0
# Skipping POS EHE1378532: invalid lambda 0.0
# Skipping POS EHE1413446: invalid lambda 0.0
# Skipping POS EHE1485331: invalid lambda 0.0
# Skipping POS EHE1500434: invalid lambda 0.0
# Skipping POS EHE2783114: invalid lambda 0.0
# Skipping POS EHE2868507: invalid lambda 0.0
# Skipping POS EHE3122248: invalid lambda 0.0
# Skipping POS EHE3223339: invalid lambda 0.0
# Skipping POS EHE3257881: invalid lambda 0.0
# Skipping POS EHE3515402: invalid lambda 0.0
# Skipping POS EHE4290302: invalid lambda 0.0
# Skipping POS EHE4526611: invalid lambda 0.0
# Skipping POS EHE5004079: invalid lambda 0.0
# Skipping POS EHE5390611: invalid lambda 0.0
# Skipping POS EHE5664841: invalid lambda 0.0
# Skipping POS EHE5836080: invalid lambda 0.0
# Skipping POS EHE5922854: invalid lambda 0.0
# Skipping POS EHE6118590: invalid lambda 0.0
# Skipping POS EHE6481976: invalid lambda 0.0
# Skipping POS EHE7681634: invalid lambda 0.0
# Skipping POS EHE7700610: invalid lambda 0.0
# Skipping POS EHE8234102: invalid lambda 0.0
# Skipping POS EHE8461588: invalid lambda 0.0
# Skipping POS EHE8589990: invalid lambda 0.0
# Skipping POS EHE9226706: invalid lambda 0.0
# Skipping POS EHE9515085: invalid lambda 0.0
# Skipping POS EHE9533329: invalid lambda 0.0
# Skipping POS EHF0605997: invalid lambda 0.0
# Skipping POS EHF1860524: invalid lambda 0.0
# Skipping POS EHF2590826: invalid lambda 0.0
# Skipping POS EHF2836262: invalid lambda 0.0
# Skipping POS EHF2957984: invalid lambda 0.0
# Skipping POS EHF3289946: invalid lambda 0.0
# Skipping POS EHF3819596: invalid lambda 0.0
# Skipping POS EHF4228857: invalid lambda 0.0
# Skipping POS EHF4446781: invalid lambda 0.0
# Skipping POS EHF4854705: invalid lambda 0.0
# Skipping POS EHF5255642: invalid lambda 0.0
# Skipping POS EHF6004442: invalid lambda 0.0
# Skipping POS EHF6702392: invalid lambda 0.0
# Skipping POS EHF7300228: invalid lambda 0.0
# Skipping POS EHF7534159: invalid lambda 0.0
# Skipping POS EHF7609136: invalid lambda 0.0
# Skipping POS EHF7626900: invalid lambda 0.0
# Skipping POS EHF7992494: invalid lambda 0.0
# Skipping POS EHF8125801: invalid lambda 0.0
# Skipping POS EHF8455399: invalid lambda 0.0
# Skipping POS EHF8524827: invalid lambda 0.0
# Skipping POS EHF8803519: invalid lambda 0.0
# Skipping POS EHF9054958: invalid lambda 0.0
# Skipping POS EHF9418785: invalid lambda 0.0
# Skipping POS EHF9993838: invalid lambda 0.0
# Skipping POS EHG0669679: invalid lambda 0.0
# Skipping POS EHG0680337: invalid lambda 0.0
# Skipping POS EHG0868904: invalid lambda 0.0
# Skipping POS EHG0925964: invalid lambda 0.0
# Skipping POS EHG2903908: invalid lambda 0.0
# Skipping POS EHG2914514: invalid lambda 0.0
# Skipping POS EHG3054152: invalid lambda 0.0
# Skipping POS EHG3125426: invalid lambda 0.0
# Skipping POS EHG3173055: invalid lambda 0.0
# Skipping POS EHG3358231: invalid lambda 0.0
# Skipping POS EHG3498289: invalid lambda 0.0
# Skipping POS EHG3537889: invalid lambda 0.0
# Skipping POS EHG3540374: invalid lambda 0.0
# Skipping POS EHG3574501: invalid lambda 0.0
# Skipping POS EHG3646429: invalid lambda 0.0
# Skipping POS EHG3809419: invalid lambda 0.0
# Skipping POS EHG4448761: invalid lambda 0.0
# Skipping POS EHG4971720: invalid lambda 0.0
# Skipping POS EHG5761560: invalid lambda 0.0
# Skipping POS EHG6808965: invalid lambda 0.0
# Skipping POS EHG7012095: invalid lambda 0.0
# Skipping POS EHG7092992: invalid lambda 0.0
# Skipping POS EHG7297099: invalid lambda 0.0
# Skipping POS EHG7725447: invalid lambda 0.0
# Skipping POS EHG7991539: invalid lambda 0.0
# Skipping POS EHG8395112: invalid lambda 0.0
# Skipping POS EHG8644274: invalid lambda 0.0
# Skipping POS EHG8932724: invalid lambda 0.0
# Skipping POS EHG9173907: invalid lambda 0.0
# Skipping POS EHG9542882: invalid lambda 0.0
# Skipping POS EHG9834631: invalid lambda 0.0
# Skipping POS EHG9991650: invalid lambda 0.0
# Skipping POS EHH0239029: invalid lambda 0.0
# Skipping POS EHH0667879: invalid lambda 0.0
# Skipping POS EHH0950216: invalid lambda 0.0
# Skipping POS EHH1163114: invalid lambda 0.0
# Skipping POS EHH1346852: invalid lambda 0.0
# Skipping POS EHH1987874: invalid lambda 0.0
# Skipping POS EHH2611647: invalid lambda 0.0
# Skipping POS EHH2640807: invalid lambda 0.0
# Skipping POS EHH3239276: invalid lambda 0.0
# Skipping POS EHH3354057: invalid lambda 0.0
# Skipping POS EHH3408649: invalid lambda 0.0
# Skipping POS EHH3706022: invalid lambda 0.0
# Skipping POS EHH3836204: invalid lambda 0.0
# Skipping POS EHH4246472: invalid lambda 0.0
# Skipping POS EHH4377596: invalid lambda 0.0
# Skipping POS EHH4674056: invalid lambda 0.0
# Skipping POS EHH4685569: invalid lambda 0.0
# Skipping POS EHH4896688: invalid lambda 0.0
# Skipping POS EHH5096689: invalid lambda 0.0
# Skipping POS EHH5137646: invalid lambda 0.0
# Skipping POS EHH5625806: invalid lambda 0.0
# Skipping POS EHH5706297: invalid lambda 0.0
# Skipping POS EHH5914526: invalid lambda 0.0
# Skipping POS EHH6055410: invalid lambda 0.0
# Skipping POS EHH6555298: invalid lambda 0.0
# Skipping POS EHH7548974: invalid lambda 0.0
# Skipping POS EHH7977031: invalid lambda 0.0
# Skipping POS EHH7989361: invalid lambda 0.0
# Skipping POS EHH8278639: invalid lambda 0.0
# Skipping POS EHH8472180: invalid lambda 0.0
# Skipping POS EHH8621071: invalid lambda 0.0
# Skipping POS EHH8801968: invalid lambda 0.0
# Skipping POS EHH8903758: invalid lambda 0.0
# Skipping POS EHH8921187: invalid lambda 0.0
# Skipping POS EHH9068299: invalid lambda 0.0
# Skipping POS EHH9107552: invalid lambda 0.0
# Skipping POS EHH9194641: invalid lambda 0.0
# Skipping POS EHH9464641: invalid lambda 0.0
# Skipping POS EHH9588525: invalid lambda 0.0
# Skipping POS EHI0086942: invalid lambda 0.0
# Skipping POS EHI0233385: invalid lambda 0.0
# Skipping POS EHI1245602: invalid lambda 0.0
# Skipping POS EHI1691054: invalid lambda 0.0
# Skipping POS EHI2203081: invalid lambda 0.0
# Skipping POS EHI2473832: invalid lambda 0.0
# Skipping POS EHI2567522: invalid lambda 0.0
# Skipping POS EHI2649139: invalid lambda 0.0
# Skipping POS EHI3077791: invalid lambda 0.0
# Skipping POS EHI3167925: invalid lambda 0.0
# Skipping POS EHI3219870: invalid lambda 0.0
# Skipping POS EHI3405990: invalid lambda 0.0
# Skipping POS EHI3651808: invalid lambda 0.0
# Skipping POS EHI3675118: invalid lambda 0.0
# Skipping POS EHI4127929: invalid lambda 0.0
# Skipping POS EHI4454324: invalid lambda 0.0
# Skipping POS EHI4638481: invalid lambda 0.0
# Skipping POS EHI4657620: invalid lambda 0.0
# Skipping POS EHI4684412: invalid lambda 0.0
# Skipping POS EHI5694739: invalid lambda 0.0
# Skipping POS EHI6120477: invalid lambda 0.0
# Skipping POS EHI6573596: invalid lambda 0.0
# Skipping POS EHI7097731: invalid lambda 0.0
# Skipping POS EHI7168496: invalid lambda 0.0
# Skipping POS EHI7595307: invalid lambda 0.0
# Skipping POS EHI7699245: invalid lambda 0.0
# Skipping POS EHI7737057: invalid lambda 0.0
# Skipping POS EHI7845829: invalid lambda 0.0
# Skipping POS EHI8013422: invalid lambda 0.0
# Skipping POS EHI8098382: invalid lambda 0.0
# Skipping POS EHI8284617: invalid lambda 0.0
# Skipping POS EHI8822474: invalid lambda 0.0
# Skipping POS EHI9287925: invalid lambda 0.0
# Skipping POS EHI9646317: invalid lambda 0.0
# Skipping POS EHJ0356582: invalid lambda 0.0
# Skipping POS EHJ0433886: invalid lambda 0.0
# Skipping POS EHJ0536911: invalid lambda 0.0
# Skipping POS EHJ0760797: invalid lambda 0.0
# Skipping POS EHJ1550564: invalid lambda 0.0
# Skipping POS EHJ2247628: invalid lambda 0.0
# Skipping POS EHJ2252059: invalid lambda 0.0
# Skipping POS EHJ2777145: invalid lambda 0.0
# Skipping POS EHJ3059594: invalid lambda 0.0
# Skipping POS EHJ3388406: invalid lambda 0.0
# Skipping POS EHJ3398582: invalid lambda 0.0
# Skipping POS EHJ3531146: invalid lambda 0.0
# Skipping POS EHJ3888148: invalid lambda 0.0
# Skipping POS EHJ3944190: invalid lambda 0.0
# Skipping POS EHJ3974787: invalid lambda 0.0
# Skipping POS EHJ4132532: invalid lambda 0.0
# Skipping POS EHJ4154486: invalid lambda 0.0
# Skipping POS EHJ4338806: invalid lambda 0.0
# Skipping POS EHJ4510380: invalid lambda 0.0
# Skipping POS EHJ4728075: invalid lambda 0.0
# Skipping POS EHJ5381989: invalid lambda 0.0
# Skipping POS EHJ5395257: invalid lambda 0.0
# Skipping POS EHJ5676600: invalid lambda 0.0
# Skipping POS EHJ5916478: invalid lambda 0.0
# Skipping POS EHJ6003812: invalid lambda 0.0
# Skipping POS EHJ6161700: invalid lambda 0.0
# Skipping POS EHJ6222807: invalid lambda 0.0
# Skipping POS EHJ6477829: invalid lambda 0.0
# Skipping POS EHJ6972829: invalid lambda 0.0
# Skipping POS EHJ7046366: invalid lambda 0.0
# Skipping POS EHJ7316757: invalid lambda 0.0
# Skipping POS EHJ7477438: invalid lambda 0.0
# Skipping POS EHJ7592908: invalid lambda 0.0
# Skipping POS EHJ7709936: invalid lambda 0.0
# Skipping POS EHJ7776944: invalid lambda 0.0
# Skipping POS EHJ8006595: invalid lambda 0.0
# Skipping POS EHJ8052268: invalid lambda 0.0
# Skipping POS EHJ8125215: invalid lambda 0.0
# Skipping POS EHJ8726756: invalid lambda 0.0
# Skipping POS EHJ8735430: invalid lambda 0.0
# Skipping POS EHJ8836022: invalid lambda 0.0
# Skipping POS EHJ8930007: invalid lambda 0.0
# Skipping POS EHJ9091020: invalid lambda 0.0
# Skipping POS EHJ9301437: invalid lambda 0.0
# Skipping POS EHJ9542535: invalid lambda 0.0
# Skipping POS EHJ9550318: invalid lambda 0.0
# Skipping POS EHJ9606686: invalid lambda 0.0
#   Applying Nahmias uncensoring...
#   Applying Conrad uncensoring...
# Iter 0: mu=50.5000, wert_0=-202.00000000
# Iter 1: mu=25.7500, wert_0=-102.99999999
# Iter 2: mu=13.3750, wert_0=-53.49856631
# Converged after 23 iterations: mu=2.8478, wert_0=-0.00000919
# Iter 0: mu=50.5000, wert_0=-29110.00000000
# Iter 1: mu=25.7500, wert_0=-14754.99999682
# Iter 2: mu=13.3750, wert_0=-7577.29326517
# ✗ Max iterations reached: mu=1.0000
# Iter 0: mu=50.5000, wert_0=-20310.50000000
# Iter 1: mu=25.7500, wert_0=-10187.74997169
# Iter 2: mu=13.3750, wert_0=-5125.40323022
# Converged after 27 iterations: mu=1.2471, wert_0=0.00000301
# Iter 0: mu=50.5000, wert_0=-9196.50000000
# Iter 1: mu=25.7500, wert_0=-4568.24988235
# Iter 2: mu=13.3750, wert_0=-2251.99215127
# Converged after 26 iterations: mu=1.9386, wert_0=0.00000730
# Iter 0: mu=50.5000, wert_0=-4823.50000000
# Iter 1: mu=25.7500, wert_0=-2373.24957208
# Iter 2: mu=13.3750, wert_0=-1144.01910264
# Converged after 23 iterations: mu=2.6718, wert_0=-0.00000350
# Iter 0: mu=50.5000, wert_0=-5791.00000000
# Iter 1: mu=25.7500, wert_0=-2870.49745160
# Iter 2: mu=13.3750, wert_0=-1396.70864691
# Converged after 22 iterations: mu=2.2373, wert_0=-0.00000882
# Iter 0: mu=50.5000, wert_0=-3866.00000000
# Iter 1: mu=25.7500, wert_0=-1885.99273627
# Iter 2: mu=13.3750, wert_0=-875.42951766
# Converged after 21 iterations: mu=2.8674, wert_0=-0.00000321
# Iter 0: mu=50.5000, wert_0=-4280.00000000
# Iter 1: mu=25.7500, wert_0=-2052.47117261
# Iter 2: mu=13.3750, wert_0=-894.90969370
# Converged after 21 iterations: mu=3.3463, wert_0=-0.00000141
# Iter 0: mu=50.5000, wert_0=-1895.50000000
# Iter 1: mu=25.7500, wert_0=-880.70339797
# Iter 2: mu=13.3750, wert_0=-337.33432770
# Converged after 21 iterations: mu=5.2749, wert_0=0.00000754
# Iter 0: mu=50.5000, wert_0=-1867.50000000
# Iter 1: mu=25.7500, wert_0=-852.62593721
# Iter 2: mu=13.3750, wert_0=-293.04075707
# Converged after 23 iterations: mu=5.4709, wert_0=-0.00000256
# Iter 0: mu=50.5000, wert_0=-1288.99999999
# Iter 1: mu=25.7500, wert_0=-595.75184346
# Iter 2: mu=13.3750, wert_0=-189.14640247
# Converged after 18 iterations: mu=5.5645, wert_0=0.00000509
# Iter 0: mu=50.5000, wert_0=-1302.49999997
# Iter 1: mu=25.7500, wert_0=-584.17673436
# Iter 2: mu=13.3750, wert_0=-150.61766132
# Converged after 20 iterations: mu=6.2603, wert_0=-0.00000055
# Iter 0: mu=50.5000, wert_0=-1046.99999989
# Iter 1: mu=25.7500, wert_0=-451.91127079
# Iter 2: mu=13.3750, wert_0=-82.97668626
# Converged after 21 iterations: mu=8.1138, wert_0=0.00000203
# Iter 0: mu=50.5000, wert_0=-216.49977501
# Iter 1: mu=25.7500, wert_0=-77.74921546
# Iter 2: mu=13.3750, wert_0=-0.71147349
# Converged after 12 iterations: mu=9.6166, wert_0=0.00000479
# Iter 0: mu=50.5000, wert_0=-115.49825714
# Iter 1: mu=25.7500, wert_0=-25.45471889
# Iter 2: mu=13.3750, wert_0=0.04163830
# Converged after 16 iterations: mu=15.3214, wert_0=-0.00000539
# Iter 0: mu=50.5000, wert_0=-101.00000000
# Iter 1: mu=25.7500, wert_0=-51.49999998
# Iter 2: mu=13.3750, wert_0=-26.74794297
# Converged after 21 iterations: mu=3.9020, wert_0=0.00000479
# Iter 0: mu=50.5000, wert_0=-13546.50000000
# Iter 1: mu=25.7500, wert_0=-6839.24999797
# Iter 2: mu=13.3750, wert_0=-3485.49435828
# Converged after 26 iterations: mu=1.3578, wert_0=-0.00000485
# Iter 0: mu=50.5000, wert_0=-20402.00000000
# Iter 1: mu=25.7500, wert_0=-10254.49997142
# Iter 2: mu=13.3750, wert_0=-5179.76574336
# Converged after 27 iterations: mu=1.1648, wert_0=0.00000251
# Iter 0: mu=50.5000, wert_0=-11823.00000000
# Iter 1: mu=25.7500, wert_0=-5882.99985760
# Iter 2: mu=13.3750, wert_0=-2910.40242641
# Converged after 25 iterations: mu=1.6829, wert_0=0.00000826
# Iter 0: mu=50.5000, wert_0=-4854.00000000
# Iter 1: mu=25.7500, wert_0=-2378.99957745
# Iter 2: mu=13.3750, wert_0=-1137.46841011
# Converged after 24 iterations: mu=2.7677, wert_0=0.00000309
# Iter 0: mu=50.5000, wert_0=-4331.00000000
# Iter 1: mu=25.7500, wert_0=-2103.49816209
# Iter 2: mu=13.3750, wert_0=-980.33096389
# Converged after 17 iterations: mu=2.9808, wert_0=0.00000351
# Iter 0: mu=50.5000, wert_0=-3669.50000000
# Iter 1: mu=25.7500, wert_0=-1763.74288032
# Iter 2: mu=13.3750, wert_0=-791.40963974
# Converged after 24 iterations: mu=3.6758, wert_0=-0.00000344
# Iter 0: mu=50.5000, wert_0=-2697.50000000
# Iter 1: mu=25.7500, wert_0=-1286.73076732
# Iter 2: mu=13.3750, wert_0=-552.75182087
# Converged after 22 iterations: mu=3.9205, wert_0=0.00000134
# Iter 0: mu=50.5000, wert_0=-2081.50000000
# Iter 1: mu=25.7500, wert_0=-967.70275390
# Iter 2: mu=13.3750, wert_0=-373.80265672
# Converged after 23 iterations: mu=4.7945, wert_0=-0.00000578
# Iter 0: mu=50.5000, wert_0=-1321.50000000
# Iter 1: mu=25.7500, wert_0=-603.65482288
# Iter 2: mu=13.3750, wert_0=-205.28788633
# Converged after 23 iterations: mu=5.9561, wert_0=0.00000601
# Iter 0: mu=50.5000, wert_0=-1757.49999999
# Iter 1: mu=25.7500, wert_0=-791.94188624
# Iter 2: mu=13.3750, wert_0=-238.08925910
# Converged after 22 iterations: mu=5.8899, wert_0=0.00000379
# Iter 0: mu=50.5000, wert_0=-1152.99999998
# Iter 1: mu=25.7500, wert_0=-509.00908103
# Iter 2: mu=13.3750, wert_0=-125.82483392
# Converged after 21 iterations: mu=6.6321, wert_0=0.00000807
# Iter 0: mu=50.5000, wert_0=-1391.49999987
# Iter 1: mu=25.7500, wert_0=-622.92622024
# Iter 2: mu=13.3750, wert_0=-137.53149729
# Converged after 19 iterations: mu=5.8635, wert_0=0.00000985
# Iter 0: mu=50.5000, wert_0=-761.49999971
# Iter 1: mu=25.7500, wert_0=-339.13948560
# Iter 2: mu=13.3750, wert_0=-58.10447907
# Converged after 18 iterations: mu=6.6522, wert_0=0.00000227
# Iter 0: mu=50.5000, wert_0=-18835.00000000
# Iter 1: mu=25.7500, wert_0=-9528.99999764
# Iter 2: mu=13.3750, wert_0=-4875.84692414
# ✗ Max iterations reached: mu=1.0000
# Iter 0: mu=50.5000, wert_0=-22350.50000000
# Iter 1: mu=25.7500, wert_0=-11237.74996972
# Iter 2: mu=13.3750, wert_0=-5680.33044362
# Converged after 25 iterations: mu=1.0668, wert_0=0.00000343
# Iter 0: mu=50.5000, wert_0=-11619.50000000
# Iter 1: mu=25.7500, wert_0=-5803.24986360
# Iter 2: mu=13.3750, wert_0=-2892.61595528
# Converged after 24 iterations: mu=1.4280, wert_0=0.00000299
# Iter 0: mu=50.5000, wert_0=-4134.50000000
# Iter 1: mu=25.7500, wert_0=-2030.74962353
# Iter 2: mu=13.3750, wert_0=-975.27954973
# Converged after 26 iterations: mu=2.8289, wert_0=-0.00000172
# Iter 0: mu=50.5000, wert_0=-3394.00000000
# Iter 1: mu=25.7500, wert_0=-1661.49849805
# Iter 2: mu=13.3750, wert_0=-787.46347578
# Converged after 24 iterations: mu=2.8155, wert_0=-0.00000425
# Iter 0: mu=50.5000, wert_0=-4422.50000000
# Iter 1: mu=25.7500, wert_0=-2170.24203879
# Iter 2: mu=13.3750, wert_0=-1021.14242915
# Converged after 20 iterations: mu=2.3433, wert_0=-0.00000722
# Iter 0: mu=50.5000, wert_0=-3209.00000000
# Iter 1: mu=25.7500, wert_0=-1525.97861873
# Iter 2: mu=13.3750, wert_0=-652.56622308
# Converged after 23 iterations: mu=3.6701, wert_0=-0.00000373
# Iter 0: mu=50.5000, wert_0=-2423.00000000
# Iter 1: mu=25.7500, wert_0=-1135.94443398
# Iter 2: mu=13.3750, wert_0=-448.05928104
# Converged after 22 iterations: mu=4.5013, wert_0=0.00000060
# Iter 0: mu=50.5000, wert_0=-2041.00000000
# Iter 1: mu=25.7500, wert_0=-951.85562545
# Iter 2: mu=13.3750, wert_0=-343.96342694
# Converged after 21 iterations: mu=5.0178, wert_0=-0.00000278
# Iter 0: mu=50.5000, wert_0=-1053.99999998
# Iter 1: mu=25.7500, wert_0=-459.55406200
# Iter 2: mu=13.3750, wert_0=-108.90178743
# Converged after 18 iterations: mu=7.0725, wert_0=0.00000506
# Iter 0: mu=50.5000, wert_0=-1120.49999990
# Iter 1: mu=25.7500, wert_0=-500.68011165
# Iter 2: mu=13.3750, wert_0=-109.66868377
# Converged after 18 iterations: mu=5.9867, wert_0=-0.00000978
# Iter 0: mu=50.5000, wert_0=-1022.49999963
# Iter 1: mu=25.7500, wert_0=-451.20632909
# Iter 2: mu=13.3750, wert_0=-77.47233779
# Converged after 17 iterations: mu=6.4024, wert_0=0.00000198
# Iter 0: mu=50.5000, wert_0=-442.99999933
# Iter 1: mu=25.7500, wert_0=-193.59677177
# Iter 2: mu=13.3750, wert_0=-23.29599797
# Converged after 19 iterations: mu=7.8020, wert_0=-0.00000265
# Iter 0: mu=50.5000, wert_0=-665.49999687
# Iter 1: mu=25.7500, wert_0=-289.38479483
# Iter 2: mu=13.3750, wert_0=-28.13449126
# Converged after 16 iterations: mu=6.7879, wert_0=-0.00000979
# Iter 0: mu=50.5000, wert_0=-50.50000000
# Iter 1: mu=25.7500, wert_0=-25.74999999
# Iter 2: mu=13.3750, wert_0=-13.37319231
# Converged after 24 iterations: mu=4.4659, wert_0=-0.00000116
# Iter 0: mu=50.5000, wert_0=-7705.00000000
# Iter 1: mu=25.7500, wert_0=-3893.49999849
# Iter 2: mu=13.3750, wert_0=-1987.65253027
# Converged after 27 iterations: mu=1.7382, wert_0=0.00000949
# Iter 0: mu=50.5000, wert_0=-14594.50000000
# Iter 1: mu=25.7500, wert_0=-7342.74997798
# Iter 2: mu=13.3750, wert_0=-3716.11755175
# Converged after 26 iterations: mu=1.2977, wert_0=-0.00000642
# Iter 0: mu=50.5000, wert_0=-15504.00000000
# Iter 1: mu=25.7500, wert_0=-7781.99981625
# Iter 2: mu=13.3750, wert_0=-3917.59053765
# Converged after 24 iterations: mu=1.2206, wert_0=0.00000335
# Iter 0: mu=50.5000, wert_0=-7741.00000000
# Iter 1: mu=25.7500, wert_0=-3830.49931991
# Iter 2: mu=13.3750, wert_0=-1868.65458317
# Converged after 25 iterations: mu=2.4004, wert_0=-0.00000820
# Iter 0: mu=50.5000, wert_0=-4381.00000000
# Iter 1: mu=25.7500, wert_0=-2153.49806034
# Iter 2: mu=13.3750, wert_0=-1029.61484411
# Converged after 21 iterations: mu=2.6392, wert_0=0.00000238
# Iter 0: mu=50.5000, wert_0=-2736.00000000
# Iter 1: mu=25.7500, wert_0=-1300.49487326
# Iter 2: mu=13.3750, wert_0=-569.00846438
# Converged after 25 iterations: mu=3.9794, wert_0=0.00000019
# Iter 0: mu=50.5000, wert_0=-1961.50000000
# Iter 1: mu=25.7500, wert_0=-946.73575408
# Iter 2: mu=13.3750, wert_0=-417.68041369
# Converged after 21 iterations: mu=3.5177, wert_0=0.00000002
# Iter 0: mu=50.5000, wert_0=-2129.50000000
# Iter 1: mu=25.7500, wert_0=-1015.69899169
# Iter 2: mu=13.3750, wert_0=-416.72448028
# Converged after 20 iterations: mu=4.0399, wert_0=0.00000558
# Iter 0: mu=50.5000, wert_0=-2702.50000000
# Iter 1: mu=25.7500, wert_0=-1291.56452328
# Iter 2: mu=13.3750, wert_0=-498.92715437
# Converged after 19 iterations: mu=3.6818, wert_0=-0.00000743
# Iter 0: mu=50.5000, wert_0=-1272.99999999
# Iter 1: mu=25.7500, wert_0=-579.76963710
# Iter 2: mu=13.3750, wert_0=-178.77843892
# Converged after 19 iterations: mu=5.6855, wert_0=0.00000128
# Iter 0: mu=50.5000, wert_0=-1144.49999997
# Iter 1: mu=25.7500, wert_0=-525.23034804
# Iter 2: mu=13.3750, wert_0=-144.12194650
# Converged after 20 iterations: mu=5.5698, wert_0=0.00000104
# Iter 0: mu=50.5000, wert_0=-1209.99999988
# Iter 1: mu=25.7500, wert_0=-565.23597226
# Iter 2: mu=13.3750, wert_0=-137.07024520
# Converged after 16 iterations: mu=4.9480, wert_0=0.00000431
# Iter 0: mu=50.5000, wert_0=-777.99998824
# Iter 1: mu=25.7500, wert_0=-323.01734950
# Iter 2: mu=13.3750, wert_0=-20.09652703
# Converged after 16 iterations: mu=7.8257, wert_0=-0.00000657
# Iter 0: mu=50.5000, wert_0=-614.99997133
# Iter 1: mu=25.7500, wert_0=-255.86488112
# Iter 2: mu=13.3750, wert_0=-11.69006903
# Converged after 14 iterations: mu=7.3718, wert_0=0.00000300
# Iter 0: mu=50.5000, wert_0=-826.49989037
# Iter 1: mu=25.7500, wert_0=-330.39494658
# Iter 2: mu=13.3750, wert_0=-9.78456153
# Converged after 13 iterations: mu=7.6286, wert_0=-0.00000106
# Iter 0: mu=50.5000, wert_0=-493.99979394
# Iter 1: mu=25.7500, wert_0=-173.62918111
# Iter 2: mu=13.3750, wert_0=-1.32143911
# Converged after 20 iterations: mu=11.6761, wert_0=-0.00000117
# Iter 0: mu=50.5000, wert_0=-6133.50000000
# Iter 1: mu=25.7500, wert_0=-3089.24999877
# Iter 2: mu=13.3750, wert_0=-1567.04581649
# Converged after 21 iterations: mu=1.8786, wert_0=0.00000455
# Iter 0: mu=50.5000, wert_0=-8177.50000000
# Iter 1: mu=25.7500, wert_0=-4093.74998472
# Iter 2: mu=13.3750, wert_0=-2051.35635505
# Converged after 27 iterations: mu=1.9735, wert_0=0.00000621
# Iter 0: mu=50.5000, wert_0=-14133.00000000
# Iter 1: mu=25.7500, wert_0=-7103.99982761
# Iter 2: mu=13.3750, wert_0=-3586.29965300
# Converged after 23 iterations: mu=1.2507, wert_0=0.00000255
# Iter 0: mu=50.5000, wert_0=-14550.50000000
# Iter 1: mu=25.7500, wert_0=-7298.74887353
# Iter 2: mu=13.3750, wert_0=-3661.54020725
# Converged after 23 iterations: mu=1.2611, wert_0=0.00000229
# Iter 0: mu=50.5000, wert_0=-5978.00000000
# Iter 1: mu=25.7500, wert_0=-2958.49754408
# Iter 2: mu=13.3750, wert_0=-1435.62662917
# Converged after 19 iterations: mu=1.9671, wert_0=-0.00000231
# Iter 0: mu=50.5000, wert_0=-3688.00000000
# Iter 1: mu=25.7500, wert_0=-1806.99293776
# Iter 2: mu=13.3750, wert_0=-846.37630024
# Converged after 22 iterations: mu=2.7755, wert_0=-0.00000918
# Iter 0: mu=50.5000, wert_0=-2903.50000000
# Iter 1: mu=25.7500, wert_0=-1393.72910472
# Iter 2: mu=13.3750, wert_0=-607.38620725
# Converged after 21 iterations: mu=3.7028, wert_0=0.00000716
# Iter 0: mu=50.5000, wert_0=-2747.00000000
# Iter 1: mu=25.7500, wert_0=-1311.43417080
# Iter 2: mu=13.3750, wert_0=-539.24070778
# Converged after 18 iterations: mu=4.0025, wert_0=0.00000814
# Iter 0: mu=50.5000, wert_0=-1292.00000000
# Iter 1: mu=25.7500, wert_0=-598.90777931
# Iter 2: mu=13.3750, wert_0=-212.61104876
# Converged after 22 iterations: mu=5.3283, wert_0=-0.00000151
# Iter 0: mu=50.5000, wert_0=-2011.99999999
# Iter 1: mu=25.7500, wert_0=-922.64995653
# Iter 2: mu=13.3750, wert_0=-292.80044055
# Converged after 21 iterations: mu=5.0710, wert_0=-0.00000598
# Iter 0: mu=50.5000, wert_0=-854.49999992
# Iter 1: mu=25.7500, wert_0=-383.42364016
# Iter 2: mu=13.3750, wert_0=-84.69320843
# Converged after 19 iterations: mu=5.9323, wert_0=0.00000074
# Iter 0: mu=50.5000, wert_0=-1246.99999955
# Iter 1: mu=25.7500, wert_0=-551.51525023
# Iter 2: mu=13.3750, wert_0=-95.67010281
# Converged after 19 iterations: mu=6.2633, wert_0=0.00000273
# Iter 0: mu=50.5000, wert_0=-673.49999908
# Iter 1: mu=25.7500, wert_0=-299.53596609
# Iter 2: mu=13.3750, wert_0=-41.01143116
# Converged after 14 iterations: mu=6.2237, wert_0=-0.00000654
# Iter 0: mu=50.5000, wert_0=-721.49999662
# Iter 1: mu=25.7500, wert_0=-295.78146263
# Iter 2: mu=13.3750, wert_0=-23.19830100
# Converged after 19 iterations: mu=8.5477, wert_0=0.00000709
# Iter 0: mu=50.5000, wert_0=-639.49997025
# Iter 1: mu=25.7500, wert_0=-255.62622023
# Iter 2: mu=13.3750, wert_0=-10.03198103
# Converged after 15 iterations: mu=8.5455, wert_0=-0.00000434
# Iter 0: mu=50.5000, wert_0=-613.99991747
# Iter 1: mu=25.7500, wert_0=-247.92319160
# Iter 2: mu=13.3750, wert_0=-7.47847676
# Converged after 11 iterations: mu=7.5017, wert_0=0.00000905
# Iter 0: mu=50.5000, wert_0=-124.49965139
# Iter 1: mu=25.7500, wert_0=-38.61311119
# Iter 2: mu=13.3750, wert_0=-0.06257611
# Converged after 16 iterations: mu=12.5041, wert_0=0.00000704
# Iter 0: mu=50.5000, wert_0=-118.48399476
# Iter 1: mu=25.7500, wert_0=-16.96006961
# Iter 2: mu=13.3750, wert_0=0.00501972
# Converged after 16 iterations: mu=15.2610, wert_0=0.00000167
# Iter 0: mu=50.5000, wert_0=-11098.00000000
# Iter 1: mu=25.7500, wert_0=-5603.49999829
# Iter 2: mu=13.3750, wert_0=-2856.14008297
# Converged after 27 iterations: mu=1.3959, wert_0=-0.00000606
# Iter 0: mu=50.5000, wert_0=-14858.00000000
# Iter 1: mu=25.7500, wert_0=-7482.49997844
# Iter 2: mu=13.3750, wert_0=-3794.00601069
# Converged after 26 iterations: mu=1.1614, wert_0=0.00000927
# Iter 0: mu=50.5000, wert_0=-14281.00000000
# Iter 1: mu=25.7500, wert_0=-7152.99983091
# Iter 2: mu=13.3750, wert_0=-3585.87461573
# Converged after 24 iterations: mu=1.3190, wert_0=-0.00000304
# Iter 0: mu=50.5000, wert_0=-5021.50000000
# Iter 1: mu=25.7500, wert_0=-2472.24955191
# Iter 2: mu=13.3750, wert_0=-1193.32250544
# Converged after 25 iterations: mu=2.6655, wert_0=0.00000685
# Iter 0: mu=50.5000, wert_0=-4192.00000000
# Iter 1: mu=25.7500, wert_0=-2063.49819249
# Iter 2: mu=13.3750, wert_0=-989.75122681
# Converged after 23 iterations: mu=2.4549, wert_0=0.00000000
# Iter 0: mu=50.5000, wert_0=-2300.00000000
# Iter 1: mu=25.7500, wert_0=-1111.99538042
# Iter 2: mu=13.3750, wert_0=-505.27131617
# Converged after 22 iterations: mu=3.5983, wert_0=0.00000581
# Iter 0: mu=50.5000, wert_0=-3391.00000000
# Iter 1: mu=25.7500, wert_0=-1658.47661986
# Iter 2: mu=13.3750, wert_0=-755.22217907
# Converged after 20 iterations: mu=2.5549, wert_0=0.00000610
# Iter 0: mu=50.5000, wert_0=-2082.00000000
# Iter 1: mu=25.7500, wert_0=-992.95000717
# Iter 2: mu=13.3750, wert_0=-407.21896153
# Converged after 21 iterations: mu=4.0609, wert_0=-0.00000856
# Iter 0: mu=50.5000, wert_0=-2615.50000000
# Iter 1: mu=25.7500, wert_0=-1254.07420542
# Iter 2: mu=13.3750, wert_0=-489.56194511
# Converged after 15 iterations: mu=3.3309, wert_0=0.00000792
# Iter 0: mu=50.5000, wert_0=-1914.49999996
# Iter 1: mu=25.7500, wert_0=-898.90445835
# Iter 2: mu=13.3750, wert_0=-265.73911223
# Converged after 18 iterations: mu=4.2065, wert_0=0.00000068
# Iter 0: mu=50.5000, wert_0=-662.49998991
# Iter 1: mu=25.7500, wert_0=-282.90634519
# Iter 2: mu=13.3750, wert_0=-19.30204296
# Converged after 13 iterations: mu=7.0364, wert_0=0.00000271
# Iter 0: mu=50.5000, wert_0=-202.49978773
# Iter 1: mu=25.7500, wert_0=-65.84132632
# Iter 2: mu=13.3750, wert_0=-0.25888178
# Converged after 17 iterations: mu=12.0030, wert_0=0.00000490
# Iter 0: mu=50.5000, wert_0=-151.50000000
# Iter 1: mu=25.7500, wert_0=-77.24999998
# Iter 2: mu=13.3750, wert_0=-40.12292219
# Converged after 24 iterations: mu=3.5066, wert_0=-0.00000517
# Iter 0: mu=50.5000, wert_0=-24087.00000000
# Iter 1: mu=25.7500, wert_0=-12206.99999712
# Iter 2: mu=13.3750, wert_0=-6266.81308186
# ✗ Max iterations reached: mu=1.0000
# Iter 0: mu=50.5000, wert_0=-29605.00000000
# Iter 1: mu=25.7500, wert_0=-14903.49996038
# Iter 2: mu=13.3750, wert_0=-7551.37945864
# ✗ Max iterations reached: mu=1.0000
# Iter 0: mu=50.5000, wert_0=-9674.00000000
# Iter 1: mu=25.7500, wert_0=-4773.49988236
# Iter 2: mu=13.3750, wert_0=-2321.13775183
# Converged after 25 iterations: mu=2.0899, wert_0=-0.00000409
# Iter 0: mu=50.5000, wert_0=-5306.50000000
# Iter 1: mu=25.7500, wert_0=-2608.74956977
# Iter 2: mu=13.3750, wert_0=-1255.72742189
# Converged after 23 iterations: mu=2.3934, wert_0=-0.00000580
# Iter 0: mu=50.5000, wert_0=-3002.50000000
# Iter 1: mu=25.7500, wert_0=-1443.24858426
# Iter 2: mu=13.3750, wert_0=-656.57269042
# Converged after 23 iterations: mu=3.8061, wert_0=0.00000845
# Iter 0: mu=50.5000, wert_0=-3683.00000000
# Iter 1: mu=25.7500, wert_0=-1801.99322842
# Iter 2: mu=13.3750, wert_0=-842.14086623
# Converged after 22 iterations: mu=2.6100, wert_0=0.00000403
# Iter 0: mu=50.5000, wert_0=-2802.00000000
# Iter 1: mu=25.7500, wert_0=-1316.98036842
# Iter 2: mu=13.3750, wert_0=-546.18170562
# Converged after 24 iterations: mu=4.4479, wert_0=0.00000515
# Iter 0: mu=50.5000, wert_0=-1995.50000000
# Iter 1: mu=25.7500, wert_0=-931.20357330
# Iter 2: mu=13.3750, wert_0=-362.50961234
# Converged after 22 iterations: mu=4.7848, wert_0=-0.00000891
# Iter 0: mu=50.5000, wert_0=-1588.00000000
# Iter 1: mu=25.7500, wert_0=-746.38560628
# Iter 2: mu=13.3750, wert_0=-274.64262999
# Converged after 19 iterations: mu=4.8242, wert_0=-0.00000583
# Iter 0: mu=50.5000, wert_0=-1253.99999999
# Iter 1: mu=25.7500, wert_0=-560.76466457
# Iter 2: mu=13.3750, wert_0=-161.87705986
# Converged after 21 iterations: mu=6.6608, wert_0=0.00000746
# Iter 0: mu=50.5000, wert_0=-1051.99999998
# Iter 1: mu=25.7500, wert_0=-457.52794638
# Iter 2: mu=13.3750, wert_0=-104.98326493
# Converged after 20 iterations: mu=7.5796, wert_0=-0.00000991
# Iter 0: mu=50.5000, wert_0=-1301.49999988
# Iter 1: mu=25.7500, wert_0=-582.51015985
# Iter 2: mu=13.3750, wert_0=-128.43638199
# Converged after 17 iterations: mu=5.8880, wert_0=-0.00000987
# Iter 0: mu=50.5000, wert_0=-970.99999965
# Iter 1: mu=25.7500, wert_0=-424.57343935
# Iter 2: mu=13.3750, wert_0=-70.74326069
# Converged after 17 iterations: mu=6.7264, wert_0=0.00000758
# Iter 0: mu=50.5000, wert_0=-570.49999922
# Iter 1: mu=25.7500, wert_0=-246.49703924
# Iter 2: mu=13.3750, wert_0=-30.55695841
# Converged after 18 iterations: mu=7.2662, wert_0=-0.00000841
# Iter 0: mu=50.5000, wert_0=-394.49998107
# Iter 1: mu=25.7500, wert_0=-163.50311533
# Iter 2: mu=13.3750, wert_0=-7.10980615
# Converged after 9 iterations: mu=7.8643, wert_0=-0.00000312
# Iter 0: mu=50.5000, wert_0=-227.99990920
# Iter 1: mu=25.7500, wert_0=-70.25524498
# Iter 2: mu=13.3750, wert_0=0.14639996
# Converged after 20 iterations: mu=13.7756, wert_0=-0.00000310
# Iter 0: mu=50.5000, wert_0=-50.50000000
# Iter 1: mu=25.7500, wert_0=-25.74999998
# Iter 2: mu=13.3750, wert_0=-13.37277675
# Converged after 23 iterations: mu=4.6728, wert_0=-0.00000956
# Iter 0: mu=50.5000, wert_0=-14950.50000000
# Iter 1: mu=25.7500, wert_0=-7550.24999790
# Iter 2: mu=13.3750, wert_0=-3849.98927540
# Converged after 29 iterations: mu=1.2519, wert_0=0.00000055
# Iter 0: mu=50.5000, wert_0=-23581.50000000
# Iter 1: mu=25.7500, wert_0=-11825.24996616
# Iter 2: mu=13.3750, wert_0=-5945.96510065
# Converged after 27 iterations: mu=1.3272, wert_0=-0.00000352
# Iter 0: mu=50.5000, wert_0=-10869.00000000
# Iter 1: mu=25.7500, wert_0=-5324.99986404
# Iter 2: mu=13.3750, wert_0=-2550.59236506
# Converged after 26 iterations: mu=2.4734, wert_0=0.00000194
# Iter 0: mu=50.5000, wert_0=-10096.50000000
# Iter 1: mu=25.7500, wert_0=-4973.24913380
# Iter 2: mu=13.3750, wert_0=-2403.27806809
# Converged after 26 iterations: mu=2.5089, wert_0=-0.00000171
# Iter 0: mu=50.5000, wert_0=-4318.50000000
# Iter 1: mu=25.7500, wert_0=-2066.24803103
# Iter 2: mu=13.3750, wert_0=-930.38135795
# Converged after 25 iterations: mu=3.8675, wert_0=0.00000518
# Iter 0: mu=50.5000, wert_0=-4630.00000000
# Iter 1: mu=25.7500, wert_0=-2204.49137463
# Iter 2: mu=13.3750, wert_0=-968.53229766
# Converged after 24 iterations: mu=3.8837, wert_0=0.00000966
# Iter 0: mu=50.5000, wert_0=-3215.50000000
# Iter 1: mu=25.7500, wert_0=-1507.72709822
# Iter 2: mu=13.3750, wert_0=-621.08966737
# Converged after 24 iterations: mu=4.6267, wert_0=0.00000148
# Iter 0: mu=50.5000, wert_0=-2584.00000000
# Iter 1: mu=25.7500, wert_0=-1197.94166652
# Iter 2: mu=13.3750, wert_0=-459.51171327
# Converged after 21 iterations: mu=4.8805, wert_0=0.00000326
# Iter 0: mu=50.5000, wert_0=-2343.50000000
# Iter 1: mu=25.7500, wert_0=-1031.59025573
# Iter 2: mu=13.3750, wert_0=-315.27464238
# Converged after 24 iterations: mu=6.9948, wert_0=0.00000408
# Iter 0: mu=50.5000, wert_0=-1623.49999999
# Iter 1: mu=25.7500, wert_0=-707.47284006
# Iter 2: mu=13.3750, wert_0=-191.53659564
# Converged after 23 iterations: mu=7.0288, wert_0=-0.00000668
# Iter 0: mu=50.5000, wert_0=-1115.99999998
# Iter 1: mu=25.7500, wert_0=-472.04270317
# Iter 2: mu=13.3750, wert_0=-100.52573412
# Converged after 21 iterations: mu=7.9753, wert_0=0.00000447
# Iter 0: mu=50.5000, wert_0=-1108.99999989
# Iter 1: mu=25.7500, wert_0=-464.38536350
# Iter 2: mu=13.3750, wert_0=-75.90270770
# Converged after 22 iterations: mu=8.8775, wert_0=-0.00000522
# Iter 0: mu=50.5000, wert_0=-1008.99999964
# Iter 1: mu=25.7500, wert_0=-413.12378582
# Iter 2: mu=13.3750, wert_0=-53.77428366
# Converged after 22 iterations: mu=8.7232, wert_0=-0.00000666
# Iter 0: mu=50.5000, wert_0=-688.99999892
# Iter 1: mu=25.7500, wert_0=-290.03812613
# Iter 2: mu=13.3750, wert_0=-28.95575495
# Converged after 20 iterations: mu=9.1622, wert_0=0.00000418
# Iter 0: mu=50.5000, wert_0=-735.99999640
# Iter 1: mu=25.7500, wert_0=-285.50697347
# Iter 2: mu=13.3750, wert_0=-15.83279380
# Converged after 22 iterations: mu=10.3699, wert_0=0.00000356
# Iter 0: mu=50.5000, wert_0=-445.49999305
# Iter 1: mu=25.7500, wert_0=-168.16456315
# Iter 2: mu=13.3750, wert_0=-6.10879223
# Converged after 20 iterations: mu=10.6793, wert_0=-0.00000920
# Iter 0: mu=50.5000, wert_0=-657.99996943
# Iter 1: mu=25.7500, wert_0=-249.65969789
# Iter 2: mu=13.3750, wert_0=-7.58589082
# Converged after 18 iterations: mu=9.9370, wert_0=0.00000738
# Iter 0: mu=50.5000, wert_0=-101.00000000
# Iter 1: mu=25.7500, wert_0=-51.49999998
# Iter 2: mu=13.3750, wert_0=-26.74815075
# Converged after 24 iterations: mu=3.7955, wert_0=0.00000835
# Iter 0: mu=50.5000, wert_0=-15779.50000000
# Iter 1: mu=25.7500, wert_0=-7983.24999788
# Iter 2: mu=13.3750, wert_0=-4084.98764027
# Converged after 28 iterations: mu=1.1090, wert_0=-0.00000473
# Iter 0: mu=50.5000, wert_0=-18298.00000000
# Iter 1: mu=25.7500, wert_0=-9189.99997398
# Iter 2: mu=13.3750, wert_0=-4635.10546179
# Converged after 27 iterations: mu=1.2358, wert_0=-0.00000337
# Iter 0: mu=50.5000, wert_0=-9831.00000000
# Iter 1: mu=25.7500, wert_0=-4880.99987337
# Iter 2: mu=13.3750, wert_0=-2403.70714046
# Converged after 23 iterations: mu=1.9798, wert_0=0.00000567
# Iter 0: mu=50.5000, wert_0=-11523.00000000
# Iter 1: mu=25.7500, wert_0=-5731.49907316
# Iter 2: mu=13.3750, wert_0=-2826.60894774
# Converged after 21 iterations: mu=1.8329, wert_0=0.00000760
# Iter 0: mu=50.5000, wert_0=-5807.50000000
# Iter 1: mu=25.7500, wert_0=-2812.74760705
# Iter 2: mu=13.3750, wert_0=-1303.14875768
# Converged after 24 iterations: mu=2.9824, wert_0=0.00000774
# Iter 0: mu=50.5000, wert_0=-4145.00000000
# Iter 1: mu=25.7500, wert_0=-2016.49229046
# Iter 2: mu=13.3750, wert_0=-930.51258335
# Converged after 22 iterations: mu=2.9387, wert_0=0.00000167
# Iter 0: mu=50.5000, wert_0=-3268.00000000
# Iter 1: mu=25.7500, wert_0=-1535.47698388
# Iter 2: mu=13.3750, wert_0=-636.09850257
# Converged after 24 iterations: mu=4.4883, wert_0=-0.00000817
# Iter 0: mu=50.5000, wert_0=-2845.50000000
# Iter 1: mu=25.7500, wert_0=-1335.68551784
# Iter 2: mu=13.3750, wert_0=-529.02797686
# Converged after 21 iterations: mu=4.3717, wert_0=-0.00000029
# Iter 0: mu=50.5000, wert_0=-2235.00000000
# Iter 1: mu=25.7500, wert_0=-1046.85210483
# Iter 2: mu=13.3750, wert_0=-386.11939853
# Converged after 19 iterations: mu=4.3274, wert_0=0.00000841
# Iter 0: mu=50.5000, wert_0=-1638.49999999
# Iter 1: mu=25.7500, wert_0=-722.47331158
# Iter 2: mu=13.3750, wert_0=-204.27246759
# Converged after 18 iterations: mu=6.5090, wert_0=0.00000062
# Iter 0: mu=50.5000, wert_0=-1648.49999997
# Iter 1: mu=25.7500, wert_0=-732.07017884
# Iter 2: mu=13.3750, wert_0=-186.67287816
# Converged after 20 iterations: mu=6.1250, wert_0=0.00000960
# Iter 0: mu=50.5000, wert_0=-1108.99999989
# Iter 1: mu=25.7500, wert_0=-464.41533332
# Iter 2: mu=13.3750, wert_0=-77.32436075
# Converged after 22 iterations: mu=8.6927, wert_0=0.00000038
# Iter 0: mu=50.5000, wert_0=-693.99999906
# Iter 1: mu=25.7500, wert_0=-295.32259340
# Iter 2: mu=13.3750, wert_0=-34.96601866
# Converged after 19 iterations: mu=7.6344, wert_0=0.00000556
# Iter 0: mu=50.5000, wert_0=-595.99999718
# Iter 1: mu=25.7500, wert_0=-245.34619726
# Iter 2: mu=13.3750, wert_0=-19.37782497
# Converged after 19 iterations: mu=8.5237, wert_0=-0.00000809
# Iter 0: mu=50.5000, wert_0=-202.49991811
# Iter 1: mu=25.7500, wert_0=-69.58410244
# Iter 2: mu=13.3750, wert_0=-0.47855968
# Converged after 18 iterations: mu=11.8457, wert_0=0.00000474
# Iter 0: mu=50.5000, wert_0=-167.99955333
# Iter 1: mu=25.7500, wert_0=-53.54282869
# Iter 2: mu=13.3750, wert_0=-0.18164735
# Converged after 16 iterations: mu=11.3727, wert_0=0.00000027
# Iter 0: mu=50.5000, wert_0=-6825.50000000
# Iter 1: mu=25.7500, wert_0=-3434.74999856
# Iter 2: mu=13.3750, wert_0=-1739.28252106
# Converged after 27 iterations: mu=1.9765, wert_0=-0.00000656
# Iter 0: mu=50.5000, wert_0=-22428.50000000
# Iter 1: mu=25.7500, wert_0=-11266.24996814
# Iter 2: mu=13.3750, wert_0=-5684.02965929
# Converged after 23 iterations: mu=1.2255, wert_0=0.00000194
# Iter 0: mu=50.5000, wert_0=-13495.00000000
# Iter 1: mu=25.7500, wert_0=-6713.49983582
# Iter 2: mu=13.3750, wert_0=-3319.75792741
# Converged after 24 iterations: mu=1.7234, wert_0=-0.00000531
# Iter 0: mu=50.5000, wert_0=-5924.50000000
# Iter 1: mu=25.7500, wert_0=-2880.24947264
# Iter 2: mu=13.3750, wert_0=-1353.17078127
# Converged after 26 iterations: mu=3.1643, wert_0=0.00000853
# Iter 0: mu=50.5000, wert_0=-3957.50000000
# Iter 1: mu=25.7500, wert_0=-1903.24818680
# Iter 2: mu=13.3750, wert_0=-867.06675956
# Converged after 25 iterations: mu=3.6844, wert_0=0.00000455
# Iter 0: mu=50.5000, wert_0=-2117.00000000
# Iter 1: mu=25.7500, wert_0=-978.49515254
# Iter 2: mu=13.3750, wert_0=-397.12529292
# Converged after 24 iterations: mu=5.7273, wert_0=-0.00000915
# Iter 0: mu=50.5000, wert_0=-2536.00000000
# Iter 1: mu=25.7500, wert_0=-1199.48216948
# Iter 2: mu=13.3750, wert_0=-505.16537630
# Converged after 21 iterations: mu=4.2040, wert_0=-0.00000559
# Iter 0: mu=50.5000, wert_0=-3766.50000000
# Iter 1: mu=25.7500, wert_0=-1761.66488304
# Iter 2: mu=13.3750, wert_0=-691.51319282
# Converged after 21 iterations: mu=4.5107, wert_0=-0.00000430
# Iter 0: mu=50.5000, wert_0=-2471.50000000
# Iter 1: mu=25.7500, wert_0=-1110.08200528
# Iter 2: mu=13.3750, wert_0=-362.15251952
# Converged after 24 iterations: mu=6.2520, wert_0=0.00000507
# Iter 0: mu=50.5000, wert_0=-2232.99999999
# Iter 1: mu=25.7500, wert_0=-995.11146596
# Iter 2: mu=13.3750, wert_0=-289.33895177
# Converged after 23 iterations: mu=6.2871, wert_0=0.00000577
# Iter 0: mu=50.5000, wert_0=-1641.99999985
# Iter 1: mu=25.7500, wert_0=-699.98614338
# Iter 2: mu=13.3750, wert_0=-130.69608514
# Converged after 21 iterations: mu=7.6227, wert_0=0.00000946
# Iter 0: mu=50.5000, wert_0=-1341.49999951
# Iter 1: mu=25.7500, wert_0=-571.61723336
# Iter 2: mu=13.3750, wert_0=-86.30808917
# Converged after 21 iterations: mu=7.6893, wert_0=-0.00000001
# Iter 0: mu=50.5000, wert_0=-749.99999899
# Iter 1: mu=25.7500, wert_0=-301.76657517
# Iter 2: mu=13.3750, wert_0=-28.32970117
# Converged after 21 iterations: mu=9.2143, wert_0=-0.00000891
# Iter 0: mu=50.5000, wert_0=-954.99999558
# Iter 1: mu=25.7500, wert_0=-403.78673822
# Iter 2: mu=13.3750, wert_0=-36.14734805
# Converged after 18 iterations: mu=7.5087, wert_0=0.00000006
# Iter 0: mu=50.5000, wert_0=-110.49831776
# Iter 1: mu=25.7500, wert_0=-22.14716070
# Iter 2: mu=13.3750, wert_0=0.06940494
# Converged after 18 iterations: mu=16.6291, wert_0=0.00000050
# Iter 0: mu=50.5000, wert_0=-4952.50000000
# Iter 1: mu=25.7500, wert_0=-2502.24999868
# Iter 2: mu=13.3750, wert_0=-1277.04034266
# Converged after 27 iterations: mu=2.1834, wert_0=-0.00000521
# Iter 0: mu=50.5000, wert_0=-23521.50000000
# Iter 1: mu=25.7500, wert_0=-11864.24996646
# Iter 2: mu=13.3750, wert_0=-6034.46383644
# Converged after 24 iterations: mu=1.0453, wert_0=0.00000846
# Iter 0: mu=50.5000, wert_0=-12371.50000000
# Iter 1: mu=25.7500, wert_0=-6159.24984555
# Iter 2: mu=13.3750, wert_0=-3050.31030332
# Converged after 26 iterations: mu=1.7670, wert_0=-0.00000544
# Iter 0: mu=50.5000, wert_0=-6399.50000000
# Iter 1: mu=25.7500, wert_0=-3157.24945210
# Iter 2: mu=13.3750, wert_0=-1530.82931694
# Converged after 25 iterations: mu=2.4337, wert_0=-0.00000647
# Iter 0: mu=50.5000, wert_0=-3246.50000000
# Iter 1: mu=25.7500, wert_0=-1588.24852185
# Iter 2: mu=13.3750, wert_0=-751.49346107
# Converged after 24 iterations: mu=2.9656, wert_0=-0.00000100
# Iter 0: mu=50.5000, wert_0=-1737.00000000
# Iter 1: mu=25.7500, wert_0=-845.99581037
# Iter 2: mu=13.3750, wert_0=-389.05244490
# Converged after 23 iterations: mu=4.1724, wert_0=0.00000341
# Iter 0: mu=50.5000, wert_0=-2438.50000000
# Iter 1: mu=25.7500, wert_0=-1176.22920532
# Iter 2: mu=13.3750, wert_0=-514.32137437
# Converged after 23 iterations: mu=4.4608, wert_0=-0.00000246
# Iter 0: mu=50.5000, wert_0=-3362.00000000
# Iter 1: mu=25.7500, wert_0=-1629.41835674
# Iter 2: mu=13.3750, wert_0=-693.48017255
# Converged after 19 iterations: mu=3.4211, wert_0=-0.00000687
# Iter 0: mu=50.5000, wert_0=-2559.50000000
# Iter 1: mu=25.7500, wert_0=-1198.06320797
# Iter 2: mu=13.3750, wert_0=-435.26441959
# Converged after 22 iterations: mu=5.0890, wert_0=0.00000239
# Iter 0: mu=50.5000, wert_0=-1364.99999997
# Iter 1: mu=25.7500, wert_0=-621.87846417
# Iter 2: mu=13.3750, wert_0=-166.69255567
# Converged after 19 iterations: mu=5.9072, wert_0=-0.00000170
# Iter 0: mu=50.5000, wert_0=-1446.99999987
# Iter 1: mu=25.7500, wert_0=-653.61248831
# Iter 2: mu=13.3750, wert_0=-148.14246513
# Converged after 18 iterations: mu=5.5328, wert_0=0.00000265
# Iter 0: mu=50.5000, wert_0=-1511.49999946
# Iter 1: mu=25.7500, wert_0=-691.64905322
# Iter 2: mu=13.3750, wert_0=-132.59225629
# Converged after 16 iterations: mu=4.9843, wert_0=-0.00000335
# Iter 0: mu=50.5000, wert_0=-971.99999865
# Iter 1: mu=25.7500, wert_0=-423.59735176
# Iter 2: mu=13.3750, wert_0=-53.65942320
# Converged after 18 iterations: mu=7.1001, wert_0=0.00000093
# Iter 0: mu=50.5000, wert_0=-737.49999655
# Iter 1: mu=25.7500, wert_0=-311.52710645
# Iter 2: mu=13.3750, wert_0=-27.52591986
# Converged after 18 iterations: mu=7.6511, wert_0=0.00000715
# Iter 0: mu=50.5000, wert_0=-50.50000000
# Iter 1: mu=25.7500, wert_0=-25.74999998
# Iter 2: mu=13.3750, wert_0=-13.37292219
# Converged after 23 iterations: mu=4.6052, wert_0=-0.00000661
# Iter 0: mu=50.5000, wert_0=-5342.50000000
# Iter 1: mu=25.7500, wert_0=-2694.24999874
# Iter 2: mu=13.3750, wert_0=-1370.04437977
# Converged after 28 iterations: mu=2.0610, wert_0=0.00000177
# Iter 0: mu=50.5000, wert_0=-18423.50000000
# Iter 1: mu=25.7500, wert_0=-9290.74997351
# Iter 2: mu=13.3750, wert_0=-4723.45877424
# Converged after 27 iterations: mu=1.0758, wert_0=-0.00000294
# Iter 0: mu=50.5000, wert_0=-12666.50000000
# Iter 1: mu=25.7500, wert_0=-6355.24984431
# Iter 2: mu=13.3750, wert_0=-3196.74563320
# Converged after 22 iterations: mu=1.3624, wert_0=-0.00000773
# Iter 0: mu=50.5000, wert_0=-6848.50000000
# Iter 1: mu=25.7500, wert_0=-3408.24944141
# ...
# Iter 2: mu=13.3750, wert_0=-923.66280392
# Converged after 26 iterations: mu=2.0930, wert_0=-0.00000214
# Iter 0: mu=50.5000, wert_0=-5898.50000000
# Iter 1: mu=25.7500, wert_0=-2953.24993408
# Iter 2: mu=13.3750, wert_0=-1479.40266364
# Converged after 20 iterations: mu=1.1428, wert_0=-0.00000999
# Iter 0: mu=50.5000, wert_0=-3758.50000000
# Iter 1: mu=25.7500, wert_0=-1852.74971055
# Iter 2: mu=13.3750, wert_0=-897.05899045
# Converged after 22 iterations: mu=2.0819, wert_0=0.00000697
# Iter 0: mu=50.5000, wert_0=-2297.00000000
# Iter 1: mu=25.7500, wert_0=-1108.99912518
# Iter 2: mu=13.3750, wert_0=-510.52918523
# Converged after 22 iterations: mu=2.8020, wert_0=0.00000861
# Iter 0: mu=50.5000, wert_0=-1028.00000000
# Iter 1: mu=25.7500, wert_0=-483.49827986
# Iter 2: mu=13.3750, wert_0=-206.70230377
# Converged after 21 iterations: mu=3.9457, wert_0=0.00000197
# Iter 0: mu=50.5000, wert_0=-5959.00000000
# Iter 1: mu=25.7500, wert_0=-3038.49999997
# Iter 2: mu=13.3750, wert_0=-1578.24655084
# ✗ Max iterations reached: mu=1.0000
# Iter 0: mu=50.5000, wert_0=-21302.50000000
# Iter 1: mu=25.7500, wert_0=-10783.74999782
# Iter 2: mu=13.3750, wert_0=-5524.23329022
# ✗ Max iterations reached: mu=1.0000
# Iter 0: mu=50.5000, wert_0=-7372.50000000
# Iter 1: mu=25.7500, wert_0=-3684.74999016
# Iter 2: mu=13.3750, wert_0=-1840.53906620
# Converged after 26 iterations: mu=1.3142, wert_0=-0.00000165
# Iter 0: mu=50.5000, wert_0=-6607.00000000
# Iter 1: mu=25.7500, wert_0=-3290.49992651
# Iter 2: mu=13.3750, wert_0=-1630.90099129
# Converged after 24 iterations: mu=1.3918, wert_0=0.00000993
# Iter 0: mu=50.5000, wert_0=-3527.50000000
# Iter 1: mu=25.7500, wert_0=-1720.74974776
# Iter 2: mu=13.3750, wert_0=-814.96053430
# Converged after 21 iterations: mu=2.3097, wert_0=0.00000800
# Iter 0: mu=50.5000, wert_0=-315.50000000
# Iter 1: mu=25.7500, wert_0=-142.22621671
# Iter 2: mu=13.3750, wert_0=-46.13287089
# Converged after 21 iterations: mu=6.6889, wert_0=0.00000727
# Iter 0: mu=50.5000, wert_0=-6514.50000000
# Iter 1: mu=25.7500, wert_0=-3321.74999997
# Iter 2: mu=13.3750, wert_0=-1725.37159240
# ✗ Max iterations reached: mu=1.0000
# Iter 0: mu=50.5000, wert_0=-20268.50000000
# Iter 1: mu=25.7500, wert_0=-10244.74999791
# Iter 2: mu=13.3750, wert_0=-5232.73952197
# ✗ Max iterations reached: mu=1.0000
# Iter 0: mu=50.5000, wert_0=-5428.00000000
# Iter 1: mu=25.7500, wert_0=-2705.49999190
# Iter 2: mu=13.3750, wert_0=-1343.97557929
# Converged after 26 iterations: mu=1.6790, wert_0=-0.00000164
# Iter 0: mu=50.5000, wert_0=-6602.50000000
# Iter 1: mu=25.7500, wert_0=-3310.74992657
# Iter 2: mu=13.3750, wert_0=-1663.50880399
# Converged after 19 iterations: mu=1.0492, wert_0=-0.00000814
# Iter 0: mu=50.5000, wert_0=-4246.50000000
# Iter 1: mu=25.7500, wert_0=-2093.24968897
# Iter 2: mu=13.3750, wert_0=-1013.58681435
# Converged after 23 iterations: mu=1.8912, wert_0=-0.00000421
# Iter 0: mu=50.5000, wert_0=-1831.00000000
# Iter 1: mu=25.7500, wert_0=-890.49929126
# Iter 2: mu=13.3750, wert_0=-416.57445773
# Converged after 21 iterations: mu=2.5240, wert_0=0.00000982
# Iter 0: mu=50.5000, wert_0=-1494.00000000
# Iter 1: mu=25.7500, wert_0=-701.99746502
# Iter 2: mu=13.3750, wert_0=-299.32145814
# Converged after 23 iterations: mu=4.0458, wert_0=0.00000039
# Iter 0: mu=50.5000, wert_0=-173.00000000
# Iter 1: mu=25.7500, wert_0=-73.99507725
# Iter 2: mu=13.3750, wert_0=-21.39125098
# Converged after 22 iterations: mu=8.4808, wert_0=0.00000469
# Iter 0: mu=50.5000, wert_0=-79.99999999
# Iter 1: mu=25.7500, wert_0=-30.40681640
# Iter 2: mu=13.3750, wert_0=-1.89878587
# Converged after 22 iterations: mu=12.0910, wert_0=0.00000034
# Iter 0: mu=50.5000, wert_0=-2373.50000000
# Iter 1: mu=25.7500, wert_0=-1210.24999999
# Iter 2: mu=13.3750, wert_0=-628.62346242
# ✗ Max iterations reached: mu=1.0000
# Iter 0: mu=50.5000, wert_0=-22037.00000000
# Iter 1: mu=25.7500, wert_0=-11146.99999776
# Iter 2: mu=13.3750, wert_0=-5701.85432358
# ✗ Max iterations reached: mu=1.0000
# Iter 0: mu=50.5000, wert_0=-8190.00000000
# Iter 1: mu=25.7500, wert_0=-4081.49998873
# Iter 2: mu=13.3750, wert_0=-2026.86728023
# Converged after 26 iterations: mu=1.5168, wert_0=0.00000273
# Iter 0: mu=50.5000, wert_0=-5203.00000000
# Iter 1: mu=25.7500, wert_0=-2579.49994242
# Iter 2: mu=13.3750, wert_0=-1266.70215907
# Converged after 24 iterations: mu=1.5999, wert_0=-0.00000844
# Iter 0: mu=50.5000, wert_0=-3982.00000000
# Iter 1: mu=25.7500, wert_0=-1952.49969956
# Iter 2: mu=13.3750, wert_0=-934.85366760
# Converged after 24 iterations: mu=2.2553, wert_0=0.00000382
# Iter 0: mu=50.5000, wert_0=-1840.50000000
# Iter 1: mu=25.7500, wert_0=-875.24927098
# Iter 2: mu=13.3750, wert_0=-389.03309932
# Converged after 22 iterations: mu=3.6316, wert_0=0.00000009
# Iter 0: mu=50.5000, wert_0=-1685.00000000
# Iter 1: mu=25.7500, wert_0=-793.99715073
# Iter 2: mu=13.3750, wert_0=-340.93977445
# Converged after 23 iterations: mu=3.9074, wert_0=-0.00000430
# Iter 0: mu=50.5000, wert_0=-728.00000000
# Iter 1: mu=25.7500, wert_0=-331.99537034
# Iter 2: mu=13.3750, wert_0=-127.74185055
# Converged after 20 iterations: mu=5.2343, wert_0=-0.00000238
# Iter 0: mu=50.5000, wert_0=-303.50000000
# Iter 1: mu=25.7500, wert_0=-130.24337627
# Iter 2: mu=13.3750, wert_0=-39.44123037
# Converged after 20 iterations: mu=7.5717, wert_0=0.00000296
# Iter 0: mu=50.5000, wert_0=-181.00000000
# Iter 1: mu=25.7500, wert_0=-81.98664439
# Iter 2: mu=13.3750, wert_0=-27.08622353
# Converged after 20 iterations: mu=6.4048, wert_0=-0.00000034
# Iter 0: mu=50.5000, wert_0=-1515.00000000
# Iter 1: mu=25.7500, wert_0=-772.49999999
# Iter 2: mu=13.3750, wert_0=-401.24846242
# ✗ Max iterations reached: mu=1.0000
# Iter 0: mu=50.5000, wert_0=-17746.00000000
# Iter 1: mu=25.7500, wert_0=-8984.49999814
# Iter 2: mu=13.3750, wert_0=-4603.62940503
# ✗ Max iterations reached: mu=1.0000
# Iter 0: mu=50.5000, wert_0=-9017.00000000
# Iter 1: mu=25.7500, wert_0=-4512.49998833
# Iter 2: mu=13.3750, wert_0=-2259.85014436
# Converged after 26 iterations: mu=1.1826, wert_0=0.00000116
# Iter 0: mu=50.5000, wert_0=-8537.50000000
# Iter 1: mu=25.7500, wert_0=-4255.74990622
# Iter 2: mu=13.3750, wert_0=-2113.14916491
# Converged after 22 iterations: mu=1.3066, wert_0=0.00000901
# Iter 0: mu=50.5000, wert_0=-5535.00000000
# Iter 1: mu=25.7500, wert_0=-2713.49960759
# Iter 2: mu=13.3750, wert_0=-1298.95112894
# Converged after 23 iterations: mu=2.0368, wert_0=0.00000461
# Iter 0: mu=50.5000, wert_0=-2544.50000000
# Iter 1: mu=25.7500, wert_0=-1232.74904706
# Iter 2: mu=13.3750, wert_0=-571.95895774
# Converged after 22 iterations: mu=2.5646, wert_0=-0.00000476
# Iter 0: mu=50.5000, wert_0=-1363.50000000
# Iter 1: mu=25.7500, wert_0=-695.24999999
# Iter 2: mu=13.3750, wert_0=-361.12337931
# Converged after 25 iterations: mu=1.0609, wert_0=0.00000475
# Iter 0: mu=50.5000, wert_0=-13747.50000000
# Iter 1: mu=25.7500, wert_0=-6941.24999847
# Iter 2: mu=13.3750, wert_0=-3538.02597886
# ✗ Max iterations reached: mu=1.0000
# Iter 0: mu=50.5000, wert_0=-8361.50000000
# Iter 1: mu=25.7500, wert_0=-4178.74998760
# Iter 2: mu=13.3750, wert_0=-2086.95284697
# Converged after 26 iterations: mu=1.5513, wert_0=0.00000801
# Iter 0: mu=50.5000, wert_0=-4206.50000000
# Iter 1: mu=25.7500, wert_0=-2102.74995052
# Iter 2: mu=13.3750, wert_0=-1049.96334856
# Converged after 22 iterations: mu=1.3927, wert_0=-0.00000782
# Iter 0: mu=50.5000, wert_0=-3760.50000000
# Iter 1: mu=25.7500, wert_0=-1854.74971027
# Iter 2: mu=13.3750, wert_0=-899.05328597
# Converged after 24 iterations: mu=2.0580, wert_0=-0.00000206
# Iter 0: mu=50.5000, wert_0=-2994.50000000
# Iter 1: mu=25.7500, wert_0=-1435.24889314
# Iter 2: mu=13.3750, wert_0=-650.04797928
# Converged after 18 iterations: mu=3.0252, wert_0=-0.00000809
# Iter 0: mu=50.5000, wert_0=-1639.50000000
# Iter 1: mu=25.7500, wert_0=-773.24715322
# Iter 2: mu=13.3750, wert_0=-332.57330837
# Converged after 24 iterations: mu=3.9811, wert_0=0.00000012
# Iter 0: mu=50.5000, wert_0=-1414.00000000
# Iter 1: mu=25.7500, wert_0=-720.99999999
# Iter 2: mu=13.3750, wert_0=-374.49885721
# ✗ Max iterations reached: mu=1.0000
# Iter 0: mu=50.5000, wert_0=-17521.00000000
# Iter 1: mu=25.7500, wert_0=-8858.49999808
# Iter 2: mu=13.3750, wert_0=-4527.12555527
# ✗ Max iterations reached: mu=1.0000
# Iter 0: mu=50.5000, wert_0=-5319.00000000
# Iter 1: mu=25.7500, wert_0=-2645.99999216
# Iter 2: mu=13.3750, wert_0=-1309.23490094
# Converged after 26 iterations: mu=1.7400, wert_0=-0.00000395
# Iter 0: mu=50.5000, wert_0=-4565.00000000
# Iter 1: mu=25.7500, wert_0=-2287.99994662
# Iter 2: mu=13.3750, wert_0=-1148.51134364
# Converged after 23 iterations: mu=1.2451, wert_0=-0.00000635
# Iter 0: mu=50.5000, wert_0=-5236.50000000
# Iter 1: mu=25.7500, wert_0=-2588.24961289
# Iter 2: mu=13.3750, wert_0=-1260.32547389
# Converged after 22 iterations: mu=1.7949, wert_0=-0.00000104
# Iter 0: mu=50.5000, wert_0=-2020.00000000
# Iter 1: mu=25.7500, wert_0=-980.49919098
# Iter 2: mu=13.3750, wert_0=-456.58630050
# Converged after 20 iterations: mu=2.7645, wert_0=0.00000963
# Iter 0: mu=50.5000, wert_0=-953.00000000
# Iter 1: mu=25.7500, wert_0=-457.99836698
# Iter 2: mu=13.3750, wert_0=-205.96786289
# Converged after 19 iterations: mu=3.0729, wert_0=-0.00000264
# Iter 0: mu=50.5000, wert_0=-183.00000000
# Iter 1: mu=25.7500, wert_0=-83.98637516
# Iter 2: mu=13.3750, wert_0=-28.80133311
# Converged after 20 iterations: mu=5.9835, wert_0=0.00000151
# Iter 0: mu=50.5000, wert_0=-78.99999999
# Iter 1: mu=25.7500, wert_0=-29.40888898
# Iter 2: mu=13.3750, wert_0=-1.32131823
# Converged after 21 iterations: mu=12.4775, wert_0=0.00000680
# Iter 0: mu=50.5000, wert_0=-1363.50000000
# Iter 1: mu=25.7500, wert_0=-695.24999999
# Iter 2: mu=13.3750, wert_0=-361.12385721
# ✗ Max iterations reached: mu=1.0000
# Iter 0: mu=50.5000, wert_0=-17933.00000000
# Iter 1: mu=25.7500, wert_0=-9072.49999814
# Iter 2: mu=13.3750, wert_0=-4642.12910108
# ✗ Max iterations reached: mu=1.0000
# Iter 0: mu=50.5000, wert_0=-5555.50000000
# Iter 1: mu=25.7500, wert_0=-2758.74999240
# Iter 2: mu=13.3750, wert_0=-1360.11842208
# Converged after 26 iterations: mu=1.6669, wert_0=0.00000574
# Iter 0: mu=50.5000, wert_0=-4855.00000000
# Iter 1: mu=25.7500, wert_0=-2429.49994557
# Iter 2: mu=13.3750, wert_0=-1215.74197910
# Converged after 20 iterations: mu=1.1804, wert_0=0.00000806
# Iter 0: mu=50.5000, wert_0=-5460.00000000
# Iter 1: mu=25.7500, wert_0=-2687.99960809
# Iter 2: mu=13.3750, wert_0=-1298.17556242
# Converged after 21 iterations: mu=1.8757, wert_0=-0.00000294
# Iter 0: mu=50.5000, wert_0=-2410.00000000
# Iter 1: mu=25.7500, wert_0=-1172.49909285
# Iter 2: mu=13.3750, wert_0=-549.02805459
# Converged after 22 iterations: mu=2.3813, wert_0=-0.00000422
# Iter 0: mu=50.5000, wert_0=-696.50000000
# Iter 1: mu=25.7500, wert_0=-325.24875208
# Iter 2: mu=13.3750, wert_0=-136.39799049
# Converged after 19 iterations: mu=4.5198, wert_0=-0.00000232
# Iter 0: mu=50.5000, wert_0=-1868.50000000
# Iter 1: mu=25.7500, wert_0=-952.74999999
# Iter 2: mu=13.3750, wert_0=-494.87329620
# ✗ Max iterations reached: mu=1.0000
# Iter 0: mu=50.5000, wert_0=-18674.50000000
# Iter 1: mu=25.7500, wert_0=-9442.74999802
# Iter 2: mu=13.3750, wert_0=-4826.74664324
# ✗ Max iterations reached: mu=1.0000
# Iter 0: mu=50.5000, wert_0=-6518.00000000
# Iter 1: mu=25.7500, wert_0=-3250.99999057
# Iter 2: mu=13.3750, wert_0=-1617.17964970
# Converged after 27 iterations: mu=1.5860, wert_0=-0.00000159
# Iter 0: mu=50.5000, wert_0=-4604.50000000
# Iter 1: mu=25.7500, wert_0=-2302.74994775
# Iter 2: mu=13.3750, wert_0=-1150.90934672
# Converged after 23 iterations: mu=1.2512, wert_0=0.00000674
# Iter 0: mu=50.5000, wert_0=-4247.50000000
# Iter 1: mu=25.7500, wert_0=-2094.24969812
# Iter 2: mu=13.3750, wert_0=-1014.66707919
# Converged after 23 iterations: mu=1.7610, wert_0=0.00000535
# Iter 0: mu=50.5000, wert_0=-1476.50000000
# Iter 1: mu=25.7500, wert_0=-709.24944497
# Iter 2: mu=13.3750, wert_0=-322.81779379
# Converged after 21 iterations: mu=2.9875, wert_0=-0.00000869
# Iter 0: mu=50.5000, wert_0=-448.00000000
# Iter 1: mu=25.7500, wert_0=-200.49024056
# Iter 2: mu=13.3750, wert_0=-69.79017576
# Converged after 21 iterations: mu=6.0986, wert_0=-0.00000150
# Iter 0: mu=50.5000, wert_0=-1868.50000000
# Iter 1: mu=25.7500, wert_0=-952.74999999
# Iter 2: mu=13.3750, wert_0=-494.87352476
# ✗ Max iterations reached: mu=1.0000
# Iter 0: mu=50.5000, wert_0=-20710.50000000
# Iter 1: mu=25.7500, wert_0=-10488.74999791
# Iter 2: mu=13.3750, wert_0=-5377.73878505
# ✗ Max iterations reached: mu=1.0000
# Iter 0: mu=50.5000, wert_0=-6766.50000000
# Iter 1: mu=25.7500, wert_0=-3375.74999095
# Iter 2: mu=13.3750, wert_0=-1680.06681092
# Converged after 24 iterations: mu=1.4056, wert_0=-0.00000179
# Iter 0: mu=50.5000, wert_0=-4699.50000000
# Iter 1: mu=25.7500, wert_0=-2348.24994343
# Iter 2: mu=13.3750, wert_0=-1171.58514472
# Converged after 23 iterations: mu=1.4860, wert_0=-0.00000847
# Iter 0: mu=50.5000, wert_0=-4255.50000000
# Iter 1: mu=25.7500, wert_0=-2102.24968770
# Iter 2: mu=13.3750, wert_0=-1022.56114420
# Converged after 20 iterations: mu=1.7920, wert_0=0.00000832
# Iter 0: mu=50.5000, wert_0=-327.50000000
# Iter 1: mu=25.7500, wert_0=-154.24230499
# Iter 2: mu=13.3750, wert_0=-61.42990024
# Converged after 20 iterations: mu=4.4587, wert_0=0.00000228
# Iter 0: mu=50.5000, wert_0=-1313.00000000
# Iter 1: mu=25.7500, wert_0=-669.49999999
# Iter 2: mu=13.3750, wert_0=-347.74871176
# ✗ Max iterations reached: mu=1.0000
# Iter 0: mu=50.5000, wert_0=-18244.00000000
# Iter 1: mu=25.7500, wert_0=-9234.99999810
# Iter 2: mu=13.3750, wert_0=-4730.37629660
# ✗ Max iterations reached: mu=1.0000
# Iter 0: mu=50.5000, wert_0=-7471.00000000
# Iter 1: mu=25.7500, wert_0=-3758.49998954
# Iter 2: mu=13.3750, wert_0=-1901.88929934
# Converged after 25 iterations: mu=1.1208, wert_0=0.00000716
# Iter 0: mu=50.5000, wert_0=-4810.50000000
# Iter 1: mu=25.7500, wert_0=-2409.74994406
# Iter 2: mu=13.3750, wert_0=-1208.33959413
# Converged after 24 iterations: mu=1.2525, wert_0=-0.00000054
# Iter 0: mu=50.5000, wert_0=-5414.00000000
# Iter 1: mu=25.7500, wert_0=-2691.49961688
# Iter 2: mu=13.3750, wert_0=-1326.42810376
# Converged after 22 iterations: mu=1.3176, wert_0=-0.00000380
# Iter 0: mu=50.5000, wert_0=-2159.00000000
# Iter 1: mu=25.7500, wert_0=-1069.99917076
# Iter 2: mu=13.3750, wert_0=-521.01516750
# Converged after 18 iterations: mu=1.5391, wert_0=0.00000655
# Iter 0: mu=50.5000, wert_0=-757.50000000
# Iter 1: mu=25.7500, wert_0=-386.24999999
# Iter 2: mu=13.3750, wert_0=-200.62375332
# Converged after 20 iterations: mu=1.3863, wert_0=0.00000984
# Iter 0: mu=50.5000, wert_0=-15273.50000000
# Iter 1: mu=25.7500, wert_0=-7724.74999833
# Iter 2: mu=13.3750, wert_0=-3950.26677267
# ✗ Max iterations reached: mu=1.0000
# Iter 0: mu=50.5000, wert_0=-7803.00000000
# Iter 1: mu=25.7500, wert_0=-3892.49998951
# Iter 2: mu=13.3750, wert_0=-1936.89294687
# Converged after 26 iterations: mu=1.4206, wert_0=0.00000821
# Iter 0: mu=50.5000, wert_0=-5756.00000000
# Iter 1: mu=25.7500, wert_0=-2884.99993407
# Iter 2: mu=13.3750, wert_0=-1448.27710813
# Converged after 23 iterations: mu=1.1734, wert_0=0.00000663
# Iter 0: mu=50.5000, wert_0=-5471.00000000
# Iter 1: mu=25.7500, wert_0=-2698.99960345
# Iter 2: mu=13.3750, wert_0=-1309.11648210
# Converged after 24 iterations: mu=1.8110, wert_0=0.00000021
# Iter 0: mu=50.5000, wert_0=-3139.50000000
# Iter 1: mu=25.7500, wert_0=-1530.74874086
# Iter 2: mu=13.3750, wert_0=-719.83358419
# Converged after 22 iterations: mu=2.5625, wert_0=0.00000408
# Iter 0: mu=50.5000, wert_0=-807.50000000
# Iter 1: mu=25.7500, wert_0=-386.74861038
# Iter 2: mu=13.3750, wert_0=-172.55080304
# Converged after 18 iterations: mu=3.2540, wert_0=-0.00000161
# Iter 0: mu=50.5000, wert_0=-169.00000000
# Iter 1: mu=25.7500, wert_0=-69.96839151
# Iter 2: mu=13.3750, wert_0=-14.92303270
# Converged after 19 iterations: mu=9.1354, wert_0=-0.00000590
# Successfully estimated μ for 465 groups
#   Applying Baseline uncensoring...
#
# Inventory optimization processing complete!
# Results saved as: Test1/inventory_optimization_wide_format_results.csv
# Total rows: 20409
# Magazines processed: 9
# POS locations: 8650
# Method-specific KPI columns created: 40
# Sample KPI columns: ['N1_pinball_loss', 'N1_avg_oos_rate', 'N1_avg_alpha_service_level', 'N1_avg_beta_fill_rate', 'N1_n_periods', 'N2_pinball_loss', 'N2_avg_oos_rate', 'N2_avg_alpha_service_level', 'N2_avg_beta_fill_rate', 'N2_n_periods']
#
# Sample statistics (N1 method):
# Average N1 Pinball Loss: 0.2020
# Average N1 OOS Rate: 0.0482

# %% [markdown]
# # Adding best method

# %%
import pandas as pd
import numpy as np

def add_best_method_column(df):
    """
    Add a column showing which method performs best based on pinball loss
    with alpha service level as tiebreaker.
    
    Parameters:
    - df: DataFrame with wide format results (one row per POS+Magazine)
    
    Returns:
    - DataFrame with new column 'best_method_pinball_loss'
    """
    
    # Find all pinball_loss columns
    pinball_loss_cols = [col for col in df.columns if col.endswith('_pinball_loss')]
    alpha_service_cols = [col for col in df.columns if col.endswith('_avg_alpha_service_level')]
    
    if not pinball_loss_cols:
        raise ValueError("No pinball_loss columns found in DataFrame")
    
    print(f"Found {len(pinball_loss_cols)} methods with pinball_loss data")
    
    df_copy = df.copy()
    best_methods = []
    
    # For each row, find the method with lowest pinball loss
    for idx, row in df_copy.iterrows():
        # Get pinball loss values for all methods
        method_pinball_loss = {}
        for col in pinball_loss_cols:
            method_name = col.replace('_pinball_loss', '')  # Extract method name (e.g., 'N1' from 'N1_pinball_loss')
            if pd.notna(row[col]):
                method_pinball_loss[method_name] = row[col]
        
        if not method_pinball_loss:
            best_methods.append(None)
            continue
        
        # Find the method(s) with minimum pinball loss
        min_pinball_loss = min(method_pinball_loss.values())
        best_methods_pinball = [method for method, loss in method_pinball_loss.items() if loss == min_pinball_loss]
        
        # If there's only one best method, use it
        if len(best_methods_pinball) == 1:
            best_method = best_methods_pinball[0]
        else:
            # Use alpha service level as tiebreaker (higher is better)
            tiebreaker_values = {}
            for method in best_methods_pinball:
                alpha_col = f"{method}_avg_alpha_service_level"
                if alpha_col in df.columns and pd.notna(row[alpha_col]):
                    tiebreaker_values[method] = row[alpha_col]
            
            if not tiebreaker_values:
                # If no tiebreaker values available, pick the first method alphabetically
                best_method = sorted(best_methods_pinball)[0]
            else:
                # Pick method with highest alpha service level
                max_alpha = max(tiebreaker_values.values())
                best_method = [method for method, alpha in tiebreaker_values.items() if alpha == max_alpha][0]
        
        best_methods.append(best_method)
    
    # Add the best method column
    df_copy['best_method_pinball_loss'] = best_methods
    
    return df_copy

# Usage example
if __name__ == "__main__":
    # Load your data
    df = pd.read_csv("NaiveEMPDConradNahmias_Optimization_KPIs_FeaturesNOTFINAL.csv")
    
    # Add best method column
    df_with_best = add_best_method_column(df)
    
    # Analyze results
    print("\nBest method distribution:")
    print(df_with_best['best_method_pinball_loss'].value_counts())
    
    # Save results
    df_with_best.to_csv("all_methods_optimization_KPIs_Features_with_BestNOTFINAL.csv", index=False)
    print(f"\nResults saved with {len(df_with_best)} rows")
# Out:
# Found 8 methods with pinball_loss data
#
# Best method distribution:
# best_method_pinball_loss
# N1          17040
# N3           1665
# EM            731
# Conrad        688
# Nahmias       168
# N2             83
# PD             32
# Baseline        2
# Name: count, dtype: int64
#
# Results saved with 20409 rows

# %% [markdown]
# # Merging Sofortremission

# %%
import pandas as pd

# Read the files
best_methods_df = pd.read_csv("all_methods_optimization_KPIs_Features_with_BestNOTFINAL.csv")
sofortremission_df = pd.read_csv("sofortremissionFeatures3007.csv")

# Fix the EHASTRA_EH_NUMMER format - add "EH" prefix to sofortremission
sofortremission_df['EHASTRA_EH_NUMMER'] = 'EH' + sofortremission_df['EHASTRA_EH_NUMMER'].astype(str)

# Merge
merged_df = best_methods_df.merge(
    sofortremission_df, 
    left_on=['EHASTRA_EH_NUMMER', 'magazine'], 
    right_on=['EHASTRA_EH_NUMMER', 'VDZ'], 
    how='left'
).drop('VDZ', axis=1)

# Sort by magazine
merged_df = merged_df.sort_values('magazine')

# Save
merged_df.to_csv("Sales_DT_Input.csv", index=False)
