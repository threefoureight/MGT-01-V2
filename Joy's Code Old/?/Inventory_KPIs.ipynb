# %%
import numpy as np
import pandas as pd
def inventory_KPI(df, method_name, c_ratio):
    '''
    Calculate KPIs for sales evaluation using quantity suggested by method
    Parameters:
    - df: pandas DataFrame indexed by date, must have columns: '(Method Name)_Q' (predicted) and 'Verkauf_MBR' (ground truth)
    - method_name: string name of the method being evaluated

    Output:
    OOS rate, alpha service level, beta rate, lost sales, and pinball_loss over all rows
    '''
    def pinball_loss_calculator(row):
        if row['Verkauf_MBR'] >= row[method_name+'_Q']: return c_ratio*(row['Verkauf_MBR']-row[method_name+'_Q'])
        else: return (1-c_ratio)*(-row['Verkauf_MBR']+row[method_name+'_Q'])

    df['avg_oos_rate'] = df['Verkauf_MBR']>df[method_name+"_Q"]
    df['avg_beta_fill_rate'] = df.apply(lambda row: min(row['Verkauf_MBR'], row[method_name+"_Q"])/row['Verkauf_MBR'] if row['Verkauf_MBR']!=0 else None, axis=1)
    df['lost_sales'] = df.apply(lambda row: np.abs(row['Verkauf_MBR']-row[method_name+'_Q']), axis=1)
    df['pinball_loss'] = df.apply(pinball_loss_calculator, axis=1)

    OOS_rate = df['avg_oos_rate'].mean()
    alpha_level = 1 - OOS_rate
    beta_rate = df['avg_beta_fill_rate'].mean()
    lost_sales = df['lost_sales'].sum()
    pinball_loss = df['pinball_loss'].mean()
    
    return {
        method_name + '_avg_oos_rate' : OOS_rate,
        method_name + '_avg_beta_fill_rate': beta_rate,
        method_name + '_avg_alpha_service_level' : alpha_level,
        method_name + '_lost_sales': lost_sales,
        method_name + '_pinball_loss': pinball_loss
    }

def inventory_KPI_POS(dataframe, methods, magazines, c_ratio=0.9):
    '''
    dataframe: df containing all inventory suggestions and original data columns
    Calculate uncensoring KPIs grouped by POS.
    Returns dataframe with KPI of each method per magazine and POS
    '''
    df = dataframe.copy()
    df=df.dropna(subset=['Verkauf', 'Bezug'])
    df = df[df['Heftjahr']==2024]
    
    df_KPIs = pd.DataFrame() #initialize final output KPI dataframe
    for letter in magazines:
        print('-'*10+ f'Magazine {letter} KPIs' + '-'*10)
        df_magazine = df[df['Magazine']==letter]
        df_magazine_KPIs = None #initialize KPI dataframe for this magazine

        for method in methods:
            method_KPIs = [] #initialize KPIs for this magazine and method
            
            for pos, group in df_magazine.groupby('EHASTRA_EH_NUMMER'):
                pos_result = inventory_KPI(group, method, c_ratio)

                #catch None output
                if pos_result is not None:
                    pos_result['EHASTRA_EH_NUMMER'] = pos
                    method_KPIs.append(pos_result)
            df_method_KPIs = pd.DataFrame(method_KPIs)
            if len(df_method_KPIs)==0: continue
            df_method_KPIs['Magazine']=letter

            print('-'*10)
            kpi_cols = [c for c in df_method_KPIs.columns if c not in ['Magazine', 'EHASTRA_EH_NUMMER']]
            for col in kpi_cols:
                print(f'{col}: {df_method_KPIs[col].mean():.3f}')

            if df_magazine_KPIs is None: df_magazine_KPIs = df_method_KPIs
            else:
                new_cols = [c for c in df_method_KPIs if c not in df_magazine_KPIs or c in ['EHASTRA_EH_NUMMER']]
                df_magazine_KPIs = pd.merge(df_magazine_KPIs, df_method_KPIs[new_cols], how = 'outer', on = ['EHASTRA_EH_NUMMER'])
        df_KPIs = pd.concat([df_KPIs, df_magazine_KPIs])

    #move magazine and pos columns to the front
    df_KPIs.set_index(['Magazine', 'EHASTRA_EH_NUMMER'], inplace=True)
    df_KPIs.reset_index(inplace=True)
    return df_KPIs

# %%
df = pd.read_csv('Inventory_results.csv')
uncensoring_methods = ['Baseline', 'N1', 'N2', 'N3', 'EM', 'PD', 'Nahmias', 'Conrad', 'Bayesian']
magazine_letters = [letter for letter in 'ABCDEFGHI']
df_KPIs = inventory_KPI_POS(df, uncensoring_methods, magazine_letters, c_ratio=0.9)
df_KPIs.to_csv('Inventory_KPIs.csv', index=False) #adjust accordingly
# Out:
# ----------Magazine A KPIs----------
# ----------
# Baseline_avg_oos_rate: 0.039
# Baseline_avg_beta_fill_rate: 0.985
# Baseline_avg_alpha_service_level: 0.961
# Baseline_lost_sales: 38.857
# Baseline_pinball_loss: 0.187
# ----------
# N1_avg_oos_rate: 0.049
# N1_avg_beta_fill_rate: 0.981
# N1_avg_alpha_service_level: 0.951
# N1_lost_sales: 36.714
# N1_pinball_loss: 0.182
# ----------
# N2_avg_oos_rate: 0.049
# N2_avg_beta_fill_rate: 0.981
# N2_avg_alpha_service_level: 0.951
# N2_lost_sales: 36.714
# N2_pinball_loss: 0.182
# ----------
# N3_avg_oos_rate: 0.039
# N3_avg_beta_fill_rate: 0.985
# N3_avg_alpha_service_level: 0.961
# N3_lost_sales: 38.857
# N3_pinball_loss: 0.187
# ----------
# EM_avg_oos_rate: 0.039
# EM_avg_beta_fill_rate: 0.985
# EM_avg_alpha_service_level: 0.961
# EM_lost_sales: 43.000
# EM_pinball_loss: 0.201
# ----------
# PD_avg_oos_rate: 0.039
# PD_avg_beta_fill_rate: 0.985
# PD_avg_alpha_service_level: 0.961
# PD_lost_sales: 38.857
# PD_pinball_loss: 0.187
# ----------
# Nahmias_avg_oos_rate: 0.039
# Nahmias_avg_beta_fill_rate: 0.985
# Nahmias_avg_alpha_service_level: 0.961
# Nahmias_lost_sales: 38.857
# Nahmias_pinball_loss: 0.187
# ----------
# Conrad_avg_oos_rate: 0.030
# Conrad_avg_beta_fill_rate: 0.991
# Conrad_avg_alpha_service_level: 0.970
# Conrad_lost_sales: 40.000
# Conrad_pinball_loss: 0.179
# ----------
# Bayesian_avg_oos_rate: 0.010
# Bayesian_avg_beta_fill_rate: 0.998
# Bayesian_avg_alpha_service_level: 0.990
# Bayesian_lost_sales: 63.143
# Bayesian_pinball_loss: 0.235
# ----------Magazine B KPIs----------
# ----------
# Baseline_avg_oos_rate: 0.097
# Baseline_avg_beta_fill_rate: 0.654
# Baseline_avg_alpha_service_level: 0.903
# Baseline_lost_sales: 30.333
# Baseline_pinball_loss: 0.230
# ----------
# N1_avg_oos_rate: 0.097
# N1_avg_beta_fill_rate: 0.654
# N1_avg_alpha_service_level: 0.903
# N1_lost_sales: 30.333
# N1_pinball_loss: 0.230
# ----------
# N2_avg_oos_rate: 0.097
# N2_avg_beta_fill_rate: 0.654
# N2_avg_alpha_service_level: 0.903
# N2_lost_sales: 30.333
# N2_pinball_loss: 0.230
# ----------
# N3_avg_oos_rate: 0.097
# N3_avg_beta_fill_rate: 0.654
# N3_avg_alpha_service_level: 0.903
# N3_lost_sales: 30.333
# N3_pinball_loss: 0.230
# ----------
# EM_avg_oos_rate: 0.097
# EM_avg_beta_fill_rate: 0.654
# EM_avg_alpha_service_level: 0.903
# EM_lost_sales: 30.333
# EM_pinball_loss: 0.230
# ----------
# PD_avg_oos_rate: 0.097
# PD_avg_beta_fill_rate: 0.654
# PD_avg_alpha_service_level: 0.903
# PD_lost_sales: 30.333
# PD_pinball_loss: 0.230
# ----------
# Nahmias_avg_oos_rate: 0.097
# Nahmias_avg_beta_fill_rate: 0.654
# Nahmias_avg_alpha_service_level: 0.903
# Nahmias_lost_sales: 30.333
# Nahmias_pinball_loss: 0.230
# ----------
# Conrad_avg_oos_rate: 0.097
# Conrad_avg_beta_fill_rate: 0.654
# Conrad_avg_alpha_service_level: 0.903
# Conrad_lost_sales: 30.333
# Conrad_pinball_loss: 0.230
# ----------
# Bayesian_avg_oos_rate: 0.011
# Bayesian_avg_beta_fill_rate: 0.999
# Bayesian_avg_alpha_service_level: 0.989
# Bayesian_lost_sales: 63.667
# Bayesian_pinball_loss: 0.240
# ----------Magazine C KPIs----------
# ----------
# Baseline_avg_oos_rate: 0.034
# Baseline_avg_beta_fill_rate: 0.997
# Baseline_avg_alpha_service_level: 0.966
# Baseline_lost_sales: 77.000
# Baseline_pinball_loss: 0.293
# ----------
# N1_avg_oos_rate: 0.034
# N1_avg_beta_fill_rate: 0.997
# N1_avg_alpha_service_level: 0.966
# N1_lost_sales: 77.000
# N1_pinball_loss: 0.293
# ----------
# N2_avg_oos_rate: 0.034
# N2_avg_beta_fill_rate: 0.997
# N2_avg_alpha_service_level: 0.966
# N2_lost_sales: 77.000
# N2_pinball_loss: 0.293
# ----------
# N3_avg_oos_rate: 0.034
# N3_avg_beta_fill_rate: 0.997
# N3_avg_alpha_service_level: 0.966
# N3_lost_sales: 77.000
# N3_pinball_loss: 0.293
# ----------
# EM_avg_oos_rate: 0.034
# EM_avg_beta_fill_rate: 0.997
# EM_avg_alpha_service_level: 0.966
# EM_lost_sales: 77.000
# EM_pinball_loss: 0.293
# ----------
# PD_avg_oos_rate: 0.034
# PD_avg_beta_fill_rate: 0.997
# PD_avg_alpha_service_level: 0.966
# PD_lost_sales: 77.000
# PD_pinball_loss: 0.293
# ----------
# Nahmias_avg_oos_rate: 0.034
# Nahmias_avg_beta_fill_rate: 0.997
# Nahmias_avg_alpha_service_level: 0.966
# Nahmias_lost_sales: 77.000
# Nahmias_pinball_loss: 0.293
# ----------
# Conrad_avg_oos_rate: 0.034
# Conrad_avg_beta_fill_rate: 0.997
# Conrad_avg_alpha_service_level: 0.966
# Conrad_lost_sales: 77.000
# Conrad_pinball_loss: 0.293
# ----------
# Bayesian_avg_oos_rate: 0.000
# Bayesian_avg_beta_fill_rate: 1.000
# Bayesian_avg_alpha_service_level: 1.000
# Bayesian_lost_sales: 133.000
# Bayesian_pinball_loss: 0.459
# ----------Magazine D KPIs----------
# ----------
# Baseline_avg_oos_rate: 0.000
# Baseline_avg_beta_fill_rate: 1.000
# Baseline_avg_alpha_service_level: 1.000
# Baseline_lost_sales: 9.000
# Baseline_pinball_loss: 0.069
# ----------
# N1_avg_oos_rate: 0.000
# N1_avg_beta_fill_rate: 1.000
# N1_avg_alpha_service_level: 1.000
# N1_lost_sales: 9.000
# N1_pinball_loss: 0.069
# ----------
# N2_avg_oos_rate: 0.000
# N2_avg_beta_fill_rate: 1.000
# N2_avg_alpha_service_level: 1.000
# N2_lost_sales: 9.000
# N2_pinball_loss: 0.069
# ----------
# N3_avg_oos_rate: 0.000
# N3_avg_beta_fill_rate: 1.000
# N3_avg_alpha_service_level: 1.000
# N3_lost_sales: 9.000
# N3_pinball_loss: 0.069
# ----------
# EM_avg_oos_rate: 0.000
# EM_avg_beta_fill_rate: 1.000
# EM_avg_alpha_service_level: 1.000
# EM_lost_sales: 9.000
# EM_pinball_loss: 0.069
# ----------
# PD_avg_oos_rate: 0.000
# PD_avg_beta_fill_rate: 1.000
# PD_avg_alpha_service_level: 1.000
# PD_lost_sales: 9.000
# PD_pinball_loss: 0.069
# ----------
# Nahmias_avg_oos_rate: 0.000
# Nahmias_avg_beta_fill_rate: 1.000
# Nahmias_avg_alpha_service_level: 1.000
# Nahmias_lost_sales: 9.000
# Nahmias_pinball_loss: 0.069
# ----------
# Conrad_avg_oos_rate: 0.000
# Conrad_avg_beta_fill_rate: 1.000
# Conrad_avg_alpha_service_level: 1.000
# Conrad_lost_sales: 9.000
# Conrad_pinball_loss: 0.069
# ----------
# Bayesian_avg_oos_rate: 0.000
# Bayesian_avg_beta_fill_rate: 1.000
# Bayesian_avg_alpha_service_level: 1.000
# Bayesian_lost_sales: 22.000
# Bayesian_pinball_loss: 0.169
# ----------Magazine E KPIs----------
# ----------
# Baseline_avg_oos_rate: 0.000
# Baseline_avg_beta_fill_rate: 1.000
# Baseline_avg_alpha_service_level: 1.000
# Baseline_lost_sales: 28.000
# Baseline_pinball_loss: 0.400
# ----------
# N1_avg_oos_rate: 0.000
# N1_avg_beta_fill_rate: 1.000
# N1_avg_alpha_service_level: 1.000
# N1_lost_sales: 17.000
# N1_pinball_loss: 0.243
# ----------
# N2_avg_oos_rate: 0.000
# N2_avg_beta_fill_rate: 1.000
# N2_avg_alpha_service_level: 1.000
# N2_lost_sales: 17.000
# N2_pinball_loss: 0.243
# ----------
# N3_avg_oos_rate: 0.000
# N3_avg_beta_fill_rate: 1.000
# N3_avg_alpha_service_level: 1.000
# N3_lost_sales: 28.000
# N3_pinball_loss: 0.400
# ----------
# EM_avg_oos_rate: 0.000
# EM_avg_beta_fill_rate: 1.000
# EM_avg_alpha_service_level: 1.000
# EM_lost_sales: 31.000
# EM_pinball_loss: 0.443
# ----------
# PD_avg_oos_rate: 0.000
# PD_avg_beta_fill_rate: 1.000
# PD_avg_alpha_service_level: 1.000
# PD_lost_sales: 28.000
# PD_pinball_loss: 0.400
# ----------
# Nahmias_avg_oos_rate: 0.000
# Nahmias_avg_beta_fill_rate: 1.000
# Nahmias_avg_alpha_service_level: 1.000
# Nahmias_lost_sales: 28.000
# Nahmias_pinball_loss: 0.400
# ----------
# Conrad_avg_oos_rate: 0.000
# Conrad_avg_beta_fill_rate: 1.000
# Conrad_avg_alpha_service_level: 1.000
# Conrad_lost_sales: 28.000
# Conrad_pinball_loss: 0.400
# ----------
# Bayesian_avg_oos_rate: 0.000
# Bayesian_avg_beta_fill_rate: 1.000
# Bayesian_avg_alpha_service_level: 1.000
# Bayesian_lost_sales: 27.000
# Bayesian_pinball_loss: 0.386
# ----------Magazine F KPIs----------
# ----------
# Baseline_avg_oos_rate: 0.125
# Baseline_avg_beta_fill_rate: 0.875
# Baseline_avg_alpha_service_level: 0.875
# Baseline_lost_sales: 5.000
# Baseline_pinball_loss: 0.162
# ----------
# N1_avg_oos_rate: 0.125
# N1_avg_beta_fill_rate: 0.875
# N1_avg_alpha_service_level: 0.875
# N1_lost_sales: 5.000
# N1_pinball_loss: 0.162
# ----------
# N2_avg_oos_rate: 0.125
# N2_avg_beta_fill_rate: 0.875
# N2_avg_alpha_service_level: 0.875
# N2_lost_sales: 5.000
# N2_pinball_loss: 0.162
# ----------
# N3_avg_oos_rate: 0.125
# N3_avg_beta_fill_rate: 0.875
# N3_avg_alpha_service_level: 0.875
# N3_lost_sales: 5.000
# N3_pinball_loss: 0.162
# ----------
# EM_avg_oos_rate: 0.125
# EM_avg_beta_fill_rate: 0.875
# EM_avg_alpha_service_level: 0.875
# EM_lost_sales: 5.000
# EM_pinball_loss: 0.162
# ----------
# PD_avg_oos_rate: 0.125
# PD_avg_beta_fill_rate: 0.875
# PD_avg_alpha_service_level: 0.875
# PD_lost_sales: 5.000
# PD_pinball_loss: 0.162
# ----------
# Nahmias_avg_oos_rate: 0.125
# Nahmias_avg_beta_fill_rate: 0.875
# Nahmias_avg_alpha_service_level: 0.875
# Nahmias_lost_sales: 5.000
# Nahmias_pinball_loss: 0.162
# ----------
# Conrad_avg_oos_rate: 0.125
# Conrad_avg_beta_fill_rate: 0.875
# Conrad_avg_alpha_service_level: 0.875
# Conrad_lost_sales: 5.000
# Conrad_pinball_loss: 0.162
# ----------
# Bayesian_avg_oos_rate: 0.000
# Bayesian_avg_beta_fill_rate: 1.000
# Bayesian_avg_alpha_service_level: 1.000
# Bayesian_lost_sales: 11.000
# Bayesian_pinball_loss: 0.137
# ----------Magazine G KPIs----------
# ----------
# Baseline_avg_oos_rate: 0.062
# Baseline_avg_beta_fill_rate: 0.967
# Baseline_avg_alpha_service_level: 0.938
# Baseline_lost_sales: 8.500
# Baseline_pinball_loss: 0.142
# ----------
# N1_avg_oos_rate: 0.062
# N1_avg_beta_fill_rate: 0.933
# N1_avg_alpha_service_level: 0.938
# N1_lost_sales: 8.000
# N1_pinball_loss: 0.185
# ----------
# N2_avg_oos_rate: 0.062
# N2_avg_beta_fill_rate: 0.933
# N2_avg_alpha_service_level: 0.938
# N2_lost_sales: 8.000
# N2_pinball_loss: 0.185
# ----------
# N3_avg_oos_rate: 0.062
# N3_avg_beta_fill_rate: 0.967
# N3_avg_alpha_service_level: 0.938
# N3_lost_sales: 8.500
# N3_pinball_loss: 0.142
# ----------
# EM_avg_oos_rate: 0.062
# EM_avg_beta_fill_rate: 0.967
# EM_avg_alpha_service_level: 0.938
# EM_lost_sales: 8.500
# EM_pinball_loss: 0.142
# ----------
# PD_avg_oos_rate: 0.062
# PD_avg_beta_fill_rate: 0.967
# PD_avg_alpha_service_level: 0.938
# PD_lost_sales: 8.500
# PD_pinball_loss: 0.142
# ----------
# Nahmias_avg_oos_rate: 0.062
# Nahmias_avg_beta_fill_rate: 0.967
# Nahmias_avg_alpha_service_level: 0.938
# Nahmias_lost_sales: 8.500
# Nahmias_pinball_loss: 0.142
# ----------
# Conrad_avg_oos_rate: 0.062
# Conrad_avg_beta_fill_rate: 0.967
# Conrad_avg_alpha_service_level: 0.938
# Conrad_lost_sales: 8.500
# Conrad_pinball_loss: 0.142
# ----------
# Bayesian_avg_oos_rate: 0.000
# Bayesian_avg_beta_fill_rate: 1.000
# Bayesian_avg_alpha_service_level: 1.000
# Bayesian_lost_sales: 11.500
# Bayesian_pinball_loss: 0.129
# ----------Magazine H KPIs----------
# ----------
# Baseline_avg_oos_rate: 0.000
# Baseline_avg_beta_fill_rate: 1.000
# Baseline_avg_alpha_service_level: 1.000
# Baseline_lost_sales: 6.667
# Baseline_pinball_loss: 0.116
# ----------
# N1_avg_oos_rate: 0.000
# N1_avg_beta_fill_rate: 1.000
# N1_avg_alpha_service_level: 1.000
# N1_lost_sales: 6.667
# N1_pinball_loss: 0.116
# ----------
# N2_avg_oos_rate: 0.000
# N2_avg_beta_fill_rate: 1.000
# N2_avg_alpha_service_level: 1.000
# N2_lost_sales: 6.667
# N2_pinball_loss: 0.116
# ----------
# N3_avg_oos_rate: 0.000
# N3_avg_beta_fill_rate: 1.000
# N3_avg_alpha_service_level: 1.000
# N3_lost_sales: 6.667
# N3_pinball_loss: 0.116
# ----------
# EM_avg_oos_rate: 0.000
# EM_avg_beta_fill_rate: 1.000
# EM_avg_alpha_service_level: 1.000
# EM_lost_sales: 6.667
# EM_pinball_loss: 0.116
# ----------
# PD_avg_oos_rate: 0.000
# PD_avg_beta_fill_rate: 1.000
# PD_avg_alpha_service_level: 1.000
# PD_lost_sales: 6.667
# PD_pinball_loss: 0.116
# ----------
# Nahmias_avg_oos_rate: 0.000
# Nahmias_avg_beta_fill_rate: 1.000
# Nahmias_avg_alpha_service_level: 1.000
# Nahmias_lost_sales: 6.667
# Nahmias_pinball_loss: 0.116
# ----------
# Conrad_avg_oos_rate: 0.000
# Conrad_avg_beta_fill_rate: 1.000
# Conrad_avg_alpha_service_level: 1.000
# Conrad_lost_sales: 6.667
# Conrad_pinball_loss: 0.116
# ----------
# Bayesian_avg_oos_rate: 0.000
# Bayesian_avg_beta_fill_rate: 1.000
# Bayesian_avg_alpha_service_level: 1.000
# Bayesian_lost_sales: 8.667
# Bayesian_pinball_loss: 0.149
# ----------Magazine I KPIs----------
# ----------
# Baseline_avg_oos_rate: 0.000
# Baseline_avg_beta_fill_rate: 1.000
# Baseline_avg_alpha_service_level: 1.000
# Baseline_lost_sales: 8.500
# Baseline_pinball_loss: 0.170
# ----------
# N1_avg_oos_rate: 0.000
# N1_avg_beta_fill_rate: 1.000
# N1_avg_alpha_service_level: 1.000
# N1_lost_sales: 8.500
# N1_pinball_loss: 0.170
# ----------
# N2_avg_oos_rate: 0.000
# N2_avg_beta_fill_rate: 1.000
# N2_avg_alpha_service_level: 1.000
# N2_lost_sales: 8.500
# N2_pinball_loss: 0.170
# ----------
# N3_avg_oos_rate: 0.000
# N3_avg_beta_fill_rate: 1.000
# N3_avg_alpha_service_level: 1.000
# N3_lost_sales: 8.500
# N3_pinball_loss: 0.170
# ----------
# EM_avg_oos_rate: 0.000
# EM_avg_beta_fill_rate: 1.000
# EM_avg_alpha_service_level: 1.000
# EM_lost_sales: 11.000
# EM_pinball_loss: 0.220
# ----------
# PD_avg_oos_rate: 0.000
# PD_avg_beta_fill_rate: 1.000
# PD_avg_alpha_service_level: 1.000
# PD_lost_sales: 8.500
# PD_pinball_loss: 0.170
# ----------
# Nahmias_avg_oos_rate: 0.000
# Nahmias_avg_beta_fill_rate: 1.000
# Nahmias_avg_alpha_service_level: 1.000
# Nahmias_lost_sales: 8.500
# Nahmias_pinball_loss: 0.170
# ----------
# Conrad_avg_oos_rate: 0.000
# Conrad_avg_beta_fill_rate: 1.000
# Conrad_avg_alpha_service_level: 1.000
# Conrad_lost_sales: 8.500
# Conrad_pinball_loss: 0.170
# ----------
# Bayesian_avg_oos_rate: 0.000
# Bayesian_avg_beta_fill_rate: 1.000
# Bayesian_avg_alpha_service_level: 1.000
# Bayesian_lost_sales: 11.000
# Bayesian_pinball_loss: 0.220
