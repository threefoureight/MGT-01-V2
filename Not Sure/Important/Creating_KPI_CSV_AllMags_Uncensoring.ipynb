# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

path = 'Test1/A_20250212_ZQ0.35_ZG0.4_testfile.csv'
df = pd.read_csv(path)

df["is_stockout"] = (df["Zensiert"] == 1)
df = df.dropna(subset=['Verkauf_MBR'])
df = df.dropna(subset=['Verkauf'])

df.head()
len(df)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[1], line 6
#       3 import matplotlib.pyplot as plt
#       5 path = 'Test1/A_20250212_ZQ0.35_ZG0.4_testfile.csv'
# ----> 6 df = pd.read_csv(path)
#       8 df["is_stockout"] = (df["Zensiert"] == 1)
#       9 df = df.dropna(subset=['Verkauf_MBR'])
#
# File /opt/anaconda3/envs/tum/lib/python3.11/site-packages/pandas/io/parsers/readers.py:1026, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#    1013 kwds_defaults = _refine_defaults_read(
#    1014     dialect,
#    1015     delimiter,
#    (...)   1022     dtype_backend=dtype_backend,
#    1023 )
#    1024 kwds.update(kwds_defaults)
# -> 1026 return _read(filepath_or_buffer, kwds)
#
# File /opt/anaconda3/envs/tum/lib/python3.11/site-packages/pandas/io/parsers/readers.py:620, in _read(filepath_or_buffer, kwds)
#     617 _validate_names(kwds.get("names", None))
#     619 # Create the parser.
# --> 620 parser = TextFileReader(filepath_or_buffer, **kwds)
#     622 if chunksize or iterator:
#     623     return parser
#
# File /opt/anaconda3/envs/tum/lib/python3.11/site-packages/pandas/io/parsers/readers.py:1620, in TextFileReader.__init__(self, f, engine, **kwds)
#    1617     self.options["has_index_names"] = kwds["has_index_names"]
#    1619 self.handles: IOHandles | None = None
# -> 1620 self._engine = self._make_engine(f, self.engine)
#
# File /opt/anaconda3/envs/tum/lib/python3.11/site-packages/pandas/io/parsers/readers.py:1880, in TextFileReader._make_engine(self, f, engine)
#    1878     if "b" not in mode:
#    1879         mode += "b"
# -> 1880 self.handles = get_handle(
#    1881     f,
#    1882     mode,
#    1883     encoding=self.options.get("encoding", None),
#    1884     compression=self.options.get("compression", None),
#    1885     memory_map=self.options.get("memory_map", False),
#    1886     is_text=is_text,
#    1887     errors=self.options.get("encoding_errors", "strict"),
#    1888     storage_options=self.options.get("storage_options", None),
#    1889 )
#    1890 assert self.handles is not None
#    1891 f = self.handles.handle
#
# File /opt/anaconda3/envs/tum/lib/python3.11/site-packages/pandas/io/common.py:873, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     868 elif isinstance(handle, str):
#     869     # Check whether the filename is to be opened in binary mode.
#     870     # Binary mode does not support 'encoding' and 'newline'.
#     871     if ioargs.encoding and "b" not in ioargs.mode:
#     872         # Encoding
# --> 873         handle = open(
#     874             handle,
#     875             ioargs.mode,
#     876             encoding=ioargs.encoding,
#     877             errors=errors,
#     878             newline="",
#     879         )
#     880     else:
#     881         # Binary mode
#     882         handle = open(handle, ioargs.mode)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'Test1/A_20250212_ZQ0.35_ZG0.4_testfile.csv'

# %% [markdown]
# # N3

# %%
# Grouping N3

import pandas as pd
import numpy as np

def apply_n3_uncensoring(df):
    df = df.copy()
    
    # Mark closed observations
    df["is_closed"] = (df["Zensiert"] == 1)
    df['Verkauf_Uncensored'] = df['Verkauf'].copy()
    
    # Compute open group means
    open_means = (
        df[~df['is_closed']]
        .groupby(['EHASTRA_EH_NUMMER'])['Verkauf_Uncensored']
        .mean()
        .rename('open_mean')
        .reset_index()
        .round()
    )
    
    # Merge open means back to df
    df = df.merge(open_means, on=['EHASTRA_EH_NUMMER'], how='left')
    
    # Compute the max(mean, observed) for censored rows only
    mask = df['is_closed'] & df['open_mean'].notna()
    df.loc[mask, 'Verkauf_Uncensored'] = np.maximum(df.loc[mask, 'Verkauf_Uncensored'], df.loc[mask, 'open_mean'])
    
    return df.drop(['is_closed', 'open_mean'], axis=1)

# %% [markdown]
# # N2

# %%
# Grouping N2
def apply_n2_uncensoring(df):
    """
    N2 uncensoring with grouping: replace censored values with mean of uncensored values within each group.
    """
    df = df.copy()

    df['Verkauf_Uncensored'] = df['Verkauf'].copy()
    
    # Calculate mean of uncensored observations for each group
    uncensored_means = (
        df[df['Zensiert'] == 0]
        .groupby(['EHASTRA_EH_NUMMER'])['Verkauf_Uncensored']
        .mean()
        .rename('uncensored_mean')
        .reset_index()
        .round()
    )
    
    # Merge back to original DataFrame
    df = df.merge(uncensored_means, on=['EHASTRA_EH_NUMMER'], how='left')
    
    # Replace censored values with group mean
    df.loc[df['Zensiert'] == 1, 'Verkauf_Uncensored'] = df.loc[df['Zensiert'] == 1, 'uncensored_mean']
    
    return df.drop('uncensored_mean', axis=1)

# %% [markdown]
# # N1

# %%
# Grouping N1

import pandas as pd
import numpy as np

def apply_n1_uncensoring(df):
    df = df.copy()
    df['Verkauf_Uncensored'] = df['Verkauf'].copy()

    # Identify closed observations
    is_closed = (df["Zensiert"] == 1)

    # Compute mean Verkauf per group and broadcast using transform
    group_means = df.groupby(['EHASTRA_EH_NUMMER'])['Verkauf_Uncensored'].transform('mean').round()
    
    # Replace closed observations
    df.loc[is_closed, 'Verkauf_Uncensored'] = group_means[is_closed]
    
    return df

# %% [markdown]
# # EM

# %%
import numpy as np
from scipy.stats import poisson
import pandas as pd

def apply_em_uncensoring(df, max_iter=30, tolerance=1e-6):

    df = df.copy()
    df['Verkauf_Uncensored'] = df['Verkauf'].copy()
    
    # Direct boolean indexing without extra columns
    stockout_condition = (df['Zensiert'] == 1)
    
    # Process groups with minimal overhead
    for (pos), group in df.groupby(['EHASTRA_EH_NUMMER']):
        group_stockout = stockout_condition.loc[group.index]
        
        if not group_stockout.any():
            continue
            
        sales = group['Verkauf_Uncensored'].values
        is_stockout = group_stockout.values
        
        uncensored = sales[~is_stockout]
        censored = sales[is_stockout]
        
        # Quick lambda initialization
        lambda_est = np.mean(uncensored) if len(uncensored) > 0 else np.mean(sales) * 1.5
        lambda_est = max(lambda_est, 0.1)
        
        # Fast EM loop
        for _ in range(max_iter):
            lambda_old = lambda_est
            
            # Batch E-step
            surv_prob = 1 - poisson.cdf(censored - 1, lambda_est)
            exact_prob = poisson.pmf(censored, lambda_est)
            surv_prob = np.maximum(surv_prob, 1e-12)
            
            expected = lambda_est + censored * exact_prob / surv_prob
            expected = np.maximum(expected, censored.astype(float))
            
            # M-step
            lambda_est = max(np.mean(np.concatenate([uncensored, expected])), 0.1)
            
            if abs(lambda_est - lambda_old) < tolerance:
                break
        
        # Final update
        surv_prob = 1 - poisson.cdf(censored - 1, lambda_est)
        exact_prob = poisson.pmf(censored, lambda_est)
        surv_prob = np.maximum(surv_prob, 1e-12)
        
        final_expected = lambda_est + censored * exact_prob / surv_prob
        final_expected = np.maximum(final_expected, censored.astype(float))
        
        # Update original dataframe
        stockout_indices = group.index[is_stockout]
        df.loc[stockout_indices, 'Verkauf_Uncensored'] = final_expected.round()
    
    return df

# new_df = apply_em_uncensoring(df)
# new_df.to_csv("test_df.csv")

# %% [markdown]
# # PD

# %%
import pandas as pd
import numpy as np
from scipy.stats import poisson

# grouped by POS only

def apply_projection_detruncation_fixed1(df, tau=0.5, max_iter=20, tolerance=1e-4):
    """
    Proper Projection Detruncation implementation using Poisson distribution.
    
    Parameters:
    - tau: Parameter that controls the aggressiveness of unconstraining (0 < tau < 1)
           tau = 0.5 gives balanced results similar to EM
           smaller tau values are more aggressive
    - max_iter: Maximum number of iterations
    - tolerance: Convergence tolerance
    """
    df = df.copy()
    df["is_closed"] = (df["Zensiert"] == 1)
    df['Verkauf_Uncensored'] = df['Verkauf'].copy()

    def compute_pd_projection1(obs_val, lambda_est, tau):
        """
        Compute the PD projection for a single observation using Poisson distribution.
        This balances area A (original to new estimate) with area B (new estimate to infinity)
        weighted by parameter tau.
        """
        # For Poisson distribution, we need to find the projection value
        # that balances the two areas according to tau
        
        def objective(k_proj):
            k_proj = int(round(k_proj))  # Ensure integer for discrete distribution
            
            if k_proj < obs_val:
                return float('inf')  # Invalid projection
            
            # Area A: P(obs_val <= X <= k_proj) = P(X <= k_proj) - P(X <= obs_val-1)
            area_A = poisson.cdf(k_proj, lambda_est) - poisson.cdf(obs_val - 1, lambda_est)
            
            # Area B: P(X > k_proj) = 1 - P(X <= k_proj)
            area_B = 1 - poisson.cdf(k_proj, lambda_est)
            
            # PD tries to balance: tau * area_A = (1 - tau) * area_B
            # Rearranging: area_A / area_B = (1 - tau) / tau
            if area_B > 1e-10:  # Avoid division by zero
                ratio = area_A / area_B
                target_ratio = (1 - tau) / tau
                return abs(ratio - target_ratio)
            else:
                return abs(area_A - (1 - tau))
        
        # Search for optimal projection in reasonable range
        # For Poisson, search from obs_val to obs_val + reasonable upper bound
        upper_bound = int(obs_val + max(10, int(3 * np.sqrt(lambda_est))))
        
        best_k = obs_val
        best_objective = float('inf')
        
        # Discrete search since Poisson is discrete
        for k in range(int(obs_val), upper_bound + 1):
            obj_val = objective(k)
            if obj_val < best_objective:
                best_objective = obj_val
                best_k = k
        
        return best_k
    
    # Process groups - now only grouping by POS
    grouped = df.groupby('EHASTRA_EH_NUMMER')
    
    for pos, group in grouped:
        open_mask = ~group['is_closed']
        closed_mask = group['is_closed']
        
        open_sales = group.loc[open_mask, 'Verkauf_Uncensored'].values
        closed_sales = group.loc[closed_mask, 'Verkauf_Uncensored'].values
        
        if len(closed_sales) == 0:
            continue
        
        # Initialize lambda parameter using all available data
        all_sales = group['Verkauf_Uncensored'].values
        lambda_est = np.mean(all_sales)
        
        # Ensure minimum lambda for numerical stability
        lambda_est = max(lambda_est, 0.1)
        
        closed_indices = group[closed_mask].index.values
        
        # Iterative process
        for iteration in range(max_iter):
            lambda_old = lambda_est
            
            # Project closed observations using PD heuristic
            projected_values = np.array([
                compute_pd_projection1(obs, lambda_est, tau) 
                for obs in closed_sales
            ])
            
            # Re-estimate lambda using open + projected values
            all_values = np.concatenate([open_sales, projected_values])
            lambda_est = np.mean(all_values)
            
            # Ensure minimum lambda
            lambda_est = max(lambda_est, 0.1)
            
            # Check convergence
            if abs(lambda_est - lambda_old) < tolerance:
                break
        
        # Final projection
        final_projections = np.array([
            compute_pd_projection1(obs, lambda_est, tau) 
            for obs in closed_sales
        ])
        
        # Update dataframe (already integers from Poisson)
        df.loc[closed_indices, 'Verkauf_Uncensored'] = final_projections.round()
    
    return df.drop('is_closed', axis=1)

def apply_projection_detruncation_aggressive1(df, max_iter=20, tolerance=1e-4):
    """
    More aggressive PD implementation with tau=0.3 as mentioned in the paper
    """
    return apply_projection_detruncation_fixed1(df, tau=0.3, max_iter=max_iter, tolerance=tolerance)

def apply_pd_uncensoring(df, max_iter=20, tolerance=1e-4):
    """
    Balanced PD implementation with tau=0.5 (similar to EM results)
    """
    return apply_projection_detruncation_fixed1(df, tau=0.5, max_iter=max_iter, tolerance=tolerance)

# df_pd_uncensored = apply_pd_uncensoring(df)

# %% [markdown]
# # Conrad

# %%
from scipy.stats import poisson
import pandas as pd
import numpy as np

# def compute_mu(left, right, n, N, r, x_sum, tolerance=0.001):
#     """
#     Binary search for mu using Conrad's method, with proper stopping and iteration limits.
#     """
#     iteration = 0

#     while (right - left) > tolerance:
#         mu = (left + right) / 2  # midpoint of current search interval

#         # Equation 2 from Conrad
#         value_0 = (x_sum - mu * n) * (1 - poisson.cdf(N - 1, mu)) + mu * (n - r) * (1 - poisson.cdf(N - 2, mu))

#         if abs(value_0) < tolerance:
#             return mu
#         elif value_0 < 0:
#             right = mu
#         else:
#             left = mu

#         iteration += 1

#     return (left + right) / 2  # final estimate if not converged early

def compute_mu(left, right, n, N, r, x_sum, value_tol=0.01, interval_tol=0.01, max_iterations=1000000000000000):
    iteration = 0

    while iteration < max_iterations and (right - left) > interval_tol:
        mu = (left + right) / 2
        value_0 = (x_sum - mu * n) * (1 - poisson.cdf(N - 1, mu)) + mu * (n - r) * (1 - poisson.cdf(N - 2, mu))

        if iteration % 10 == 0:
            print(f"Iteration {iteration}: mu={mu:.4f}, value_0={value_0:.6f}")

        if abs(value_0) < value_tol:
            print(f"Converged after {iteration} iterations: mu={mu:.4f}")
            return mu

        if value_0 < 0:
            right = mu
        else:
            left = mu

        iteration += 1

    print(f"Stopped after {iteration} iterations: mu={mu:.4f}, value_0={value_0:.6f}")
    return mu


def create_order_specific_mu_dict(df):
    """
    Create μ estimates for each (week, order_quantity) combination using Conrad's method.
    Each stockout level gets its own Poisson distribution.
    """
    order_specific_mu_dict = {}
    total_skipped = 0

    for (year, week), week_data in df.groupby(['Heftjahr', 'Heftnummer']):
        for bezug_val, group in week_data.groupby('Bezug'):
            n = len(group)
            N = bezug_val
            r = (group['Verkauf'] == bezug_val).sum()  # stockouts
            x_sum = np.minimum(group['Verkauf'], N).sum()

            if n < 2:
                # total_skipped += 1
                # print(f"Skipping: n={n} too small")
                continue
            if r == 0:
                # total_skipped += 1
                # print(f"Skipping: no stockouts in group")
                continue
            if r == n:
                # total_skipped += 1
                # print(f"Skipping: all stockouts in group")
                continue
            
            # bounds are problematic
            try:
                mu_est = compute_mu(0.1, 4, n, N, r, x_sum)
                if mu_est:
                    # Store with (year, week, order_quantity) key
                    key = (year, week, bezug_val)
                    order_specific_mu_dict[key] = mu_est
            except Exception as e:
                print(f"Error in week {week}, Bezug {N}: {e}")
                continue
    #print(f"total skipped: {total_skipped}")

    return order_specific_mu_dict

def expected_poisson_tail(mu, N, max_k=200):
    """
    Compute E[X | X >= N] for X ~ Poisson(mu)
    """
    k_vals = np.arange(N, max_k)
    pmf = poisson.pmf(k_vals, mu)
    tail_prob = 1 - poisson.cdf(N - 1, mu)
    if tail_prob < 1e-8:
        return N  # fallback: don't uncensor
    return np.sum(k_vals * pmf) / tail_prob

def apply_conrad_uncensoring_1(df, order_specific_mu_dict):
    """
    Given a DataFrame with Verkauf, Bezug, is_stockout, Heftjahr, Heftnummer,
    replace Verkauf with E[X | X >= Bezug] when censored.
    
    Uses order-quantity-specific Poisson(μ) parameters.
    
    Modifies the DataFrame in place by updating the Verkauf column.
    """
    df = df.copy()

    df['Verkauf_Uncensored'] = df['Verkauf'].copy()

    for idx, row in df.iterrows():
        # Skip if no stockout occurred
        if row['Zensiert'] == 0:
            continue
            
        # Get the order-quantity-specific demand parameter
        key = (row['Heftjahr'], row['Heftnummer'], row['Bezug'])
        mu = order_specific_mu_dict.get(key, None)

        if mu is None:
            # no estimate available for this specific (week, order_quantity) — keep original value
            continue

        # POS sold out — uncensor using the specific distribution for this order quantity
        est_demand = expected_poisson_tail(mu, row['Bezug'])
        df.at[idx, 'Verkauf_Uncensored'] = np.round(est_demand)

    return df

def apply_conrad_uncensoring(df):
    """
    WRAPPER FUNCTION: This is what gets called by the main processing loop
    """
    # Step 1: Create mu dictionary from the dataset
    order_specific_mu_dict = create_order_specific_mu_dict(df)
    
    # Step 2: Apply uncensoring using the mu dictionary  
    return apply_conrad_uncensoring_1(df, order_specific_mu_dict)

# Usage
# order_specific_mu_dict = create_order_specific_mu_dict(df)
# df_conrad_uncensored = apply_conrad_uncensoring_1(df, order_specific_mu_dict)
# results = calculate_kpis(df_conrad_uncensored, "Conrad, Altered")

# %%
import pandas as pd
import numpy as np

def apply_baseline_uncensoring(df):
    df_result = df.copy()
    df_result['Verkauf_Uncensored'] = df_result['Verkauf'] 
    return df_result

# Process all magazines A through I
magazines = ['A', 'B', 'C', 'D', 'E', 'F', 'G', 'H', 'I']
all_kpis = []

for magazine in magazines:
    filename = f'test1/{magazine}_20250212_ZQ0.35_ZG0.4_testfile.csv'
    
    # Load data
    df = pd.read_csv(filename)
    
    # Apply baseline uncensoring
    baseline_df = apply_conrad_uncensoring(df)
    
    # Calculate KPIs
    kpis = calculate_kpis(baseline_df, f"baseline_{magazine}")
    all_kpis.append(kpis)
    
    print(f"Processed magazine {magazine}")

# Calculate average KPIs
print("\nCalculating averages...")

# Convert to DataFrame if KPIs are dictionaries
if isinstance(all_kpis[0], dict):
    kpi_df = pd.DataFrame(all_kpis)
    average_kpis = kpi_df.mean()
    print("\nAverage KPIs:")
    print(average_kpis)
else:
    # If KPIs are single values
    average_kpis = np.mean(all_kpis)
    print(f"\nAverage KPI: {average_kpis}")

print(f"\nProcessed {len(magazines)} magazines successfully.")
# Out:
# Iteration 0: mu=2.0500, value_0=-95.529164
# Stopped after 9 iterations: mu=1.0064, value_0=0.306352
# Iteration 0: mu=2.0500, value_0=157.670785
# Stopped after 9 iterations: mu=3.0174, value_0=-1.387527
# Iteration 0: mu=2.0500, value_0=264.010846
# Stopped after 9 iterations: mu=3.9924, value_0=238.080823
# Iteration 0: mu=2.0500, value_0=114.205064
# Stopped after 9 iterations: mu=3.9924, value_0=259.426858
# Iteration 0: mu=2.0500, value_0=32.023764
# Stopped after 9 iterations: mu=3.9924, value_0=128.245570
# Iteration 0: mu=2.0500, value_0=11.102363
# Stopped after 9 iterations: mu=3.9924, value_0=93.032315
# Iteration 0: mu=2.0500, value_0=3.522657
# Stopped after 9 iterations: mu=3.9924, value_0=58.636756
# Iteration 0: mu=2.0500, value_0=0.773547
# Stopped after 9 iterations: mu=3.9924, value_0=24.982560
# Iteration 0: mu=2.0500, value_0=0.264131
# Stopped after 9 iterations: mu=3.9924, value_0=16.629564
# Iteration 0: mu=2.0500, value_0=0.040009
# Stopped after 9 iterations: mu=3.9924, value_0=4.793517
# Iteration 0: mu=2.0500, value_0=0.009141
# Converged after 0 iterations: mu=2.0500
# Iteration 0: mu=2.0500, value_0=0.001543
# Converged after 0 iterations: mu=2.0500
# Iteration 0: mu=2.0500, value_0=0.000237
# Converged after 0 iterations: mu=2.0500
# Iteration 0: mu=2.0500, value_0=0.000030
# Converged after 0 iterations: mu=2.0500
# Iteration 0: mu=2.0500, value_0=0.000005
# Converged after 0 iterations: mu=2.0500
# Iteration 0: mu=2.0500, value_0=0.000000
# Converged after 0 iterations: mu=2.0500
# Iteration 0: mu=2.0500, value_0=0.000000
# Converged after 0 iterations: mu=2.0500
# Iteration 0: mu=2.0500, value_0=0.000000
# Converged after 0 iterations: mu=2.0500
# Iteration 0: mu=2.0500, value_0=0.000000
# Converged after 0 iterations: mu=2.0500
# Iteration 0: mu=2.0500, value_0=0.000000
# Converged after 0 iterations: mu=2.0500
# Iteration 0: mu=2.0500, value_0=0.000000
# Converged after 0 iterations: mu=2.0500
# Iteration 0: mu=2.0500, value_0=0.000000
# Converged after 0 iterations: mu=2.0500
# Iteration 0: mu=2.0500, value_0=0.000000
# Converged after 0 iterations: mu=2.0500
# Iteration 0: mu=2.0500, value_0=0.000000
# Converged after 0 iterations: mu=2.0500
# Iteration 0: mu=2.0500, value_0=0.000000
# Converged after 0 iterations: mu=2.0500
# Iteration 0: mu=2.0500, value_0=0.000000
# Converged after 0 iterations: mu=2.0500
# Iteration 0: mu=2.0500, value_0=-130.556548
# Stopped after 9 iterations: mu=1.0064, value_0=-0.216919
# Iteration 0: mu=2.0500, value_0=160.243127
# Stopped after 9 iterations: mu=2.9564, value_0=-1.565271
# Iteration 0: mu=2.0500, value_0=352.578267
# Stopped after 9 iterations: mu=3.9924, value_0=400.331595
# Iteration 0: mu=2.0500, value_0=166.493677
# Stopped after 9 iterations: mu=3.9924, value_0=427.299519
# Iteration 0: mu=2.0500, value_0=53.203923
# Stopped after 9 iterations: mu=3.9924, value_0=255.926757
# Iteration 0: mu=2.0500, value_0=17.957643
# Stopped after 9 iterations: mu=3.9924, value_0=165.439207
# Iteration 0: mu=2.0500, value_0=6.675474
# Stopped after 9 iterations: mu=3.9924, value_0=117.846703
# Iteration 0: mu=2.0500, value_0=0.929379
# Stopped after 9 iterations: mu=3.9924, value_0=31.113748
# Iteration 0: mu=2.0500, value_0=0.214458
# Stopped after 9 iterations: mu=3.9924, value_0=13.913157
# Iteration 0: mu=2.0500, value_0=0.050702
# Stopped after 9 iterations: mu=3.9924, value_0=6.352020
# Iteration 0: mu=2.0500, value_0=0.007329
# Converged after 0 iterations: mu=2.0500
# Iteration 0: mu=2.0500, value_0=0.001645
# Converged after 0 iterations: mu=2.0500
# Iteration 0: mu=2.0500, value_0=0.000116
# Converged after 0 iterations: mu=2.0500
# Iteration 0: mu=2.0500, value_0=0.000024
# Converged after 0 iterations: mu=2.0500
# Iteration 0: mu=2.0500, value_0=0.000002
# Converged after 0 iterations: mu=2.0500
# Iteration 0: mu=2.0500, value_0=0.000000
# Converged after 0 iterations: mu=2.0500
# Iteration 0: mu=2.0500, value_0=0.000000
# Converged after 0 iterations: mu=2.0500
# Iteration 0: mu=2.0500, value_0=0.000000
# Converged after 0 iterations: mu=2.0500
# Iteration 0: mu=2.0500, value_0=0.000000
# Converged after 0 iterations: mu=2.0500
# Iteration 0: mu=2.0500, value_0=0.000000
# Converged after 0 iterations: mu=2.0500
# Iteration 0: mu=2.0500, value_0=0.000000
# Converged after 0 iterations: mu=2.0500
# Iteration 0: mu=2.0500, value_0=38.850020
# Stopped after 9 iterations: mu=2.3014, value_0=-0.332774
# Iteration 0: mu=2.0500, value_0=299.350691
# Stopped after 9 iterations: mu=3.9924, value_0=281.899158
# Iteration 0: mu=2.0500, value_0=208.230419
# Stopped after 9 iterations: mu=3.9924, value_0=510.796623
# Iteration 0: mu=2.0500, value_0=69.533598
# Stopped after 9 iterations: mu=3.9924, value_0=330.807948
# Iteration 0: mu=2.0500, value_0=22.034075
# Stopped after 9 iterations: mu=3.9924, value_0=200.433647
# Iteration 0: mu=2.0500, value_0=7.451859
# Stopped after 9 iterations: mu=3.9924, value_0=129.630879
# Iteration 0: mu=2.0500, value_0=1.388007
# Stopped after 9 iterations: mu=3.9924, value_0=46.686277
# Iteration 0: mu=2.0500, value_0=0.257671
# Stopped after 9 iterations: mu=3.9924, value_0=16.681525
# Iteration 0: mu=2.0500, value_0=0.059907
# Stopped after 9 iterations: mu=3.9924, value_0=7.477548
# Iteration 0: mu=2.0500, value_0=0.009735
# Converged after 0 iterations: mu=2.0500
# Iteration 0: mu=2.0500, value_0=0.001294
# Converged after 0 iterations: mu=2.0500
# Iteration 0: mu=2.0500, value_0=0.000267
# Converged after 0 iterations: mu=2.0500
# Iteration 0: mu=2.0500, value_0=0.000028
# Converged after 0 iterations: mu=2.0500
# Iteration 0: mu=2.0500, value_0=0.000003
# Converged after 0 iterations: mu=2.0500
# Iteration 0: mu=2.0500, value_0=0.000000
# Converged after 0 iterations: mu=2.0500
# Iteration 0: mu=2.0500, value_0=0.000000
# Converged after 0 iterations: mu=2.0500
# Iteration 0: mu=2.0500, value_0=0.000000
# Converged after 0 iterations: mu=2.0500
# Iteration 0: mu=2.0500, value_0=0.000000
# Converged after 0 iterations: mu=2.0500
# Iteration 0: mu=2.0500, value_0=0.000000
# Converged after 0 iterations: mu=2.0500
# Iteration 0: mu=2.0500, value_0=0.000000
# Converged after 0 iterations: mu=2.0500
# Iteration 0: mu=2.0500, value_0=40.254856
# Stopped after 9 iterations: mu=2.3166, value_0=1.011373
# Iteration 0: mu=2.0500, value_0=279.013367
# Stopped after 9 iterations: mu=3.9924, value_0=206.417534
# Iteration 0: mu=2.0500, value_0=206.259758
# Stopped after 9 iterations: mu=3.9924, value_0=473.681057
# Iteration 0: mu=2.0500, value_0=77.733462
# Stopped after 9 iterations: mu=3.9924, value_0=364.927769
# Iteration 0: mu=2.0500, value_0=17.364793
# Stopped after 9 iterations: mu=3.9924, value_0=157.807980
# Iteration 0: mu=2.0500, value_0=5.761222
# Stopped after 9 iterations: mu=3.9924, value_0=99.632601
# Iteration 0: mu=2.0500, value_0=1.557037
# Stopped after 9 iterations: mu=3.9924, value_0=52.526839
# Iteration 0: mu=2.0500, value_0=0.323409
# Stopped after 9 iterations: mu=3.9924, value_0=20.861264
# Iteration 0: mu=2.0500, value_0=0.047990
# Stopped after 9 iterations: mu=3.9924, value_0=5.922058
# Iteration 0: mu=2.0500, value_0=0.007391
# Converged after 0 iterations: mu=2.0500
# Iteration 0: mu=2.0500, value_0=0.001576
# Converged after 0 iterations: mu=2.0500
# Iteration 0: mu=2.0500, value_0=0.000203
# Converged after 0 iterations: mu=2.0500
# Iteration 0: mu=2.0500, value_0=0.000028
# Converged after 0 iterations: mu=2.0500
# Iteration 0: mu=2.0500, value_0=0.000003
# Converged after 0 iterations: mu=2.0500
# Iteration 0: mu=2.0500, value_0=0.000000
# Converged after 0 iterations: mu=2.0500
# Iteration 0: mu=2.0500, value_0=0.000000
# Converged after 0 iterations: mu=2.0500
# Iteration 0: mu=2.0500, value_0=0.000000
# Converged after 0 iterations: mu=2.0500
# Iteration 0: mu=2.0500, value_0=0.000000
# Converged after 0 iterations: mu=2.0500
# Iteration 0: mu=2.0500, value_0=0.000000
# Converged after 0 iterations: mu=2.0500
# Iteration 0: mu=2.0500, value_0=0.000000
# Converged after 0 iterations: mu=2.0500
# Iteration 0: mu=2.0500, value_0=0.000000
# Converged after 0 iterations: mu=2.0500
# Iteration 0: mu=2.0500, value_0=0.000000
# Converged after 0 iterations: mu=2.0500
# Iteration 0: mu=2.0500, value_0=0.000000
# Converged after 0 iterations: mu=2.0500
# Iteration 0: mu=2.0500, value_0=90.008237
# Stopped after 9 iterations: mu=2.5604, value_0=0.191521
# Iteration 0: mu=2.0500, value_0=299.986632
# Stopped after 9 iterations: mu=3.9924, value_0=270.776899
# Iteration 0: mu=2.0500, value_0=191.361860
# Stopped after 9 iterations: mu=3.9924, value_0=449.503052
# Iteration 0: mu=2.0500, value_0=63.841719
# Stopped after 9 iterations: mu=3.9924, value_0=294.268896
# Iteration 0: mu=2.0500, value_0=19.237021
# Stopped after 9 iterations: mu=3.9924, value_0=168.805903
# Iteration 0: mu=2.0500, value_0=5.663658
# Stopped after 9 iterations: mu=3.9924, value_0=97.113867
# Iteration 0: mu=2.0500, value_0=1.456189
# Stopped after 9 iterations: mu=3.9924, value_0=48.241686
# Iteration 0: mu=2.0500, value_0=0.275212
# Stopped after 9 iterations: mu=3.9924, value_0=17.496041
# Iteration 0: mu=2.0500, value_0=0.052720
# Stopped after 9 iterations: mu=3.9924, value_0=6.484829
# Iteration 0: mu=2.0500, value_0=0.007165
# Converged after 0 iterations: mu=2.0500
# Iteration 0: mu=2.0500, value_0=0.001365
# Converged after 0 iterations: mu=2.0500
# Iteration 0: mu=2.0500, value_0=0.000242
# Converged after 0 iterations: mu=2.0500
# Iteration 0: mu=2.0500, value_0=0.000028
# Converged after 0 iterations: mu=2.0500
# Iteration 0: mu=2.0500, value_0=0.000002
# Converged after 0 iterations: mu=2.0500
# Iteration 0: mu=2.0500, value_0=0.000000
# Converged after 0 iterations: mu=2.0500
# Iteration 0: mu=2.0500, value_0=0.000000
# Converged after 0 iterations: mu=2.0500
# Iteration 0: mu=2.0500, value_0=0.000000
# Converged after 0 iterations: mu=2.0500
# Iteration 0: mu=2.0500, value_0=0.000000
# Converged after 0 iterations: mu=2.0500
# Iteration 0: mu=2.0500, value_0=0.000000
# Converged after 0 iterations: mu=2.0500
# Iteration 0: mu=2.0500, value_0=0.000000
# Converged after 0 iterations: mu=2.0500
# Iteration 0: mu=2.0500, value_0=0.000000
# Converged after 0 iterations: mu=2.0500
# Iteration 0: mu=2.0500, value_0=0.000000
# Converged after 0 iterations: mu=2.0500
# Iteration 0: mu=2.0500, value_0=99.895932
# Stopped after 9 iterations: mu=2.5908, value_0=1.429594
# Iteration 0: mu=2.0500, value_0=383.759492
# Stopped after 9 iterations: mu=3.9924, value_0=394.265608
# Iteration 0: mu=2.0500, value_0=202.442331
# Stopped after 9 iterations: mu=3.9924, value_0=491.160501
# Iteration 0: mu=2.0500, value_0=51.751245
# Stopped after 9 iterations: mu=3.9924, value_0=236.955895
# Iteration 0: mu=2.0500, value_0=17.082715
# Stopped after 9 iterations: mu=3.9924, value_0=152.048379
# Iteration 0: mu=2.0500, value_0=5.552940
# Stopped after 9 iterations: mu=3.9924, value_0=95.514214
# Iteration 0: mu=2.0500, value_0=1.153275
# Stopped after 9 iterations: mu=3.9924, value_0=38.359036
# Iteration 0: mu=2.0500, value_0=0.282688
# Stopped after 9 iterations: mu=3.9924, value_0=18.141947
# Iteration 0: mu=2.0500, value_0=0.046130
# Stopped after 9 iterations: mu=3.9924, value_0=5.693079
# Iteration 0: mu=2.0500, value_0=0.007183
# Converged after 0 iterations: mu=2.0500
# Iteration 0: mu=2.0500, value_0=0.001200
# Converged after 0 iterations: mu=2.0500
# Iteration 0: mu=2.0500, value_0=0.000170
# Converged after 0 iterations: mu=2.0500
# Iteration 0: mu=2.0500, value_0=0.000017
# Converged after 0 iterations: mu=2.0500
# Iteration 0: mu=2.0500, value_0=0.000003
# Converged after 0 iterations: mu=2.0500
# Iteration 0: mu=2.0500, value_0=0.000000
# Converged after 0 iterations: mu=2.0500
# Iteration 0: mu=2.0500, value_0=0.000000
# Converged after 0 iterations: mu=2.0500
# Iteration 0: mu=2.0500, value_0=0.000000
# Converged after 0 iterations: mu=2.0500
# Iteration 0: mu=2.0500, value_0=0.000000
# Converged after 0 iterations: mu=2.0500
# Iteration 0: mu=2.0500, value_0=0.000000
# Converged after 0 iterations: mu=2.0500
# Iteration 0: mu=2.0500, value_0=0.000000
# Converged after 0 iterations: mu=2.0500
# Iteration 0: mu=2.0500, value_0=0.000000
# Converged after 0 iterations: mu=2.0500
# Iteration 0: mu=2.0500, value_0=99.675446
# Stopped after 9 iterations: mu=2.6518, value_0=-0.811126
# Iteration 0: mu=2.0500, value_0=385.483829
# Stopped after 9 iterations: mu=3.9924, value_0=411.829989
# Iteration 0: mu=2.0500, value_0=185.649880
# Stopped after 9 iterations: mu=3.9924, value_0=447.709092
# Iteration 0: mu=2.0500, value_0=56.481744
# Stopped after 9 iterations: mu=3.9924, value_0=258.720783
# Iteration 0: mu=2.0500, value_0=17.496957
# Stopped after 9 iterations: mu=3.9924, value_0=156.459501
# Iteration 0: mu=2.0500, value_0=6.023617
# Stopped after 9 iterations: mu=3.9924, value_0=105.804093
# Iteration 0: mu=2.0500, value_0=1.402956
# Stopped after 9 iterations: mu=3.9924, value_0=46.920881
# Iteration 0: mu=2.0500, value_0=0.273219
# Stopped after 9 iterations: mu=3.9924, value_0=17.477164
# Iteration 0: mu=2.0500, value_0=0.049050
# Stopped after 9 iterations: mu=3.9924, value_0=6.062839
# Iteration 0: mu=2.0500, value_0=0.007246
# Converged after 0 iterations: mu=2.0500
# Iteration 0: mu=2.0500, value_0=0.001701
# Converged after 0 iterations: mu=2.0500
# Iteration 0: mu=2.0500, value_0=0.000209
# Converged after 0 iterations: mu=2.0500
# Iteration 0: mu=2.0500, value_0=0.000023
# Converged after 0 iterations: mu=2.0500
# Iteration 0: mu=2.0500, value_0=0.000003
# Converged after 0 iterations: mu=2.0500
# Iteration 0: mu=2.0500, value_0=0.000000
# Converged after 0 iterations: mu=2.0500
# Iteration 0: mu=2.0500, value_0=0.000000
# Converged after 0 iterations: mu=2.0500
# Iteration 0: mu=2.0500, value_0=0.000000
# Converged after 0 iterations: mu=2.0500
# Iteration 0: mu=2.0500, value_0=0.000000
# Converged after 0 iterations: mu=2.0500
# Iteration 0: mu=2.0500, value_0=0.000000
# Converged after 0 iterations: mu=2.0500
# Iteration 0: mu=2.0500, value_0=0.000000
# Converged after 0 iterations: mu=2.0500
# Iteration 0: mu=2.0500, value_0=0.000000
# Converged after 0 iterations: mu=2.0500
# Iteration 0: mu=2.0500, value_0=-113.174809
# Stopped after 9 iterations: mu=1.0064, value_0=-0.139220
# Iteration 0: mu=2.0500, value_0=80.816708
# Stopped after 9 iterations: mu=2.4842, value_0=0.280353
# Iteration 0: mu=2.0500, value_0=357.021680
# Stopped after 9 iterations: mu=3.9924, value_0=383.906768
# Iteration 0: mu=2.0500, value_0=176.173266
# Stopped after 9 iterations: mu=3.9924, value_0=422.986937
# Iteration 0: mu=2.0500, value_0=50.705569
# Stopped after 9 iterations: mu=3.9924, value_0=233.110686
# Iteration 0: mu=2.0500, value_0=16.789456
# Stopped after 9 iterations: mu=3.9924, value_0=148.629588
# Iteration 0: mu=2.0500, value_0=5.271937
# Stopped after 9 iterations: mu=3.9924, value_0=91.015414
# Iteration 0: mu=2.0500, value_0=1.262180
# Stopped after 9 iterations: mu=3.9924, value_0=41.704963
# Iteration 0: mu=2.0500, value_0=0.217149
# Stopped after 9 iterations: mu=3.9924, value_0=13.929130
# Iteration 0: mu=2.0500, value_0=0.054904
# Stopped after 9 iterations: mu=3.9924, value_0=6.822432
# Iteration 0: mu=2.0500, value_0=0.008749
# Converged after 0 iterations: mu=2.0500
# Iteration 0: mu=2.0500, value_0=0.001316
# Converged after 0 iterations: mu=2.0500
# Iteration 0: mu=2.0500, value_0=0.000181
# Converged after 0 iterations: mu=2.0500
# Iteration 0: mu=2.0500, value_0=0.000029
# Converged after 0 iterations: mu=2.0500
# Iteration 0: mu=2.0500, value_0=0.000003
# Converged after 0 iterations: mu=2.0500
# Iteration 0: mu=2.0500, value_0=0.000000
# Converged after 0 iterations: mu=2.0500
# Iteration 0: mu=2.0500, value_0=0.000000
# Converged after 0 iterations: mu=2.0500
# Iteration 0: mu=2.0500, value_0=0.000000
# Converged after 0 iterations: mu=2.0500
# Iteration 0: mu=2.0500, value_0=0.000000
# Converged after 0 iterations: mu=2.0500
# Iteration 0: mu=2.0500, value_0=0.000000
# Converged after 0 iterations: mu=2.0500
# Iteration 0: mu=2.0500, value_0=0.000000
# Converged after 0 iterations: mu=2.0500
# Iteration 0: mu=2.0500, value_0=0.000000
# Converged after 0 iterations: mu=2.0500
# Iteration 0: mu=2.0500, value_0=72.819736
# Stopped after 9 iterations: mu=2.4689, value_0=0.286747
# Iteration 0: mu=2.0500, value_0=333.169333
# Stopped after 9 iterations: mu=3.9924, value_0=337.134919
# Iteration 0: mu=2.0500, value_0=168.805165
# Stopped after 9 iterations: mu=3.9924, value_0=409.082284
# Iteration 0: mu=2.0500, value_0=59.666845
# Stopped after 9 iterations: mu=3.9924, value_0=282.947094
# Iteration 0: mu=2.0500, value_0=17.237922
# Stopped after 9 iterations: mu=3.9924, value_0=151.707133
# Iteration 0: mu=2.0500, value_0=5.923000
# Stopped after 9 iterations: mu=3.9924, value_0=103.122857
# Iteration 0: mu=2.0500, value_0=1.316122
# Stopped after 9 iterations: mu=3.9924, value_0=44.016833
# Iteration 0: mu=2.0500, value_0=0.317575
# Stopped after 9 iterations: mu=3.9924, value_0=20.399465
# Iteration 0: mu=2.0500, value_0=0.049424
# Stopped after 9 iterations: mu=3.9924, value_0=6.050982
# Iteration 0: mu=2.0500, value_0=0.006421
# Converged after 0 iterations: mu=2.0500
# Iteration 0: mu=2.0500, value_0=0.001326
# Converged after 0 iterations: mu=2.0500
# Iteration 0: mu=2.0500, value_0=0.000121
# Converged after 0 iterations: mu=2.0500
# Iteration 0: mu=2.0500, value_0=0.000025
# Converged after 0 iterations: mu=2.0500
# Iteration 0: mu=2.0500, value_0=0.000004
# Converged after 0 iterations: mu=2.0500
# Iteration 0: mu=2.0500, value_0=0.000000
# Converged after 0 iterations: mu=2.0500
# Iteration 0: mu=2.0500, value_0=0.000000
# Converged after 0 iterations: mu=2.0500
# Iteration 0: mu=2.0500, value_0=0.000000
# Converged after 0 iterations: mu=2.0500
# Iteration 0: mu=2.0500, value_0=0.000000
# Converged after 0 iterations: mu=2.0500
# Iteration 0: mu=2.0500, value_0=0.000000
# Converged after 0 iterations: mu=2.0500
# Iteration 0: mu=2.0500, value_0=0.000000
# Converged after 0 iterations: mu=2.0500
# Iteration 0: mu=2.0500, value_0=0.000000
# Converged after 0 iterations: mu=2.0500
# Iteration 0: mu=2.0500, value_0=0.000000
# Converged after 0 iterations: mu=2.0500
# Iteration 0: mu=2.0500, value_0=110.109763
# Stopped after 9 iterations: mu=2.6822, value_0=-0.159989
# Iteration 0: mu=2.0500, value_0=339.595340
# Stopped after 9 iterations: mu=3.9924, value_0=314.927994
# Iteration 0: mu=2.0500, value_0=165.476202
# Stopped after 9 iterations: mu=3.9924, value_0=391.219902
# Iteration 0: mu=2.0500, value_0=63.240387
# Stopped after 9 iterations: mu=3.9924, value_0=291.176884
# Iteration 0: mu=2.0500, value_0=16.956995
# Stopped after 9 iterations: mu=3.9924, value_0=152.371653
# Iteration 0: mu=2.0500, value_0=5.419648
# Stopped after 9 iterations: mu=3.9924, value_0=93.893800
# Iteration 0: mu=2.0500, value_0=1.405226
# Stopped after 9 iterations: mu=3.9924, value_0=47.089982
# Iteration 0: mu=2.0500, value_0=0.284223
# Stopped after 9 iterations: mu=3.9924, value_0=18.160341
# Iteration 0: mu=2.0500, value_0=0.049939
# Stopped after 9 iterations: mu=3.9924, value_0=6.139272
# Iteration 0: mu=2.0500, value_0=0.009872
# Converged after 0 iterations: mu=2.0500
# Iteration 0: mu=2.0500, value_0=0.001457
# Converged after 0 iterations: mu=2.0500
# Iteration 0: mu=2.0500, value_0=0.000225
# Converged after 0 iterations: mu=2.0500
# Iteration 0: mu=2.0500, value_0=0.000029
# Converged after 0 iterations: mu=2.0500
# Iteration 0: mu=2.0500, value_0=0.000003
# Converged after 0 iterations: mu=2.0500
# Iteration 0: mu=2.0500, value_0=0.000000
# Converged after 0 iterations: mu=2.0500
# Iteration 0: mu=2.0500, value_0=0.000000
# Converged after 0 iterations: mu=2.0500
# Iteration 0: mu=2.0500, value_0=0.000000
# Converged after 0 iterations: mu=2.0500
# Iteration 0: mu=2.0500, value_0=0.000000
# Converged after 0 iterations: mu=2.0500
# Iteration 0: mu=2.0500, value_0=0.000000
# Converged after 0 iterations: mu=2.0500
# Iteration 0: mu=2.0500, value_0=0.000000
# Converged after 0 iterations: mu=2.0500
# Iteration 0: mu=2.0500, value_0=0.000000
# Converged after 0 iterations: mu=2.0500
# Iteration 0: mu=2.0500, value_0=-128.726891
# Stopped after 9 iterations: mu=1.0064, value_0=-0.208740
# Iteration 0: mu=2.0500, value_0=105.521910
# Stopped after 9 iterations: mu=2.6518, value_0=0.544714
# Iteration 0: mu=2.0500, value_0=341.198204
# Stopped after 9 iterations: mu=3.9924, value_0=330.441360
# Iteration 0: mu=2.0500, value_0=165.475057
# Stopped after 9 iterations: mu=3.9924, value_0=387.296565
# Iteration 0: mu=2.0500, value_0=59.474260
# Stopped after 9 iterations: mu=3.9924, value_0=272.109081
# Iteration 0: mu=2.0500, value_0=13.455670
# Stopped after 9 iterations: mu=3.9924, value_0=120.557217
# Iteration 0: mu=2.0500, value_0=4.992632
# Stopped after 9 iterations: mu=3.9924, value_0=86.092509
# Iteration 0: mu=2.0500, value_0=1.549554
# Stopped after 9 iterations: mu=3.9924, value_0=51.481416
# Iteration 0: mu=2.0500, value_0=0.300618
# Stopped after 9 iterations: mu=3.9924, value_0=19.245131
# Iteration 0: mu=2.0500, value_0=0.060766
# Stopped after 9 iterations: mu=3.9924, value_0=7.474460
# Iteration 0: mu=2.0500, value_0=0.005801
# Converged after 0 iterations: mu=2.0500
# Iteration 0: mu=2.0500, value_0=0.001578
# Converged after 0 iterations: mu=2.0500
# Iteration 0: mu=2.0500, value_0=0.000242
# Converged after 0 iterations: mu=2.0500
# Iteration 0: mu=2.0500, value_0=0.000027
# Converged after 0 iterations: mu=2.0500
# Iteration 0: mu=2.0500, value_0=0.000005
# Converged after 0 iterations: mu=2.0500
# Iteration 0: mu=2.0500, value_0=0.000000
# Converged after 0 iterations: mu=2.0500
# Iteration 0: mu=2.0500, value_0=0.000000
# Converged after 0 iterations: mu=2.0500
# Iteration 0: mu=2.0500, value_0=0.000000
# Converged after 0 iterations: mu=2.0500
# Iteration 0: mu=2.0500, value_0=0.000000
# Converged after 0 iterations: mu=2.0500
# Iteration 0: mu=2.0500, value_0=0.000000
# Converged after 0 iterations: mu=2.0500
# Iteration 0: mu=2.0500, value_0=0.000000
# Converged after 0 iterations: mu=2.0500
# Iteration 0: mu=2.0500, value_0=0.000000
# Converged after 0 iterations: mu=2.0500
# Iteration 0: mu=2.0500, value_0=0.000000
# Converged after 0 iterations: mu=2.0500
# Iteration 0: mu=2.0500, value_0=0.000000
# Converged after 0 iterations: mu=2.0500
# Iteration 0: mu=2.0500, value_0=-112.259981
# Stopped after 9 iterations: mu=1.0064, value_0=-0.135130
# Iteration 0: mu=2.0500, value_0=107.846715
# Stopped after 9 iterations: mu=2.7432, value_0=0.269027
# Iteration 0: mu=2.0500, value_0=380.193940
# Stopped after 9 iterations: mu=3.9924, value_0=418.428096
# Iteration 0: mu=2.0500, value_0=179.693335
# Stopped after 9 iterations: mu=3.9924, value_0=436.699135
# Iteration 0: mu=2.0500, value_0=70.117693
# Stopped after 9 iterations: mu=3.9924, value_0=335.903441
# Iteration 0: mu=2.0500, value_0=15.174646
# Stopped after 9 iterations: mu=3.9924, value_0=137.894867
# Iteration 0: mu=2.0500, value_0=5.311374
# Stopped after 9 iterations: mu=3.9924, value_0=91.591621
# Iteration 0: mu=2.0500, value_0=1.471522
# Stopped after 9 iterations: mu=3.9924, value_0=49.082151
# Iteration 0: mu=2.0500, value_0=0.269491
# Stopped after 9 iterations: mu=3.9924, value_0=17.371155
# Iteration 0: mu=2.0500, value_0=0.049373
# Stopped after 9 iterations: mu=3.9924, value_0=6.074956
# Iteration 0: mu=2.0500, value_0=0.008742
# Converged after 0 iterations: mu=2.0500
# Iteration 0: mu=2.0500, value_0=0.001468
# Converged after 0 iterations: mu=2.0500
# Iteration 0: mu=2.0500, value_0=0.000181
# Converged after 0 iterations: mu=2.0500
# Iteration 0: mu=2.0500, value_0=0.000025
# Converged after 0 iterations: mu=2.0500
# Iteration 0: mu=2.0500, value_0=0.000004
# Converged after 0 iterations: mu=2.0500
# Iteration 0: mu=2.0500, value_0=0.000000
# Converged after 0 iterations: mu=2.0500
# Iteration 0: mu=2.0500, value_0=0.000000
# Converged after 0 iterations: mu=2.0500
# Iteration 0: mu=2.0500, value_0=0.000000
# Converged after 0 iterations: mu=2.0500
# Iteration 0: mu=2.0500, value_0=0.000000
# Converged after 0 iterations: mu=2.0500
# Iteration 0: mu=2.0500, value_0=0.000000
# Converged after 0 iterations: mu=2.0500
# Iteration 0: mu=2.0500, value_0=0.000000
# Converged after 0 iterations: mu=2.0500
# Iteration 0: mu=2.0500, value_0=196.591749
# Stopped after 9 iterations: mu=3.2002, value_0=-1.592809
# Iteration 0: mu=2.0500, value_0=356.699883
# Stopped after 9 iterations: mu=3.9924, value_0=376.166134
# Iteration 0: mu=2.0500, value_0=177.642296
# Stopped after 9 iterations: mu=3.9924, value_0=429.702230
# Iteration 0: mu=2.0500, value_0=51.229858
# Stopped after 9 iterations: mu=3.9924, value_0=233.803826
# Iteration 0: mu=2.0500, value_0=17.487166
# Stopped after 9 iterations: mu=3.9924, value_0=158.626200
# Iteration 0: mu=2.0500, value_0=4.734526
# Stopped after 9 iterations: mu=3.9924, value_0=81.325371
# Iteration 0: mu=2.0500, value_0=1.497752
# Stopped after 9 iterations: mu=3.9924, value_0=50.180958
# Iteration 0: mu=2.0500, value_0=0.320655
# Stopped after 9 iterations: mu=3.9924, value_0=20.704104
# Iteration 0: mu=2.0500, value_0=0.054161
# Stopped after 9 iterations: mu=3.9924, value_0=6.702014
# Iteration 0: mu=2.0500, value_0=0.007211
# Converged after 0 iterations: mu=2.0500
# Iteration 0: mu=2.0500, value_0=0.001363
# Converged after 0 iterations: mu=2.0500
# Iteration 0: mu=2.0500, value_0=0.000156
# Converged after 0 iterations: mu=2.0500
# Iteration 0: mu=2.0500, value_0=0.000023
# Converged after 0 iterations: mu=2.0500
# Iteration 0: mu=2.0500, value_0=0.000004
# Converged after 0 iterations: mu=2.0500
# Iteration 0: mu=2.0500, value_0=0.000000
# Converged after 0 iterations: mu=2.0500
# Iteration 0: mu=2.0500, value_0=0.000000
# Converged after 0 iterations: mu=2.0500
# Iteration 0: mu=2.0500, value_0=0.000000
# Converged after 0 iterations: mu=2.0500
# Iteration 0: mu=2.0500, value_0=0.000000
# Converged after 0 iterations: mu=2.0500
# Iteration 0: mu=2.0500, value_0=0.000000
# Converged after 0 iterations: mu=2.0500
# Iteration 0: mu=2.0500, value_0=0.000000
# Converged after 0 iterations: mu=2.0500
# Iteration 0: mu=2.0500, value_0=0.000000
# Converged after 0 iterations: mu=2.0500
# Iteration 0: mu=2.0500, value_0=-111.345152
# Stopped after 9 iterations: mu=1.0064, value_0=-0.131041
# Iteration 0: mu=2.0500, value_0=239.276039
# Stopped after 9 iterations: mu=3.3678, value_0=-1.708468
# Iteration 0: mu=2.0500, value_0=360.081187
# Stopped after 9 iterations: mu=3.9924, value_0=434.786309
# Iteration 0: mu=2.0500, value_0=182.439349
# Stopped after 9 iterations: mu=3.9924, value_0=463.525360
# Iteration 0: mu=2.0500, value_0=46.565562
# Stopped after 9 iterations: mu=3.9924, value_0=225.683074
# Iteration 0: mu=2.0500, value_0=16.992260
# Stopped after 9 iterations: mu=3.9924, value_0=152.315182
# Iteration 0: mu=2.0500, value_0=5.984799
# Stopped after 9 iterations: mu=3.9924, value_0=103.714487
# Iteration 0: mu=2.0500, value_0=1.744676
# Stopped after 9 iterations: mu=3.9924, value_0=58.458188
# Iteration 0: mu=2.0500, value_0=0.272210
# Stopped after 9 iterations: mu=3.9924, value_0=17.573172
# Iteration 0: mu=2.0500, value_0=0.041563
# Stopped after 9 iterations: mu=3.9924, value_0=5.126084
# Iteration 0: mu=2.0500, value_0=0.007775
# Converged after 0 iterations: mu=2.0500
# Iteration 0: mu=2.0500, value_0=0.001296
# Converged after 0 iterations: mu=2.0500
# Iteration 0: mu=2.0500, value_0=0.000160
# Converged after 0 iterations: mu=2.0500
# Iteration 0: mu=2.0500, value_0=0.000019
# Converged after 0 iterations: mu=2.0500
# Iteration 0: mu=2.0500, value_0=0.000002
# Converged after 0 iterations: mu=2.0500
# Iteration 0: mu=2.0500, value_0=0.000000
# Converged after 0 iterations: mu=2.0500
# Iteration 0: mu=2.0500, value_0=0.000000
# Converged after 0 iterations: mu=2.0500
# Iteration 0: mu=2.0500, value_0=0.000000
# Converged after 0 iterations: mu=2.0500
# Iteration 0: mu=2.0500, value_0=0.000000
# Converged after 0 iterations: mu=2.0500
# Iteration 0: mu=2.0500, value_0=0.000000
# Converged after 0 iterations: mu=2.0500
# Iteration 0: mu=2.0500, value_0=0.000000
# Converged after 0 iterations: mu=2.0500
# Iteration 0: mu=2.0500, value_0=0.000000
# Converged after 0 iterations: mu=2.0500
# Iteration 0: mu=2.0500, value_0=248.155978
# Stopped after 9 iterations: mu=3.5049, value_0=1.393946
# Iteration 0: mu=2.0500, value_0=316.095670
# Stopped after 9 iterations: mu=3.9924, value_0=352.307307
# Iteration 0: mu=2.0500, value_0=181.316508
# Stopped after 9 iterations: mu=3.9924, value_0=452.924795
# Iteration 0: mu=2.0500, value_0=52.819962
# Stopped after 9 iterations: mu=3.9924, value_0=248.240768
# Iteration 0: mu=2.0500, value_0=19.493518
# Stopped after 9 iterations: mu=3.9924, value_0=176.944348
# Iteration 0: mu=2.0500, value_0=5.019421
# Stopped after 9 iterations: mu=3.9924, value_0=88.386457
# Iteration 0: mu=2.0500, value_0=1.148116
# Stopped after 9 iterations: mu=3.9924, value_0=37.823045
# Iteration 0: mu=2.0500, value_0=0.224043
# Stopped after 9 iterations: mu=3.9924, value_0=14.490646
# Iteration 0: mu=2.0500, value_0=0.045475
# Stopped after 9 iterations: mu=3.9924, value_0=5.640526
# Iteration 0: mu=2.0500, value_0=0.007413
# Converged after 0 iterations: mu=2.0500
# Iteration 0: mu=2.0500, value_0=0.001465
# Converged after 0 iterations: mu=2.0500
# Iteration 0: mu=2.0500, value_0=0.000155
# Converged after 0 iterations: mu=2.0500
# Iteration 0: mu=2.0500, value_0=0.000002
# Converged after 0 iterations: mu=2.0500
# Iteration 0: mu=2.0500, value_0=0.000001
# Converged after 0 iterations: mu=2.0500
# Iteration 0: mu=2.0500, value_0=0.000000
# Converged after 0 iterations: mu=2.0500
# Iteration 0: mu=2.0500, value_0=0.000000
# Converged after 0 iterations: mu=2.0500
# Iteration 0: mu=2.0500, value_0=0.000000
# Converged after 0 iterations: mu=2.0500
# Iteration 0: mu=2.0500, value_0=0.000000
# Converged after 0 iterations: mu=2.0500
# Iteration 0: mu=2.0500, value_0=0.000000
# Converged after 0 iterations: mu=2.0500
# Iteration 0: mu=2.0500, value_0=-112.259981
# Stopped after 9 iterations: mu=1.0064, value_0=-0.135130
# Iteration 0: mu=2.0500, value_0=204.580810
# Stopped after 9 iterations: mu=3.2154, value_0=-1.485035
# Iteration 0: mu=2.0500, value_0=320.081523
# Stopped after 9 iterations: mu=3.9924, value_0=364.332007
# Iteration 0: mu=2.0500, value_0=176.223242
# Stopped after 9 iterations: mu=3.9924, value_0=432.266153
# Iteration 0: mu=2.0500, value_0=61.243206
# Stopped after 9 iterations: mu=3.9924, value_0=296.727226
# Iteration 0: mu=2.0500, value_0=19.617851
# Stopped after 9 iterations: mu=3.9924, value_0=178.130296
# Iteration 0: mu=2.0500, value_0=5.822872
# Stopped after 9 iterations: mu=3.9924, value_0=101.961895
# Iteration 0: mu=2.0500, value_0=1.514832
# Stopped after 9 iterations: mu=3.9924, value_0=50.622065
# Iteration 0: mu=2.0500, value_0=0.176192
# Stopped after 9 iterations: mu=3.9924, value_0=11.287749
# Iteration 0: mu=2.0500, value_0=0.040547
# Stopped after 9 iterations: mu=3.9924, value_0=5.029517
# Iteration 0: mu=2.0500, value_0=0.009383
# Converged after 0 iterations: mu=2.0500
# Iteration 0: mu=2.0500, value_0=0.001369
# Converged after 0 iterations: mu=2.0500
# Iteration 0: mu=2.0500, value_0=0.000139
# Converged after 0 iterations: mu=2.0500
# Iteration 0: mu=2.0500, value_0=0.000018
# Converged after 0 iterations: mu=2.0500
# Iteration 0: mu=2.0500, value_0=0.000003
# Converged after 0 iterations: mu=2.0500
# Iteration 0: mu=2.0500, value_0=0.000000
# Converged after 0 iterations: mu=2.0500
# Iteration 0: mu=2.0500, value_0=0.000000
# Converged after 0 iterations: mu=2.0500
# Iteration 0: mu=2.0500, value_0=0.000000
# Converged after 0 iterations: mu=2.0500
# Iteration 0: mu=2.0500, value_0=0.000000
# Converged after 0 iterations: mu=2.0500
# Iteration 0: mu=2.0500, value_0=0.000000
# Converged after 0 iterations: mu=2.0500
# Iteration 0: mu=2.0500, value_0=0.000000
# Converged after 0 iterations: mu=2.0500
# Iteration 0: mu=2.0500, value_0=190.941018
# Stopped after 9 iterations: mu=3.0936, value_0=1.209403
# Iteration 0: mu=2.0500, value_0=375.764817
# Stopped after 9 iterations: mu=3.9924, value_0=426.166206
# Iteration 0: mu=2.0500, value_0=180.430633
# Stopped after 9 iterations: mu=3.9924, value_0=450.414451
# Iteration 0: mu=2.0500, value_0=47.861973
# Stopped after 9 iterations: mu=3.9924, value_0=229.300145
# Iteration 0: mu=2.0500, value_0=17.261319
# Stopped after 9 iterations: mu=3.9924, value_0=153.933373
# Iteration 0: mu=2.0500, value_0=5.503365
# Stopped after 9 iterations: mu=3.9924, value_0=95.445196
# Iteration 0: mu=2.0500, value_0=1.321205
# Stopped after 9 iterations: mu=3.9924, value_0=43.766616
# Iteration 0: mu=2.0500, value_0=0.300371
# Stopped after 9 iterations: mu=3.9924, value_0=19.377604
# Iteration 0: mu=2.0500, value_0=0.045889
# Stopped after 9 iterations: mu=3.9924, value_0=5.716822
# Iteration 0: mu=2.0500, value_0=0.007420
# Converged after 0 iterations: mu=2.0500
# Iteration 0: mu=2.0500, value_0=0.000951
# Converged after 0 iterations: mu=2.0500
# Iteration 0: mu=2.0500, value_0=0.000166
# Converged after 0 iterations: mu=2.0500
# Iteration 0: mu=2.0500, value_0=0.000025
# Converged after 0 iterations: mu=2.0500
# Iteration 0: mu=2.0500, value_0=0.000003
# Converged after 0 iterations: mu=2.0500
# Iteration 0: mu=2.0500, value_0=0.000000
# Converged after 0 iterations: mu=2.0500
# Iteration 0: mu=2.0500, value_0=0.000000
# Converged after 0 iterations: mu=2.0500
# Iteration 0: mu=2.0500, value_0=0.000000
# Converged after 0 iterations: mu=2.0500
# Iteration 0: mu=2.0500, value_0=0.000000
# Converged after 0 iterations: mu=2.0500
# Iteration 0: mu=2.0500, value_0=0.000000
# Converged after 0 iterations: mu=2.0500
# Iteration 0: mu=2.0500, value_0=0.000000
# Converged after 0 iterations: mu=2.0500
# Iteration 0: mu=2.0500, value_0=0.000000
# Converged after 0 iterations: mu=2.0500
# Iteration 0: mu=2.0500, value_0=-122.974014
# Stopped after 9 iterations: mu=1.0064, value_0=0.183668
# Iteration 0: mu=2.0500, value_0=172.615378
# Stopped after 9 iterations: mu=3.1545, value_0=-0.468491
# Iteration 0: mu=2.0500, value_0=359.230119
# Stopped after 9 iterations: mu=3.9924, value_0=397.175690
# Iteration 0: mu=2.0500, value_0=185.914907
# Stopped after 9 iterations: mu=3.9924, value_0=482.089284
# Iteration 0: mu=2.0500, value_0=49.963331
# Stopped after 9 iterations: mu=3.9924, value_0=233.985663
# Iteration 0: mu=2.0500, value_0=16.243735
# Stopped after 9 iterations: mu=3.9924, value_0=145.625044
# Iteration 0: mu=2.0500, value_0=5.388006
# Stopped after 9 iterations: mu=3.9924, value_0=93.812708
# Iteration 0: mu=2.0500, value_0=1.548774
# Stopped after 9 iterations: mu=3.9924, value_0=51.553317
# Iteration 0: mu=2.0500, value_0=0.304752
# Stopped after 9 iterations: mu=3.9924, value_0=19.676757
# Iteration 0: mu=2.0500, value_0=0.042845
# Stopped after 9 iterations: mu=3.9924, value_0=5.226735
# Iteration 0: mu=2.0500, value_0=0.006751
# Converged after 0 iterations: mu=2.0500
# Iteration 0: mu=2.0500, value_0=0.001361
# Converged after 0 iterations: mu=2.0500
# Iteration 0: mu=2.0500, value_0=0.000189
# Converged after 0 iterations: mu=2.0500
# Iteration 0: mu=2.0500, value_0=0.000021
# Converged after 0 iterations: mu=2.0500
# Iteration 0: mu=2.0500, value_0=0.000002
# Converged after 0 iterations: mu=2.0500
# Iteration 0: mu=2.0500, value_0=0.000000
# Converged after 0 iterations: mu=2.0500
# Iteration 0: mu=2.0500, value_0=0.000000
# Converged after 0 iterations: mu=2.0500
# Iteration 0: mu=2.0500, value_0=0.000000
# Converged after 0 iterations: mu=2.0500
# Iteration 0: mu=2.0500, value_0=0.000000
# Converged after 0 iterations: mu=2.0500
# Iteration 0: mu=2.0500, value_0=0.000000
# Converged after 0 iterations: mu=2.0500
# Iteration 0: mu=2.0500, value_0=-97.358820
# Stopped after 9 iterations: mu=1.0064, value_0=0.298173
# Iteration 0: mu=2.0500, value_0=176.833202
# Stopped after 9 iterations: mu=3.1393, value_0=-0.679339
# Iteration 0: mu=2.0500, value_0=339.614479
# Stopped after 9 iterations: mu=3.9924, value_0=376.669350
# Iteration 0: mu=2.0500, value_0=193.874754
# Stopped after 9 iterations: mu=3.9924, value_0=484.396159
# Iteration 0: mu=2.0500, value_0=46.640356
# Stopped after 9 iterations: mu=3.9924, value_0=227.175808
# Iteration 0: mu=2.0500, value_0=16.098204
# Stopped after 9 iterations: mu=3.9924, value_0=144.283329
# Iteration 0: mu=2.0500, value_0=5.632847
# Stopped after 9 iterations: mu=3.9924, value_0=97.542335
# Iteration 0: mu=2.0500, value_0=1.359062
# Stopped after 9 iterations: mu=3.9924, value_0=45.636119
# Iteration 0: mu=2.0500, value_0=0.265470
# Stopped after 9 iterations: mu=3.9924, value_0=17.077973
# Iteration 0: mu=2.0500, value_0=0.055963
# Stopped after 9 iterations: mu=3.9924, value_0=6.963213
# Iteration 0: mu=2.0500, value_0=0.008404
# Converged after 0 iterations: mu=2.0500
# Iteration 0: mu=2.0500, value_0=0.001507
# Converged after 0 iterations: mu=2.0500
# Iteration 0: mu=2.0500, value_0=0.000147
# Converged after 0 iterations: mu=2.0500
# Iteration 0: mu=2.0500, value_0=0.000021
# Converged after 0 iterations: mu=2.0500
# Iteration 0: mu=2.0500, value_0=0.000003
# Converged after 0 iterations: mu=2.0500
# Iteration 0: mu=2.0500, value_0=0.000000
# Converged after 0 iterations: mu=2.0500
# Iteration 0: mu=2.0500, value_0=0.000000
# Converged after 0 iterations: mu=2.0500
# Iteration 0: mu=2.0500, value_0=0.000000
# Converged after 0 iterations: mu=2.0500
# Iteration 0: mu=2.0500, value_0=-136.045518
# Stopped after 9 iterations: mu=1.0064, value_0=-0.241456
# Iteration 0: mu=2.0500, value_0=136.467082
# Stopped after 9 iterations: mu=2.9260, value_0=-0.210619
# Iteration 0: mu=2.0500, value_0=338.571252
# Stopped after 9 iterations: mu=3.9924, value_0=352.593695
# Iteration 0: mu=2.0500, value_0=167.667329
# Stopped after 9 iterations: mu=3.9924, value_0=409.398958
# Iteration 0: mu=2.0500, value_0=46.129178
# Stopped after 9 iterations: mu=3.9924, value_0=216.175300
# Iteration 0: mu=2.0500, value_0=17.847137
# Stopped after 9 iterations: mu=3.9924, value_0=162.338275
# Iteration 0: mu=2.0500, value_0=5.235775
# Stopped after 9 iterations: mu=3.9924, value_0=90.246242
# Iteration 0: mu=2.0500, value_0=1.303321
# Stopped after 9 iterations: mu=3.9924, value_0=43.629698
# Iteration 0: mu=2.0500, value_0=0.235414
# Stopped after 9 iterations: mu=3.9924, value_0=15.249176
# Iteration 0: mu=2.0500, value_0=0.048068
# Stopped after 9 iterations: mu=3.9924, value_0=5.962479
# Iteration 0: mu=2.0500, value_0=0.008149
# Converged after 0 iterations: mu=2.0500
# Iteration 0: mu=2.0500, value_0=0.001477
# Converged after 0 iterations: mu=2.0500
# Iteration 0: mu=2.0500, value_0=0.000216
# Converged after 0 iterations: mu=2.0500
# Iteration 0: mu=2.0500, value_0=0.000019
# Converged after 0 iterations: mu=2.0500
# Iteration 0: mu=2.0500, value_0=0.000004
# Converged after 0 iterations: mu=2.0500
# Iteration 0: mu=2.0500, value_0=0.000000
# Converged after 0 iterations: mu=2.0500
# Iteration 0: mu=2.0500, value_0=0.000000
# Converged after 0 iterations: mu=2.0500
# Iteration 0: mu=2.0500, value_0=0.000000
# Converged after 0 iterations: mu=2.0500
# Iteration 0: mu=2.0500, value_0=0.000000
# Converged after 0 iterations: mu=2.0500
# Iteration 0: mu=2.0500, value_0=0.000000
# Converged after 0 iterations: mu=2.0500
# Iteration 0: mu=2.0500, value_0=0.000000
# Converged after 0 iterations: mu=2.0500
# Iteration 0: mu=2.0500, value_0=-115.004466
# Stopped after 9 iterations: mu=1.0064, value_0=-0.147399
# Iteration 0: mu=2.0500, value_0=120.497891
# Stopped after 9 iterations: mu=2.8346, value_0=-1.047020
# Iteration 0: mu=2.0500, value_0=335.664097
# Stopped after 9 iterations: mu=3.9924, value_0=376.171792
# Iteration 0: mu=2.0500, value_0=185.004983
# Stopped after 9 iterations: mu=3.9924, value_0=465.693876
# Iteration 0: mu=2.0500, value_0=53.072892
# Stopped after 9 iterations: mu=3.9924, value_0=255.341454
# Iteration 0: mu=2.0500, value_0=16.719281
# Stopped after 9 iterations: mu=3.9924, value_0=149.961537
# Iteration 0: mu=2.0500, value_0=5.821239
# Stopped after 9 iterations: mu=3.9924, value_0=101.877974
# Iteration 0: mu=2.0500, value_0=1.460179
# Stopped after 9 iterations: mu=3.9924, value_0=48.363395
# Iteration 0: mu=2.0500, value_0=0.314331
# Stopped after 9 iterations: mu=3.9924, value_0=20.383331
# Iteration 0: mu=2.0500, value_0=0.035823
# Stopped after 9 iterations: mu=3.9924, value_0=4.382555
# Iteration 0: mu=2.0500, value_0=0.008559
# Converged after 0 iterations: mu=2.0500
# Iteration 0: mu=2.0500, value_0=0.001394
# Converged after 0 iterations: mu=2.0500
# Iteration 0: mu=2.0500, value_0=0.000097
# Converged after 0 iterations: mu=2.0500
# Iteration 0: mu=2.0500, value_0=0.000030
# Converged after 0 iterations: mu=2.0500
# Iteration 0: mu=2.0500, value_0=0.000003
# Converged after 0 iterations: mu=2.0500
# Iteration 0: mu=2.0500, value_0=0.000000
# Converged after 0 iterations: mu=2.0500
# Iteration 0: mu=2.0500, value_0=0.000000
# Converged after 0 iterations: mu=2.0500
# Iteration 0: mu=2.0500, value_0=0.000000
# Converged after 0 iterations: mu=2.0500
# Iteration 0: mu=2.0500, value_0=0.000000
# Converged after 0 iterations: mu=2.0500
# Iteration 0: mu=2.0500, value_0=0.000000
# Converged after 0 iterations: mu=2.0500
# Iteration 0: mu=2.0500, value_0=0.000000
# Converged after 0 iterations: mu=2.0500
# Iteration 0: mu=2.0500, value_0=0.000000
# Converged after 0 iterations: mu=2.0500
# Iteration 0: mu=2.0500, value_0=180.521246
# Stopped after 9 iterations: mu=3.1850, value_0=1.277271
# Iteration 0: mu=2.0500, value_0=291.090361
# Stopped after 9 iterations: mu=3.9924, value_0=290.074053
# Iteration 0: mu=2.0500, value_0=98.852334
# Stopped after 9 iterations: mu=3.9924, value_0=207.843530
# Iteration 0: mu=2.0500, value_0=16.906333
# Stopped after 9 iterations: mu=3.9924, value_0=55.096792
# Iteration 0: mu=2.0500, value_0=7.376913
# Stopped after 9 iterations: mu=3.9924, value_0=55.190033
# Iteration 0: mu=2.0500, value_0=3.166415
# Stopped after 9 iterations: mu=3.9924, value_0=51.060250
# Iteration 0: mu=2.0500, value_0=0.990692
# Stopped after 9 iterations: mu=3.9924, value_0=31.941202
# Iteration 0: mu=2.0500, value_0=0.181526
# Stopped after 9 iterations: mu=3.9924, value_0=11.220621
# Iteration 0: mu=2.0500, value_0=0.042948
# Stopped after 9 iterations: mu=3.9924, value_0=5.139411
# Iteration 0: mu=2.0500, value_0=0.010647
# Stopped after 9 iterations: mu=3.9924, value_0=2.480248
# Iteration 0: mu=2.0500, value_0=0.001516
# Converged after 0 iterations: mu=2.0500
# Iteration 0: mu=2.0500, value_0=0.000204
# Converged after 0 iterations: mu=2.0500
# Iteration 0: mu=2.0500, value_0=0.000034
# Converged after 0 iterations: mu=2.0500
# Iteration 0: mu=2.0500, value_0=0.000004
# Converged after 0 iterations: mu=2.0500
# Iteration 0: mu=2.0500, value_0=0.000001
# Converged after 0 iterations: mu=2.0500
# Iteration 0: mu=2.0500, value_0=0.000000
# Converged after 0 iterations: mu=2.0500
# Iteration 0: mu=2.0500, value_0=0.000000
# Converged after 0 iterations: mu=2.0500
# Iteration 0: mu=2.0500, value_0=0.000000
# Converged after 0 iterations: mu=2.0500
# Iteration 0: mu=2.0500, value_0=0.000000
# Converged after 0 iterations: mu=2.0500
# Iteration 0: mu=2.0500, value_0=0.000000
# Converged after 0 iterations: mu=2.0500
# Iteration 0: mu=2.0500, value_0=0.000000
# Converged after 0 iterations: mu=2.0500
# Iteration 0: mu=2.0500, value_0=0.000000
# Converged after 0 iterations: mu=2.0500
# Iteration 0: mu=2.0500, value_0=0.000000
# Converged after 0 iterations: mu=2.0500
# Iteration 0: mu=2.0500, value_0=0.000000
# Converged after 0 iterations: mu=2.0500
# Iteration 0: mu=2.0500, value_0=0.000000
# Converged after 0 iterations: mu=2.0500
# Iteration 0: mu=2.0500, value_0=0.000000
# Converged after 0 iterations: mu=2.0500
# Iteration 0: mu=2.0500, value_0=0.000000
# Converged after 0 iterations: mu=2.0500
# Iteration 0: mu=2.0500, value_0=174.095495
# Stopped after 9 iterations: mu=3.0174, value_0=-1.352516
# Iteration 0: mu=2.0500, value_0=305.205067
# Stopped after 9 iterations: mu=3.9924, value_0=337.166833
# Iteration 0: mu=2.0500, value_0=155.235269
# Stopped after 9 iterations: mu=3.9924, value_0=389.682876
# Iteration 0: mu=2.0500, value_0=59.782849
# Stopped after 9 iterations: mu=3.9924, value_0=289.637481
# Iteration 0: mu=2.0500, value_0=14.625122
# Stopped after 9 iterations: mu=3.9924, value_0=133.671130
# Iteration 0: mu=2.0500, value_0=5.240083
# Stopped after 9 iterations: mu=3.9924, value_0=90.928983
# Iteration 0: mu=2.0500, value_0=1.578246
# Stopped after 9 iterations: mu=3.9924, value_0=53.052254
# Iteration 0: mu=2.0500, value_0=0.263912
# Stopped after 9 iterations: mu=3.9924, value_0=16.948082
# Iteration 0: mu=2.0500, value_0=0.056542
# Stopped after 9 iterations: mu=3.9924, value_0=7.031600
# Iteration 0: mu=2.0500, value_0=0.008661
# Converged after 0 iterations: mu=2.0500
# Iteration 0: mu=2.0500, value_0=0.001421
# Converged after 0 iterations: mu=2.0500
# Iteration 0: mu=2.0500, value_0=0.000149
# Converged after 0 iterations: mu=2.0500
# Iteration 0: mu=2.0500, value_0=0.000018
# Converged after 0 iterations: mu=2.0500
# Iteration 0: mu=2.0500, value_0=0.000000
# Converged after 0 iterations: mu=2.0500
# Iteration 0: mu=2.0500, value_0=0.000000
# Converged after 0 iterations: mu=2.0500
# Iteration 0: mu=2.0500, value_0=0.000000
# Converged after 0 iterations: mu=2.0500
# Iteration 0: mu=2.0500, value_0=0.000000
# Converged after 0 iterations: mu=2.0500
# Iteration 0: mu=2.0500, value_0=0.000000
# Converged after 0 iterations: mu=2.0500
# Iteration 0: mu=2.0500, value_0=154.101916
# Stopped after 9 iterations: mu=3.0174, value_0=-0.060938
# Iteration 0: mu=2.0500, value_0=326.355945
# Stopped after 9 iterations: mu=3.9924, value_0=358.037685
# Iteration 0: mu=2.0500, value_0=182.492604
# Stopped after 9 iterations: mu=3.9924, value_0=463.722748
# Iteration 0: mu=2.0500, value_0=55.122868
# Stopped after 9 iterations: mu=3.9924, value_0=259.482292
# Iteration 0: mu=2.0500, value_0=13.525842
# Stopped after 9 iterations: mu=3.9924, value_0=117.890157
# Iteration 0: mu=2.0500, value_0=4.260924
# Stopped after 9 iterations: mu=3.9924, value_0=74.125589
# Iteration 0: mu=2.0500, value_0=1.385709
# Stopped after 9 iterations: mu=3.9924, value_0=46.869143
# Iteration 0: mu=2.0500, value_0=0.288820
# Stopped after 9 iterations: mu=3.9924, value_0=18.666997
# Iteration 0: mu=2.0500, value_0=0.044935
# Stopped after 9 iterations: mu=3.9924, value_0=5.544097
# Iteration 0: mu=2.0500, value_0=0.007930
# Converged after 0 iterations: mu=2.0500
# Iteration 0: mu=2.0500, value_0=0.001456
# Converged after 0 iterations: mu=2.0500
# Iteration 0: mu=2.0500, value_0=0.000174
# Converged after 0 iterations: mu=2.0500
# Iteration 0: mu=2.0500, value_0=0.000027
# Converged after 0 iterations: mu=2.0500
# Iteration 0: mu=2.0500, value_0=0.000003
# Converged after 0 iterations: mu=2.0500
# Iteration 0: mu=2.0500, value_0=0.000000
# Converged after 0 iterations: mu=2.0500
# Iteration 0: mu=2.0500, value_0=0.000000
# Converged after 0 iterations: mu=2.0500
# Iteration 0: mu=2.0500, value_0=0.000000
# Converged after 0 iterations: mu=2.0500
# Iteration 0: mu=2.0500, value_0=0.000000
# Converged after 0 iterations: mu=2.0500
# Iteration 0: mu=2.0500, value_0=0.000000
# Converged after 0 iterations: mu=2.0500
# Iteration 0: mu=2.0500, value_0=0.000000
# Converged after 0 iterations: mu=2.0500
# Iteration 0: mu=2.0500, value_0=0.000000
# Converged after 0 iterations: mu=2.0500
# Iteration 0: mu=2.0500, value_0=0.000000
# Converged after 0 iterations: mu=2.0500
# Iteration 0: mu=2.0500, value_0=0.000000
# Converged after 0 iterations: mu=2.0500
# Iteration 0: mu=2.0500, value_0=-90.040194
# Stopped after 9 iterations: mu=1.0064, value_0=0.330888
# Iteration 0: mu=2.0500, value_0=157.467142
# Stopped after 9 iterations: mu=3.0936, value_0=-0.421296
# Iteration 0: mu=2.0500, value_0=337.696452
# Stopped after 9 iterations: mu=3.9924, value_0=402.784580
# Iteration 0: mu=2.0500, value_0=166.396015
# Stopped after 9 iterations: mu=3.9924, value_0=416.587760
# Iteration 0: mu=2.0500, value_0=54.864043
# Stopped after 9 iterations: mu=3.9924, value_0=266.917615
# Iteration 0: mu=2.0500, value_0=16.451376
# Stopped after 9 iterations: mu=3.9924, value_0=147.801602
# Iteration 0: mu=2.0500, value_0=5.572580
# Stopped after 9 iterations: mu=3.9924, value_0=98.985879
# Iteration 0: mu=2.0500, value_0=1.535053
# Stopped after 9 iterations: mu=3.9924, value_0=51.953648
# Iteration 0: mu=2.0500, value_0=0.230513
# Stopped after 9 iterations: mu=3.9924, value_0=14.808353
# Iteration 0: mu=2.0500, value_0=0.055853
# Stopped after 9 iterations: mu=3.9924, value_0=6.903211
# Iteration 0: mu=2.0500, value_0=0.009415
# Converged after 0 iterations: mu=2.0500
# Iteration 0: mu=2.0500, value_0=0.001245
# Converged after 0 iterations: mu=2.0500
# Iteration 0: mu=2.0500, value_0=0.000150
# Converged after 0 iterations: mu=2.0500
# Iteration 0: mu=2.0500, value_0=0.000022
# Converged after 0 iterations: mu=2.0500
# Iteration 0: mu=2.0500, value_0=0.000002
# Converged after 0 iterations: mu=2.0500
# Iteration 0: mu=2.0500, value_0=0.000000
# Converged after 0 iterations: mu=2.0500
# Iteration 0: mu=2.0500, value_0=0.000000
# Converged after 0 iterations: mu=2.0500
# Iteration 0: mu=2.0500, value_0=0.000000
# Converged after 0 iterations: mu=2.0500
# Iteration 0: mu=2.0500, value_0=0.000000
# Converged after 0 iterations: mu=2.0500
# Iteration 0: mu=2.0500, value_0=0.000000
# Converged after 0 iterations: mu=2.0500
# Iteration 0: mu=2.0500, value_0=0.000000
# Converged after 0 iterations: mu=2.0500
# Iteration 0: mu=2.0500, value_0=169.974389
# ...
# Iteration 0: mu=2.0500, value_0=164.802912
# Stopped after 9 iterations: mu=3.9924, value_0=191.441368
# Iteration 0: mu=2.0500, value_0=108.543690
# Stopped after 9 iterations: mu=3.9924, value_0=281.814457
# Iteration 0: mu=2.0500, value_0=19.962856
# Stopped after 9 iterations: mu=3.9924, value_0=89.161407
# Iteration 0: mu=2.0500, value_0=8.393348
# Stopped after 9 iterations: mu=3.9924, value_0=75.011306
# Iteration 0: mu=2.0500, value_0=2.379126
# Stopped after 9 iterations: mu=3.9924, value_0=40.783297
# Iteration 0: mu=2.0500, value_0=0.553746
# Stopped after 9 iterations: mu=3.9924, value_0=18.293223
# Iteration 0: mu=2.0500, value_0=0.102059
# Stopped after 9 iterations: mu=3.9924, value_0=6.585058
# Iteration 0: mu=2.0500, value_0=0.026749
# Stopped after 9 iterations: mu=3.9924, value_0=3.328854
# Iteration 0: mu=2.0500, value_0=0.003562
# Converged after 0 iterations: mu=2.0500
# Iteration 0: mu=2.0500, value_0=0.000583
# Converged after 0 iterations: mu=2.0500
# Iteration 0: mu=2.0500, value_0=0.000060
# Converged after 0 iterations: mu=2.0500
# Iteration 0: mu=2.0500, value_0=0.000001
# Converged after 0 iterations: mu=2.0500
# Iteration 0: mu=2.0500, value_0=0.000000
# Converged after 0 iterations: mu=2.0500
# Iteration 0: mu=2.0500, value_0=0.000000
# Converged after 0 iterations: mu=2.0500
# Iteration 0: mu=2.0500, value_0=0.000000
# Converged after 0 iterations: mu=2.0500
# Iteration 0: mu=2.0500, value_0=0.000000
# Converged after 0 iterations: mu=2.0500
# Iteration 0: mu=2.0500, value_0=-45.846837
# Stopped after 9 iterations: mu=1.0979, value_0=0.206184
# Iteration 0: mu=2.0500, value_0=206.314079
# Stopped after 9 iterations: mu=3.9924, value_0=37.295997
# Iteration 0: mu=2.0500, value_0=198.785898
# Stopped after 9 iterations: mu=3.9924, value_0=252.222457
# Iteration 0: mu=2.0500, value_0=72.084402
# Stopped after 9 iterations: mu=3.9924, value_0=177.018346
# Iteration 0: mu=2.0500, value_0=24.489483
# Stopped after 9 iterations: mu=3.9924, value_0=109.855078
# Iteration 0: mu=2.0500, value_0=7.863761
# Stopped after 9 iterations: mu=3.9924, value_0=67.673178
# Iteration 0: mu=2.0500, value_0=1.613747
# Stopped after 9 iterations: mu=3.9924, value_0=27.558265
# Iteration 0: mu=2.0500, value_0=0.544927
# Stopped after 9 iterations: mu=3.9924, value_0=17.901051
# Iteration 0: mu=2.0500, value_0=0.085574
# Stopped after 9 iterations: mu=3.9924, value_0=5.473322
# Iteration 0: mu=2.0500, value_0=0.018602
# Stopped after 9 iterations: mu=3.9924, value_0=2.287853
# Iteration 0: mu=2.0500, value_0=0.004867
# Converged after 0 iterations: mu=2.0500
# Iteration 0: mu=2.0500, value_0=0.000080
# Converged after 0 iterations: mu=2.0500
# Iteration 0: mu=2.0500, value_0=0.000001
# Converged after 0 iterations: mu=2.0500
# Iteration 0: mu=2.0500, value_0=0.000000
# Converged after 0 iterations: mu=2.0500
# Iteration 0: mu=2.0500, value_0=-41.800508
# Stopped after 9 iterations: mu=1.0979, value_0=-0.200226
# Iteration 0: mu=2.0500, value_0=157.773372
# Stopped after 9 iterations: mu=3.9924, value_0=6.994906
# Iteration 0: mu=2.0500, value_0=200.710816
# Stopped after 9 iterations: mu=3.9924, value_0=259.011708
# Iteration 0: mu=2.0500, value_0=96.323249
# Stopped after 9 iterations: mu=3.9924, value_0=253.478848
# Iteration 0: mu=2.0500, value_0=21.131473
# Stopped after 9 iterations: mu=3.9924, value_0=100.799105
# Iteration 0: mu=2.0500, value_0=10.184342
# Stopped after 9 iterations: mu=3.9924, value_0=91.868473
# Iteration 0: mu=2.0500, value_0=2.282808
# Stopped after 9 iterations: mu=3.9924, value_0=39.145609
# Iteration 0: mu=2.0500, value_0=0.623205
# Stopped after 9 iterations: mu=3.9924, value_0=20.943579
# Iteration 0: mu=2.0500, value_0=0.121174
# Stopped after 9 iterations: mu=3.9924, value_0=7.770049
# Iteration 0: mu=2.0500, value_0=0.024985
# Stopped after 9 iterations: mu=3.9924, value_0=3.079864
# Iteration 0: mu=2.0500, value_0=0.003017
# Converged after 0 iterations: mu=2.0500
# Iteration 0: mu=2.0500, value_0=0.000424
# Converged after 0 iterations: mu=2.0500
# Iteration 0: mu=2.0500, value_0=0.000094
# Converged after 0 iterations: mu=2.0500
# Iteration 0: mu=2.0500, value_0=0.000011
# Converged after 0 iterations: mu=2.0500
# Iteration 0: mu=2.0500, value_0=0.000000
# Converged after 0 iterations: mu=2.0500
# Iteration 0: mu=2.0500, value_0=0.000000
# Converged after 0 iterations: mu=2.0500
# Iteration 0: mu=2.0500, value_0=0.000000
# Converged after 0 iterations: mu=2.0500
# Iteration 0: mu=2.0500, value_0=-44.562683
# Stopped after 9 iterations: mu=1.0064, value_0=0.167489
# Iteration 0: mu=2.0500, value_0=132.213276
# Stopped after 9 iterations: mu=3.6115, value_0=-0.602673
# Iteration 0: mu=2.0500, value_0=195.561028
# Stopped after 9 iterations: mu=3.9924, value_0=248.117751
# Iteration 0: mu=2.0500, value_0=96.937795
# Stopped after 9 iterations: mu=3.9924, value_0=245.258401
# Iteration 0: mu=2.0500, value_0=18.725674
# Stopped after 9 iterations: mu=3.9924, value_0=86.920830
# Iteration 0: mu=2.0500, value_0=8.723594
# Stopped after 9 iterations: mu=3.9924, value_0=77.038608
# Iteration 0: mu=2.0500, value_0=2.047515
# Stopped after 9 iterations: mu=3.9924, value_0=35.339772
# Iteration 0: mu=2.0500, value_0=0.616651
# Stopped after 9 iterations: mu=3.9924, value_0=20.840185
# Iteration 0: mu=2.0500, value_0=0.130489
# Stopped after 9 iterations: mu=3.9924, value_0=8.368514
# Iteration 0: mu=2.0500, value_0=0.010581
# Stopped after 9 iterations: mu=3.9924, value_0=1.286673
# Iteration 0: mu=2.0500, value_0=0.004830
# Converged after 0 iterations: mu=2.0500
# Iteration 0: mu=2.0500, value_0=0.000761
# Converged after 0 iterations: mu=2.0500
# Iteration 0: mu=2.0500, value_0=0.000082
# Converged after 0 iterations: mu=2.0500
# Iteration 0: mu=2.0500, value_0=0.000002
# Converged after 0 iterations: mu=2.0500
# Iteration 0: mu=2.0500, value_0=0.000000
# Converged after 0 iterations: mu=2.0500
# Iteration 0: mu=2.0500, value_0=0.000000
# Converged after 0 iterations: mu=2.0500
# Iteration 0: mu=2.0500, value_0=0.000000
# Converged after 0 iterations: mu=2.0500
# Iteration 0: mu=2.0500, value_0=0.000000
# Converged after 0 iterations: mu=2.0500
# Iteration 0: mu=2.0500, value_0=0.000000
# Converged after 0 iterations: mu=2.0500
# Iteration 0: mu=2.0500, value_0=0.000000
# Converged after 0 iterations: mu=2.0500
# Iteration 0: mu=2.0500, value_0=-37.367165
# Stopped after 9 iterations: mu=1.0521, value_0=0.044152
# Iteration 0: mu=2.0500, value_0=100.208543
# Stopped after 9 iterations: mu=3.4592, value_0=0.619382
# Iteration 0: mu=2.0500, value_0=150.403410
# Stopped after 9 iterations: mu=3.9924, value_0=177.099369
# Iteration 0: mu=2.0500, value_0=82.239697
# Stopped after 9 iterations: mu=3.9924, value_0=207.711882
# Iteration 0: mu=2.0500, value_0=32.187839
# Stopped after 9 iterations: mu=3.9924, value_0=147.626640
# Iteration 0: mu=2.0500, value_0=10.341515
# Stopped after 9 iterations: mu=3.9924, value_0=94.565177
# Iteration 0: mu=2.0500, value_0=2.167514
# Stopped after 9 iterations: mu=3.9924, value_0=37.005095
# Iteration 0: mu=2.0500, value_0=0.676699
# Stopped after 9 iterations: mu=3.9924, value_0=22.548612
# Iteration 0: mu=2.0500, value_0=0.110979
# Stopped after 9 iterations: mu=3.9924, value_0=7.023943
# Iteration 0: mu=2.0500, value_0=0.021917
# Stopped after 9 iterations: mu=3.9924, value_0=2.697834
# Iteration 0: mu=2.0500, value_0=0.003218
# Converged after 0 iterations: mu=2.0500
# Iteration 0: mu=2.0500, value_0=0.000543
# Converged after 0 iterations: mu=2.0500
# Iteration 0: mu=2.0500, value_0=0.000051
# Converged after 0 iterations: mu=2.0500
# Iteration 0: mu=2.0500, value_0=0.000012
# Converged after 0 iterations: mu=2.0500
# Iteration 0: mu=2.0500, value_0=0.000001
# Converged after 0 iterations: mu=2.0500
# Iteration 0: mu=2.0500, value_0=0.000000
# Converged after 0 iterations: mu=2.0500
# Iteration 0: mu=2.0500, value_0=0.000000
# Converged after 0 iterations: mu=2.0500
# Iteration 0: mu=2.0500, value_0=0.000000
# Converged after 0 iterations: mu=2.0500
# Iteration 0: mu=2.0500, value_0=0.000000
# Converged after 0 iterations: mu=2.0500
# Iteration 0: mu=2.0500, value_0=0.000000
# Converged after 0 iterations: mu=2.0500
# Iteration 0: mu=2.0500, value_0=103.863923
# Stopped after 9 iterations: mu=3.4744, value_0=0.283161
# Iteration 0: mu=2.0500, value_0=166.533629
# Stopped after 9 iterations: mu=3.9924, value_0=219.734715
# Iteration 0: mu=2.0500, value_0=79.391699
# Stopped after 9 iterations: mu=3.9924, value_0=203.867278
# Iteration 0: mu=2.0500, value_0=27.867744
# Stopped after 9 iterations: mu=3.9924, value_0=133.584256
# Iteration 0: mu=2.0500, value_0=6.465578
# Stopped after 9 iterations: mu=3.9924, value_0=56.038843
# Iteration 0: mu=2.0500, value_0=2.245004
# Stopped after 9 iterations: mu=3.9924, value_0=38.653322
# Iteration 0: mu=2.0500, value_0=0.151280
# Stopped after 9 iterations: mu=3.9924, value_0=9.794571
# Iteration 0: mu=2.0500, value_0=0.027518
# Stopped after 9 iterations: mu=3.9924, value_0=3.397471
# Iteration 0: mu=2.0500, value_0=0.002985
# Converged after 0 iterations: mu=2.0500
# Iteration 0: mu=2.0500, value_0=0.000590
# Converged after 0 iterations: mu=2.0500
# Iteration 0: mu=2.0500, value_0=0.000089
# Converged after 0 iterations: mu=2.0500
# Iteration 0: mu=2.0500, value_0=0.000011
# Converged after 0 iterations: mu=2.0500
# Iteration 0: mu=2.0500, value_0=0.000001
# Converged after 0 iterations: mu=2.0500
# Iteration 0: mu=2.0500, value_0=0.000000
# Converged after 0 iterations: mu=2.0500
# Iteration 0: mu=2.0500, value_0=0.000000
# Converged after 0 iterations: mu=2.0500
# Iteration 0: mu=2.0500, value_0=111.674349
# Stopped after 9 iterations: mu=3.6877, value_0=-0.205752
# Iteration 0: mu=2.0500, value_0=162.087152
# Stopped after 9 iterations: mu=3.9924, value_0=203.781547
# Iteration 0: mu=2.0500, value_0=71.621916
# Stopped after 9 iterations: mu=3.9924, value_0=178.120785
# Iteration 0: mu=2.0500, value_0=16.543088
# Stopped after 9 iterations: mu=3.9924, value_0=74.696260
# Iteration 0: mu=2.0500, value_0=7.940846
# Stopped after 9 iterations: mu=3.9924, value_0=71.682046
# Iteration 0: mu=2.0500, value_0=2.402797
# Stopped after 9 iterations: mu=3.9924, value_0=41.171738
# Iteration 0: mu=2.0500, value_0=0.530139
# Stopped after 9 iterations: mu=3.9924, value_0=17.396755
# Iteration 0: mu=2.0500, value_0=0.088085
# Stopped after 9 iterations: mu=3.9924, value_0=5.537218
# Iteration 0: mu=2.0500, value_0=0.022857
# Stopped after 9 iterations: mu=3.9924, value_0=2.790546
# Iteration 0: mu=2.0500, value_0=0.003327
# Converged after 0 iterations: mu=2.0500
# Iteration 0: mu=2.0500, value_0=0.000717
# Converged after 0 iterations: mu=2.0500
# Iteration 0: mu=2.0500, value_0=0.000081
# Converged after 0 iterations: mu=2.0500
# Iteration 0: mu=2.0500, value_0=0.000001
# Converged after 0 iterations: mu=2.0500
# Iteration 0: mu=2.0500, value_0=0.000000
# Converged after 0 iterations: mu=2.0500
# Iteration 0: mu=2.0500, value_0=0.000000
# Converged after 0 iterations: mu=2.0500
# Iteration 0: mu=2.0500, value_0=0.000000
# Converged after 0 iterations: mu=2.0500
# Iteration 0: mu=2.0500, value_0=90.567110
# Stopped after 9 iterations: mu=3.4135, value_0=-0.427478
# Iteration 0: mu=2.0500, value_0=154.836873
# Stopped after 9 iterations: mu=3.9924, value_0=192.063262
# Iteration 0: mu=2.0500, value_0=80.373256
# Stopped after 9 iterations: mu=3.9924, value_0=207.045402
# Iteration 0: mu=2.0500, value_0=22.756149
# Stopped after 9 iterations: mu=3.9924, value_0=104.869914
# Iteration 0: mu=2.0500, value_0=6.076911
# Stopped after 9 iterations: mu=3.9924, value_0=54.879630
# Iteration 0: mu=2.0500, value_0=2.022534
# Stopped after 9 iterations: mu=3.9924, value_0=34.578310
# Iteration 0: mu=2.0500, value_0=0.693403
# Stopped after 9 iterations: mu=3.9924, value_0=23.188769
# Iteration 0: mu=2.0500, value_0=0.084210
# Stopped after 9 iterations: mu=3.9924, value_0=5.337622
# Iteration 0: mu=2.0500, value_0=0.023529
# Stopped after 9 iterations: mu=3.9924, value_0=2.958803
# Iteration 0: mu=2.0500, value_0=0.004901
# Converged after 0 iterations: mu=2.0500
# Iteration 0: mu=2.0500, value_0=0.000724
# Converged after 0 iterations: mu=2.0500
# Iteration 0: mu=2.0500, value_0=0.000014
# Converged after 0 iterations: mu=2.0500
# Iteration 0: mu=2.0500, value_0=0.000001
# Converged after 0 iterations: mu=2.0500
# Iteration 0: mu=2.0500, value_0=0.000000
# Converged after 0 iterations: mu=2.0500
# Iteration 0: mu=2.0500, value_0=0.000000
# Converged after 0 iterations: mu=2.0500
# Iteration 0: mu=2.0500, value_0=0.000000
# Converged after 0 iterations: mu=2.0500
# Iteration 0: mu=2.0500, value_0=0.000000
# Converged after 0 iterations: mu=2.0500
# Iteration 0: mu=2.0500, value_0=-34.481882
# Stopped after 9 iterations: mu=1.1131, value_0=-0.111714
# Iteration 0: mu=2.0500, value_0=97.755376
# Stopped after 9 iterations: mu=3.3830, value_0=0.625906
# Iteration 0: mu=2.0500, value_0=171.065595
# Stopped after 9 iterations: mu=3.9924, value_0=233.590701
# Iteration 0: mu=2.0500, value_0=81.808655
# Stopped after 9 iterations: mu=3.9924, value_0=210.656370
# Iteration 0: mu=2.0500, value_0=29.717418
# Stopped after 9 iterations: mu=3.9924, value_0=141.963662
# Iteration 0: mu=2.0500, value_0=10.757368
# Stopped after 9 iterations: mu=3.9924, value_0=100.795241
# Iteration 0: mu=2.0500, value_0=2.336876
# Stopped after 9 iterations: mu=3.9924, value_0=40.985127
# Iteration 0: mu=2.0500, value_0=0.495963
# Stopped after 9 iterations: mu=3.9924, value_0=16.873574
# Iteration 0: mu=2.0500, value_0=0.127175
# Stopped after 9 iterations: mu=3.9924, value_0=8.340279
# Iteration 0: mu=2.0500, value_0=0.021562
# Stopped after 9 iterations: mu=3.9924, value_0=2.705513
# Iteration 0: mu=2.0500, value_0=0.002971
# Converged after 0 iterations: mu=2.0500
# Iteration 0: mu=2.0500, value_0=0.000521
# Converged after 0 iterations: mu=2.0500
# Iteration 0: mu=2.0500, value_0=0.000090
# Converged after 0 iterations: mu=2.0500
# Iteration 0: mu=2.0500, value_0=0.000002
# Converged after 0 iterations: mu=2.0500
# Iteration 0: mu=2.0500, value_0=0.000000
# Converged after 0 iterations: mu=2.0500
# Iteration 0: mu=2.0500, value_0=0.000000
# Converged after 0 iterations: mu=2.0500
# Iteration 0: mu=2.0500, value_0=0.000000
# Converged after 0 iterations: mu=2.0500
# Iteration 0: mu=2.0500, value_0=-34.745788
# Stopped after 9 iterations: mu=1.0979, value_0=-0.044779
# Iteration 0: mu=2.0500, value_0=108.388744
# Stopped after 9 iterations: mu=3.6877, value_0=-0.615980
# Iteration 0: mu=2.0500, value_0=185.379607
# Stopped after 9 iterations: mu=3.9924, value_0=250.029882
# Iteration 0: mu=2.0500, value_0=85.108309
# Stopped after 9 iterations: mu=3.9924, value_0=213.671538
# Iteration 0: mu=2.0500, value_0=27.007344
# Stopped after 9 iterations: mu=3.9924, value_0=131.605563
# Iteration 0: mu=2.0500, value_0=8.933883
# Stopped after 9 iterations: mu=3.9924, value_0=80.976103
# Iteration 0: mu=2.0500, value_0=2.717084
# Stopped after 9 iterations: mu=3.9924, value_0=47.725775
# Iteration 0: mu=2.0500, value_0=0.573417
# Stopped after 9 iterations: mu=3.9924, value_0=19.408315
# Iteration 0: mu=2.0500, value_0=0.103110
# Stopped after 9 iterations: mu=3.9924, value_0=6.615393
# Iteration 0: mu=2.0500, value_0=0.018016
# Stopped after 9 iterations: mu=3.9924, value_0=2.247402
# Iteration 0: mu=2.0500, value_0=0.003594
# Converged after 0 iterations: mu=2.0500
# Iteration 0: mu=2.0500, value_0=0.000727
# Converged after 0 iterations: mu=2.0500
# Iteration 0: mu=2.0500, value_0=0.000048
# Converged after 0 iterations: mu=2.0500
# Iteration 0: mu=2.0500, value_0=0.000000
# Converged after 0 iterations: mu=2.0500
# Method: baseline_I, on Test1/A_20250212_ZQ0.35_ZG0.4_testfile.csv
# - Bias: 0.337 (overestimation)
# - Weighted MAE (α=0): 1.128
# - Weighted MAE (α=0.5): 1.297
# - Weighted MAE (α=1): 1.647
# - Weighted MAE (α=1.5): 2.240
# - Accuracy (exact matches): 0.284
# - Overestimation Rate: 0.502
# - Underestimation Rate: 0.214
# - Gini Coefficient: 0.462
# Overstock: 3738
# Processed magazine I
#
# Calculating averages...
#
# Average KPIs:
# bias                        0.712214
# weighted_mae_0              1.092300
# weighted_mae_0.5            1.178954
# weighted_mae_1              1.544882
# weighted_mae_1.5            3.533946
# accuracy                    0.327025
# overestimation_rate         0.572619
# underestimation_rate        0.100356
# gini_coefficient            0.457125
# overstock               20290.777778
# dtype: float64
#
# Processed 9 magazines successfully.

# %% [markdown]
# # Nahmias

# %%
import numpy as np
import pandas as pd
from scipy.stats import norm

def compute_mu_sigma_nahmias(sales, S):
    """
    Compute mu and sigma using Nahmias method for censored normal data.
    
    Parameters:
    -----------
    sales : array-like
        Observed sales data (censored at S)
    S : float
        Censoring limit (inventory level)
    
    Returns:
    --------
    tuple: (mu_hat, sigma_hat) or (None, None) if estimation fails
    """
    sales = np.array(sales)
    sales = sales[~np.isnan(sales)]
    
    if len(sales) < 5:  # Need reasonable sample size
        return None, None
    
    # The uncensored observations are those < S
    observed = sales[sales < S]
    n = len(sales)
    r = len(observed)
    
    if r < 2 or r >= n-1:  # Need at least 2 uncensored, 1 censored
        return None, None
        
    p = r / n  # Proportion uncensored
    
    # # Avoid extreme proportions where method is unstable
    # if p < 0.2 or p > 0.8:
    #     return None, None
    
    x_bar = np.mean(observed)
    s2 = np.var(observed, ddof=1)
    
    if s2 <= 1e-6:
        return None, None
    
    try:
        z = norm.ppf(p)
        
        # Check for extreme z values that cause instability
        if abs(z) > 2:
            return None, None
        
        pdf_z = norm.pdf(z)
        
        denominator = 1 - (z * pdf_z / p) - (pdf_z**2 / p**2)
        
        if denominator <= 0.1:  # Need substantial positive denominator
            return None, None
            
        sigma_hat2 = s2 / denominator
        
        if sigma_hat2 <= 0 or sigma_hat2 > 1e6:
            return None, None
            
        sigma_hat = np.sqrt(sigma_hat2)
        mu_hat = x_bar + sigma_hat * pdf_z / p
        
        # Sanity check on estimates
        if abs(mu_hat) > 1e6 or sigma_hat > 1e3:
            return None, None
        
        return mu_hat, sigma_hat
        
    except Exception:
        return None, None

def create_order_specific_nahmias_dict(df):
    """
    Create μ and σ estimates for each (week, order_quantity) combination using Nahmias method.
    Each stockout level gets its own Normal distribution.
    """
    order_specific_mu_dict = {}
    order_specific_sigma_dict = {}

    for (year, week), week_data in df.groupby(['Heftjahr', 'Heftnummer']):
        for bezug_val, group in week_data.groupby('Bezug'):
            n = len(group)
            S = bezug_val
            
            # Count stockouts (sales = order quantity)
            stockouts = (group['Verkauf'] == bezug_val).sum()
            
            if n < 5 or stockouts == 0 or stockouts == n:
                continue  # Not enough variation or unusable

            try:
                mu_est, sigma_est = compute_mu_sigma_nahmias(group['Verkauf'], S)
                if mu_est is not None and sigma_est is not None:
                    # Store with (year, week, order_quantity) key
                    key = (year, week, bezug_val)
                    order_specific_mu_dict[key] = mu_est
                    order_specific_sigma_dict[key] = sigma_est
            except Exception as e:
                print(f"Error in week {week}, Bezug {bezug_val}: {e}")
                continue

    return order_specific_mu_dict, order_specific_sigma_dict

def expected_normal_tail(mu, sigma, S, max_iterations=1000):
    """
    Compute E[X | X >= S] for X ~ Normal(mu, sigma)
    Using numerical integration approximation
    """
    if sigma <= 0:
        return S
    
    # Standardize
    z = (S - mu) / sigma
    
    # If S is way above the mean, just return S (no meaningful tail)
    if z > 6:
        return S
    
    # Use the formula: E[X | X >= S] = mu + sigma * phi(z) / (1 - Phi(z))
    # where phi is PDF and Phi is CDF
    tail_prob = 1 - norm.cdf(z)
    
    if tail_prob < 1e-10:  # Essentially no tail probability
        return S
    
    expected_value = mu + sigma * norm.pdf(z) / tail_prob
    
    return expected_value

def apply_nahmias_uncensoring_1(df, order_specific_mu_dict, order_specific_sigma_dict):
    """
    Given a DataFrame with Verkauf, Bezug, is_stockout, Heftjahr, Heftnummer,
    replace Verkauf with E[X | X >= Bezug] when censored.
    
    Uses order-quantity-specific Normal(μ, σ) parameters.
    
    Modifies the DataFrame in place by updating the Verkauf column.
    """
    df = df.copy()
    df['Verkauf_Uncensored'] = df['Verkauf'].copy()

    for idx, row in df.iterrows():
        # Skip if no stockout occurred
        if row['Zensiert'] == 0:
            continue
            
        # Get the order-quantity-specific demand parameters
        key = (row['Heftjahr'], row['Heftnummer'], row['Bezug'])
        mu = order_specific_mu_dict.get(key, None)
        sigma = order_specific_sigma_dict.get(key, None)

        if mu is None or sigma is None:
            # no estimate available for this specific (week, order_quantity) — keep original value
            continue

        # POS sold out — uncensor using the specific distribution for this order quantity
        est_demand = expected_normal_tail(mu, sigma, row['Bezug'])
        df.at[idx, 'Verkauf_Uncensored'] = np.round(est_demand)

    return df

def apply_nahmias_uncensoring(df):
    """
    WRAPPER FUNCTION: This is what gets called by the main processing loop
    """
    # Step 1: Create mu dictionary from the dataset
    order_specific_mu_dict, compute_mu_sigma_nahmias = create_order_specific_nahmias_dict(df)
    
    # Step 2: Apply uncensoring using the mu dictionary  
    return apply_nahmias_uncensoring_1(df, order_specific_mu_dict, compute_mu_sigma_nahmias)


# Usage
# order_specific_mu_dict, order_specific_sigma_dict = create_order_specific_nahmias_dict(df)
# df_nahmias_uncensored = apply_nahmias_uncensoring_1(df, order_specific_mu_dict, order_specific_sigma_dict)

# %%
import pandas as pd
import numpy as np

def apply_baseline_uncensoring(df):
    df_result = df.copy()
    df_result['Verkauf_Uncensored'] = df_result['Verkauf'] 
    return df_result

# Process all magazines A through I
magazines = ['A', 'B', 'C', 'D', 'E', 'F', 'G', 'H', 'I']
all_kpis = []

for magazine in magazines:
    filename = f'test1/{magazine}_20250212_ZQ0.35_ZG0.4_testfile.csv'
    
    # Load data
    df = pd.read_csv(filename)
    
    # Apply baseline uncensoring
    baseline_df = apply_nahmias_uncensoring(df)
    
    # Calculate KPIs
    kpis = calculate_kpis(baseline_df, f"baseline_{magazine}")
    all_kpis.append(kpis)
    
    print(f"Processed magazine {magazine}")

# Calculate average KPIs
print("\nCalculating averages...")

# Convert to DataFrame if KPIs are dictionaries
if isinstance(all_kpis[0], dict):
    kpi_df = pd.DataFrame(all_kpis)
    average_kpis = kpi_df.mean()
    print("\nAverage KPIs:")
    print(average_kpis)
else:
    # If KPIs are single values
    average_kpis = np.mean(all_kpis)
    print(f"\nAverage KPI: {average_kpis}")

print(f"\nProcessed {len(magazines)} magazines successfully.")
# Out:
# Method: baseline_A, on Test1/A_20250212_ZQ0.35_ZG0.4_testfile.csv
# - Bias: -0.500 (underestimation)
# - Weighted MAE (α=0): 0.872
# - Weighted MAE (α=0.5): 1.057
# - Weighted MAE (α=1): 1.341
# - Weighted MAE (α=1.5): 1.734
# - Accuracy (exact matches): 0.346
# - Overestimation Rate: 0.171
# - Underestimation Rate: 0.483
# - Gini Coefficient: 0.485
# Overstock: 14069
# Processed magazine A
# Method: baseline_B, on Test1/A_20250212_ZQ0.35_ZG0.4_testfile.csv
# - Bias: -0.613 (underestimation)
# - Weighted MAE (α=0): 0.893
# - Weighted MAE (α=0.5): 1.165
# - Weighted MAE (α=1): 1.730
# - Weighted MAE (α=1.5): 2.944
# - Accuracy (exact matches): 0.359
# - Overestimation Rate: 0.128
# - Underestimation Rate: 0.513
# - Gini Coefficient: 0.512
# Overstock: 6785
# Processed magazine B
# Method: baseline_C, on Test1/A_20250212_ZQ0.35_ZG0.4_testfile.csv
# - Bias: -0.454 (underestimation)
# - Weighted MAE (α=0): 0.742
# - Weighted MAE (α=0.5): 0.812
# - Weighted MAE (α=1): 0.905
# - Weighted MAE (α=1.5): 1.030
# - Accuracy (exact matches): 0.364
# - Overestimation Rate: 0.142
# - Underestimation Rate: 0.494
# - Gini Coefficient: 0.443
# Overstock: 5966
# Processed magazine C
# Method: baseline_D, on Test1/A_20250212_ZQ0.35_ZG0.4_testfile.csv
# - Bias: -0.551 (underestimation)
# - Weighted MAE (α=0): 0.675
# - Weighted MAE (α=0.5): 0.760
# - Weighted MAE (α=1): 0.928
# - Weighted MAE (α=1.5): 1.312
# - Accuracy (exact matches): 0.421
# - Overestimation Rate: 0.061
# - Underestimation Rate: 0.518
# - Gini Coefficient: 0.494
# Overstock: 774
# Processed magazine D
# Method: baseline_E, on Test1/A_20250212_ZQ0.35_ZG0.4_testfile.csv
# - Bias: -0.512 (underestimation)
# - Weighted MAE (α=0): 0.806
# - Weighted MAE (α=0.5): 1.067
# - Weighted MAE (α=1): 2.854
# - Weighted MAE (α=1.5): 17.001
# - Accuracy (exact matches): 0.366
# - Overestimation Rate: 0.132
# - Underestimation Rate: 0.503
# - Gini Coefficient: 0.480
# Overstock: 1943
# Processed magazine E
# Method: baseline_F, on Test1/A_20250212_ZQ0.35_ZG0.4_testfile.csv
# - Bias: -0.505 (underestimation)
# - Weighted MAE (α=0): 0.687
# - Weighted MAE (α=0.5): 0.762
# - Weighted MAE (α=1): 0.908
# - Weighted MAE (α=1.5): 1.240
# - Accuracy (exact matches): 0.401
# - Overestimation Rate: 0.091
# - Underestimation Rate: 0.508
# - Gini Coefficient: 0.470
# Overstock: 911
# Processed magazine F
# Method: baseline_G, on Test1/A_20250212_ZQ0.35_ZG0.4_testfile.csv
# - Bias: -0.550 (underestimation)
# - Weighted MAE (α=0): 0.559
# - Weighted MAE (α=0.5): 0.583
# - Weighted MAE (α=1): 0.619
# - Weighted MAE (α=1.5): 0.672
# - Accuracy (exact matches): 0.479
# - Overestimation Rate: 0.004
# - Underestimation Rate: 0.517
# - Gini Coefficient: 0.511
# Overstock: 30
# Processed magazine G
# Method: baseline_H, on Test1/A_20250212_ZQ0.35_ZG0.4_testfile.csv
# - Bias: -0.554 (underestimation)
# - Weighted MAE (α=0): 0.660
# - Weighted MAE (α=0.5): 0.786
# - Weighted MAE (α=1): 1.146
# - Weighted MAE (α=1.5): 2.254
# - Accuracy (exact matches): 0.435
# - Overestimation Rate: 0.051
# - Underestimation Rate: 0.514
# - Gini Coefficient: 0.509
# Overstock: 213
# Processed magazine H
# Method: baseline_I, on Test1/A_20250212_ZQ0.35_ZG0.4_testfile.csv
# - Bias: -0.479 (underestimation)
# - Weighted MAE (α=0): 0.866
# - Weighted MAE (α=0.5): 1.085
# - Weighted MAE (α=1): 1.457
# - Weighted MAE (α=1.5): 2.017
# - Accuracy (exact matches): 0.351
# - Overestimation Rate: 0.164
# - Underestimation Rate: 0.485
# - Gini Coefficient: 0.491
# Overstock: 987
# Processed magazine I
#
# Calculating averages...
#
# Average KPIs:
# bias                      -0.524198
# weighted_mae_0             0.751102
# weighted_mae_0.5           0.897627
# weighted_mae_1             1.320868
# weighted_mae_1.5           3.355938
# accuracy                   0.391145
# overestimation_rate        0.104912
# underestimation_rate       0.503942
# gini_coefficient           0.488428
# overstock               3519.777778
# dtype: float64
#
# Processed 9 magazines successfully.

# %%
import pandas as pd
import numpy as np

def calculate_kpis(dataframe, method_name):
   """
   Calculate KPIs for demand forecasting evaluation
   
   Parameters:
   - dataframe: pandas DataFrame containing 'Verkauf' (predicted) and 'Verkauf_MBR' (ground truth) columns
   - method_name: string name of the method being evaluated
   - censorship_pct: censorship percentage for display
   - reduction_pct: reduction percentage for display
   - alpha: weight parameter for Weighted MAE (default=1)
            α = 0: standard MAE (no weighting)
            α = 1: linear weighting by true demand
            α > 1: over-proportional penalization of larger errors --> 1.5
            α < 1: emphasis on smaller demands --> 0.5
   """
   df = dataframe.copy()
   censored_df = df[df['Zensiert'] == 1]
   
   # Extract predicted and true values
   y_pred = censored_df['Verkauf_Uncensored'].values  # ŷᵢ (estimated demand)
   y_true = censored_df['Verkauf_MBR'].values  # yᵢ (true demand)
   
   n = len(y_pred)
   
   # 1. Bias calculation
   bias = np.sum(y_pred - y_true) / n
   
   # 2. Accuracy (exact matches)
   exact_matches = np.sum(y_pred == y_true)
   accuracy = exact_matches / n
   
   # 3. Overestimation Rate
   overestimations = np.sum(y_pred > y_true)
   overestimation_rate = overestimations / n
   
   # 4. Underestimation Rate
   underestimations = np.sum(y_pred < y_true)
   underestimation_rate = underestimations / n
   
   # 5. Weighted MAE for different alpha values
   alphas = [0, 0.5, 1, 1.5]
   weighted_maes = {}
   
   for a in alphas:
       if a == 0:
           # Standard MAE (no weighting)
           weighted_maes[a] = np.mean(np.abs(y_pred - y_true))
       else:
           # Weighted MAE with α parameter
           weights = np.power(y_true, a)
           # Handle case where y_true might be 0
           weights = np.where(y_true == 0, 0, weights)
           weighted_maes[a] = np.sum(weights * np.abs(y_pred - y_true)) / np.sum(weights) if np.sum(weights) > 0 else 0
   
   # 6. Gini Coefficient
   abs_errors = np.abs(y_pred - y_true)
   mean_abs_error = np.mean(abs_errors)
   n = len(abs_errors)
   sorted_errors = np.sort(abs_errors)
   
   weighted_sum = 0.0
   total_sum = 0.0

   # 7. Overstock, out of curiosity
   overstock = np.sum(np.maximum(0, y_pred - y_true))
   
   for i in range(n):
       weighted_sum += (i + 1) * sorted_errors[i]
       total_sum += sorted_errors[i]
   
   gini_coefficient = (2 * weighted_sum) / (n * total_sum) - (n + 1) / n
   
   # Determine bias direction
   bias_direction = "overestimation" if bias > 0 else "underestimation" if bias < 0 else "neutral"
   
   # Print results in the specified format
   print(f"Method: {method_name}, on {path}")
   print(f"- Bias: {bias:.3f} ({bias_direction})")
   print(f"- Weighted MAE (α=0): {weighted_maes[0]:.3f}")
   print(f"- Weighted MAE (α=0.5): {weighted_maes[0.5]:.3f}")
   print(f"- Weighted MAE (α=1): {weighted_maes[1]:.3f}")
   print(f"- Weighted MAE (α=1.5): {weighted_maes[1.5]:.3f}")
   print(f"- Accuracy (exact matches): {accuracy:.3f}")
   print(f"- Overestimation Rate: {overestimation_rate:.3f}")
   print(f"- Underestimation Rate: {underestimation_rate:.3f}")
   print(f"- Gini Coefficient: {gini_coefficient:.3f}")
   print(f"Overstock: {int(overstock)}")
   
   return {
       'bias': bias,
       'weighted_mae_0': weighted_maes[0],
       'weighted_mae_0.5': weighted_maes[0.5],
       'weighted_mae_1': weighted_maes[1],
       'weighted_mae_1.5': weighted_maes[1.5],
       'accuracy': accuracy,
       'overestimation_rate': overestimation_rate,
       'underestimation_rate': underestimation_rate,
       'gini_coefficient': gini_coefficient,
       'overstock': overstock
   }

# %% [markdown]
# # Baseline

# %%
def apply_baseline_uncensoring(df):
    df_result = df.copy()
    df_result['Verkauf_Uncensored'] = df_result['Verkauf'] 
    return df_result

# baseline_df = apply_baseline_uncensoring(df)
#calculate_kpis(baseline_df, "baseline")

# %%
import pandas as pd
import numpy as np

def apply_baseline_uncensoring(df):
    df_result = df.copy()
    df_result['Verkauf_Uncensored'] = df_result['Verkauf'] 
    return df_result

# Process all magazines A through I
magazines = ['A', 'B', 'C', 'D', 'E', 'F', 'G', 'H', 'I']
all_kpis = []

for magazine in magazines:
    filename = f'test1/{magazine}_20250212_ZQ0.35_ZG0.4_testfile.csv'
    
    # Load data
    df = pd.read_csv(filename)
    
    # Apply baseline uncensoring
    baseline_df = apply_baseline_uncensoring(df)
    
    # Calculate KPIs
    kpis = calculate_kpis(baseline_df, f"baseline_{magazine}")
    all_kpis.append(kpis)
    
    print(f"Processed magazine {magazine}")

# Calculate average KPIs
print("\nCalculating averages...")

# Convert to DataFrame if KPIs are dictionaries
if isinstance(all_kpis[0], dict):
    kpi_df = pd.DataFrame(all_kpis)
    average_kpis = kpi_df.mean()
    print("\nAverage KPIs:")
    print(average_kpis)
else:
    # If KPIs are single values
    average_kpis = np.mean(all_kpis)
    print(f"\nAverage KPI: {average_kpis}")

print(f"\nProcessed {len(magazines)} magazines successfully.")
# Out:
# Method: baseline_A, on Test1/A_20250212_ZQ0.35_ZG0.4_testfile.csv
# - Bias: -0.953 (underestimation)
# - Weighted MAE (α=0): 0.953
# - Weighted MAE (α=0.5): 1.227
# - Weighted MAE (α=1): 1.625
# - Weighted MAE (α=1.5): 2.143
# - Accuracy (exact matches): 0.404
# - Overestimation Rate: 0.000
# - Underestimation Rate: 0.596
# - Gini Coefficient: 0.578
# Overstock: 0
# Processed magazine A
# Method: baseline_B, on Test1/A_20250212_ZQ0.35_ZG0.4_testfile.csv
# - Bias: -0.974 (underestimation)
# - Weighted MAE (α=0): 0.974
# - Weighted MAE (α=0.5): 1.318
# - Weighted MAE (α=1): 1.974
# - Weighted MAE (α=1.5): 3.271
# - Accuracy (exact matches): 0.400
# - Overestimation Rate: 0.000
# - Underestimation Rate: 0.600
# - Gini Coefficient: 0.582
# Overstock: 0
# Processed magazine B
# Method: baseline_C, on Test1/A_20250212_ZQ0.35_ZG0.4_testfile.csv
# - Bias: -0.732 (underestimation)
# - Weighted MAE (α=0): 0.732
# - Weighted MAE (α=0.5): 0.832
# - Weighted MAE (α=1): 0.971
# - Weighted MAE (α=1.5): 1.155
# - Accuracy (exact matches): 0.434
# - Overestimation Rate: 0.000
# - Underestimation Rate: 0.566
# - Gini Coefficient: 0.539
# Overstock: 0
# Processed magazine C
# Method: baseline_D, on Test1/A_20250212_ZQ0.35_ZG0.4_testfile.csv
# - Bias: -0.661 (underestimation)
# - Weighted MAE (α=0): 0.661
# - Weighted MAE (α=0.5): 0.755
# - Weighted MAE (α=1): 0.940
# - Weighted MAE (α=1.5): 1.350
# - Accuracy (exact matches): 0.456
# - Overestimation Rate: 0.000
# - Underestimation Rate: 0.544
# - Gini Coefficient: 0.540
# Overstock: 0
# Processed magazine D
# Method: baseline_E, on Test1/A_20250212_ZQ0.35_ZG0.4_testfile.csv
# - Bias: -0.831 (underestimation)
# - Weighted MAE (α=0): 0.831
# - Weighted MAE (α=0.5): 1.146
# - Weighted MAE (α=1): 3.006
# - Weighted MAE (α=1.5): 17.207
# - Accuracy (exact matches): 0.420
# - Overestimation Rate: 0.000
# - Underestimation Rate: 0.580
# - Gini Coefficient: 0.562
# Overstock: 0
# Processed magazine E
# Method: baseline_F, on Test1/A_20250212_ZQ0.35_ZG0.4_testfile.csv
# - Bias: -0.646 (underestimation)
# - Weighted MAE (α=0): 0.646
# - Weighted MAE (α=0.5): 0.729
# - Weighted MAE (α=1): 0.892
# - Weighted MAE (α=1.5): 1.248
# - Accuracy (exact matches): 0.462
# - Overestimation Rate: 0.000
# - Underestimation Rate: 0.538
# - Gini Coefficient: 0.540
# Overstock: 0
# Processed magazine F
# Method: baseline_G, on Test1/A_20250212_ZQ0.35_ZG0.4_testfile.csv
# - Bias: -0.556 (underestimation)
# - Weighted MAE (α=0): 0.556
# - Weighted MAE (α=0.5): 0.581
# - Weighted MAE (α=1): 0.617
# - Weighted MAE (α=1.5): 0.672
# - Accuracy (exact matches): 0.482
# - Overestimation Rate: 0.000
# - Underestimation Rate: 0.518
# - Gini Coefficient: 0.515
# Overstock: 0
# Processed magazine G
# Method: baseline_H, on Test1/A_20250212_ZQ0.35_ZG0.4_testfile.csv
# - Bias: -0.647 (underestimation)
# - Weighted MAE (α=0): 0.647
# - Weighted MAE (α=0.5): 0.777
# - Weighted MAE (α=1): 1.146
# - Weighted MAE (α=1.5): 2.267
# - Accuracy (exact matches): 0.461
# - Overestimation Rate: 0.000
# - Underestimation Rate: 0.539
# - Gini Coefficient: 0.542
# Overstock: 0
# Processed magazine H
# Method: baseline_I, on Test1/A_20250212_ZQ0.35_ZG0.4_testfile.csv
# - Bias: -0.913 (underestimation)
# - Weighted MAE (α=0): 0.913
# - Weighted MAE (α=0.5): 1.215
# - Weighted MAE (α=1): 1.702
# - Weighted MAE (α=1.5): 2.398
# - Accuracy (exact matches): 0.418
# - Overestimation Rate: 0.000
# - Underestimation Rate: 0.582
# - Gini Coefficient: 0.588
# Overstock: 0
# Processed magazine I
#
# Calculating averages...
#
# Average KPIs:
# bias                   -0.768103
# weighted_mae_0          0.768103
# weighted_mae_0.5        0.953344
# weighted_mae_1          1.430325
# weighted_mae_1.5        3.523289
# accuracy                0.437441
# overestimation_rate     0.000000
# underestimation_rate    0.562559
# gini_coefficient        0.554170
# overstock               0.000000
# dtype: float64
#
# Processed 9 magazines successfully.

# %% [markdown]
# # Rewriting N1, N2, N3, EM, PD

# %%
import pandas as pd
import numpy as np
from scipy.stats import poisson

def apply_n1_uncensoring(df):
    df = df.copy()
    df['Verkauf_Uncensored'] = df['Verkauf'].copy()
    
    # Use transform to get group means - NO MERGE!
    group_means = df.groupby('EHASTRA_EH_NUMMER')['Verkauf'].transform('mean')
    
    # Replace censored with group means
    censored_mask = (df['Zensiert'] == 1)
    df.loc[censored_mask, 'Verkauf_Uncensored'] = group_means[censored_mask]
    
    return df

def apply_n2_uncensoring(df):
    df = df.copy()
    df['Verkauf_Uncensored'] = df['Verkauf'].copy()
    
    # Calculate uncensored means per group - NO MERGE!
    uncensored_means = (
        df[df['Zensiert'] == 0]
        .groupby('EHASTRA_EH_NUMMER')['Verkauf']
        .transform('mean')
    )
    
    # Map to all rows using the POS ID
    df['group_uncensored_mean'] = df.groupby('EHASTRA_EH_NUMMER')['EHASTRA_EH_NUMMER'].transform(
        lambda group: df[df['Zensiert'] == 0].groupby('EHASTRA_EH_NUMMER')['Verkauf'].mean().get(group.iloc[0], 0)
    )
    
    # Replace censored values
    censored_mask = (df['Zensiert'] == 1)
    df.loc[censored_mask, 'Verkauf_Uncensored'] = df.loc[censored_mask, 'group_uncensored_mean']
    
    return df.drop('group_uncensored_mean', axis=1)

def apply_n3_uncensoring(df):
    df = df.copy()
    df['Verkauf_Uncensored'] = df['Verkauf'].copy()
    
    # Calculate uncensored means per group - NO MERGE!
    uncensored_group_means = (
        df[df['Zensiert'] == 0]
        .groupby('EHASTRA_EH_NUMMER')['Verkauf']
        .mean()
    )
    
    # Map means to each row based on POS ID
    df['group_mean'] = df['EHASTRA_EH_NUMMER'].map(uncensored_group_means).fillna(0)
    
    # For censored: max(observed, group_mean)
    censored_mask = (df['Zensiert'] == 1)
    df.loc[censored_mask, 'Verkauf_Uncensored'] = np.maximum(
        df.loc[censored_mask, 'Verkauf'],
        df.loc[censored_mask, 'group_mean']
    )
    
    return df.drop('group_mean', axis=1)

def apply_em_uncensoring(df, max_iter=30, tolerance=1e-6):
    df = df.copy()
    df['Verkauf_Uncensored'] = df['Verkauf'].copy()
    
    # Direct boolean indexing without extra columns
    stockout_condition = (df['Zensiert'] == 1)
    
    # Process groups with minimal overhead
    for (pos,), group in df.groupby(['EHASTRA_EH_NUMMER']):
        try:
            group_stockout = stockout_condition.loc[group.index]
            
            if not group_stockout.any():
                continue
            
            sales = group['Verkauf_Uncensored'].values
            is_stockout = group_stockout.values
            
            uncensored = sales[~is_stockout]
            censored = sales[is_stockout]
            
            # Skip if no uncensored data - but keep original values
            if len(uncensored) == 0:
                continue
            
            # Quick lambda initialization
            lambda_est = np.mean(uncensored) if len(uncensored) > 0 else np.mean(sales) * 1.5
            lambda_est = max(lambda_est, 0.1)
            
            # Fast EM loop
            for iteration in range(max_iter):
                lambda_old = lambda_est
                
                # Batch E-step
                surv_prob = 1 - poisson.cdf(censored - 1, lambda_est)
                exact_prob = poisson.pmf(censored, lambda_est)
                surv_prob = np.maximum(surv_prob, 1e-12)
                
                expected = lambda_est + censored * exact_prob / surv_prob
                expected = np.maximum(expected, censored.astype(float))
                
                # M-step
                lambda_est = max(np.mean(np.concatenate([uncensored, expected])), 0.1)
                
                if abs(lambda_est - lambda_old) < tolerance:
                    break
            
            # Final update
            surv_prob = 1 - poisson.cdf(censored - 1, lambda_est)
            exact_prob = poisson.pmf(censored, lambda_est)
            surv_prob = np.maximum(surv_prob, 1e-12)
            
            final_expected = lambda_est + censored * exact_prob / surv_prob
            final_expected = np.maximum(final_expected, censored.astype(float))
            
            # Update original dataframe
            stockout_indices = group.index[is_stockout]
            df.loc[stockout_indices, 'Verkauf_Uncensored'] = final_expected.round()
            
        except Exception as e:
            print(f"EM error for POS {pos}: {e}")
            # Fill with original Verkauf values for this POS when error occurs
            group_stockout_indices = group.index[stockout_condition.loc[group.index]]
            df.loc[group_stockout_indices, 'Verkauf_Uncensored'] = df.loc[group_stockout_indices, 'Verkauf']
            continue
    
    # ADD THIS: Final NaN handling - replace any NaN values with original Verkauf
    nan_mask = df['Verkauf_Uncensored'].isna()
    df.loc[nan_mask, 'Verkauf_Uncensored'] = df.loc[nan_mask, 'Verkauf']
    
    return df

def apply_pd_uncensoring(df, tau=0.5, max_iter=20, tolerance=1e-4):
    """PD with skip for invalid POS groups and fallback to original Verkauf"""
    df = df.copy()
    df["is_closed"] = (df["Zensiert"] == 1)
    df['Verkauf_Uncensored'] = df['Verkauf'].copy().astype(float)

    def compute_pd_projection1(obs_val, lambda_est, tau):
        """Your PD projection with NaN protection"""
        try:
            # Check for NaN inputs
            if pd.isna(obs_val) or pd.isna(lambda_est) or lambda_est <= 0:
                return float(obs_val) if not pd.isna(obs_val) else 0.0
            
            obs_val = int(round(obs_val))
            
            def objective(k_proj):
                k_proj = int(round(k_proj))
                
                if k_proj < obs_val:
                    return float('inf')
                
                # Area A: P(obs_val <= X <= k_proj)
                area_A = poisson.cdf(k_proj, lambda_est) - poisson.cdf(obs_val - 1, lambda_est)
                
                # Area B: P(X > k_proj)
                area_B = 1 - poisson.cdf(k_proj, lambda_est)
                
                if area_B > 1e-10:
                    ratio = area_A / area_B
                    target_ratio = (1 - tau) / tau
                    return abs(ratio - target_ratio)
                else:
                    return abs(area_A - (1 - tau))
            
            # Search for optimal projection
            upper_bound = int(obs_val + max(10, int(3 * np.sqrt(lambda_est))))
            
            best_k = obs_val
            best_objective = float('inf')
            
            for k in range(int(obs_val), upper_bound + 1):
                obj_val = objective(k)
                if obj_val < best_objective:
                    best_objective = obj_val
                    best_k = k
            
            return float(best_k)
            
        except Exception:
            # Silent fallback to original value
            return float(obs_val) if not pd.isna(obs_val) else 0.0
    
    # Process groups
    grouped = df.groupby('EHASTRA_EH_NUMMER')
    
    for pos, group in grouped:
        try:
            open_mask = ~group['is_closed']
            closed_mask = group['is_closed']
            
            open_sales = group.loc[open_mask, 'Verkauf_Uncensored'].values
            closed_sales = group.loc[closed_mask, 'Verkauf_Uncensored'].values
            
            # SKIP POS WITHOUT VALID UNCENSORED DATA
            if len(open_sales) == 0 or np.all(pd.isna(open_sales)):
                print(f"Skipping POS {pos}: no valid uncensored data")
                continue
            
            # Initialize lambda parameter
            lambda_est = np.mean(open_sales[~pd.isna(open_sales)])
            
            # SKIP IF LAMBDA IS INVALID
            if pd.isna(lambda_est) or lambda_est <= 0:
                print(f"Skipping POS {pos}: invalid lambda {lambda_est}")
                continue
            
            lambda_est = max(lambda_est, 0.1)
            closed_indices = group[closed_mask].index.values
            
            # Iterative process
            for iteration in range(max_iter):
                lambda_old = lambda_est
                
                # Project closed observations
                projected_values = np.array([
                    compute_pd_projection1(obs, lambda_est, tau) 
                    for obs in closed_sales
                ])
                
                # Re-estimate lambda
                all_values = np.concatenate([open_sales, projected_values])
                lambda_est = np.mean(all_values)
                lambda_est = max(lambda_est, 0.1)
                
                # Check convergence
                if abs(lambda_est - lambda_old) < tolerance:
                    break
            
            # Final projection
            final_projections = np.array([
                compute_pd_projection1(obs, lambda_est, tau) 
                for obs in closed_sales
            ])
            
            # Update dataframe
            df.loc[closed_indices, 'Verkauf_Uncensored'] = final_projections.round()
            
        except Exception as e:
            print(f"PD error for POS {pos}: {e}")
            # FALLBACK: Keep original values for this POS
            continue
    
    # FINAL FALLBACK: Any remaining NaN values get original Verkauf
    nan_mask = df['Verkauf_Uncensored'].isna()
    df.loc[nan_mask, 'Verkauf_Uncensored'] = df.loc[nan_mask, 'Verkauf']
    
    return df.drop('is_closed', axis=1)

# %% [markdown]
# # Script for creating csv of all features for all mags

# %%
import pandas as pd
import numpy as np
import os
import glob
from pathlib import Path

def calculate_kpis_for_pos_fast(pos_uncensored_data, pos_censored_data, method_name, magazine_name, pos_id):
    """
    Fast KPI calculation using pre-filtered data
    
    Parameters:
    - pos_uncensored_data: Pre-filtered uncensored data for this POS
    - pos_censored_data: Pre-filtered censored data for this POS  
    - method_name: string name of the method being evaluated
    - magazine_name: string name of the magazine
    - pos_id: EHASTRA_EH_NUMMER for this POS
    """
    
    if len(pos_censored_data) == 0:
        # Return empty KPIs if no censored data for this POS
        return {
            'bias': 0,
            'weighted_mae_0': 0,
            'weighted_mae_0.5': 0,
            'weighted_mae_1': 0,
            'weighted_mae_1.5': 0,
            'accuracy': 0,
            'overestimation_rate': 0,
            'underestimation_rate': 0,
            'gini_coefficient': 0,
            'overstock': 0,
            'n_censored_observations': 0
        }
    
    # Extract values directly (already filtered)
    y_pred = pos_uncensored_data['Verkauf_Uncensored'].values
    y_true = pos_censored_data['Verkauf_MBR'].values
    
    n = len(y_pred)
    
    # Vectorized calculations for speed
    errors = y_pred - y_true
    abs_errors = np.abs(errors)
    
    # 1. Bias calculation
    bias = np.mean(errors)
    
    # 2. Accuracy (exact matches)
    accuracy = np.mean(y_pred == y_true)
    
    # 3. Overestimation Rate
    overestimation_rate = np.mean(y_pred > y_true)
    
    # 4. Underestimation Rate  
    underestimation_rate = np.mean(y_pred < y_true)
    
    # 5. Weighted MAE for different alpha values (vectorized)
    alphas = [0, 0.5, 1, 1.5]
    weighted_maes = {}
    
    for a in alphas:
        if a == 0:
            weighted_maes[a] = np.mean(abs_errors)
        else:
            weights = np.power(y_true, a)
            weights = np.where(y_true == 0, 0, weights)
            weighted_maes[a] = np.sum(weights * abs_errors) / np.sum(weights) if np.sum(weights) > 0 else 0
    
    # 6. Gini Coefficient (optimized)
    sorted_errors = np.sort(abs_errors)
    total_sum = np.sum(sorted_errors)
    
    if total_sum > 0:
        indices = np.arange(1, n + 1)
        weighted_sum = np.sum(indices * sorted_errors)
        gini_coefficient = (2 * weighted_sum) / (n * total_sum) - (n + 1) / n
    else:
        gini_coefficient = 0
    
    # 7. Overstock
    overstock = np.sum(np.maximum(0, errors))
    
    return {
        'bias': bias,
        'weighted_mae_0': weighted_maes[0],
        'weighted_mae_0.5': weighted_maes[0.5],
        'weighted_mae_1': weighted_maes[1],
        'weighted_mae_1.5': weighted_maes[1.5],
        'accuracy': accuracy,
        'overestimation_rate': overestimation_rate,
        'underestimation_rate': underestimation_rate,
        'gini_coefficient': gini_coefficient,
        'overstock': overstock,
        'n_censored_observations': n
    }

def calculate_pos_features(df, magazine_name):
    """
    Calculate features for each POS (EHASTRA_EH_NUMMER)
    
    Parameters:
    df (DataFrame): Input dataframe with 'EHASTRA_EH_NUMMER', 'Verkauf', and 'Laenge' columns
    magazine_name (str): Name of the magazine
    
    Returns:
    DataFrame: DataFrame with EHASTRA_EH_NUMMER and calculated features
    """
    
    results = []
    
    for pos_id, pos_data in df.groupby('EHASTRA_EH_NUMMER'):
        
        verkauf = pos_data['Verkauf'].dropna()
        
        if len(verkauf) == 0:
            continue
        
        features = {
            'EHASTRA_EH_NUMMER': pos_id,
            'magazine': magazine_name
        }
        
        # 1. Data Sparsity
        actual_data_points = len(pos_data)
        laenge = pos_data['Laenge'].iloc[0] if 'Laenge' in pos_data.columns else actual_data_points
        
        features['data_sparsity'] = laenge / actual_data_points if actual_data_points > 0 else 0
        
        # 2. Stockout Rate
        if 'Zensiert' in pos_data.columns:
            features['stockout_rate'] = (pos_data['Zensiert'] == 1).sum() / len(pos_data['Zensiert'])
        else:
            features['stockout_rate'] = 0
        
        # 3. Verkauf Variance
        features['verkauf_variance'] = verkauf.var()
        
        # 4. Verkauf Mean
        features['verkauf_mean'] = verkauf.mean()
        
        # 5. Coefficient of Variation
        if features['verkauf_mean'] > 0:
            features['coefficient_of_variation'] = verkauf.std() / features['verkauf_mean']
        else:
            features['coefficient_of_variation'] = 0
        
        # 6. Number of unique order quantities
        features['unique_quantities'] = verkauf.nunique()
        
        # 7. Variance to Mean Ratio
        if features['verkauf_mean'] > 0:
            features['variance_to_mean_ratio'] = features['verkauf_variance'] / features['verkauf_mean']
        else:
            features['variance_to_mean_ratio'] = 0
        
        # 8. Verkauf autocorrelation
        if len(verkauf) > 1:
            try:
                autocorr = verkauf.autocorr(lag=1)
                features['verkauf_autocorr'] = autocorr if not pd.isna(autocorr) else 0
            except:
                features['verkauf_autocorr'] = 0
        else:
            features['verkauf_autocorr'] = 0
        
        # 9. ADI (Average Inter-demand Interval)
        non_zero_periods = (verkauf > 0).sum()
        if non_zero_periods > 0:
            features['adi'] = len(verkauf) / non_zero_periods
        else:
            features['adi'] = len(verkauf)
        
        results.append(features)
    
    return pd.DataFrame(results)

def parse_filename(filename):
    """
    Parse filename to extract magazine letter and parameters
    
    Example: A_20250212_ZQ0.35_ZG0.4_testfile.csv -> ('A', '20250212', 'ZQ0.35', 'ZG0.4')
    """
    parts = filename.split('_')
    if len(parts) >= 4:
        magazine = parts[0]
        date = parts[1]
        zq = parts[2]
        zg = parts[3]
        return magazine, date, zq, zg
    return None, None, None, None

def process_all_datasets(data_directory, output_filename='combined_kpis_features_pivoted.csv'):
    """
    Process specific datasets and create a combined CSV with KPIs and POS features
    Each row represents one POS/Magazine combination with methods as column prefixes
    Only processes files with ZQ0.35_ZG0.4 pattern
    
    Parameters:
    - data_directory: path to directory containing CSV files
    - output_filename: name of the output file
    """
    
    # Method mapping
    method_functions = {
        'N1': apply_n1_uncensoring,
        'N2': apply_n2_uncensoring,
        'N3': apply_n3_uncensoring,
        'EM': apply_em_uncensoring,
        'PD': apply_pd_uncensoring,
        'Nahmias': apply_nahmias_uncensoring,
        'Conrad': apply_conrad_uncensoring,
        #'Nahmias_NG': apply_nahmias_ng_uncensoring,
        #'Conrad_NG': apply_conrad_ng_uncensoring,
        'Baseline': apply_baseline_uncensoring
    }
    
    # Find only the specific files with ZQ0.35_ZG0.4 pattern
    pattern = os.path.join(data_directory, "*_20250212_ZQ0.35_ZG0.4_testfile.csv")
    csv_files = glob.glob(pattern)
    
    if not csv_files:
        print(f"No CSV files found matching pattern *_20250212_ZQ0.35_ZG0.4_testfile.csv in {data_directory}")
        return
    
    print(f"Found {len(csv_files)} CSV files to process (ZQ0.35_ZG0.4 only)")
    
    all_results = []
    
    for csv_file in csv_files:
        filename = os.path.basename(csv_file)
        magazine, date, zq, zg = parse_filename(filename)
        
        if not magazine:
            print(f"Could not parse filename: {filename}")
            continue
            
        print(f"Processing {filename}...")
        
        try:
            # Read the original CSV file
            original_df = pd.read_csv(csv_file)
            
            # Filter out POS locations with less than 3 censored data points
            censored_counts = original_df[original_df['Zensiert'] == 1].groupby('EHASTRA_EH_NUMMER').size()
            valid_pos_ids = censored_counts[censored_counts >= 3].index
            original_df = original_df[original_df['EHASTRA_EH_NUMMER'].isin(valid_pos_ids)]
            
            if len(original_df) == 0:
                print(f"  No POS locations with >= 3 censored data points in {filename}")
                continue
            
            # Calculate POS features once for this magazine (they don't depend on uncensoring method)
            pos_features = calculate_pos_features(original_df, magazine)
            
            # Get unique POS IDs and convert to numpy array for faster iteration
            pos_ids = original_df['EHASTRA_EH_NUMMER'].unique()
            
            # Pre-filter censored data by POS to avoid repeated filtering
            censored_mask = original_df['Zensiert'] == 1
            censored_data = original_df[censored_mask]
            pos_censored_groups = censored_data.groupby('EHASTRA_EH_NUMMER')
            
            # Convert pos_features to dictionary for faster lookup
            pos_features_dict = pos_features.set_index('EHASTRA_EH_NUMMER').to_dict('index')
            
            # Initialize results dictionary for each POS
            pos_results = {}
            
            # Process each uncensoring method
            for method_name, method_function in method_functions.items():
                print(f"  Applying {method_name} uncensoring...")
                
                try:
                    # Apply the uncensoring method to the entire dataset
                    uncensored_df = method_function(original_df)
                    
                    # Pre-calculate uncensored values for censored data only
                    uncensored_censored = uncensored_df[censored_mask]
                    uncensored_groups = uncensored_censored.groupby('EHASTRA_EH_NUMMER')
                    
                    # Process all POS locations for this method
                    for pos_id in pos_ids:
                        if pos_id in pos_censored_groups.groups and pos_id in pos_features_dict:
                            # Get pre-filtered censored data for this POS
                            pos_censored = pos_censored_groups.get_group(pos_id)
                            pos_uncensored = uncensored_groups.get_group(pos_id) if pos_id in uncensored_groups.groups else None
                            
                            if pos_uncensored is not None and len(pos_uncensored) > 0:
                                # Calculate KPIs using pre-filtered data
                                kpis = calculate_kpis_for_pos_fast(pos_uncensored, pos_censored, method_name, magazine, pos_id)
                                
                                # Initialize POS entry if it doesn't exist
                                if pos_id not in pos_results:
                                    pos_results[pos_id] = {
                                        'EHASTRA_EH_NUMMER': pos_id,
                                        'magazine': magazine,
                                        'date': date,
                                        'zq_parameter': zq,
                                        'zg_parameter': zg,
                                        'filename': filename,
                                        **pos_features_dict[pos_id]  # Add POS features
                                    }
                                
                                # Add method-specific KPIs with method prefix
                                for kpi_name, kpi_value in kpis.items():
                                    column_name = f"{method_name}_{kpi_name}"
                                    pos_results[pos_id][column_name] = kpi_value
                
                except Exception as e:
                    print(f"    Error applying {method_name}: {str(e)}")
                    continue
            
            # Add all POS results from this file to main results
            all_results.extend(list(pos_results.values()))
            
        except Exception as e:
            print(f"Error processing {filename}: {str(e)}")
            continue
    
    if all_results:
        # Create final DataFrame
        final_df = pd.DataFrame(all_results)
        
        # Save to CSV
        output_path = os.path.join(data_directory, output_filename)
        final_df.to_csv(output_path, index=False)
        
        print(f"\nProcessing complete!")
        print(f"Combined dataset saved as: {output_path}")
        print(f"Total rows: {len(final_df)}")
        print(f"Magazines processed: {final_df['magazine'].nunique()}")
        print(f"POS locations: {final_df['EHASTRA_EH_NUMMER'].nunique()}")
        
        return final_df
    else:
        print("No data was processed successfully.")
        return None

# Usage
data_directory = "Test1"  # Change this to your actual directory path
result_df = process_all_datasets(data_directory, 'combined_magazine_kpis_features_attempt1.csv')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 341
#     339 # Usage
#     340 data_directory = "Test1"  # Change this to your actual directory path
# --> 341 result_df = process_all_datasets(data_directory, 'combined_magazine_kpis_features_attempt1.csv')
#
# Cell In[1], line 205, in process_all_datasets(data_directory, output_filename)
#     193 """
#     194 Process specific datasets and create a combined CSV with KPIs and POS features
#     195 Each row represents one POS/Magazine combination with methods as column prefixes
#    (...)    200 - output_filename: name of the output file
#     201 """
#     203 # Method mapping
#     204 method_functions = {
# --> 205     'N1': apply_n1_uncensoring,
#     206     'N2': apply_n2_uncensoring,
#     207     'N3': apply_n3_uncensoring,
#     208     'EM': apply_em_uncensoring,
#     209     'PD': apply_pd_uncensoring,
#     210     'Nahmias': apply_nahmias_uncensoring,
#     211     'Conrad': apply_conrad_uncensoring,
#     212     #'Nahmias_NG': apply_nahmias_ng_uncensoring,
#     213     #'Conrad_NG': apply_conrad_ng_uncensoring,
#     214     'Baseline': apply_baseline_uncensoring
#     215 }
#     217 # Find only the specific files with ZQ0.35_ZG0.4 pattern
#     218 pattern = os.path.join(data_directory, "*_20250212_ZQ0.35_ZG0.4_testfile.csv")
#
# NameError: name 'apply_n1_uncensoring' is not defined

# %% [markdown]
# # Cleaning & Merging with Agrawal + Bayesian

# %%
import pandas as pd

def merge_all_methods_data(pivoted_csv_path, bayesian_csv_path, agrawal_csv_path, output_csv_path):
    """
    Simply add Bayesian and Agrawal columns to the pivoted dataset
    
    Parameters:
    - pivoted_csv_path: path to the pivoted CSV with method-prefixed columns
    - bayesian_csv_path: path to Bayesian results CSV
    - agrawal_csv_path: path to Agrawal results CSV  
    - output_csv_path: path for the merged output CSV
    """
    
    # Read all datasets
    print("Reading datasets...")
    pivoted_df = pd.read_csv(pivoted_csv_path)
    bayesian_df = pd.read_csv(bayesian_csv_path)
    agrawal_df = pd.read_csv(agrawal_csv_path)
    
    print(f"Pivoted data shape: {pivoted_df.shape}")
    print(f"Bayesian data shape: {bayesian_df.shape}")
    print(f"Agrawal data shape: {agrawal_df.shape}")
    
    # Merge Bayesian data (POS -> EHASTRA_EH_NUMMER, Magazine -> magazine)
    print("Merging Bayesian data...")
    merged_df = pivoted_df.merge(
        bayesian_df, 
        left_on=['EHASTRA_EH_NUMMER', 'magazine'], 
        right_on=['POS', 'Magazine'], 
        how='left'
    )
    
    # Drop the duplicate columns from Bayesian
    columns_to_drop = ['POS', 'Magazine']
    for col in columns_to_drop:
        if col in merged_df.columns:
            merged_df = merged_df.drop(col, axis=1)
    
    # Merge Agrawal data (POS -> EHASTRA_EH_NUMMER, Magazine -> magazine)  
    print("Merging Agrawal data...")
    merged_df = merged_df.merge(
        agrawal_df, 
        left_on=['EHASTRA_EH_NUMMER', 'magazine'], 
        right_on=['POS', 'Magazine'], 
        how='left',
        suffixes=('', '_agrawal_dup')
    )
    
    # Drop the duplicate columns from Agrawal
    columns_to_drop = ['POS', 'Magazine']
    for col in columns_to_drop:
        if col in merged_df.columns:
            merged_df = merged_df.drop(col, axis=1)
    
    print(f"Final merged dataset shape: {merged_df.shape}")
    
    # Check merge success
    bayesian_cols = [col for col in merged_df.columns if col.startswith('Bayesian_')]
    agrawal_cols = [col for col in merged_df.columns if col.startswith('Agrawal_')]
    
    if bayesian_cols:
        bayesian_matches = merged_df[bayesian_cols[0]].notna().sum()
        print(f"Successful Bayesian merges: {bayesian_matches}/{len(merged_df)}")
    
    if agrawal_cols:
        agrawal_matches = merged_df[agrawal_cols[0]].notna().sum() 
        print(f"Successful Agrawal merges: {agrawal_matches}/{len(merged_df)}")
    
    # Save the merged dataset
    merged_df.to_csv(output_csv_path, index=False)
    print(f"Final dataset saved to: {output_csv_path}")
    
    # Show column summary
    all_method_cols = [col for col in merged_df.columns if any(method in col for method in [
        'N1_', 'N2_', 'N3_', 'EM_', 'PD_', 'Nahmias_', 'Conrad_', 'Baseline_', 'Bayesian_', 'Agrawal_'
    ])]
    
    print(f"Total method-specific columns: {len(all_method_cols)}")
    
    return merged_df

# Example usage
if __name__ == "__main__":
    # Replace with your actual file paths
    pivoted_file = "combined_magazine_kpis_features_attempt1.csv"
    bayesian_file = "bayesian_results.csv"  # Update with actual filename
    agrawal_file = "agrawal_results.csv"    # Update with actual filename
    output_file = "final_merged_all_methods.csv"
    
    # Merge all datasets
    merged_df = merge_all_methods_data(
        pivoted_file, 
        bayesian_file, 
        agrawal_file, 
        output_file
    )
    
    print(f"\nFinal dataset: {len(merged_df)} rows, {len(merged_df.columns)} columns")
    print("All methods combined - ready for analysis!")
# Out:
# Reading datasets...
# Pivoted data shape: (10685, 103)
# Bayesian data shape: (10685, 14)
# Agrawal data shape: (10685, 14)
# Merging Bayesian data...
# Merging Agrawal data...
# Final merged dataset shape: (10685, 127)
# Successful Bayesian merges: 10685/10685
# Successful Agrawal merges: 10685/10685
# Final dataset saved to: final_merged_all_methods.csv
# Total method-specific columns: 110
#
# Final dataset: 10685 rows, 127 columns
# All methods combined - ready for analysis!

# %% [markdown]
# # Adding best method

# %%
import pandas as pd
import numpy as np

def add_best_method_column_pivoted(df, primary_kpi, tiebreaker_kpi):
    """
    Add a column showing which method performs best for each POS+Magazine combination
    
    Parameters:
    - primary_kpi: The main KPI to optimize (e.g., 'weighted_mae_0')
    - tiebreaker_kpi: KPI to use for breaking ties (e.g., 'accuracy')
    
    Returns:
    - DataFrame with new column 'best_method_{primary_kpi}'
    
    """
    
    # Define which KPIs should be minimized vs maximized
    minimize_kpis = [
        'bias', 'weighted_mae_0', 'weighted_mae_0.5', 'weighted_mae_1', 'weighted_mae_1.5',
        'gini_coefficient', 'overstock', 'overestimation_rate', 'underestimation_rate'
    ]
    
    maximize_kpis = [
        'accuracy'
    ]
    
    
    # Determine optimization direction for primary and tiebreaker KPIs
    primary_minimize = primary_kpi in minimize_kpis
    tiebreaker_minimize = tiebreaker_kpi in minimize_kpis
    
    primary_kpi_cols = [col for col in df.columns if col.endswith(f'_{primary_kpi}') and not col.startswith('best_')]
    tiebreaker_kpi_cols = [col for col in df.columns if col.endswith(f'_{tiebreaker_kpi}') and not col.startswith('best_')]
    
    if not primary_kpi_cols:
        raise ValueError(f"No columns found ending with '_{primary_kpi}'")
    if not tiebreaker_kpi_cols:
        raise ValueError(f"No columns found ending with '_{tiebreaker_kpi}'")
    
    print(f"Found {len(primary_kpi_cols)} methods for {primary_kpi}: {[col.split('_')[0] for col in primary_kpi_cols]}")
    print(f"Found {len(tiebreaker_kpi_cols)} methods for {tiebreaker_kpi}: {[col.split('_')[0] for col in tiebreaker_kpi_cols]}")
    
    # Create the new column name
    new_column_name = f'best_method_{primary_kpi}'
    
    df_copy = df.copy()
    best_methods = []
    
    # For each row, find the best method
    for idx, row in df_copy.iterrows():
        # Get primary KPI values for all methods
        primary_values = {}
        for col in primary_kpi_cols:
            method_name = col.split('_')[0]  # Extract method name (e.g., 'N1' from 'N1_weighted_mae_0')
            if pd.notna(row[col]):
                primary_values[method_name] = row[col]
        
        if not primary_values:
            best_methods.append(None)
            continue
        
        # Find the best primary KPI value
        if primary_minimize:
            best_primary_value = min(primary_values.values())
            best_methods_primary = [method for method, value in primary_values.items() if value == best_primary_value]
        else:
            best_primary_value = max(primary_values.values())
            best_methods_primary = [method for method, value in primary_values.items() if value == best_primary_value]
        
        # If there's only one best method, use it
        if len(best_methods_primary) == 1:
            best_method = best_methods_primary[0]
        else:
            # Use tiebreaker KPI to resolve ties
            tiebreaker_values = {}
            for method in best_methods_primary:
                tiebreaker_col = f"{method}_{tiebreaker_kpi}"
                if tiebreaker_col in df.columns and pd.notna(row[tiebreaker_col]):
                    tiebreaker_values[method] = row[tiebreaker_col]
            
            if not tiebreaker_values:
                # If no tiebreaker values available, pick the first method alphabetically
                best_method = sorted(best_methods_primary)[0]
            else:
                if tiebreaker_minimize:
                    best_tiebreaker_value = min(tiebreaker_values.values())
                    best_method = [method for method, value in tiebreaker_values.items() if value == best_tiebreaker_value][0]
                else:
                    best_tiebreaker_value = max(tiebreaker_values.values())
                    best_method = [method for method, value in tiebreaker_values.items() if value == best_tiebreaker_value][0]
        
        best_methods.append(best_method)
    
    # Add the best method column
    df_copy[new_column_name] = best_methods
    
    return df_copy

def add_multiple_best_method_columns_pivoted(df, kpi_configs):
    """
    Add multiple best method columns for different KPI combinations
    Works with pivoted data
    
    Parameters:
    - df: DataFrame with pivoted KPI results
    - kpi_configs: List of tuples [(primary_kpi, tiebreaker_kpi), ...]
    
    Example:
    kpi_configs = [
        ('weighted_mae_0', 'accuracy'),
        ('weighted_mae_1', 'accuracy'),
        ('accuracy', 'weighted_mae_0'),
        ('bias', 'weighted_mae_0')
    ]
    """
    result_df = df.copy()
    
    for primary_kpi, tiebreaker_kpi in kpi_configs:
        print(f"\nAdding best method column for {primary_kpi} (tiebreaker: {tiebreaker_kpi})")
        result_df = add_best_method_column_pivoted(result_df, primary_kpi, tiebreaker_kpi)
    
    return result_df

def analyze_best_methods(df, kpi_name):
    """
    Analyze and display summary statistics for best methods
    """
    best_method_col = f'best_method_{kpi_name}'
    
    if best_method_col not in df.columns:
        print(f"Column {best_method_col} not found in DataFrame")
        return
    
    print(f"\n=== Best Method Analysis for {kpi_name.upper()} ===")
    
    # Overall best method counts
    print(f"\nOverall best method distribution:")
    method_counts = df[best_method_col].value_counts()
    print(method_counts)
    
    # Best methods by magazine
    print(f"\nBest methods by magazine:")
    magazine_summary = df.groupby(['magazine', best_method_col]).size().unstack(fill_value=0)
    print(magazine_summary)
    
    # Calculate percentages
    print(f"\nBest method percentages:")
    percentages = (method_counts / len(df) * 100).round(2)
    for method, pct in percentages.items():
        print(f"  {method}: {pct}%")

# Usage
if __name__ == "__main__":
    # Load the pivoted CSV file
    df = pd.read_csv("final_merged_all_methods.csv")
    
    print(f"Loaded dataset with {len(df)} rows and {len(df.columns)} columns")
    print(f"Magazines: {df['magazine'].unique()}")
    
    # Define KPI configurations for analysis
    kpi_configs = [
        ('weighted_mae_0', 'accuracy'),      # Best for unweighted MAE with accuracy tiebreaker
        ('weighted_mae_1', 'accuracy'),      # Best for weighted MAE (α=1) with accuracy tiebreaker
        ('weighted_mae_1.5', 'accuracy'),    # Best for weighted MAE (α=1.5) with accuracy tiebreaker
        ('accuracy', 'weighted_mae_0'),      # Best for accuracy with MAE tiebreaker
        ('bias', 'weighted_mae_0'),          # Best for bias with MAE tiebreaker
        ('overstock', 'accuracy'),           # Best for overstock with accuracy tiebreaker
    ]
    
    # Add all best method columns
    print("Adding best method columns...")
    df_with_best = add_multiple_best_method_columns_pivoted(df, kpi_configs)
    
    # Save results
    output_filename = "final_merged_with_best_methods.csv"
    df_with_best.to_csv(output_filename, index=False)
    print(f"\nResults saved to: {output_filename}")
    
    # Analyze results for key KPIs
    key_kpis = ['weighted_mae_0', 'weighted_mae_1', 'accuracy', 'bias']
    
    for kpi in key_kpis:
        if f'best_method_{kpi}' in df_with_best.columns:
            analyze_best_methods(df_with_best, kpi)
    
    print(f"\nFinal dataset: {len(df_with_best)} rows, {len(df_with_best.columns)} columns")
    
    # Show sample of the new columns
    best_method_cols = [col for col in df_with_best.columns if col.startswith('best_method_')]
    print(f"\nBest method columns added: {len(best_method_cols)}")
    print("Sample of best method assignments:")
    sample_cols = ['EHASTRA_EH_NUMMER', 'magazine'] + best_method_cols[:3]
    print(df_with_best[sample_cols].head())
# Out:
# Loaded dataset with 10685 rows and 127 columns
# Magazines: ['E' 'C' 'H' 'D' 'B' 'I' 'G' 'A' 'F']
# Adding best method columns...
#
# Adding best method column for weighted_mae_0 (tiebreaker: accuracy)
# Found 10 methods for weighted_mae_0: ['N1', 'N2', 'N3', 'EM', 'PD', 'Nahmias', 'Conrad', 'Baseline', 'Bayesian', 'Agrawal']
# Found 10 methods for accuracy: ['N1', 'N2', 'N3', 'EM', 'PD', 'Nahmias', 'Conrad', 'Baseline', 'Bayesian', 'Agrawal']
#
# Adding best method column for weighted_mae_1 (tiebreaker: accuracy)
# Found 10 methods for weighted_mae_1: ['N1', 'N2', 'N3', 'EM', 'PD', 'Nahmias', 'Conrad', 'Baseline', 'Bayesian', 'Agrawal']
# Found 10 methods for accuracy: ['N1', 'N2', 'N3', 'EM', 'PD', 'Nahmias', 'Conrad', 'Baseline', 'Bayesian', 'Agrawal']
#
# Adding best method column for weighted_mae_1.5 (tiebreaker: accuracy)
# Found 10 methods for weighted_mae_1.5: ['N1', 'N2', 'N3', 'EM', 'PD', 'Nahmias', 'Conrad', 'Baseline', 'Bayesian', 'Agrawal']
# Found 10 methods for accuracy: ['N1', 'N2', 'N3', 'EM', 'PD', 'Nahmias', 'Conrad', 'Baseline', 'Bayesian', 'Agrawal']
#
# Adding best method column for accuracy (tiebreaker: weighted_mae_0)
# Found 10 methods for accuracy: ['N1', 'N2', 'N3', 'EM', 'PD', 'Nahmias', 'Conrad', 'Baseline', 'Bayesian', 'Agrawal']
# Found 10 methods for weighted_mae_0: ['N1', 'N2', 'N3', 'EM', 'PD', 'Nahmias', 'Conrad', 'Baseline', 'Bayesian', 'Agrawal']
#
# Adding best method column for bias (tiebreaker: weighted_mae_0)
# Found 10 methods for bias: ['N1', 'N2', 'N3', 'EM', 'PD', 'Nahmias', 'Conrad', 'Baseline', 'Bayesian', 'Agrawal']
# Found 10 methods for weighted_mae_0: ['N1', 'N2', 'N3', 'EM', 'PD', 'Nahmias', 'Conrad', 'Baseline', 'Bayesian', 'Agrawal']
#
# Adding best method column for overstock (tiebreaker: accuracy)
# Found 10 methods for overstock: ['N1', 'N2', 'N3', 'EM', 'PD', 'Nahmias', 'Conrad', 'Baseline', 'Bayesian', 'Agrawal']
# Found 10 methods for accuracy: ['N1', 'N2', 'N3', 'EM', 'PD', 'Nahmias', 'Conrad', 'Baseline', 'Bayesian', 'Agrawal']
#
# Results saved to: final_merged_with_best_methods.csv
#
# === Best Method Analysis for WEIGHTED_MAE_0 ===
#
# Overall best method distribution:
# best_method_weighted_mae_0
# N3          5084
# PD          1791
# Conrad      1622
# Nahmias     1117
# EM           674
# Baseline     310
# N1            51
# N2            20
# Bayesian      10
# Agrawal        6
# Name: count, dtype: int64
#
# Best methods by magazine:
# best_method_weighted_mae_0  Agrawal  Baseline  Bayesian  Conrad   EM  N1  N2  \
# magazine
# A                                 3        56         1     375   63  14   2
# B                                 0        36         5     359   31  10   1
# C                                 0        37         0     211   57   4   1
# D                                 0        21         0     103  101   1   2
# E                                 2        63         2     232   73   3   3
# F                                 0        16         0      89   73   3   0
# G                                 0         0         1      58   73   0   0
# H                                 0        19         0      75   76   3   4
# I                                 1        62         1     120  127  13   7
#
# best_method_weighted_mae_0    N3  Nahmias   PD
# magazine
# A                           1031      298  485
# B                            768      138  308
# C                            761       62  282
# D                            561       67  128
# E                            676      306  212
# F                            384       23  114
# G                            336        6   47
# H                            249       50   69
# I                            318      167  146
#
# Best method percentages:
#   N3: 47.58%
#   PD: 16.76%
#   Conrad: 15.18%
#   Nahmias: 10.45%
#   EM: 6.31%
#   Baseline: 2.9%
#   N1: 0.48%
#   N2: 0.19%
#   Bayesian: 0.09%
#   Agrawal: 0.06%
#
# === Best Method Analysis for WEIGHTED_MAE_1 ===
#
# Overall best method distribution:
# best_method_weighted_mae_1
# N3          4918
# PD          1726
# Conrad      1700
# Nahmias     1282
# EM           863
# Baseline     110
# N1            48
# N2            24
# Bayesian       8
# Agrawal        6
# Name: count, dtype: int64
#
# Best methods by magazine:
# best_method_weighted_mae_1  Agrawal  Baseline  Bayesian  Conrad   EM  N1  N2  \
# magazine
# A                                 5        15         1     379   96  11   3
# B                                 0         1         4     339   41   7   1
# C                                 0         0         0     213   83   3   2
# D                                 0        10         0     109  121   1   2
# E                                 1        31         1     278  106   3   4
# F                                 0         2         0     104   91   2   1
# G                                 0         0         1      61   83   0   0
# H                                 0         8         0      87   89   3   3
# I                                 0        43         1     130  153  18   8
#
# best_method_weighted_mae_1    N3  Nahmias   PD
# magazine
# A                           1017      279  522
# B                            772      139  352
# C                            761       67  286
# D                            558       74  109
# E                            589      417  142
# F                            372       30  100
# G                            332        7   37
# H                            227       73   55
# I                            290      196  123
#
# Best method percentages:
#   N3: 46.03%
#   PD: 16.15%
#   Conrad: 15.91%
#   Nahmias: 12.0%
#   EM: 8.08%
#   Baseline: 1.03%
#   N1: 0.45%
#   N2: 0.22%
#   Bayesian: 0.07%
#   Agrawal: 0.06%
#
# === Best Method Analysis for ACCURACY ===
#
# Overall best method distribution:
# best_method_accuracy
# N3          3981
# PD          2197
# Conrad      1876
# Nahmias      938
# EM           850
# Baseline     775
# Bayesian      22
# N1            21
# N2            16
# Agrawal        9
# Name: count, dtype: int64
#
# Best methods by magazine:
# best_method_accuracy  Agrawal  Baseline  Bayesian  Conrad   EM  N1  N2   N3  \
# magazine
# A                           3       241         5     357  113   4   1  756
# B                           1       144         8     420   51   3   0  538
# C                           0       103         0     313   89   1   1  531
# D                           0        44         0     142  111   0   2  465
# E                           3       107         6     233   86   3   2  601
# F                           1        24         0     123   88   0   0  303
# G                           0         3         1      83   87   0   0  281
# H                           0        25         0      77   84   2   3  225
# I                           1        84         2     128  141   8   7  281
#
# best_method_accuracy  Nahmias   PD
# magazine
# A                         219  629
# B                         128  363
# C                          40  337
# D                          73  147
# E                         238  293
# F                          31  132
# G                          11   55
# H                          50   79
# I                         148  162
#
# Best method percentages:
#   N3: 37.26%
#   PD: 20.56%
#   Conrad: 17.56%
#   Nahmias: 8.78%
#   EM: 7.96%
#   Baseline: 7.25%
#   Bayesian: 0.21%
#   N1: 0.2%
#   N2: 0.15%
#   Agrawal: 0.08%
#
# === Best Method Analysis for BIAS ===
#
# Overall best method distribution:
# best_method_bias
# N2          4124
# Agrawal     3944
# Bayesian    2525
# PD            78
# Baseline       7
# N1             4
# Nahmias        3
# Name: count, dtype: int64
#
# Best methods by magazine:
# best_method_bias  Agrawal  Baseline  Bayesian  N1   N2  Nahmias  PD
# magazine
# A                    1051         5       352   0  889        0  31
# B                     849         0       224   0  579        1   3
# C                     326         0       551   0  535        0   3
# D                     377         0       110   0  493        1   3
# E                     570         0       371   0  620        0  11
# F                      10         0       485   0  206        0   1
# G                      85         0       163   0  273        0   0
# H                     209         0        96   0  235        1   4
# I                     467         2       173   4  294        0  22
#
# Best method percentages:
#   N2: 38.6%
#   Agrawal: 36.91%
#   Bayesian: 23.63%
#   PD: 0.73%
#   Baseline: 0.07%
#   N1: 0.04%
#   Nahmias: 0.03%
#
# Final dataset: 10685 rows, 133 columns
#
# Best method columns added: 6
# Sample of best method assignments:
#   EHASTRA_EH_NUMMER magazine best_method_weighted_mae_0  \
# 0        EHA0086402        E                         PD
# 1        EHA0089037        E                    Nahmias
# 2        EHA0089518        E                    Nahmias
# 3        EHA0092474        E                         N3
# 4        EHA0225854        E                         N3
#
#   best_method_weighted_mae_1 best_method_weighted_mae_1.5
# 0                    Nahmias                      Nahmias
# 1                         EM                           EM
# 2                    Nahmias                      Nahmias
# 3                         N3                           N3
# 4                         N3                           N3

# %% [markdown]
# # Merging Sofortremission

# %%
import pandas as pd

# Read the files
best_methods_df = pd.read_csv("final_merged_with_best_methods.csv")
sofortremission_df = pd.read_csv("sofortremissionFeatures3007.csv")

# Fix the EHASTRA_EH_NUMMER format - add "EH" prefix to sofortremission
sofortremission_df['EHASTRA_EH_NUMMER'] = 'EH' + sofortremission_df['EHASTRA_EH_NUMMER'].astype(str)

# Merge
merged_df = best_methods_df.merge(
    sofortremission_df, 
    left_on=['EHASTRA_EH_NUMMER', 'magazine'], 
    right_on=['EHASTRA_EH_NUMMER', 'VDZ'], 
    how='left'
).drop('VDZ', axis=1)

# Sort by magazine
merged_df = merged_df.sort_values('magazine')

# Save
merged_df.to_csv("Input_DT_All_Mags.csv", index=False)

print(f"Done! {len(merged_df)} rows, {len(merged_df.columns)} columns")
# Out:
# Done! 10685 rows, 140 columns
